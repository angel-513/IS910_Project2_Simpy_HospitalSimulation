# %%
import pandas as pd
import numpy as np
import simpy
import random

# %%
class Unidad:
    def __init__(self, env, nombre, num_camas, personal, num_kits_medicos):
        self.env = env
        self.nombre = nombre
        self.num_camas = simpy.Resource(env, capacity=num_camas)
        self.personal = simpy.Resource(env, capacity=personal)
        self.num_kits_medicos = simpy.Resource(env, capacity=num_kits_medicos)

# %%
class Hospital:
    def __init__(self, env, recepcionistas, unidades):
        self.env = env
        self.unidades = unidades
        self.recepcionistas = simpy.Resource(env, capacity=recepcionistas)

# %%
class Paciente:
    def __init__(self, env, id, hospital: Hospital, unidad: Unidad):
        self.env = env
        self.id = id
        self.hospital = hospital
        self.unidad = unidad
        self.cirugia = random.choice([True, False]) if unidad.nombre == "Urgencias" else False
        self.alcanzo_cama = False
        
        self.env.process(self.start())
        self.eventos = pd.DataFrame()
    
    def start(self):
        print(f"{self.env.now}: Paciente {self.id} llega al hospital a la unidad {self.unidad.nombre}.")

        with self.hospital.recepcionistas.request() as request:
            yield request
            print(f"{self.env.now}: Paciente {self.id} es atendido.")
            self.eventos = pd.concat([self.eventos, pd.DataFrame({
                "id": [self.id],
                "evento": ["LLEGADA"],
                "time": [self.env.now]
            })])

            if self.unidad.nombre == "Urgencias" or self.unidad.nombre == "UCI":
                tiempo_atencion_inferior = 1
                tiempo_atencion_superior = 7
                cant_personal = random.randint(3, 8)
            else:
                tiempo_atencion_inferior = 7
                tiempo_atencion_superior = 25
                cant_personal = 1 #Solo se necesita un doctor para una consulta general

            # El paciente toma una cama y se le asigna personal
            with self.unidad.num_camas.request() as cama_request:
                yield cama_request
                with self.unidad.personal.request() as personal_request:
                    yield personal_request
                    yield self.env.timeout(random.randint(tiempo_atencion_inferior, tiempo_atencion_superior))
                    print(f"{self.env.now}: Al Paciente {self.id} se le asigno una cama y {cant_personal} miembro(s) del personal.")
                    self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id],
                        "evento": ["ASIGNACION_CAMA_PERSONAL"],
                        "time": [self.env.now]
                    })])

            #Si el paciente es de urgencias y necesita cirugia, espera que se le asigne un kit medico
            if self.cirugia:
                print(f"{self.env.now}: El Paciente {self.id} necesita cirugia.")
                with self.unidad.num_kits_medicos.request() as kit_request:
                    yield kit_request
                    tiempo_espera_kit = random.randint(15, 60*8) #Se consideran cirugias de 8 horas maximo
                    yield self.env.timeout(tiempo_espera_kit)
                    
                    if tiempo_espera_kit > 60:
                        print(f"{self.env.now}: El Paciente {self.id} murio esperando un kit medico.")
                        self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id],
                        "evento": ["MUERTE"],
                        "time": [self.env.now]
                    })])
                    else:
                        print(f"{self.env.now}: Al Paciente {self.id} se le asigno un kit medico.")
                        self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id],
                        "evento": ["ASIGNACION_KIT"],
                        "time": [self.env.now]
                    })])

# %%
class Simulation:
    def __init__(self, env, unidades_settings, recepcionistas):
        self.env = env
        self.unidades = [Unidad(env, u["nombre"], u["num_camas"], u["personal"], u["num_kits_medicos"]) for u in unidades_settings]
        self.hospital = Hospital(env, recepcionistas, self.unidades)
        self.pacientes = []

        self.env.process(self.run_simulation())
    
    def run_simulation(self):
        while True:
            # Generar de 1 a 5 pacientes a la vez
            yield self.env.timeout(random.randint(1, 5))

            for _ in range(random.randint(1, 5)):
                paciente = Paciente(
                    self.env,
                    len(self.pacientes) + 1,
                    self.hospital,
                    random.choice(self.unidades)
                )
                self.pacientes.append(paciente)

# %% [markdown]
# # Inicio de la simulacion

# %%
env = simpy.Environment()
unidades_settings = [
    {"nombre": "Urgencias", "num_camas": 20, "personal": 30, "num_kits_medicos": 8},
    {"nombre": "UCI", "num_camas": 35, "personal": 25, "num_kits_medicos": 1},
    {"nombre": "Consultorios", "num_camas": 10, "personal": 8, "num_kits_medicos": 1}
]
num_recepcionistas = 2

#random.seed(111)

simulacion = Simulation(env, unidades_settings, num_recepcionistas)
env.run(until=60*8)
# Out:
# 4: Paciente 1 llega al hospital a la unidad Consultorios.
# 4: Paciente 2 llega al hospital a la unidad Consultorios.
# 4: Paciente 1 es atendido.
# 4: Paciente 2 es atendido.
# 6: Paciente 3 llega al hospital a la unidad UCI.
# 6: Paciente 4 llega al hospital a la unidad Urgencias.
# 7: Paciente 5 llega al hospital a la unidad UCI.
# 7: Paciente 6 llega al hospital a la unidad Consultorios.
# 9: Paciente 7 llega al hospital a la unidad Urgencias.
# 9: Paciente 8 llega al hospital a la unidad Urgencias.
# 12: Paciente 9 llega al hospital a la unidad Consultorios.
# 12: Paciente 10 llega al hospital a la unidad UCI.
# 12: Paciente 11 llega al hospital a la unidad UCI.
# 12: Paciente 12 llega al hospital a la unidad Urgencias.
# 12: Paciente 13 llega al hospital a la unidad Consultorios.
# 14: Al Paciente 1 se le asigno una cama y 1 miembro(s) del personal.
# 14: Paciente 14 llega al hospital a la unidad Urgencias.
# 14: Paciente 3 es atendido.
# 16: Al Paciente 3 se le asigno una cama y 3 miembro(s) del personal.
# 16: Paciente 4 es atendido.
# 18: Paciente 15 llega al hospital a la unidad Consultorios.
# 18: Paciente 16 llega al hospital a la unidad Consultorios.
# 18: Paciente 17 llega al hospital a la unidad Consultorios.
# 19: Al Paciente 4 se le asigno una cama y 4 miembro(s) del personal.
# 19: El Paciente 4 necesita cirugia.
# 21: Paciente 18 llega al hospital a la unidad Consultorios.
# 23: Paciente 19 llega al hospital a la unidad Consultorios.
# 23: Paciente 20 llega al hospital a la unidad UCI.
# 23: Paciente 21 llega al hospital a la unidad Consultorios.
# 25: Al Paciente 2 se le asigno una cama y 1 miembro(s) del personal.
# 25: Paciente 5 es atendido.
# 28: Paciente 22 llega al hospital a la unidad Urgencias.
# 28: Paciente 23 llega al hospital a la unidad UCI.
# 30: Al Paciente 5 se le asigno una cama y 8 miembro(s) del personal.
# 30: Paciente 6 es atendido.
# 31: Paciente 24 llega al hospital a la unidad Consultorios.
# 33: Paciente 25 llega al hospital a la unidad Urgencias.
# 33: Paciente 26 llega al hospital a la unidad Consultorios.
# 33: Paciente 27 llega al hospital a la unidad Urgencias.
# 37: Paciente 28 llega al hospital a la unidad UCI.
# 39: Al Paciente 6 se le asigno una cama y 1 miembro(s) del personal.
# 39: Paciente 29 llega al hospital a la unidad Consultorios.
# 39: Paciente 30 llega al hospital a la unidad Consultorios.
# 39: Paciente 7 es atendido.
# 42: Paciente 31 llega al hospital a la unidad UCI.
# 43: Al Paciente 7 se le asigno una cama y 6 miembro(s) del personal.
# 43: El Paciente 7 necesita cirugia.
# 43: Paciente 32 llega al hospital a la unidad Consultorios.
# 43: Paciente 33 llega al hospital a la unidad Urgencias.
# 43: Paciente 34 llega al hospital a la unidad UCI.
# 43: Paciente 35 llega al hospital a la unidad Urgencias.
# 43: Paciente 36 llega al hospital a la unidad Consultorios.
# 47: Paciente 37 llega al hospital a la unidad Consultorios.
# 47: Paciente 38 llega al hospital a la unidad UCI.
# 47: Paciente 39 llega al hospital a la unidad Consultorios.
# 51: Paciente 40 llega al hospital a la unidad Urgencias.
# 54: Paciente 41 llega al hospital a la unidad Urgencias.
# 54: Paciente 42 llega al hospital a la unidad Consultorios.
# 54: Paciente 43 llega al hospital a la unidad Urgencias.
# 56: Paciente 44 llega al hospital a la unidad Consultorios.
# 57: Paciente 45 llega al hospital a la unidad Consultorios.
# 57: Paciente 46 llega al hospital a la unidad UCI.
# 57: Paciente 47 llega al hospital a la unidad Consultorios.
# 57: Paciente 48 llega al hospital a la unidad Urgencias.
# 57: Paciente 49 llega al hospital a la unidad UCI.
# 62: Paciente 50 llega al hospital a la unidad Consultorios.
# 62: Paciente 51 llega al hospital a la unidad Consultorios.
# 62: Paciente 52 llega al hospital a la unidad Consultorios.
# 62: Paciente 53 llega al hospital a la unidad Consultorios.
# 62: Paciente 54 llega al hospital a la unidad Urgencias.
# 65: Paciente 55 llega al hospital a la unidad UCI.
# 65: Paciente 56 llega al hospital a la unidad Consultorios.
# 65: Paciente 57 llega al hospital a la unidad UCI.
# 65: Paciente 58 llega al hospital a la unidad Consultorios.
# 69: Paciente 59 llega al hospital a la unidad UCI.
# 73: Paciente 60 llega al hospital a la unidad UCI.
# 73: Paciente 61 llega al hospital a la unidad Urgencias.
# 73: Paciente 62 llega al hospital a la unidad Consultorios.
# 73: Paciente 63 llega al hospital a la unidad Urgencias.
# 75: Paciente 64 llega al hospital a la unidad Consultorios.
# 80: Paciente 65 llega al hospital a la unidad Consultorios.
# 81: Paciente 66 llega al hospital a la unidad Urgencias.
# 81: Paciente 67 llega al hospital a la unidad Urgencias.
# 81: Paciente 68 llega al hospital a la unidad Urgencias.
# 81: Paciente 69 llega al hospital a la unidad UCI.
# 81: Paciente 70 llega al hospital a la unidad Consultorios.
# 82: Paciente 71 llega al hospital a la unidad Consultorios.
# 82: Paciente 72 llega al hospital a la unidad Urgencias.
# 82: Paciente 73 llega al hospital a la unidad Consultorios.
# 87: Paciente 74 llega al hospital a la unidad Urgencias.
# 87: Paciente 75 llega al hospital a la unidad Urgencias.
# 87: Paciente 76 llega al hospital a la unidad UCI.
# 87: Paciente 77 llega al hospital a la unidad UCI.
# 89: Paciente 78 llega al hospital a la unidad UCI.
# 91: Paciente 79 llega al hospital a la unidad Consultorios.
# 91: Paciente 80 llega al hospital a la unidad UCI.
# 96: Paciente 81 llega al hospital a la unidad Consultorios.
# 99: Paciente 82 llega al hospital a la unidad Consultorios.
# 99: Paciente 83 llega al hospital a la unidad UCI.
# 99: Paciente 84 llega al hospital a la unidad Consultorios.
# 100: Paciente 85 llega al hospital a la unidad UCI.
# 100: Paciente 86 llega al hospital a la unidad UCI.
# 100: Paciente 87 llega al hospital a la unidad Consultorios.
# 100: Paciente 88 llega al hospital a la unidad Urgencias.
# 100: Paciente 89 llega al hospital a la unidad UCI.
# 105: Paciente 90 llega al hospital a la unidad UCI.
# 105: Paciente 91 llega al hospital a la unidad UCI.
# 108: Paciente 92 llega al hospital a la unidad UCI.
# 108: Paciente 93 llega al hospital a la unidad Urgencias.
# 113: Paciente 94 llega al hospital a la unidad UCI.
# 116: Paciente 95 llega al hospital a la unidad Urgencias.
# 116: Paciente 96 llega al hospital a la unidad Urgencias.
# 118: Paciente 97 llega al hospital a la unidad Consultorios.
# 118: Paciente 98 llega al hospital a la unidad Urgencias.
# 118: Paciente 99 llega al hospital a la unidad Urgencias.
# 118: Paciente 100 llega al hospital a la unidad Consultorios.
# 118: Paciente 101 llega al hospital a la unidad Urgencias.
# 120: Paciente 102 llega al hospital a la unidad UCI.
# 120: Paciente 103 llega al hospital a la unidad Consultorios.
# 120: Paciente 104 llega al hospital a la unidad UCI.
# 120: Paciente 105 llega al hospital a la unidad Consultorios.
# 120: Paciente 106 llega al hospital a la unidad Urgencias.
# 122: Paciente 107 llega al hospital a la unidad Consultorios.
# 124: Paciente 108 llega al hospital a la unidad UCI.
# 124: Paciente 109 llega al hospital a la unidad UCI.
# 128: Paciente 110 llega al hospital a la unidad Consultorios.
# 130: Paciente 111 llega al hospital a la unidad Consultorios.
# 135: Paciente 112 llega al hospital a la unidad Urgencias.
# 138: Paciente 113 llega al hospital a la unidad Consultorios.
# 138: Paciente 114 llega al hospital a la unidad UCI.
# 138: Paciente 115 llega al hospital a la unidad UCI.
# 138: Paciente 116 llega al hospital a la unidad Consultorios.
# 138: Paciente 117 llega al hospital a la unidad UCI.
# 143: Paciente 118 llega al hospital a la unidad UCI.
# 143: Paciente 119 llega al hospital a la unidad UCI.
# 143: Paciente 120 llega al hospital a la unidad Consultorios.
# 143: Paciente 121 llega al hospital a la unidad Urgencias.
# 148: Paciente 122 llega al hospital a la unidad Urgencias.
# 148: Paciente 123 llega al hospital a la unidad UCI.
# 148: Paciente 124 llega al hospital a la unidad Urgencias.
# 148: Paciente 125 llega al hospital a la unidad Consultorios.
# 148: Paciente 126 llega al hospital a la unidad Consultorios.
# 149: Paciente 127 llega al hospital a la unidad Consultorios.
# 149: Paciente 128 llega al hospital a la unidad Urgencias.
# 154: Paciente 129 llega al hospital a la unidad Consultorios.
# 154: Paciente 130 llega al hospital a la unidad Urgencias.
# 154: Paciente 131 llega al hospital a la unidad UCI.
# 154: Paciente 132 llega al hospital a la unidad Urgencias.
# 158: Paciente 133 llega al hospital a la unidad UCI.
# 158: Paciente 134 llega al hospital a la unidad Urgencias.
# 158: Paciente 135 llega al hospital a la unidad Consultorios.
# 158: Paciente 136 llega al hospital a la unidad UCI.
# 159: Paciente 137 llega al hospital a la unidad UCI.
# 159: Paciente 138 llega al hospital a la unidad Consultorios.
# 159: Paciente 139 llega al hospital a la unidad Consultorios.
# 160: Paciente 140 llega al hospital a la unidad Urgencias.
# 160: Paciente 141 llega al hospital a la unidad Urgencias.
# 160: Paciente 142 llega al hospital a la unidad Consultorios.
# 160: Paciente 143 llega al hospital a la unidad Urgencias.
# 160: Paciente 144 llega al hospital a la unidad Consultorios.
# 163: Paciente 145 llega al hospital a la unidad Urgencias.
# 163: Paciente 146 llega al hospital a la unidad Urgencias.
# 164: Paciente 147 llega al hospital a la unidad UCI.
# 165: Paciente 148 llega al hospital a la unidad Urgencias.
# 165: Paciente 149 llega al hospital a la unidad UCI.
# 165: Paciente 150 llega al hospital a la unidad UCI.
# 165: Paciente 151 llega al hospital a la unidad Consultorios.
# 168: Paciente 152 llega al hospital a la unidad UCI.
# 168: Paciente 153 llega al hospital a la unidad Urgencias.
# 168: Paciente 154 llega al hospital a la unidad Consultorios.
# 170: Paciente 155 llega al hospital a la unidad UCI.
# 170: Paciente 156 llega al hospital a la unidad UCI.
# 170: Paciente 157 llega al hospital a la unidad Urgencias.
# 170: Paciente 158 llega al hospital a la unidad Consultorios.
# 170: Paciente 159 llega al hospital a la unidad Urgencias.
# 172: Paciente 160 llega al hospital a la unidad UCI.
# 177: Paciente 161 llega al hospital a la unidad Consultorios.
# 177: Paciente 162 llega al hospital a la unidad Consultorios.
# 181: Paciente 163 llega al hospital a la unidad UCI.
# 183: Paciente 164 llega al hospital a la unidad Urgencias.
# 183: Paciente 165 llega al hospital a la unidad Urgencias.
# 185: Paciente 166 llega al hospital a la unidad UCI.
# 185: Paciente 167 llega al hospital a la unidad Consultorios.
# 185: Paciente 168 llega al hospital a la unidad UCI.
# 185: Paciente 169 llega al hospital a la unidad Urgencias.
# 185: Paciente 170 llega al hospital a la unidad Consultorios.
# 190: Paciente 171 llega al hospital a la unidad Urgencias.
# 190: Paciente 172 llega al hospital a la unidad UCI.
# 190: Paciente 173 llega al hospital a la unidad Urgencias.
# 190: Paciente 174 llega al hospital a la unidad Urgencias.
# 190: Paciente 175 llega al hospital a la unidad UCI.
# 195: Paciente 176 llega al hospital a la unidad Consultorios.
# 195: Paciente 177 llega al hospital a la unidad UCI.
# 200: Paciente 178 llega al hospital a la unidad UCI.
# 200: Paciente 179 llega al hospital a la unidad Consultorios.
# 200: Paciente 180 llega al hospital a la unidad Consultorios.
# 200: Paciente 181 llega al hospital a la unidad UCI.
# 201: Paciente 182 llega al hospital a la unidad Consultorios.
# 201: Paciente 183 llega al hospital a la unidad UCI.
# 205: Paciente 184 llega al hospital a la unidad Urgencias.
# 205: Paciente 185 llega al hospital a la unidad Urgencias.
# 205: Paciente 186 llega al hospital a la unidad Urgencias.
# 205: Paciente 187 llega al hospital a la unidad Urgencias.
# 206: Paciente 188 llega al hospital a la unidad UCI.
# 206: Paciente 189 llega al hospital a la unidad Consultorios.
# 208: Paciente 190 llega al hospital a la unidad Urgencias.
# 208: Paciente 191 llega al hospital a la unidad UCI.
# 208: Paciente 192 llega al hospital a la unidad Urgencias.
# 213: Paciente 193 llega al hospital a la unidad Urgencias.
# 213: Paciente 194 llega al hospital a la unidad Urgencias.
# 217: Paciente 195 llega al hospital a la unidad UCI.
# 217: Paciente 196 llega al hospital a la unidad Consultorios.
# 219: Paciente 197 llega al hospital a la unidad UCI.
# 219: Paciente 198 llega al hospital a la unidad UCI.
# 224: Paciente 199 llega al hospital a la unidad UCI.
# 224: Paciente 200 llega al hospital a la unidad UCI.
# 224: Paciente 201 llega al hospital a la unidad Urgencias.
# 224: Paciente 202 llega al hospital a la unidad Consultorios.
# 224: Paciente 203 llega al hospital a la unidad UCI.
# 229: Paciente 204 llega al hospital a la unidad Consultorios.
# 229: Paciente 205 llega al hospital a la unidad Consultorios.
# 229: Paciente 206 llega al hospital a la unidad Urgencias.
# 229: Paciente 207 llega al hospital a la unidad Urgencias.
# 229: Paciente 208 llega al hospital a la unidad Consultorios.
# 231: Paciente 209 llega al hospital a la unidad Urgencias.
# 231: Paciente 210 llega al hospital a la unidad UCI.
# 231: Paciente 211 llega al hospital a la unidad Consultorios.
# 235: Paciente 212 llega al hospital a la unidad UCI.
# 240: Paciente 213 llega al hospital a la unidad Urgencias.
# 240: Paciente 214 llega al hospital a la unidad Consultorios.
# 240: Paciente 215 llega al hospital a la unidad Consultorios.
# 240: Paciente 216 llega al hospital a la unidad Consultorios.
# 244: Paciente 217 llega al hospital a la unidad Consultorios.
# 248: Paciente 218 llega al hospital a la unidad UCI.
# 248: Paciente 219 llega al hospital a la unidad Consultorios.
# 250: Paciente 220 llega al hospital a la unidad UCI.
# 250: Paciente 221 llega al hospital a la unidad Consultorios.
# 250: Paciente 222 llega al hospital a la unidad Consultorios.
# 254: Paciente 223 llega al hospital a la unidad Urgencias.
# 258: Paciente 224 llega al hospital a la unidad UCI.
# 263: Paciente 225 llega al hospital a la unidad UCI.
# 263: Paciente 226 llega al hospital a la unidad Urgencias.
# 268: Paciente 227 llega al hospital a la unidad Urgencias.
# 268: Paciente 228 llega al hospital a la unidad Urgencias.
# 268: Paciente 229 llega al hospital a la unidad Urgencias.
# 268: Paciente 230 llega al hospital a la unidad Consultorios.
# 268: Paciente 231 llega al hospital a la unidad Urgencias.
# 272: Paciente 232 llega al hospital a la unidad Consultorios.
# 272: Paciente 233 llega al hospital a la unidad Consultorios.
# 272: Paciente 234 llega al hospital a la unidad Urgencias.
# 272: Paciente 235 llega al hospital a la unidad UCI.
# 272: Paciente 236 llega al hospital a la unidad Urgencias.
# 277: Paciente 237 llega al hospital a la unidad Urgencias.
# 277: Paciente 238 llega al hospital a la unidad UCI.
# 277: Paciente 239 llega al hospital a la unidad Urgencias.
# 277: Paciente 240 llega al hospital a la unidad Urgencias.
# 280: Paciente 241 llega al hospital a la unidad UCI.
# 280: Paciente 242 llega al hospital a la unidad UCI.
# 280: Paciente 243 llega al hospital a la unidad Consultorios.
# 280: Paciente 244 llega al hospital a la unidad Urgencias.
# 281: Paciente 245 llega al hospital a la unidad Urgencias.
# 281: Paciente 246 llega al hospital a la unidad UCI.
# 281: Paciente 247 llega al hospital a la unidad UCI.
# 281: Paciente 248 llega al hospital a la unidad Urgencias.
# 281: Paciente 249 llega al hospital a la unidad Urgencias.
# 284: Paciente 250 llega al hospital a la unidad UCI.
# 286: Paciente 251 llega al hospital a la unidad Consultorios.
# 286: Paciente 252 llega al hospital a la unidad Consultorios.
# 286: Paciente 253 llega al hospital a la unidad UCI.
# 286: Paciente 254 llega al hospital a la unidad Consultorios.
# 286: Paciente 255 llega al hospital a la unidad Consultorios.
# 289: Paciente 256 llega al hospital a la unidad Urgencias.
# 289: Paciente 257 llega al hospital a la unidad Urgencias.
# 290: Paciente 258 llega al hospital a la unidad Consultorios.
# 290: Paciente 259 llega al hospital a la unidad Urgencias.
# 290: Paciente 260 llega al hospital a la unidad Consultorios.
# 290: Paciente 261 llega al hospital a la unidad Consultorios.
# 295: Paciente 262 llega al hospital a la unidad Consultorios.
# 295: Paciente 263 llega al hospital a la unidad UCI.
# 295: Paciente 264 llega al hospital a la unidad UCI.
# 295: Paciente 265 llega al hospital a la unidad Consultorios.
# 295: Paciente 266 llega al hospital a la unidad Consultorios.
# 297: Paciente 267 llega al hospital a la unidad UCI.
# 297: Paciente 268 llega al hospital a la unidad Consultorios.
# 297: Paciente 269 llega al hospital a la unidad Consultorios.
# 300: Paciente 270 llega al hospital a la unidad Urgencias.
# 300: Paciente 271 llega al hospital a la unidad Urgencias.
# 300: Paciente 272 llega al hospital a la unidad Urgencias.
# 300: Paciente 273 llega al hospital a la unidad UCI.
# 303: Paciente 274 llega al hospital a la unidad Urgencias.
# 303: Paciente 275 llega al hospital a la unidad Urgencias.
# 303: Paciente 276 llega al hospital a la unidad Consultorios.
# 303: Paciente 277 llega al hospital a la unidad Urgencias.
# 303: Paciente 278 llega al hospital a la unidad Urgencias.
# 308: Paciente 279 llega al hospital a la unidad Consultorios.
# 313: Paciente 280 llega al hospital a la unidad Consultorios.
# 313: Paciente 281 llega al hospital a la unidad UCI.
# 315: Paciente 282 llega al hospital a la unidad Urgencias.
# 315: Paciente 283 llega al hospital a la unidad UCI.
# 320: Paciente 284 llega al hospital a la unidad UCI.
# 320: Paciente 285 llega al hospital a la unidad UCI.
# 320: Paciente 286 llega al hospital a la unidad Urgencias.
# 320: Paciente 287 llega al hospital a la unidad Urgencias.
# 320: Paciente 288 llega al hospital a la unidad Consultorios.
# 322: Paciente 289 llega al hospital a la unidad UCI.
# 322: Paciente 290 llega al hospital a la unidad UCI.
# 322: Paciente 291 llega al hospital a la unidad UCI.
# 322: Paciente 292 llega al hospital a la unidad UCI.
# 322: Paciente 293 llega al hospital a la unidad UCI.
# 327: Paciente 294 llega al hospital a la unidad UCI.
# 327: Paciente 295 llega al hospital a la unidad Consultorios.
# 327: Paciente 296 llega al hospital a la unidad Urgencias.
# 327: Paciente 297 llega al hospital a la unidad UCI.
# 328: Paciente 298 llega al hospital a la unidad UCI.
# 328: Paciente 299 llega al hospital a la unidad Consultorios.
# 328: Paciente 300 llega al hospital a la unidad Urgencias.
# 328: Paciente 301 llega al hospital a la unidad Consultorios.
# 331: Paciente 302 llega al hospital a la unidad Consultorios.
# 331: Paciente 303 llega al hospital a la unidad UCI.
# 331: Paciente 304 llega al hospital a la unidad Consultorios.
# 331: Paciente 305 llega al hospital a la unidad UCI.
# 331: Paciente 306 llega al hospital a la unidad Urgencias.
# 335: Paciente 307 llega al hospital a la unidad Urgencias.
# 335: Paciente 308 llega al hospital a la unidad Urgencias.
# 335: Paciente 309 llega al hospital a la unidad UCI.
# 337: Paciente 310 llega al hospital a la unidad Consultorios.
# 337: Paciente 311 llega al hospital a la unidad Consultorios.
# 337: Paciente 312 llega al hospital a la unidad Urgencias.
# 337: Paciente 313 llega al hospital a la unidad Consultorios.
# 338: Paciente 314 llega al hospital a la unidad UCI.
# 342: Paciente 315 llega al hospital a la unidad UCI.
# 342: Paciente 316 llega al hospital a la unidad Consultorios.
# 342: Paciente 317 llega al hospital a la unidad UCI.
# 342: Paciente 318 llega al hospital a la unidad Urgencias.
# 343: Paciente 319 llega al hospital a la unidad UCI.
# 343: Paciente 320 llega al hospital a la unidad Consultorios.
# 347: Paciente 321 llega al hospital a la unidad Consultorios.
# 347: Paciente 322 llega al hospital a la unidad UCI.
# 347: Paciente 323 llega al hospital a la unidad Urgencias.
# 347: Paciente 324 llega al hospital a la unidad Urgencias.
# 348: Paciente 325 llega al hospital a la unidad UCI.
# 348: Paciente 326 llega al hospital a la unidad UCI.
# 351: Paciente 327 llega al hospital a la unidad Consultorios.
# 351: Paciente 328 llega al hospital a la unidad UCI.
# 355: Paciente 329 llega al hospital a la unidad Consultorios.
# 355: Paciente 330 llega al hospital a la unidad Consultorios.
# 355: Paciente 331 llega al hospital a la unidad UCI.
# 355: Paciente 332 llega al hospital a la unidad Urgencias.
# 355: Paciente 333 llega al hospital a la unidad Consultorios.
# 357: Paciente 334 llega al hospital a la unidad Consultorios.
# 357: Paciente 335 llega al hospital a la unidad Urgencias.
# 357: Paciente 336 llega al hospital a la unidad Urgencias.
# 357: Paciente 337 llega al hospital a la unidad UCI.
# 357: Paciente 338 llega al hospital a la unidad Urgencias.
# 358: Paciente 339 llega al hospital a la unidad UCI.
# 363: Paciente 340 llega al hospital a la unidad Urgencias.
# 363: Paciente 341 llega al hospital a la unidad Urgencias.
# 363: Paciente 342 llega al hospital a la unidad Urgencias.
# 363: Paciente 343 llega al hospital a la unidad Urgencias.
# 365: Paciente 344 llega al hospital a la unidad UCI.
# 365: Paciente 345 llega al hospital a la unidad UCI.
# 369: Paciente 346 llega al hospital a la unidad UCI.
# 369: Paciente 347 llega al hospital a la unidad Consultorios.
# 369: Paciente 348 llega al hospital a la unidad Urgencias.
# 370: Paciente 349 llega al hospital a la unidad Urgencias.
# 370: Paciente 350 llega al hospital a la unidad Consultorios.
# 370: Paciente 351 llega al hospital a la unidad Urgencias.
# 370: Paciente 352 llega al hospital a la unidad Consultorios.
# 370: Paciente 353 llega al hospital a la unidad Urgencias.
# 371: Paciente 354 llega al hospital a la unidad UCI.
# 371: Paciente 355 llega al hospital a la unidad UCI.
# 371: Paciente 356 llega al hospital a la unidad UCI.
# 371: Paciente 357 llega al hospital a la unidad Urgencias.
# 371: Paciente 358 llega al hospital a la unidad UCI.
# 375: Paciente 359 llega al hospital a la unidad Consultorios.
# 376: El Paciente 4 murio esperando un kit medico.
# 376: Paciente 8 es atendido.
# 377: Al Paciente 8 se le asigno una cama y 5 miembro(s) del personal.
# 377: El Paciente 8 necesita cirugia.
# 378: Paciente 360 llega al hospital a la unidad Urgencias.
# 378: Paciente 361 llega al hospital a la unidad UCI.
# 378: Paciente 362 llega al hospital a la unidad Urgencias.
# 380: Paciente 363 llega al hospital a la unidad Consultorios.
# 380: Paciente 364 llega al hospital a la unidad UCI.
# 380: Paciente 365 llega al hospital a la unidad Urgencias.
# 380: Paciente 366 llega al hospital a la unidad UCI.
# 380: Paciente 367 llega al hospital a la unidad Urgencias.
# 383: El Paciente 7 murio esperando un kit medico.
# 383: Paciente 368 llega al hospital a la unidad UCI.
# 383: Paciente 369 llega al hospital a la unidad Urgencias.
# 383: Paciente 9 es atendido.
# 388: Paciente 370 llega al hospital a la unidad Consultorios.
# 388: Paciente 371 llega al hospital a la unidad UCI.
# 388: Paciente 372 llega al hospital a la unidad Consultorios.
# 392: Paciente 373 llega al hospital a la unidad UCI.
# 392: Paciente 374 llega al hospital a la unidad Consultorios.
# 392: Paciente 375 llega al hospital a la unidad Urgencias.
# 392: Paciente 376 llega al hospital a la unidad Consultorios.
# 395: Al Paciente 9 se le asigno una cama y 1 miembro(s) del personal.
# 395: Paciente 377 llega al hospital a la unidad Consultorios.
# 395: Paciente 378 llega al hospital a la unidad Consultorios.
# 395: Paciente 379 llega al hospital a la unidad UCI.
# 395: Paciente 10 es atendido.
# 397: Paciente 380 llega al hospital a la unidad Consultorios.
# 397: Paciente 381 llega al hospital a la unidad Urgencias.
# 397: Paciente 382 llega al hospital a la unidad Urgencias.
# 397: Al Paciente 10 se le asigno una cama y 3 miembro(s) del personal.
# 397: Paciente 11 es atendido.
# 399: Paciente 383 llega al hospital a la unidad Consultorios.
# 401: Al Paciente 11 se le asigno una cama y 5 miembro(s) del personal.
# 401: Paciente 12 es atendido.
# 404: Paciente 384 llega al hospital a la unidad Urgencias.
# 404: Paciente 385 llega al hospital a la unidad Consultorios.
# 404: Paciente 386 llega al hospital a la unidad Consultorios.
# 407: Paciente 387 llega al hospital a la unidad Consultorios.
# 407: Paciente 388 llega al hospital a la unidad Urgencias.
# 407: Paciente 389 llega al hospital a la unidad UCI.
# 408: Al Paciente 12 se le asigno una cama y 4 miembro(s) del personal.
# 408: Paciente 390 llega al hospital a la unidad UCI.
# 408: Paciente 13 es atendido.
# 409: Paciente 391 llega al hospital a la unidad UCI.
# 413: Paciente 392 llega al hospital a la unidad UCI.
# 413: Paciente 393 llega al hospital a la unidad UCI.
# 413: Paciente 394 llega al hospital a la unidad Urgencias.
# 415: Al Paciente 13 se le asigno una cama y 1 miembro(s) del personal.
# 415: Paciente 395 llega al hospital a la unidad UCI.
# 415: Paciente 396 llega al hospital a la unidad UCI.
# 415: Paciente 397 llega al hospital a la unidad Consultorios.
# 415: Paciente 398 llega al hospital a la unidad UCI.
# 415: Paciente 399 llega al hospital a la unidad Urgencias.
# 415: Paciente 14 es atendido.
# 418: Paciente 400 llega al hospital a la unidad UCI.
# 418: Paciente 401 llega al hospital a la unidad UCI.
# 418: Paciente 402 llega al hospital a la unidad Urgencias.
# 418: Paciente 403 llega al hospital a la unidad Consultorios.
# 418: Al Paciente 14 se le asigno una cama y 6 miembro(s) del personal.
# 418: Paciente 15 es atendido.
# 419: Paciente 404 llega al hospital a la unidad Urgencias.
# 419: Paciente 405 llega al hospital a la unidad Urgencias.
# 419: Paciente 406 llega al hospital a la unidad Consultorios.
# 419: Paciente 407 llega al hospital a la unidad UCI.
# 419: Paciente 408 llega al hospital a la unidad UCI.
# 420: Paciente 409 llega al hospital a la unidad Urgencias.
# 420: Paciente 410 llega al hospital a la unidad Urgencias.
# 424: Paciente 411 llega al hospital a la unidad Consultorios.
# 426: Paciente 412 llega al hospital a la unidad Consultorios.
# 426: Paciente 413 llega al hospital a la unidad Urgencias.
# 426: Paciente 414 llega al hospital a la unidad UCI.
# 426: Paciente 415 llega al hospital a la unidad UCI.
# 427: Paciente 416 llega al hospital a la unidad UCI.
# 427: Paciente 417 llega al hospital a la unidad UCI.
# 427: Paciente 418 llega al hospital a la unidad UCI.
# 427: Paciente 419 llega al hospital a la unidad Urgencias.
# 429: Paciente 420 llega al hospital a la unidad Consultorios.
# 431: Paciente 421 llega al hospital a la unidad Urgencias.
# 431: Paciente 422 llega al hospital a la unidad Consultorios.
# 431: Paciente 423 llega al hospital a la unidad Urgencias.
# 431: Paciente 424 llega al hospital a la unidad UCI.
# 435: Paciente 425 llega al hospital a la unidad Urgencias.
# 435: Paciente 426 llega al hospital a la unidad UCI.
# 435: Paciente 427 llega al hospital a la unidad UCI.
# 435: Paciente 428 llega al hospital a la unidad UCI.
# 437: Paciente 429 llega al hospital a la unidad Consultorios.
# 437: Paciente 430 llega al hospital a la unidad UCI.
# 437: Paciente 431 llega al hospital a la unidad Consultorios.
# 437: Paciente 432 llega al hospital a la unidad Consultorios.
# 437: Paciente 433 llega al hospital a la unidad Urgencias.
# 438: Al Paciente 15 se le asigno una cama y 1 miembro(s) del personal.
# 438: Paciente 434 llega al hospital a la unidad UCI.
# 438: Paciente 435 llega al hospital a la unidad Consultorios.
# 438: Paciente 436 llega al hospital a la unidad Urgencias.
# 438: Paciente 16 es atendido.
# 441: Paciente 437 llega al hospital a la unidad UCI.
# 441: Paciente 438 llega al hospital a la unidad Urgencias.
# 441: Paciente 439 llega al hospital a la unidad Consultorios.
# 441: Paciente 440 llega al hospital a la unidad UCI.
# 441: Paciente 441 llega al hospital a la unidad Urgencias.
# 442: Paciente 442 llega al hospital a la unidad Consultorios.
# 442: Paciente 443 llega al hospital a la unidad UCI.
# 442: Paciente 444 llega al hospital a la unidad Consultorios.
# 442: Paciente 445 llega al hospital a la unidad Consultorios.
# 442: Paciente 446 llega al hospital a la unidad Urgencias.
# 443: Paciente 447 llega al hospital a la unidad Consultorios.
# 446: Al Paciente 16 se le asigno una cama y 1 miembro(s) del personal.
# 446: Paciente 17 es atendido.
# 447: Paciente 448 llega al hospital a la unidad UCI.
# 447: Paciente 449 llega al hospital a la unidad Consultorios.
# 450: Paciente 450 llega al hospital a la unidad Urgencias.
# 450: Paciente 451 llega al hospital a la unidad Consultorios.
# 450: Paciente 452 llega al hospital a la unidad Urgencias.
# 450: Paciente 453 llega al hospital a la unidad Urgencias.
# 454: Paciente 454 llega al hospital a la unidad UCI.
# 456: Paciente 455 llega al hospital a la unidad UCI.
# 456: Paciente 456 llega al hospital a la unidad Consultorios.
# 456: Paciente 457 llega al hospital a la unidad Consultorios.
# 457: Al Paciente 17 se le asigno una cama y 1 miembro(s) del personal.
# 457: Paciente 18 es atendido.
# 461: Paciente 458 llega al hospital a la unidad Urgencias.
# 461: Paciente 459 llega al hospital a la unidad UCI.
# 461: Paciente 460 llega al hospital a la unidad UCI.
# 461: Paciente 461 llega al hospital a la unidad Consultorios.
# 464: Paciente 462 llega al hospital a la unidad Consultorios.
# 464: Paciente 463 llega al hospital a la unidad Consultorios.
# 464: Paciente 464 llega al hospital a la unidad Urgencias.
# 464: Paciente 465 llega al hospital a la unidad UCI.
# 465: Paciente 466 llega al hospital a la unidad Consultorios.
# 470: Paciente 467 llega al hospital a la unidad Consultorios.
# 470: Paciente 468 llega al hospital a la unidad UCI.
# 470: Paciente 469 llega al hospital a la unidad Consultorios.
# 470: Paciente 470 llega al hospital a la unidad Consultorios.
# 470: Paciente 471 llega al hospital a la unidad UCI.
# 474: Al Paciente 18 se le asigno una cama y 1 miembro(s) del personal.
# 474: Paciente 472 llega al hospital a la unidad Urgencias.
# 474: Paciente 473 llega al hospital a la unidad Consultorios.
# 474: Paciente 474 llega al hospital a la unidad Consultorios.
# 474: Paciente 19 es atendido.
# 478: Paciente 475 llega al hospital a la unidad Urgencias.
# 479: Paciente 476 llega al hospital a la unidad UCI.
# 479: Paciente 477 llega al hospital a la unidad Urgencias.
# 479: Paciente 478 llega al hospital a la unidad Urgencias.
