# %% [markdown]
# # Escenario
# La simulación se hará sobre un hospital que contará con las siguientes unidades de atención: Unidad de Cuidados Intensivos (UCI), Unidad de Urgencias, Consultorios. Cada unidad cuenta con recursos limitados: un número específico de camas y un número específico de enfermeras y doctores, y además la Unidad de Urgencias cuenta con un número específico de set de utencilios médicos para cirugías.

# %% [markdown]
# ## Objetivos
# 1. Simular la carga de trabajo de cada unidad del hospital y los tiempos de espera de los pacientes.
# 2. Sacar conclusiones sobre la eficiencia del manejo de los recursos de cada unidad así como de la suficiencia de los mismos.

# %%
import pandas as pd
import numpy as np
import simpy
import random

# %%
class Unidad:
    def __init__(self, env, nombre, num_camas, personal, num_kits_medicos):
        self.env = env
        self.nombre = nombre
        self.num_camas = simpy.Resource(env, capacity=num_camas)
        self.personal = simpy.Resource(env, capacity=personal)
        self.num_kits_medicos = simpy.Resource(env, capacity=num_kits_medicos)

# %%
class Hospital:
    def __init__(self, env, recepcionistas, unidades):
        self.env = env
        self.unidades = unidades
        self.recepcionistas = simpy.Resource(env, capacity=recepcionistas)

# %%
class Paciente:
    def __init__(self, env, id, hospital: Hospital, unidad: Unidad):
        self.env = env
        self.id = id
        self.hospital = hospital
        self.unidad = unidad
        self.cirugia = random.choice([True, False]) if unidad.nombre == "Urgencias" else False
        self.alcanzo_cama = False
        
        self.env.process(self.start())
        self.eventos = pd.DataFrame()
    
    def start(self):
        print(f"{self.env.now}: Paciente {self.id} llega al hospital a la unidad {self.unidad.nombre}.")
        self.eventos = pd.concat([self.eventos, pd.DataFrame({
                "id": [self.id],
                "evento": ["LLEGADA"],
                "time": [self.env.now]
            })])
        
        with self.hospital.recepcionistas.request() as request:
            yield request
            print(f"{self.env.now}: Paciente {self.id} es atendido.")
            self.eventos = pd.concat([self.eventos, pd.DataFrame({
                "id": [self.id],
                "evento": ["ATENDIDO"],
                "time": [self.env.now]
            })])

            if self.unidad.nombre == "Urgencias" or self.unidad.nombre == "UCI":
                tiempo_atencion_inferior = 1
                tiempo_atencion_superior = 7
                cant_personal = random.randint(3, 8)
            else:
                tiempo_atencion_inferior = 7
                tiempo_atencion_superior = 25
                cant_personal = 1 #Solo se necesita un doctor para una consulta general

            # El paciente solicita una cama
            with self.unidad.num_camas.request() as cama_request:
                yield cama_request
                with self.unidad.personal.request() as personal_request: # Con comprueba la disponibilidad de personal
                    yield personal_request
                    yield self.env.timeout(random.randint(tiempo_atencion_inferior, tiempo_atencion_superior))
                    print(f"{self.env.now}: Al Paciente {self.id} se le asigno una cama y {cant_personal} miembro(s) del personal.")
                    self.alcanzo_cama = True
                    self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id],
                        "evento": ["ASIGNACION_CAMA_PERSONAL"],
                        "time": [self.env.now]
                    })])

        #Si el paciente es de urgencias y necesita cirugia, espera que se le asigne un kit medico
        if self.cirugia:
            print(f"{self.env.now}: El Paciente {self.id} necesita cirugía.")
            
            # Tiempo máximo que el paciente puede esperar sin morir
            tiempo_max_espera_kit = 60  # en minutos
        
            with self.unidad.num_kits_medicos.request() as kit_request:
                resultado = yield kit_request | self.env.timeout(tiempo_max_espera_kit)

                if kit_request in resultado:
                    # El paciente consiguió el kit a tiempo
                    print(f"{self.env.now}: Al Paciente {self.id} se le asignó un kit médico.")
                    self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id],
                        "evento": ["ASIGNACION_KIT"],
                        "time": [self.env.now]
                    })])
        
                    # Tiempo de cirugía real
                    tiempo_cirugia = random.randint(15, 60 * 8) # Se considera un rango de 15 minutos a 8 horas por cirugía
                    yield self.env.timeout(tiempo_cirugia)
                    print(f"{self.env.now}: Cirugía completada para el Paciente {self.id}.")
        
                    # ... tras cirugía o recuperación …
                    # decisión probabilística: 90% de alta, 10% de muerte
                    prob_supervivencia = 0.9  
                    if random.random() <= prob_supervivencia:
                        evento_final = "ALTA"
                        mensaje = f"{self.env.now}: Paciente {self.id} se le ha dado de alta."
                    else:
                        evento_final = "MUERTE"
                        mensaje = f"{self.env.now}: Paciente {self.id} murió tras el procedimiento."
                    
                    print(mensaje)
                    self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id],
                        "evento": [evento_final],
                        "time": [self.env.now]
                    })])
                else:
                    # El paciente murió esperando un kit médico disponible
                    print(f"{self.env.now}: El Paciente {self.id} murió esperando un kit médico.")
                    self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id],
                        "evento": ["MUERTE"],
                        "time": [self.env.now]
                    })])
                    return
        else:
            # Tiempo de recuperación antes del alta
            tiempo_recuperacion = random.randint(5, 30)
            yield self.env.timeout(tiempo_recuperacion)

            print(f"{self.env.now}: Al Paciente {self.id} se le ha dado de alta.")
            self.eventos = pd.concat([self.eventos, pd.DataFrame({
                "id": [self.id],
                "evento": ["ALTA"],
                "time": [self.env.now]
            })])

# %%
class Simulation:
    def __init__(self, env, unidades_settings, recepcionistas):
        self.env = env
        self.unidades = [Unidad(env, u["nombre"], u["num_camas"], u["personal"], u["num_kits_medicos"]) for u in unidades_settings]
        self.hospital = Hospital(env, recepcionistas, self.unidades)
        self.pacientes = []

        self.env.process(self.run_simulation())
    
    def run_simulation(self):
        while True:
            yield self.env.timeout(random.randint(1, 5)) # Los pacientes llegan cada 1 a 5 minutos

            # Generar de 1 a 5 pacientes a la vez
            for _ in range(random.randint(1, 5)):
                paciente = Paciente(
                    self.env,
                    len(self.pacientes) + 1,
                    self.hospital,
                    #random.choice(self.unidades)
                    np.random.choice(self.unidades, p=[0.5, 0.3, 0.2])
                )
                self.pacientes.append(paciente)

# %% [markdown]
# # Inicio de la simulacion

# %%
env = simpy.Environment()
unidades_settings = [
    {"nombre": "Urgencias", "num_camas": 20, "personal": 30, "num_kits_medicos": 8},
    {"nombre": "UCI", "num_camas": 35, "personal": 25, "num_kits_medicos": 1},
    {"nombre": "Consultorios", "num_camas": 10, "personal": 8, "num_kits_medicos": 1}
]
num_recepcionistas = 2

random.seed(111)

simulacion = Simulation(env, unidades_settings, num_recepcionistas)
env.run(until=60*8)
# Out:
# 2: Paciente 1 llega al hospital a la unidad UCI.
# 2: Paciente 2 llega al hospital a la unidad Urgencias.
# 2: Paciente 3 llega al hospital a la unidad Consultorios.
# 2: Paciente 1 es atendido.
# 2: Paciente 2 es atendido.
# 4: Paciente 4 llega al hospital a la unidad Consultorios.
# 4: Paciente 5 llega al hospital a la unidad Urgencias.
# 7: Al Paciente 1 se le asigno una cama y 6 miembro(s) del personal.
# 7: Paciente 3 es atendido.
# 8: Paciente 6 llega al hospital a la unidad Urgencias.
# 8: Paciente 7 llega al hospital a la unidad UCI.
# 9: Al Paciente 2 se le asigno una cama y 6 miembro(s) del personal.
# 9: Paciente 4 es atendido.
# 12: Paciente 8 llega al hospital a la unidad Urgencias.
# 12: Paciente 9 llega al hospital a la unidad UCI.
# 12: Paciente 10 llega al hospital a la unidad Consultorios.
# 12: Paciente 11 llega al hospital a la unidad UCI.
# 15: Paciente 12 llega al hospital a la unidad Consultorios.
# 15: Paciente 13 llega al hospital a la unidad UCI.
# 15: Paciente 14 llega al hospital a la unidad Consultorios.
# 15: Paciente 15 llega al hospital a la unidad UCI.
# 16: Paciente 16 llega al hospital a la unidad Consultorios.
# 16: Paciente 17 llega al hospital a la unidad Urgencias.
# 16: Paciente 18 llega al hospital a la unidad Urgencias.
# 20: Paciente 19 llega al hospital a la unidad UCI.
# 21: Al Paciente 3 se le asigno una cama y 1 miembro(s) del personal.
# 21: Paciente 5 es atendido.
# 22: Al Paciente 5 se le asigno una cama y 7 miembro(s) del personal.
# 22: El Paciente 5 necesita cirugía.
# 22: Paciente 6 es atendido.
# 22: Al Paciente 5 se le asignó un kit médico.
# 24: Al Paciente 4 se le asigno una cama y 1 miembro(s) del personal.
# 24: Paciente 20 llega al hospital a la unidad Urgencias.
# 24: Paciente 21 llega al hospital a la unidad Consultorios.
# 24: Paciente 7 es atendido.
# 25: Al Paciente 6 se le asigno una cama y 5 miembro(s) del personal.
# 25: Paciente 8 es atendido.
# 26: Al Paciente 2 se le ha dado de alta.
# 26: Paciente 22 llega al hospital a la unidad Urgencias.
# 26: Paciente 23 llega al hospital a la unidad Urgencias.
# 26: Paciente 24 llega al hospital a la unidad Urgencias.
# 26: Paciente 25 llega al hospital a la unidad Consultorios.
# 26: Al Paciente 8 se le asigno una cama y 8 miembro(s) del personal.
# 26: El Paciente 8 necesita cirugía.
# 26: Paciente 9 es atendido.
# 26: Al Paciente 8 se le asignó un kit médico.
# 29: Al Paciente 1 se le ha dado de alta.
# 30: Al Paciente 6 se le ha dado de alta.
# 30: Paciente 26 llega al hospital a la unidad Urgencias.
# 30: Paciente 27 llega al hospital a la unidad Urgencias.
# 30: Paciente 28 llega al hospital a la unidad Urgencias.
# 30: Paciente 29 llega al hospital a la unidad UCI.
# 30: Paciente 30 llega al hospital a la unidad Urgencias.
# 31: Al Paciente 7 se le asigno una cama y 7 miembro(s) del personal.
# 31: Paciente 10 es atendido.
# 32: Al Paciente 9 se le asigno una cama y 7 miembro(s) del personal.
# 32: Paciente 11 es atendido.
# 34: Paciente 31 llega al hospital a la unidad Urgencias.
# 34: Paciente 32 llega al hospital a la unidad Urgencias.
# 36: Paciente 33 llega al hospital a la unidad Urgencias.
# 36: Paciente 34 llega al hospital a la unidad Urgencias.
# 36: Paciente 35 llega al hospital a la unidad Urgencias.
# 36: Paciente 36 llega al hospital a la unidad Urgencias.
# 36: Paciente 37 llega al hospital a la unidad Urgencias.
# 37: Al Paciente 9 se le ha dado de alta.
# 38: Al Paciente 11 se le asigno una cama y 5 miembro(s) del personal.
# 38: Paciente 38 llega al hospital a la unidad Urgencias.
# 38: Paciente 39 llega al hospital a la unidad UCI.
# 38: Paciente 40 llega al hospital a la unidad UCI.
# 38: Paciente 41 llega al hospital a la unidad UCI.
# 38: Paciente 42 llega al hospital a la unidad Urgencias.
# 38: Paciente 12 es atendido.
# 39: Paciente 43 llega al hospital a la unidad Consultorios.
# 42: Paciente 44 llega al hospital a la unidad UCI.
# 43: Al Paciente 4 se le ha dado de alta.
# 47: Paciente 45 llega al hospital a la unidad UCI.
# 50: Al Paciente 3 se le ha dado de alta.
# 51: Paciente 46 llega al hospital a la unidad Urgencias.
# 51: Paciente 47 llega al hospital a la unidad UCI.
# 51: Paciente 48 llega al hospital a la unidad Urgencias.
# 53: Al Paciente 7 se le ha dado de alta.
# 56: Al Paciente 10 se le asigno una cama y 1 miembro(s) del personal.
# 56: Paciente 49 llega al hospital a la unidad Urgencias.
# 56: Paciente 50 llega al hospital a la unidad Consultorios.
# 56: Paciente 51 llega al hospital a la unidad UCI.
# 56: Paciente 52 llega al hospital a la unidad Urgencias.
# 56: Paciente 13 es atendido.
# 59: Al Paciente 12 se le asigno una cama y 1 miembro(s) del personal.
# 59: Paciente 14 es atendido.
# 60: Al Paciente 11 se le ha dado de alta.
# 60: Paciente 53 llega al hospital a la unidad UCI.
# 60: Paciente 54 llega al hospital a la unidad Consultorios.
# 60: Paciente 55 llega al hospital a la unidad UCI.
# 61: Paciente 56 llega al hospital a la unidad Consultorios.
# 61: Paciente 57 llega al hospital a la unidad Urgencias.
# 61: Paciente 58 llega al hospital a la unidad Consultorios.
# 61: Paciente 59 llega al hospital a la unidad UCI.
# 62: Al Paciente 13 se le asigno una cama y 4 miembro(s) del personal.
# 62: Paciente 15 es atendido.
# 63: Paciente 60 llega al hospital a la unidad Urgencias.
# 63: Paciente 61 llega al hospital a la unidad Consultorios.
# 63: Paciente 62 llega al hospital a la unidad UCI.
# 64: Paciente 63 llega al hospital a la unidad Urgencias.
# 64: Paciente 64 llega al hospital a la unidad Urgencias.
# 66: Al Paciente 15 se le asigno una cama y 6 miembro(s) del personal.
# 66: Paciente 16 es atendido.
# 67: Al Paciente 12 se le ha dado de alta.
# 69: Al Paciente 13 se le ha dado de alta.
# 69: Paciente 65 llega al hospital a la unidad UCI.
# 74: Al Paciente 15 se le ha dado de alta.
# 74: Al Paciente 16 se le asigno una cama y 1 miembro(s) del personal.
# 74: Paciente 66 llega al hospital a la unidad Consultorios.
# 74: Paciente 67 llega al hospital a la unidad UCI.
# 74: Paciente 68 llega al hospital a la unidad Urgencias.
# 74: Paciente 17 es atendido.
# 75: Al Paciente 14 se le asigno una cama y 1 miembro(s) del personal.
# 75: Paciente 18 es atendido.
# 76: Paciente 69 llega al hospital a la unidad Consultorios.
# 76: Paciente 70 llega al hospital a la unidad UCI.
# 76: Paciente 71 llega al hospital a la unidad Urgencias.
# 78: Al Paciente 18 se le asigno una cama y 7 miembro(s) del personal.
# 78: Paciente 19 es atendido.
# 80: Al Paciente 10 se le ha dado de alta.
# 80: Paciente 72 llega al hospital a la unidad Urgencias.
# 80: Paciente 73 llega al hospital a la unidad Urgencias.
# 80: Paciente 74 llega al hospital a la unidad Consultorios.
# 80: Paciente 75 llega al hospital a la unidad Consultorios.
# 80: Paciente 76 llega al hospital a la unidad UCI.
# 81: Al Paciente 17 se le asigno una cama y 8 miembro(s) del personal.
# 81: El Paciente 17 necesita cirugía.
# 81: Paciente 20 es atendido.
# 81: Al Paciente 17 se le asignó un kit médico.
# 83: Al Paciente 19 se le asigno una cama y 5 miembro(s) del personal.
# 83: Paciente 21 es atendido.
# 85: Paciente 77 llega al hospital a la unidad Urgencias.
# 85: Paciente 78 llega al hospital a la unidad Urgencias.
# 85: Paciente 79 llega al hospital a la unidad UCI.
# 85: Paciente 80 llega al hospital a la unidad UCI.
# 87: Cirugía completada para el Paciente 5.
# 87: Paciente 5 se le ha dado de alta.
# 87: Al Paciente 20 se le asigno una cama y 8 miembro(s) del personal.
# 87: Paciente 22 es atendido.
# 88: Al Paciente 22 se le asigno una cama y 5 miembro(s) del personal.
# 88: Paciente 23 es atendido.
# 90: Al Paciente 16 se le ha dado de alta.
# 90: Paciente 81 llega al hospital a la unidad Urgencias.
# 90: Paciente 82 llega al hospital a la unidad Consultorios.
# 91: Paciente 83 llega al hospital a la unidad UCI.
# 91: Paciente 84 llega al hospital a la unidad UCI.
# 91: Paciente 85 llega al hospital a la unidad Urgencias.
# 91: Paciente 86 llega al hospital a la unidad Consultorios.
# 91: Paciente 87 llega al hospital a la unidad UCI.
# 94: Al Paciente 18 se le ha dado de alta.
# 94: Al Paciente 23 se le asigno una cama y 3 miembro(s) del personal.
# 94: Paciente 88 llega al hospital a la unidad UCI.
# 94: Paciente 89 llega al hospital a la unidad Urgencias.
# 94: Paciente 90 llega al hospital a la unidad UCI.
# 94: Paciente 91 llega al hospital a la unidad Consultorios.
# 94: Paciente 92 llega al hospital a la unidad Consultorios.
# 94: Paciente 24 es atendido.
# 95: Paciente 93 llega al hospital a la unidad Consultorios.
# 95: Al Paciente 24 se le asigno una cama y 5 miembro(s) del personal.
# 95: Paciente 25 es atendido.
# 96: Cirugía completada para el Paciente 8.
# 96: Paciente 8 se le ha dado de alta.
# 98: Al Paciente 14 se le ha dado de alta.
# 98: Al Paciente 19 se le ha dado de alta.
# 98: Paciente 94 llega al hospital a la unidad UCI.
# 103: Paciente 95 llega al hospital a la unidad UCI.
# 103: Paciente 96 llega al hospital a la unidad Urgencias.
# 103: Paciente 97 llega al hospital a la unidad Urgencias.
# 103: Paciente 98 llega al hospital a la unidad UCI.
# 103: Paciente 99 llega al hospital a la unidad Urgencias.
# 105: Al Paciente 24 se le ha dado de alta.
# 106: Paciente 100 llega al hospital a la unidad UCI.
# 106: Paciente 101 llega al hospital a la unidad Urgencias.
# 106: Paciente 102 llega al hospital a la unidad Urgencias.
# 106: Paciente 103 llega al hospital a la unidad Urgencias.
# 108: Al Paciente 21 se le asigno una cama y 1 miembro(s) del personal.
# 108: Paciente 26 es atendido.
# 109: Al Paciente 20 se le ha dado de alta.
# 109: Al Paciente 26 se le asigno una cama y 8 miembro(s) del personal.
# 109: El Paciente 26 necesita cirugía.
# 109: Paciente 27 es atendido.
# 109: Al Paciente 26 se le asignó un kit médico.
# 110: Al Paciente 25 se le asigno una cama y 1 miembro(s) del personal.
# 110: Paciente 28 es atendido.
# 111: Paciente 104 llega al hospital a la unidad UCI.
# 111: Paciente 105 llega al hospital a la unidad Urgencias.
# 111: Paciente 106 llega al hospital a la unidad UCI.
# 111: Paciente 107 llega al hospital a la unidad Urgencias.
# 114: Al Paciente 22 se le ha dado de alta.
# 114: Paciente 108 llega al hospital a la unidad UCI.
# 114: Paciente 109 llega al hospital a la unidad Urgencias.
# 114: Paciente 110 llega al hospital a la unidad Consultorios.
# 114: Paciente 111 llega al hospital a la unidad Consultorios.
# 115: Al Paciente 21 se le ha dado de alta.
# 115: Al Paciente 27 se le asigno una cama y 5 miembro(s) del personal.
# 115: El Paciente 27 necesita cirugía.
# 115: Al Paciente 25 se le ha dado de alta.
# 115: Paciente 29 es atendido.
# 115: Al Paciente 27 se le asignó un kit médico.
# 116: Al Paciente 23 se le ha dado de alta.
# 116: Al Paciente 28 se le asigno una cama y 4 miembro(s) del personal.
# 116: El Paciente 28 necesita cirugía.
# 116: Paciente 112 llega al hospital a la unidad Urgencias.
# 116: Paciente 30 es atendido.
# 116: Al Paciente 28 se le asignó un kit médico.
# 120: Al Paciente 29 se le asigno una cama y 8 miembro(s) del personal.
# 120: Paciente 113 llega al hospital a la unidad Urgencias.
# 120: Paciente 114 llega al hospital a la unidad Urgencias.
# 120: Paciente 31 es atendido.
# 122: Al Paciente 30 se le asigno una cama y 4 miembro(s) del personal.
# 122: Paciente 32 es atendido.
# 124: Paciente 115 llega al hospital a la unidad UCI.
# 124: Paciente 116 llega al hospital a la unidad Consultorios.
# 124: Paciente 117 llega al hospital a la unidad UCI.
# 124: Paciente 118 llega al hospital a la unidad UCI.
# 126: Al Paciente 31 se le asigno una cama y 3 miembro(s) del personal.
# 126: Paciente 33 es atendido.
# 128: Paciente 119 llega al hospital a la unidad Consultorios.
# 128: Paciente 120 llega al hospital a la unidad Urgencias.
# 128: Paciente 121 llega al hospital a la unidad Urgencias.
# 128: Paciente 122 llega al hospital a la unidad UCI.
# 129: Al Paciente 32 se le asigno una cama y 8 miembro(s) del personal.
# 129: El Paciente 32 necesita cirugía.
# 129: Paciente 34 es atendido.
# 129: Al Paciente 32 se le asignó un kit médico.
# 131: Al Paciente 34 se le asigno una cama y 6 miembro(s) del personal.
# 131: Paciente 35 es atendido.
# 132: Paciente 123 llega al hospital a la unidad Urgencias.
# 132: Paciente 124 llega al hospital a la unidad Urgencias.
# 133: Al Paciente 29 se le ha dado de alta.
# 133: Al Paciente 33 se le asigno una cama y 7 miembro(s) del personal.
# 133: Paciente 36 es atendido.
# 135: Al Paciente 31 se le ha dado de alta.
# 135: Al Paciente 35 se le asigno una cama y 8 miembro(s) del personal.
# 135: El Paciente 35 necesita cirugía.
# 135: Paciente 37 es atendido.
# 135: Al Paciente 35 se le asignó un kit médico.
# 136: Paciente 125 llega al hospital a la unidad Urgencias.
# 136: Paciente 126 llega al hospital a la unidad UCI.
# 136: Paciente 127 llega al hospital a la unidad Urgencias.
# 139: Al Paciente 36 se le asigno una cama y 7 miembro(s) del personal.
# 139: El Paciente 36 necesita cirugía.
# 139: Paciente 38 es atendido.
# 139: Al Paciente 36 se le asignó un kit médico.
# 140: Paciente 128 llega al hospital a la unidad Consultorios.
# 140: Paciente 129 llega al hospital a la unidad UCI.
# 140: Paciente 130 llega al hospital a la unidad UCI.
# 140: Paciente 131 llega al hospital a la unidad Consultorios.
# 142: Al Paciente 37 se le asigno una cama y 4 miembro(s) del personal.
# 142: El Paciente 37 necesita cirugía.
# 142: Paciente 39 es atendido.
# 142: Al Paciente 37 se le asignó un kit médico.
# 143: Al Paciente 34 se le ha dado de alta.
# 144: Al Paciente 30 se le ha dado de alta.
# 144: Al Paciente 39 se le asigno una cama y 4 miembro(s) del personal.
# 144: Paciente 40 es atendido.
# 145: Paciente 132 llega al hospital a la unidad Consultorios.
# 145: Paciente 133 llega al hospital a la unidad UCI.
# 146: Al Paciente 38 se le asigno una cama y 8 miembro(s) del personal.
# 146: Paciente 41 es atendido.
# 148: Al Paciente 40 se le asigno una cama y 4 miembro(s) del personal.
# 148: Paciente 42 es atendido.
# 149: Paciente 134 llega al hospital a la unidad Urgencias.
# 149: Paciente 135 llega al hospital a la unidad UCI.
# 149: Paciente 136 llega al hospital a la unidad UCI.
# 153: Al Paciente 41 se le asigno una cama y 8 miembro(s) del personal.
# 153: Al Paciente 42 se le asigno una cama y 8 miembro(s) del personal.
# 153: Paciente 137 llega al hospital a la unidad UCI.
# 153: Paciente 138 llega al hospital a la unidad UCI.
# 153: Paciente 43 es atendido.
# 153: Paciente 44 es atendido.
# 154: Paciente 139 llega al hospital a la unidad UCI.
# 156: Paciente 140 llega al hospital a la unidad Consultorios.
# 157: Al Paciente 39 se le ha dado de alta.
# 158: Al Paciente 38 se le ha dado de alta.
# 158: Paciente 141 llega al hospital a la unidad UCI.
# 158: Paciente 142 llega al hospital a la unidad Consultorios.
# 158: Paciente 143 llega al hospital a la unidad UCI.
# 158: Paciente 144 llega al hospital a la unidad UCI.
# 159: Al Paciente 44 se le asigno una cama y 3 miembro(s) del personal.
# 159: Paciente 145 llega al hospital a la unidad Urgencias.
# 159: Paciente 45 es atendido.
# 161: Al Paciente 33 se le ha dado de alta.
# 162: Al Paciente 43 se le asigno una cama y 1 miembro(s) del personal.
# 162: Paciente 46 es atendido.
# 163: Al Paciente 40 se le ha dado de alta.
# 163: Paciente 146 llega al hospital a la unidad Urgencias.
# 163: Paciente 147 llega al hospital a la unidad Urgencias.
# 163: Paciente 148 llega al hospital a la unidad Urgencias.
# 163: Paciente 149 llega al hospital a la unidad Urgencias.
# 164: Al Paciente 45 se le asigno una cama y 6 miembro(s) del personal.
# 164: Paciente 47 es atendido.
# 166: Al Paciente 42 se le ha dado de alta.
# 166: Al Paciente 46 se le asigno una cama y 6 miembro(s) del personal.
# 166: El Paciente 46 necesita cirugía.
# 166: Paciente 48 es atendido.
# 168: Paciente 150 llega al hospital a la unidad Urgencias.
# 168: Al Paciente 48 se le asigno una cama y 3 miembro(s) del personal.
# 168: El Paciente 48 necesita cirugía.
# 168: Paciente 49 es atendido.
# 169: Al Paciente 47 se le asigno una cama y 3 miembro(s) del personal.
# 169: Paciente 50 es atendido.
# 170: Paciente 151 llega al hospital a la unidad Urgencias.
# 174: Al Paciente 49 se le asigno una cama y 7 miembro(s) del personal.
# 174: El Paciente 49 necesita cirugía.
# 174: Paciente 51 es atendido.
# 175: Paciente 152 llega al hospital a la unidad Urgencias.
# 175: Paciente 153 llega al hospital a la unidad Consultorios.
# 176: Paciente 154 llega al hospital a la unidad Urgencias.
# 176: Paciente 155 llega al hospital a la unidad UCI.
# 176: Paciente 156 llega al hospital a la unidad UCI.
# 176: Paciente 157 llega al hospital a la unidad Urgencias.
# 177: Paciente 158 llega al hospital a la unidad Urgencias.
# 178: Al Paciente 44 se le ha dado de alta.
# 181: Al Paciente 45 se le ha dado de alta.
# 181: Al Paciente 51 se le asigno una cama y 8 miembro(s) del personal.
# 181: Paciente 159 llega al hospital a la unidad UCI.
# 181: Paciente 160 llega al hospital a la unidad Urgencias.
# 181: Paciente 161 llega al hospital a la unidad UCI.
# 181: Paciente 162 llega al hospital a la unidad Urgencias.
# 181: Paciente 163 llega al hospital a la unidad UCI.
# 181: Paciente 52 es atendido.
# 182: Al Paciente 41 se le ha dado de alta.
# 183: Al Paciente 52 se le asigno una cama y 6 miembro(s) del personal.
# 183: Paciente 53 es atendido.
# 185: Al Paciente 50 se le asigno una cama y 1 miembro(s) del personal.
# 185: Paciente 164 llega al hospital a la unidad Urgencias.
# 185: Paciente 165 llega al hospital a la unidad Urgencias.
# 185: Paciente 166 llega al hospital a la unidad Consultorios.
# 185: Paciente 167 llega al hospital a la unidad Urgencias.
# 185: Paciente 168 llega al hospital a la unidad Urgencias.
# 185: Paciente 54 es atendido.
# 186: Al Paciente 43 se le ha dado de alta.
# 186: Al Paciente 53 se le asigno una cama y 5 miembro(s) del personal.
# 186: Paciente 55 es atendido.
# 187: Paciente 169 llega al hospital a la unidad Urgencias.
# 187: Paciente 170 llega al hospital a la unidad Urgencias.
# 189: Paciente 171 llega al hospital a la unidad UCI.
# 189: Paciente 172 llega al hospital a la unidad Urgencias.
# 189: Paciente 173 llega al hospital a la unidad Urgencias.
# 189: Paciente 174 llega al hospital a la unidad Urgencias.
# 189: Paciente 175 llega al hospital a la unidad UCI.
# 190: Al Paciente 50 se le ha dado de alta.
# 191: Al Paciente 51 se le ha dado de alta.
# 191: Al Paciente 55 se le asigno una cama y 6 miembro(s) del personal.
# 191: Paciente 56 es atendido.
# 192: Paciente 176 llega al hospital a la unidad Urgencias.
# 192: Paciente 177 llega al hospital a la unidad Urgencias.
# 192: Paciente 178 llega al hospital a la unidad UCI.
# 192: Paciente 179 llega al hospital a la unidad UCI.
# 193: Al Paciente 53 se le ha dado de alta.
# 195: Al Paciente 47 se le ha dado de alta.
# 197: Paciente 180 llega al hospital a la unidad Urgencias.
# 197: Paciente 181 llega al hospital a la unidad Urgencias.
# 197: Paciente 182 llega al hospital a la unidad Urgencias.
# 197: Paciente 183 llega al hospital a la unidad Urgencias.
# 202: Paciente 184 llega al hospital a la unidad Urgencias.
# 206: Al Paciente 56 se le asigno una cama y 1 miembro(s) del personal.
# 206: Paciente 185 llega al hospital a la unidad Urgencias.
# 206: Paciente 186 llega al hospital a la unidad Urgencias.
# 206: Paciente 57 es atendido.
# 209: Al Paciente 57 se le asigno una cama y 4 miembro(s) del personal.
# 209: El Paciente 57 necesita cirugía.
# 209: Paciente 58 es atendido.
# 210: Al Paciente 54 se le asigno una cama y 1 miembro(s) del personal.
# 210: Paciente 59 es atendido.
# 211: Paciente 187 llega al hospital a la unidad Urgencias.
# 212: Al Paciente 52 se le ha dado de alta.
# 215: Al Paciente 59 se le asigno una cama y 8 miembro(s) del personal.
# 215: Paciente 60 es atendido.
# 216: Paciente 188 llega al hospital a la unidad Consultorios.
# 216: Paciente 189 llega al hospital a la unidad Urgencias.
# 216: Paciente 190 llega al hospital a la unidad Urgencias.
# 217: Paciente 191 llega al hospital a la unidad Consultorios.
# 218: Al Paciente 55 se le ha dado de alta.
# 218: Al Paciente 54 se le ha dado de alta.
# 221: Al Paciente 58 se le asigno una cama y 1 miembro(s) del personal.
# 221: Paciente 61 es atendido.
# 222: Al Paciente 60 se le asigno una cama y 4 miembro(s) del personal.
# 222: El Paciente 60 necesita cirugía.
# 222: Paciente 192 llega al hospital a la unidad Urgencias.
# 222: Paciente 193 llega al hospital a la unidad UCI.
# 222: Paciente 62 es atendido.
# 223: Paciente 194 llega al hospital a la unidad UCI.
# 223: Paciente 195 llega al hospital a la unidad Urgencias.
# 223: Paciente 196 llega al hospital a la unidad Urgencias.
# 223: Paciente 197 llega al hospital a la unidad Consultorios.
# 225: Al Paciente 62 se le asigno una cama y 3 miembro(s) del personal.
# 225: Paciente 63 es atendido.
# 226: El Paciente 46 murió esperando un kit médico.
# 228: Cirugía completada para el Paciente 28.
# 228: Paciente 28 se le ha dado de alta.
# 228: Paciente 198 llega al hospital a la unidad Consultorios.
# 228: Paciente 199 llega al hospital a la unidad Urgencias.
# 228: Paciente 200 llega al hospital a la unidad Urgencias.
# 228: Paciente 201 llega al hospital a la unidad Urgencias.
# 228: Paciente 202 llega al hospital a la unidad UCI.
# 228: El Paciente 48 murió esperando un kit médico.
# 228: Al Paciente 49 se le asignó un kit médico.
# 229: Al Paciente 63 se le asigno una cama y 6 miembro(s) del personal.
# 229: El Paciente 63 necesita cirugía.
# 229: Paciente 64 es atendido.
# 230: Al Paciente 56 se le ha dado de alta.
# 231: Al Paciente 59 se le ha dado de alta.
# 233: Al Paciente 61 se le asigno una cama y 1 miembro(s) del personal.
# 233: Al Paciente 62 se le ha dado de alta.
# 233: Paciente 203 llega al hospital a la unidad Urgencias.
# 233: Paciente 204 llega al hospital a la unidad UCI.
# 233: Paciente 205 llega al hospital a la unidad Urgencias.
# 233: Paciente 206 llega al hospital a la unidad Urgencias.
# 233: Paciente 207 llega al hospital a la unidad UCI.
# 233: Paciente 65 es atendido.
# 235: Al Paciente 64 se le asigno una cama y 8 miembro(s) del personal.
# 235: Paciente 66 es atendido.
# 236: Paciente 208 llega al hospital a la unidad UCI.
# 236: Paciente 209 llega al hospital a la unidad UCI.
# 236: Paciente 210 llega al hospital a la unidad Urgencias.
# 236: Paciente 211 llega al hospital a la unidad Urgencias.
# 236: Paciente 212 llega al hospital a la unidad Consultorios.
# 236: Al Paciente 65 se le asigno una cama y 3 miembro(s) del personal.
# 236: Paciente 67 es atendido.
# 239: Paciente 213 llega al hospital a la unidad Urgencias.
# 242: Al Paciente 67 se le asigno una cama y 7 miembro(s) del personal.
# 242: Paciente 214 llega al hospital a la unidad Urgencias.
# 242: Paciente 215 llega al hospital a la unidad UCI.
# 242: Paciente 216 llega al hospital a la unidad UCI.
# 242: Paciente 68 es atendido.
# 243: Paciente 217 llega al hospital a la unidad Consultorios.
# 244: Paciente 218 llega al hospital a la unidad UCI.
# 244: Paciente 219 llega al hospital a la unidad UCI.
# 244: Paciente 220 llega al hospital a la unidad Urgencias.
# 244: Paciente 221 llega al hospital a la unidad UCI.
# 244: Paciente 222 llega al hospital a la unidad Urgencias.
# 245: Al Paciente 58 se le ha dado de alta.
# 246: Paciente 223 llega al hospital a la unidad Urgencias.
# 246: Paciente 224 llega al hospital a la unidad Urgencias.
# 246: Paciente 225 llega al hospital a la unidad UCI.
# 246: Paciente 226 llega al hospital a la unidad Urgencias.
# 246: Paciente 227 llega al hospital a la unidad Consultorios.
# 247: Al Paciente 61 se le ha dado de alta.
# 247: Al Paciente 65 se le ha dado de alta.
# 247: Paciente 228 llega al hospital a la unidad UCI.
# 247: Paciente 229 llega al hospital a la unidad UCI.
# 248: Al Paciente 68 se le asigno una cama y 8 miembro(s) del personal.
# 248: Paciente 230 llega al hospital a la unidad UCI.
# 248: Paciente 231 llega al hospital a la unidad UCI.
# 248: Paciente 232 llega al hospital a la unidad UCI.
# 248: Paciente 233 llega al hospital a la unidad UCI.
# 248: Paciente 234 llega al hospital a la unidad Consultorios.
# 248: Paciente 69 es atendido.
# 249: Al Paciente 64 se le ha dado de alta.
# 252: Paciente 235 llega al hospital a la unidad Consultorios.
# 252: Paciente 236 llega al hospital a la unidad Urgencias.
# 252: Paciente 237 llega al hospital a la unidad UCI.
# 252: Paciente 238 llega al hospital a la unidad Urgencias.
# 255: Al Paciente 66 se le asigno una cama y 1 miembro(s) del personal.
# 255: Paciente 70 es atendido.
# 257: Paciente 239 llega al hospital a la unidad UCI.
# 257: Paciente 240 llega al hospital a la unidad UCI.
# 257: Paciente 241 llega al hospital a la unidad Urgencias.
# 257: Paciente 242 llega al hospital a la unidad UCI.
# 257: Paciente 243 llega al hospital a la unidad UCI.
# 258: Al Paciente 70 se le asigno una cama y 6 miembro(s) del personal.
# 258: Paciente 71 es atendido.
# 261: Paciente 244 llega al hospital a la unidad UCI.
# 261: Paciente 245 llega al hospital a la unidad UCI.
# 261: Paciente 246 llega al hospital a la unidad Urgencias.
# 261: Paciente 247 llega al hospital a la unidad Urgencias.
# 261: Paciente 248 llega al hospital a la unidad Urgencias.
# 263: Paciente 249 llega al hospital a la unidad UCI.
# 263: Paciente 250 llega al hospital a la unidad Urgencias.
# 263: Paciente 251 llega al hospital a la unidad Urgencias.
# 263: Paciente 252 llega al hospital a la unidad Consultorios.
# 265: Al Paciente 71 se le asigno una cama y 6 miembro(s) del personal.
# 265: El Paciente 71 necesita cirugía.
# 265: Paciente 72 es atendido.
# 266: Al Paciente 72 se le asigno una cama y 7 miembro(s) del personal.
# 266: El Paciente 72 necesita cirugía.
# 266: Paciente 73 es atendido.
# 267: Paciente 253 llega al hospital a la unidad Urgencias.
# 267: Paciente 254 llega al hospital a la unidad Urgencias.
# 267: Paciente 255 llega al hospital a la unidad Consultorios.
# 267: Paciente 256 llega al hospital a la unidad Consultorios.
# 267: Paciente 257 llega al hospital a la unidad UCI.
# 268: Paciente 258 llega al hospital a la unidad UCI.
# 268: Paciente 259 llega al hospital a la unidad Consultorios.
# 269: Al Paciente 69 se le asigno una cama y 1 miembro(s) del personal.
# 269: El Paciente 57 murió esperando un kit médico.
# 269: Paciente 74 es atendido.
# 271: Al Paciente 67 se le ha dado de alta.
# 271: Al Paciente 70 se le ha dado de alta.
# 271: Paciente 260 llega al hospital a la unidad UCI.
# 271: Paciente 261 llega al hospital a la unidad UCI.
# 271: Paciente 262 llega al hospital a la unidad Urgencias.
# 272: Al Paciente 68 se le ha dado de alta.
# 272: Al Paciente 73 se le asigno una cama y 5 miembro(s) del personal.
# 272: Paciente 263 llega al hospital a la unidad Consultorios.
# 272: Paciente 264 llega al hospital a la unidad Urgencias.
# 272: Paciente 265 llega al hospital a la unidad Urgencias.
# 272: Paciente 266 llega al hospital a la unidad Urgencias.
# 272: Paciente 75 es atendido.
# 275: Al Paciente 66 se le ha dado de alta.
# 277: Paciente 267 llega al hospital a la unidad Urgencias.
# 277: Paciente 268 llega al hospital a la unidad Consultorios.
# 277: Paciente 269 llega al hospital a la unidad Urgencias.
# 279: Paciente 270 llega al hospital a la unidad UCI.
# 279: Paciente 271 llega al hospital a la unidad UCI.
# 279: Paciente 272 llega al hospital a la unidad Urgencias.
# 279: Paciente 273 llega al hospital a la unidad UCI.
# 279: Paciente 274 llega al hospital a la unidad Consultorios.
# 282: El Paciente 60 murió esperando un kit médico.
# 283: Paciente 275 llega al hospital a la unidad Urgencias.
# 283: Paciente 276 llega al hospital a la unidad UCI.
# 283: Paciente 277 llega al hospital a la unidad Urgencias.
# 283: Paciente 278 llega al hospital a la unidad Consultorios.
# 283: Paciente 279 llega al hospital a la unidad Urgencias.
# 284: Paciente 280 llega al hospital a la unidad UCI.
# 284: Paciente 281 llega al hospital a la unidad Consultorios.
# 286: Paciente 282 llega al hospital a la unidad UCI.
# 287: Al Paciente 74 se le asigno una cama y 1 miembro(s) del personal.
# 287: Paciente 283 llega al hospital a la unidad Consultorios.
# 287: Paciente 284 llega al hospital a la unidad UCI.
# 287: Paciente 285 llega al hospital a la unidad UCI.
# 287: Paciente 286 llega al hospital a la unidad Urgencias.
# 287: Paciente 76 es atendido.
# 288: Al Paciente 73 se le ha dado de alta.
# 289: Al Paciente 76 se le asigno una cama y 5 miembro(s) del personal.
# 289: El Paciente 63 murió esperando un kit médico.
# 289: Paciente 77 es atendido.
# 292: Al Paciente 69 se le ha dado de alta.
# 292: Paciente 287 llega al hospital a la unidad Urgencias.
# 292: Paciente 288 llega al hospital a la unidad Urgencias.
# 292: Paciente 289 llega al hospital a la unidad Consultorios.
# 293: Al Paciente 77 se le asigno una cama y 4 miembro(s) del personal.
# 293: El Paciente 77 necesita cirugía.
# 293: Paciente 78 es atendido.
# 294: Al Paciente 76 se le ha dado de alta.
# 294: Paciente 290 llega al hospital a la unidad Urgencias.
# 296: Paciente 291 llega al hospital a la unidad Urgencias.
# 297: Al Paciente 75 se le asigno una cama y 1 miembro(s) del personal.
# 297: Al Paciente 78 se le asigno una cama y 4 miembro(s) del personal.
# 297: Paciente 79 es atendido.
# 297: Paciente 80 es atendido.
# 299: Paciente 292 llega al hospital a la unidad Urgencias.
# 299: Paciente 293 llega al hospital a la unidad UCI.
# 299: Paciente 294 llega al hospital a la unidad Urgencias.
# 299: Paciente 295 llega al hospital a la unidad Urgencias.
# 299: Paciente 296 llega al hospital a la unidad Urgencias.
# 299: Al Paciente 80 se le asigno una cama y 6 miembro(s) del personal.
# 299: Paciente 81 es atendido.
# 301: Paciente 297 llega al hospital a la unidad Urgencias.
# 301: Paciente 298 llega al hospital a la unidad Urgencias.
# 301: Paciente 299 llega al hospital a la unidad UCI.
# 301: Paciente 300 llega al hospital a la unidad UCI.
# 303: Al Paciente 79 se le asigno una cama y 8 miembro(s) del personal.
# 303: Paciente 82 es atendido.
# 304: Al Paciente 81 se le asigno una cama y 8 miembro(s) del personal.
# 304: Paciente 83 es atendido.
# 306: Cirugía completada para el Paciente 35.
# 306: Paciente 35 se le ha dado de alta.
# 306: Paciente 301 llega al hospital a la unidad Urgencias.
# 306: Paciente 302 llega al hospital a la unidad Urgencias.
# 306: Paciente 303 llega al hospital a la unidad Urgencias.
# 306: Paciente 304 llega al hospital a la unidad Urgencias.
# 306: Paciente 305 llega al hospital a la unidad Urgencias.
# 306: Al Paciente 71 se le asignó un kit médico.
# 307: Al Paciente 83 se le asigno una cama y 7 miembro(s) del personal.
# 307: Paciente 84 es atendido.
# 308: Paciente 306 llega al hospital a la unidad UCI.
# 309: Al Paciente 74 se le ha dado de alta.
# 311: Al Paciente 84 se le asigno una cama y 3 miembro(s) del personal.
# 311: Paciente 307 llega al hospital a la unidad Urgencias.
# 311: Paciente 308 llega al hospital a la unidad Consultorios.
# 311: Paciente 309 llega al hospital a la unidad Consultorios.
# 311: Paciente 85 es atendido.
# 313: Al Paciente 78 se le ha dado de alta.
# 313: Al Paciente 81 se le ha dado de alta.
# 314: Paciente 310 llega al hospital a la unidad Consultorios.
# 316: Al Paciente 80 se le ha dado de alta.
# 317: Al Paciente 85 se le asigno una cama y 7 miembro(s) del personal.
# 317: Paciente 86 es atendido.
# 319: Paciente 311 llega al hospital a la unidad Urgencias.
# 319: Paciente 312 llega al hospital a la unidad Consultorios.
# 319: Paciente 313 llega al hospital a la unidad Urgencias.
# 319: Paciente 314 llega al hospital a la unidad Urgencias.
# 321: Paciente 315 llega al hospital a la unidad Consultorios.
# 321: Paciente 316 llega al hospital a la unidad Consultorios.
# 324: Paciente 317 llega al hospital a la unidad UCI.
# 324: Paciente 318 llega al hospital a la unidad Urgencias.
# 325: Al Paciente 84 se le ha dado de alta.
# 326: Al Paciente 79 se le ha dado de alta.
# 326: El Paciente 72 murió esperando un kit médico.
# 327: Al Paciente 75 se le ha dado de alta.
# 328: Al Paciente 82 se le asigno una cama y 1 miembro(s) del personal.
# 328: Paciente 87 es atendido.
# 329: Paciente 319 llega al hospital a la unidad Urgencias.
# 329: Paciente 320 llega al hospital a la unidad UCI.
# 329: Paciente 321 llega al hospital a la unidad Urgencias.
# 329: Paciente 322 llega al hospital a la unidad UCI.
# 330: Paciente 323 llega al hospital a la unidad Consultorios.
# 330: Paciente 324 llega al hospital a la unidad UCI.
# 330: Paciente 325 llega al hospital a la unidad Urgencias.
# 330: Paciente 326 llega al hospital a la unidad UCI.
# 330: Paciente 327 llega al hospital a la unidad Urgencias.
# 331: Al Paciente 87 se le asigno una cama y 3 miembro(s) del personal.
# 331: Paciente 328 llega al hospital a la unidad Urgencias.
# 331: Paciente 329 llega al hospital a la unidad Urgencias.
# 331: Paciente 330 llega al hospital a la unidad UCI.
# 331: Paciente 88 es atendido.
# 335: Al Paciente 86 se le asigno una cama y 1 miembro(s) del personal.
# 335: Paciente 331 llega al hospital a la unidad Urgencias.
# 335: Paciente 332 llega al hospital a la unidad Urgencias.
# 335: Paciente 333 llega al hospital a la unidad Urgencias.
# 335: Paciente 334 llega al hospital a la unidad Urgencias.
# 335: Paciente 335 llega al hospital a la unidad Urgencias.
# 335: Paciente 89 es atendido.
# 336: Paciente 336 llega al hospital a la unidad UCI.
# 336: Paciente 337 llega al hospital a la unidad UCI.
# 336: Al Paciente 89 se le asigno una cama y 8 miembro(s) del personal.
# 336: El Paciente 89 necesita cirugía.
# 336: Paciente 90 es atendido.
# 337: Al Paciente 83 se le ha dado de alta.
# 337: Al Paciente 88 se le asigno una cama y 5 miembro(s) del personal.
# 337: Paciente 91 es atendido.
# 338: Paciente 338 llega al hospital a la unidad UCI.
# 338: Paciente 339 llega al hospital a la unidad UCI.
# 338: Paciente 340 llega al hospital a la unidad UCI.
# 338: Paciente 341 llega al hospital a la unidad Urgencias.
# 338: Paciente 342 llega al hospital a la unidad Urgencias.
# 342: Al Paciente 87 se le ha dado de alta.
# 342: Al Paciente 90 se le asigno una cama y 3 miembro(s) del personal.
# 342: Paciente 92 es atendido.
# 343: Paciente 343 llega al hospital a la unidad Urgencias.
# 343: Paciente 344 llega al hospital a la unidad Consultorios.
# 343: Paciente 345 llega al hospital a la unidad Urgencias.
# 344: Al Paciente 85 se le ha dado de alta.
# 346: Paciente 346 llega al hospital a la unidad Consultorios.
# 346: Paciente 347 llega al hospital a la unidad Urgencias.
# 349: Paciente 348 llega al hospital a la unidad Urgencias.
# 349: Paciente 349 llega al hospital a la unidad Urgencias.
# 349: Paciente 350 llega al hospital a la unidad Urgencias.
# 349: Paciente 351 llega al hospital a la unidad Urgencias.
# 350: Al Paciente 92 se le asigno una cama y 1 miembro(s) del personal.
# 350: Paciente 93 es atendido.
# 352: Paciente 352 llega al hospital a la unidad Consultorios.
# 352: Paciente 353 llega al hospital a la unidad Consultorios.
# 352: Paciente 354 llega al hospital a la unidad UCI.
# 352: Paciente 355 llega al hospital a la unidad Urgencias.
# 353: Al Paciente 86 se le ha dado de alta.
# 353: Al Paciente 91 se le asigno una cama y 1 miembro(s) del personal.
# 353: El Paciente 77 murió esperando un kit médico.
# 353: Paciente 94 es atendido.
# 355: Al Paciente 82 se le ha dado de alta.
# 355: Al Paciente 88 se le ha dado de alta.
# 356: Paciente 356 llega al hospital a la unidad Urgencias.
# 356: Paciente 357 llega al hospital a la unidad UCI.
# 356: Paciente 358 llega al hospital a la unidad Consultorios.
# 356: Paciente 359 llega al hospital a la unidad Consultorios.
# 357: Al Paciente 94 se le asigno una cama y 8 miembro(s) del personal.
# 357: Paciente 95 es atendido.
# 360: Paciente 360 llega al hospital a la unidad Consultorios.
# 360: Paciente 361 llega al hospital a la unidad Urgencias.
# 360: Paciente 362 llega al hospital a la unidad Urgencias.
# 360: Paciente 363 llega al hospital a la unidad Urgencias.
# 360: Al Paciente 95 se le asigno una cama y 8 miembro(s) del personal.
# 360: Paciente 96 es atendido.
# 361: Al Paciente 96 se le asigno una cama y 6 miembro(s) del personal.
# 361: Paciente 97 es atendido.
# 363: Paciente 364 llega al hospital a la unidad Urgencias.
# 363: Paciente 365 llega al hospital a la unidad Urgencias.
# 363: Paciente 366 llega al hospital a la unidad Urgencias.
# 363: Paciente 367 llega al hospital a la unidad Urgencias.
# 363: Al Paciente 97 se le asigno una cama y 4 miembro(s) del personal.
# 363: El Paciente 97 necesita cirugía.
# 363: Paciente 98 es atendido.
# 366: Al Paciente 93 se le asigno una cama y 1 miembro(s) del personal.
# 366: Paciente 99 es atendido.
# 367: Paciente 368 llega al hospital a la unidad Urgencias.
# 367: Paciente 369 llega al hospital a la unidad Urgencias.
# 367: Paciente 370 llega al hospital a la unidad UCI.
# 367: Paciente 371 llega al hospital a la unidad Urgencias.
# 367: Paciente 372 llega al hospital a la unidad UCI.
# 367: Al Paciente 98 se le asigno una cama y 5 miembro(s) del personal.
# 367: Paciente 100 es atendido.
# 368: Paciente 373 llega al hospital a la unidad UCI.
# 368: Paciente 374 llega al hospital a la unidad UCI.
# 368: Paciente 375 llega al hospital a la unidad Consultorios.
# 368: Paciente 376 llega al hospital a la unidad Urgencias.
# 371: Al Paciente 90 se le ha dado de alta.
# 372: Al Paciente 96 se le ha dado de alta.
# 372: Al Paciente 99 se le asigno una cama y 7 miembro(s) del personal.
# 372: Paciente 101 es atendido.
# 373: Paciente 377 llega al hospital a la unidad Urgencias.
# 374: Al Paciente 100 se le asigno una cama y 4 miembro(s) del personal.
# 374: Paciente 378 llega al hospital a la unidad Urgencias.
# 374: Paciente 379 llega al hospital a la unidad Consultorios.
# 374: Paciente 380 llega al hospital a la unidad Urgencias.
# 374: Paciente 102 es atendido.
# 375: Al Paciente 91 se le ha dado de alta.
# 375: Al Paciente 94 se le ha dado de alta.
# 377: Paciente 381 llega al hospital a la unidad Urgencias.
# 377: Paciente 382 llega al hospital a la unidad Urgencias.
# 377: Paciente 383 llega al hospital a la unidad UCI.
# 378: Al Paciente 92 se le ha dado de alta.
# 378: Al Paciente 101 se le asigno una cama y 5 miembro(s) del personal.
# 378: Al Paciente 102 se le asigno una cama y 3 miembro(s) del personal.
# 378: Paciente 103 es atendido.
# 378: Paciente 104 es atendido.
# 379: Paciente 384 llega al hospital a la unidad UCI.
# 379: Paciente 385 llega al hospital a la unidad Urgencias.
# 379: Paciente 386 llega al hospital a la unidad UCI.
# 379: Paciente 387 llega al hospital a la unidad Consultorios.
# 379: Paciente 388 llega al hospital a la unidad UCI.
# 380: Al Paciente 99 se le ha dado de alta.
# 383: Al Paciente 95 se le ha dado de alta.
# 383: Paciente 389 llega al hospital a la unidad Urgencias.
# 383: Paciente 390 llega al hospital a la unidad UCI.
# 385: Al Paciente 103 se le asigno una cama y 3 miembro(s) del personal.
# 385: Al Paciente 104 se le asigno una cama y 6 miembro(s) del personal.
# 385: Paciente 391 llega al hospital a la unidad UCI.
# 385: Paciente 105 es atendido.
# 385: Paciente 106 es atendido.
# 386: Cirugía completada para el Paciente 17.
# 386: Paciente 17 se le ha dado de alta.
# 386: Cirugía completada para el Paciente 27.
# 386: Paciente 27 se le ha dado de alta.
# 386: Al Paciente 89 se le asignó un kit médico.
# 386: Al Paciente 97 se le asignó un kit médico.
# 389: Cirugía completada para el Paciente 26.
# 389: Paciente 26 se le ha dado de alta.
# 389: Paciente 392 llega al hospital a la unidad UCI.
# 389: Paciente 393 llega al hospital a la unidad Consultorios.
# 389: Paciente 394 llega al hospital a la unidad Urgencias.
# 389: Paciente 395 llega al hospital a la unidad Urgencias.
# 390: Al Paciente 106 se le asigno una cama y 8 miembro(s) del personal.
# 390: Paciente 396 llega al hospital a la unidad Urgencias.
# 390: Paciente 397 llega al hospital a la unidad Urgencias.
# 390: Paciente 398 llega al hospital a la unidad Urgencias.
# 390: Paciente 107 es atendido.
# 392: Al Paciente 105 se le asigno una cama y 7 miembro(s) del personal.
# 392: Paciente 108 es atendido.
# 393: Al Paciente 98 se le ha dado de alta.
# 393: Al Paciente 100 se le ha dado de alta.
# 393: Al Paciente 107 se le asigno una cama y 8 miembro(s) del personal.
# 393: El Paciente 107 necesita cirugía.
# 393: Paciente 109 es atendido.
# 393: Al Paciente 107 se le asignó un kit médico.
# 394: Cirugía completada para el Paciente 36.
# 394: Paciente 36 se le ha dado de alta.
# 395: Paciente 399 llega al hospital a la unidad Urgencias.
# 395: Paciente 400 llega al hospital a la unidad Consultorios.
# 395: Paciente 401 llega al hospital a la unidad Urgencias.
# 395: Paciente 402 llega al hospital a la unidad UCI.
# 396: Al Paciente 93 se le ha dado de alta.
# 396: Al Paciente 102 se le ha dado de alta.
# 396: Al Paciente 109 se le asigno una cama y 5 miembro(s) del personal.
# 396: El Paciente 109 necesita cirugía.
# 396: Paciente 403 llega al hospital a la unidad Urgencias.
# 396: Paciente 404 llega al hospital a la unidad Urgencias.
# 396: Paciente 405 llega al hospital a la unidad UCI.
# 396: Paciente 406 llega al hospital a la unidad Consultorios.
# 396: Paciente 407 llega al hospital a la unidad Consultorios.
# 396: Paciente 110 es atendido.
# 396: Al Paciente 109 se le asignó un kit médico.
# 397: Al Paciente 108 se le asigno una cama y 6 miembro(s) del personal.
# 397: Paciente 111 es atendido.
# 398: Al Paciente 103 se le ha dado de alta.
# 399: Paciente 408 llega al hospital a la unidad Consultorios.
# 399: Paciente 409 llega al hospital a la unidad Urgencias.
# 399: Paciente 410 llega al hospital a la unidad UCI.
# 399: Paciente 411 llega al hospital a la unidad Consultorios.
# 399: Paciente 412 llega al hospital a la unidad UCI.
# 404: Al Paciente 104 se le ha dado de alta.
# 404: Paciente 413 llega al hospital a la unidad UCI.
# 406: Al Paciente 111 se le asigno una cama y 1 miembro(s) del personal.
# 406: Paciente 112 es atendido.
# 407: Al Paciente 101 se le ha dado de alta.
# 407: Paciente 414 llega al hospital a la unidad Consultorios.
# 408: Al Paciente 112 se le asigno una cama y 3 miembro(s) del personal.
# 408: Paciente 113 es atendido.
# 411: Al Paciente 105 se le ha dado de alta.
# 411: Cirugía completada para el Paciente 109.
# 411: Paciente 109 se le ha dado de alta.
# 412: Paciente 415 llega al hospital a la unidad UCI.
# 412: Paciente 416 llega al hospital a la unidad Consultorios.
# 412: Paciente 417 llega al hospital a la unidad Urgencias.
# 412: Paciente 418 llega al hospital a la unidad UCI.
# 412: Al Paciente 113 se le asigno una cama y 7 miembro(s) del personal.
# 412: Paciente 114 es atendido.
# 413: Al Paciente 108 se le ha dado de alta.
# 413: Paciente 419 llega al hospital a la unidad Urgencias.
# 413: Paciente 420 llega al hospital a la unidad Urgencias.
# 413: Paciente 421 llega al hospital a la unidad Consultorios.
# 414: Al Paciente 106 se le ha dado de alta.
# 414: Al Paciente 110 se le asigno una cama y 1 miembro(s) del personal.
# 414: Paciente 115 es atendido.
# 416: Paciente 422 llega al hospital a la unidad Urgencias.
# 416: Al Paciente 115 se le asigno una cama y 8 miembro(s) del personal.
# 416: Paciente 116 es atendido.
# 418: Al Paciente 114 se le asigno una cama y 3 miembro(s) del personal.
# 418: Paciente 423 llega al hospital a la unidad Urgencias.
# 418: Paciente 424 llega al hospital a la unidad Urgencias.
# 418: Paciente 425 llega al hospital a la unidad UCI.
# 418: Paciente 117 es atendido.
# 419: Paciente 426 llega al hospital a la unidad Consultorios.
# 419: Paciente 427 llega al hospital a la unidad Urgencias.
# 419: Paciente 428 llega al hospital a la unidad UCI.
# 421: Al Paciente 115 se le ha dado de alta.
# 422: Paciente 429 llega al hospital a la unidad Urgencias.
# 422: Paciente 430 llega al hospital a la unidad UCI.
# 422: Paciente 431 llega al hospital a la unidad UCI.
# 423: Al Paciente 117 se le asigno una cama y 6 miembro(s) del personal.
# 423: Paciente 118 es atendido.
# 424: Cirugía completada para el Paciente 71.
# 424: Paciente 71 se le ha dado de alta.
# 425: Al Paciente 118 se le asigno una cama y 7 miembro(s) del personal.
# 425: Paciente 119 es atendido.
# 426: Paciente 432 llega al hospital a la unidad Urgencias.
# 426: Paciente 433 llega al hospital a la unidad Urgencias.
# 428: Paciente 434 llega al hospital a la unidad UCI.
# 428: Paciente 435 llega al hospital a la unidad Urgencias.
# 428: Paciente 436 llega al hospital a la unidad Urgencias.
# 429: Paciente 437 llega al hospital a la unidad Consultorios.
# 431: Al Paciente 113 se le ha dado de alta.
# 432: Al Paciente 116 se le asigno una cama y 1 miembro(s) del personal.
# 432: Al Paciente 119 se le asigno una cama y 1 miembro(s) del personal.
# 432: Paciente 438 llega al hospital a la unidad Urgencias.
# 432: Paciente 439 llega al hospital a la unidad Consultorios.
# 432: Paciente 440 llega al hospital a la unidad Urgencias.
# 432: Paciente 120 es atendido.
# 432: Paciente 121 es atendido.
# 434: Al Paciente 111 se le ha dado de alta.
# 435: Paciente 441 llega al hospital a la unidad Consultorios.
# 435: Paciente 442 llega al hospital a la unidad Urgencias.
# 435: Paciente 443 llega al hospital a la unidad Consultorios.
# 436: Al Paciente 112 se le ha dado de alta.
# 437: Al Paciente 121 se le asigno una cama y 4 miembro(s) del personal.
# 437: Paciente 122 es atendido.
# 438: Al Paciente 120 se le asigno una cama y 6 miembro(s) del personal.
# 438: Paciente 123 es atendido.
# 439: Cirugía completada para el Paciente 89.
# 439: Paciente 89 se le ha dado de alta.
# 439: Al Paciente 110 se le ha dado de alta.
# 439: Paciente 444 llega al hospital a la unidad Urgencias.
# 439: Paciente 445 llega al hospital a la unidad Urgencias.
# 439: Paciente 446 llega al hospital a la unidad Urgencias.
# 439: Al Paciente 123 se le asigno una cama y 8 miembro(s) del personal.
# 439: Paciente 124 es atendido.
# 440: Al Paciente 122 se le asigno una cama y 8 miembro(s) del personal.
# 440: Al Paciente 124 se le asigno una cama y 3 miembro(s) del personal.
# 440: Paciente 125 es atendido.
# 440: Paciente 126 es atendido.
# 441: Paciente 447 llega al hospital a la unidad UCI.
# 441: Paciente 448 llega al hospital a la unidad Urgencias.
# 441: Paciente 449 llega al hospital a la unidad Consultorios.
# 441: Paciente 450 llega al hospital a la unidad UCI.
# 442: Al Paciente 126 se le asigno una cama y 8 miembro(s) del personal.
# 442: Paciente 451 llega al hospital a la unidad UCI.
# 442: Paciente 452 llega al hospital a la unidad Urgencias.
# 442: Paciente 127 es atendido.
# 444: Al Paciente 116 se le ha dado de alta.
# 444: Al Paciente 125 se le asigno una cama y 3 miembro(s) del personal.
# 444: Paciente 128 es atendido.
# 446: Al Paciente 117 se le ha dado de alta.
# 446: Al Paciente 119 se le ha dado de alta.
# 446: Al Paciente 127 se le asigno una cama y 5 miembro(s) del personal.
# 446: Paciente 129 es atendido.
# 447: Paciente 453 llega al hospital a la unidad Urgencias.
# 447: Paciente 454 llega al hospital a la unidad UCI.
# 448: Al Paciente 114 se le ha dado de alta.
# 449: Paciente 455 llega al hospital a la unidad Urgencias.
# 449: Paciente 456 llega al hospital a la unidad Consultorios.
# 449: Paciente 457 llega al hospital a la unidad Consultorios.
# 449: Paciente 458 llega al hospital a la unidad Urgencias.
# 449: Paciente 459 llega al hospital a la unidad Consultorios.
# 451: Al Paciente 118 se le ha dado de alta.
# 451: Al Paciente 122 se le ha dado de alta.
# 451: Al Paciente 129 se le asigno una cama y 6 miembro(s) del personal.
# 451: Paciente 130 es atendido.
# 452: Al Paciente 124 se le ha dado de alta.
# 452: Al Paciente 125 se le ha dado de alta.
# 453: Al Paciente 120 se le ha dado de alta.
# 453: Paciente 460 llega al hospital a la unidad Urgencias.
# 453: Paciente 461 llega al hospital a la unidad UCI.
# 453: Paciente 462 llega al hospital a la unidad UCI.
# 454: Al Paciente 128 se le asigno una cama y 1 miembro(s) del personal.
# 454: Paciente 131 es atendido.
# 455: Al Paciente 130 se le asigno una cama y 7 miembro(s) del personal.
# 455: Paciente 463 llega al hospital a la unidad UCI.
# 455: Paciente 132 es atendido.
# 457: Al Paciente 127 se le ha dado de alta.
# 459: Al Paciente 126 se le ha dado de alta.
# 459: Al Paciente 128 se le ha dado de alta.
# 459: Paciente 464 llega al hospital a la unidad UCI.
# 459: Paciente 465 llega al hospital a la unidad Urgencias.
# 461: Paciente 466 llega al hospital a la unidad UCI.
# 463: Al Paciente 123 se le ha dado de alta.
# 464: Al Paciente 121 se le ha dado de alta.
# 464: Al Paciente 131 se le asigno una cama y 1 miembro(s) del personal.
# 464: Paciente 467 llega al hospital a la unidad Urgencias.
# 464: Paciente 468 llega al hospital a la unidad Urgencias.
# 464: Paciente 469 llega al hospital a la unidad Consultorios.
# 464: Paciente 470 llega al hospital a la unidad Urgencias.
# 464: Paciente 471 llega al hospital a la unidad Urgencias.
# 464: Paciente 133 es atendido.
# 465: Al Paciente 133 se le asigno una cama y 5 miembro(s) del personal.
# 465: Paciente 134 es atendido.
# 466: Al Paciente 134 se le asigno una cama y 5 miembro(s) del personal.
# 466: El Paciente 134 necesita cirugía.
# 466: Paciente 135 es atendido.
# 466: Al Paciente 134 se le asignó un kit médico.
# 467: Al Paciente 129 se le ha dado de alta.
# 469: Paciente 472 llega al hospital a la unidad UCI.
# 470: Al Paciente 132 se le asigno una cama y 1 miembro(s) del personal.
# 470: Paciente 473 llega al hospital a la unidad Urgencias.
# 470: Paciente 474 llega al hospital a la unidad UCI.
# 470: Paciente 475 llega al hospital a la unidad Urgencias.
# 470: Paciente 476 llega al hospital a la unidad Consultorios.
# 470: Paciente 477 llega al hospital a la unidad Urgencias.
# 470: Paciente 136 es atendido.
# 471: Al Paciente 135 se le asigno una cama y 7 miembro(s) del personal.
# 471: Paciente 137 es atendido.
# 474: Paciente 478 llega al hospital a la unidad Consultorios.
# 474: Paciente 479 llega al hospital a la unidad Urgencias.
# 474: Paciente 480 llega al hospital a la unidad UCI.
# 474: Paciente 481 llega al hospital a la unidad Urgencias.
# 475: Al Paciente 136 se le asigno una cama y 5 miembro(s) del personal.
# 475: Paciente 138 es atendido.
# 477: Al Paciente 137 se le asigno una cama y 3 miembro(s) del personal.
# 477: Paciente 482 llega al hospital a la unidad Consultorios.
# 477: Paciente 483 llega al hospital a la unidad Consultorios.
# 477: Paciente 484 llega al hospital a la unidad Consultorios.
# 477: Paciente 485 llega al hospital a la unidad UCI.
# 477: Paciente 486 llega al hospital a la unidad Urgencias.
# 477: Paciente 139 es atendido.
# 478: Paciente 487 llega al hospital a la unidad UCI.
# 478: Paciente 488 llega al hospital a la unidad Consultorios.
# 478: Paciente 489 llega al hospital a la unidad Consultorios.
# 478: Paciente 490 llega al hospital a la unidad Urgencias.
# 478: Paciente 491 llega al hospital a la unidad Consultorios.
# 479: Cirugía completada para el Paciente 37.
# 479: Paciente 37 se le ha dado de alta.
# 479: Al Paciente 130 se le ha dado de alta.

# %% [markdown]
# # 4. Recolección de Datos

# %% [markdown]
# ## Preguntas a responder:
# 1. ¿Cuál fue el tiempo promedio de espera por unidad?
#
# 2. ¿Qué unidad estuvo más congestionada?
#
# 3. ¿Cuántos pacientes no fueron atendidos por falta de recursos?
#
# 4. ¿Cuál fue el total de pacientes atendidos?
#
# 5. ¿Cuál es la cantidad y  % de pacientes que vienen a cada unidad?
#
# 6. ¿Qué impacto tuvo cambiar el número de recepcionistas o personal médico?

# %% [markdown]
# ### Construcción del dataframe de perfil de paciente

# %%
lista_pacientes = []

def registrar_paciente(paciente_id, unidad, cirugia,alcanzo_cama):
    lista_pacientes.append({
        "id": paciente_id,
        "unidad": unidad,
        "cirugia": cirugia,
        "alcanzo_cama": alcanzo_cama
    })

# %%
for p in simulacion.pacientes:
    registrar_paciente(p.id, p.unidad.nombre, p.cirugia, p.alcanzo_cama)

dfPacientes = pd.DataFrame(lista_pacientes)
dfPacientes
# Out:
#       id        unidad  cirugia  alcanzo_cama
# 0      1           UCI    False          True
# 1      2     Urgencias    False          True
# 2      3  Consultorios    False          True
# 3      4  Consultorios    False          True
# 4      5     Urgencias     True          True
# ..   ...           ...      ...           ...
# 486  487           UCI    False         False
# 487  488  Consultorios    False         False
# 488  489  Consultorios    False         False
# 489  490     Urgencias     True         False
# 490  491  Consultorios    False         False
#
# [491 rows x 4 columns]

# %% [markdown]
# ### Construcción del dataframe de eventos

# %%
lista_eventos = []
for p in simulacion.pacientes:
    lista_eventos.append( p.eventos )

dfeventos = pd.concat(lista_eventos)
dfeventos = dfeventos.reset_index()
dfeventos.drop( ["index"], axis=1, inplace=True )

dfeventos
# Out:
#       id                    evento  time
# 0      1                   LLEGADA     2
# 1      1                  ATENDIDO     2
# 2      1  ASIGNACION_CAMA_PERSONAL     7
# 3      1                      ALTA    29
# 4      2                   LLEGADA     2
# ..   ...                       ...   ...
# 905  487                   LLEGADA   478
# 906  488                   LLEGADA   478
# 907  489                   LLEGADA   478
# 908  490                   LLEGADA   478
# 909  491                   LLEGADA   478
#
# [910 rows x 3 columns]

# %%
dfPacientes.loc[ dfPacientes["id"] == 1 , : ]
# Out:
#    id unidad  cirugia  alcanzo_cama
# 0   1    UCI    False          True

# %%
dfeventos.loc[ dfeventos["id"] == 1 , : ]
# Out:
#    id                    evento  time
# 0   1                   LLEGADA     2
# 1   1                  ATENDIDO     2
# 2   1  ASIGNACION_CAMA_PERSONAL     7
# 3   1                      ALTA    29

# %% [markdown]
# ## 1. ¿Cuál fue el tiempo promedio de espera por unidad?

# %%
dfeventos["lag_time"] = dfeventos.groupby("id")["time"].shift(1)

# %%
# Filtramos y calculamos el tiempo de espera
df1 = dfeventos.loc[dfeventos["evento"] == "ATENDIDO", :].copy()
df1["tiempo_espera"] = df1["time"] - df1["lag_time"]

# Merge con la info de pacientes (asegúrate de que 'id' esté en ambos)
df_merged = df1.merge(dfPacientes, on="id", how="inner")

# Agrupamos por unidad y calculamos el promedio
resultado = (
    df_merged
    .groupby("unidad")
    .agg({"tiempo_espera": "mean"})
)

print(resultado)
# Out:
#               tiempo_espera
# unidad
# Consultorios     168.100000
# UCI              195.460000
# Urgencias        168.016949

# %% [markdown]
# ## 2. ¿Qué unidad estuvo más congestionada?

# %%
# Nombre de la unidad con mayor espera
unidad_max = resultado["tiempo_espera"].idxmax()

# Valor de la espera media más alta
espera_max = resultado["tiempo_espera"].max()
print (f'La unidad más congestionada basandonos en su tiempo medio de atención es {unidad_max} \ncon un tiempo de espera de {espera_max}')
# Out:
# La unidad más congestionada basandonos en su tiempo medio de atención es UCI
# con un tiempo de espera de 195.46

# %% [markdown]
# ## 3. ¿Cuántos pacientes no fueron atendidos por falta de recursos?

# %%
# 1. Pacientes totales que intentaron ser atendidos
todos = set(dfeventos["id"].unique())

# 2. Pacientes que sí consiguieron cama/personal
con_cama = set(dfeventos.loc[dfeventos["evento"] == "ASIGNACION_CAMA_PERSONAL", "id"].unique())

# 3. Pacientes que nunca obtuvieron cama
sin_cama = todos - con_cama

# 4. Pacientes que murieron esperando kit (sin haberse asignado uno)
muertes = set(dfeventos.loc[dfeventos["evento"] == "MUERTE", "id"].unique())
con_kit = set(dfeventos.loc[dfeventos["evento"] == "ASIGNACION_KIT", "id"].unique())
muertes_por_kit = muertes - con_kit

print(f"Pacientes sin cama asignada: {len(sin_cama)}")
print(f"Pacientes que murieron por falta de kits: {len(muertes_por_kit)}")
print(f"Total no atendidos por falta de recursos: {len(sin_cama) + len(muertes_por_kit)}")
# Out:
# Pacientes sin cama asignada: 354
# Pacientes que murieron por falta de kits: 7
# Total no atendidos por falta de recursos: 361

# %% [markdown]
# ### 4. ¿Cuál fue el total de pacientes atentidos y cuantos quedaron en recepción?

# %%
# Filtrar eventos de tipo 'ATENDIDO'
df_atendidos = dfeventos[dfeventos["evento"] == "ATENDIDO"]

# Contar cuántos pacientes únicos fueron atendidos
total_atendidos = df_atendidos["id"].nunique()

print(f"Total de pacientes atendidos: {total_atendidos}")
print(f"Total de pacientes esperando en recepción o cama: {(len(todos)-total_atendidos)
}")
# Out:
# Total de pacientes atendidos: 139
# Total de pacientes esperando en recepción o cama: 352

# %% [markdown]
# ### 5. ¿Cuál es la cantidad y % de pacientes que vienen a cada unidad?

# %%
df_unique = dfPacientes[['id', 'unidad']].drop_duplicates()


df_stats = (
    df_unique['unidad']
    .value_counts()
    .rename_axis('unidad')
    .reset_index(name='total')
)
df_stats['porcentaje'] = df_stats['total'] / df_stats['total'].sum() * 100

print(df_stats)
# Out:
#          unidad  total  porcentaje
# 0     Urgencias    238   48.472505
# 1           UCI    155   31.568228
# 2  Consultorios     98   19.959267

# %% [markdown]
# ## 5.¿Qué impacto tuvo cambiar el número de recepcionistas o personal médico?

# %% [markdown]
# ### Aumento de recepcionistas

# %%
env2 = simpy.Environment()
unidades_settings = [
    {"nombre": "Urgencias", "num_camas": 20, "personal": 30, "num_kits_medicos": 8},
    {"nombre": "UCI", "num_camas": 35, "personal": 25, "num_kits_medicos": 1},
    {"nombre": "Consultorios", "num_camas": 10, "personal": 8, "num_kits_medicos": 1}
]
num_recepcionistas = 6

random.seed(111)

simulacion2 = Simulation(env2, unidades_settings, num_recepcionistas)
env2.run(until=60*8)
# Out:
# 2: Paciente 1 llega al hospital a la unidad UCI.
# 2: Paciente 2 llega al hospital a la unidad Urgencias.
# 2: Paciente 3 llega al hospital a la unidad UCI.
# 2: Paciente 1 es atendido.
# 2: Paciente 2 es atendido.
# 2: Paciente 3 es atendido.
# 4: Paciente 4 llega al hospital a la unidad Consultorios.
# 4: Paciente 5 llega al hospital a la unidad Consultorios.
# 4: Al Paciente 2 se le asigno una cama y 6 miembro(s) del personal.
# 4: Paciente 4 es atendido.
# 4: Paciente 5 es atendido.
# 8: Al Paciente 3 se le asigno una cama y 7 miembro(s) del personal.
# 8: Paciente 6 llega al hospital a la unidad Urgencias.
# 8: Paciente 7 llega al hospital a la unidad UCI.
# 8: Paciente 8 llega al hospital a la unidad Urgencias.
# 8: Paciente 9 llega al hospital a la unidad UCI.
# 8: Paciente 6 es atendido.
# 8: Paciente 7 es atendido.
# 8: Paciente 8 es atendido.
# 9: Al Paciente 1 se le asigno una cama y 6 miembro(s) del personal.
# 9: Paciente 9 es atendido.
# 11: Paciente 10 llega al hospital a la unidad Urgencias.
# 11: Paciente 11 llega al hospital a la unidad UCI.
# 11: Al Paciente 8 se le asigno una cama y 8 miembro(s) del personal.
# 11: Paciente 10 es atendido.
# 12: Al Paciente 9 se le asigno una cama y 3 miembro(s) del personal.
# 12: Paciente 11 es atendido.
# 14: Al Paciente 6 se le asigno una cama y 6 miembro(s) del personal.
# 15: Al Paciente 7 se le asigno una cama y 4 miembro(s) del personal.
# 15: Paciente 12 llega al hospital a la unidad UCI.
# 15: Paciente 13 llega al hospital a la unidad Urgencias.
# 15: Paciente 14 llega al hospital a la unidad UCI.
# 15: Paciente 15 llega al hospital a la unidad Consultorios.
# 15: Al Paciente 11 se le asigno una cama y 3 miembro(s) del personal.
# 15: Paciente 12 es atendido.
# 15: Paciente 13 es atendido.
# 15: Paciente 14 es atendido.
# 16: Al Paciente 5 se le asigno una cama y 1 miembro(s) del personal.
# 16: Al Paciente 12 se le asigno una cama y 7 miembro(s) del personal.
# 16: Paciente 15 es atendido.
# 18: Al Paciente 4 se le asigno una cama y 1 miembro(s) del personal.
# 18: Al Paciente 8 se le ha dado de alta.
# 18: Al Paciente 10 se le asigno una cama y 6 miembro(s) del personal.
# 18: Paciente 16 llega al hospital a la unidad Consultorios.
# 18: Paciente 17 llega al hospital a la unidad Urgencias.
# 18: Paciente 18 llega al hospital a la unidad Urgencias.
# 18: Paciente 19 llega al hospital a la unidad Consultorios.
# 18: Paciente 16 es atendido.
# 18: Paciente 17 es atendido.
# 18: Paciente 18 es atendido.
# 19: Al Paciente 13 se le asigno una cama y 3 miembro(s) del personal.
# 19: El Paciente 13 necesita cirugía.
# 19: Paciente 19 es atendido.
# 19: Al Paciente 13 se le asignó un kit médico.
# 21: Al Paciente 14 se le asigno una cama y 8 miembro(s) del personal.
# 22: Al Paciente 6 se le ha dado de alta.
# 22: Al Paciente 17 se le asigno una cama y 4 miembro(s) del personal.
# 23: Paciente 20 llega al hospital a la unidad UCI.
# 23: Paciente 20 es atendido.
# 24: Al Paciente 18 se le asigno una cama y 3 miembro(s) del personal.
# 24: El Paciente 18 necesita cirugía.
# 24: Al Paciente 18 se le asignó un kit médico.
# 25: Al Paciente 20 se le asigno una cama y 8 miembro(s) del personal.
# 26: Al Paciente 2 se le ha dado de alta.
# 26: Paciente 21 llega al hospital a la unidad UCI.
# 26: Paciente 22 llega al hospital a la unidad Consultorios.
# 26: Paciente 21 es atendido.
# 26: Paciente 22 es atendido.
# 27: Al Paciente 11 se le ha dado de alta.
# 28: Paciente 23 llega al hospital a la unidad Urgencias.
# 28: Paciente 24 llega al hospital a la unidad Urgencias.
# 28: Paciente 25 llega al hospital a la unidad UCI.
# 28: Paciente 26 llega al hospital a la unidad Urgencias.
# 28: Paciente 23 es atendido.
# 29: Al Paciente 1 se le ha dado de alta.
# 30: Al Paciente 7 se le ha dado de alta.
# 30: Al Paciente 16 se le asigno una cama y 1 miembro(s) del personal.
# 30: Paciente 27 llega al hospital a la unidad Urgencias.
# 30: Paciente 28 llega al hospital a la unidad Urgencias.
# 30: Paciente 29 llega al hospital a la unidad UCI.
# 30: Paciente 24 es atendido.
# 32: Al Paciente 15 se le asigno una cama y 1 miembro(s) del personal.
# 32: Paciente 25 es atendido.
# 33: Al Paciente 9 se le ha dado de alta.
# 33: Al Paciente 21 se le asigno una cama y 7 miembro(s) del personal.
# 33: Al Paciente 23 se le asigno una cama y 4 miembro(s) del personal.
# 33: Al Paciente 25 se le asigno una cama y 8 miembro(s) del personal.
# 33: Paciente 26 es atendido.
# 33: Paciente 27 es atendido.
# 33: Paciente 28 es atendido.
# 34: Al Paciente 3 se le ha dado de alta.
# 34: Paciente 30 llega al hospital a la unidad Urgencias.
# 34: Paciente 31 llega al hospital a la unidad Consultorios.
# 34: Paciente 32 llega al hospital a la unidad Consultorios.
# 34: Paciente 33 llega al hospital a la unidad Consultorios.
# 35: Al Paciente 26 se le asigno una cama y 5 miembro(s) del personal.
# 35: El Paciente 26 necesita cirugía.
# 35: Paciente 29 es atendido.
# 35: Al Paciente 26 se le asignó un kit médico.
# 37: Al Paciente 5 se le ha dado de alta.
# 37: Al Paciente 24 se le asigno una cama y 3 miembro(s) del personal.
# 37: El Paciente 24 necesita cirugía.
# 37: Al Paciente 29 se le asigno una cama y 6 miembro(s) del personal.
# 37: Paciente 30 es atendido.
# 37: Al Paciente 24 se le asignó un kit médico.
# 37: Paciente 31 es atendido.
# 38: Al Paciente 10 se le ha dado de alta.
# 38: Al Paciente 27 se le asigno una cama y 4 miembro(s) del personal.
# 38: Al Paciente 28 se le asigno una cama y 8 miembro(s) del personal.
# 38: El Paciente 28 necesita cirugía.
# 38: Paciente 32 es atendido.
# 38: Paciente 33 es atendido.
# 38: Al Paciente 28 se le asignó un kit médico.
# 39: Paciente 34 llega al hospital a la unidad UCI.
# 39: Paciente 35 llega al hospital a la unidad Urgencias.
# 39: Paciente 36 llega al hospital a la unidad UCI.
# 39: Paciente 37 llega al hospital a la unidad UCI.
# 40: Al Paciente 19 se le asigno una cama y 1 miembro(s) del personal.
# 40: Al Paciente 30 se le asigno una cama y 3 miembro(s) del personal.
# 40: El Paciente 30 necesita cirugía.
# 40: Paciente 34 es atendido.
# 40: Paciente 35 es atendido.
# 40: Al Paciente 30 se le asignó un kit médico.
# 41: Al Paciente 23 se le ha dado de alta.
# 42: Al Paciente 12 se le ha dado de alta.
# 42: Paciente 38 llega al hospital a la unidad Consultorios.
# 42: Paciente 39 llega al hospital a la unidad Urgencias.
# 42: Paciente 40 llega al hospital a la unidad Consultorios.
# 42: Paciente 41 llega al hospital a la unidad UCI.
# 42: Paciente 42 llega al hospital a la unidad UCI.
# 42: Al Paciente 34 se le asigno una cama y 3 miembro(s) del personal.
# 42: Paciente 36 es atendido.
# 43: Al Paciente 14 se le ha dado de alta.
# 43: Paciente 43 llega al hospital a la unidad UCI.
# 43: Paciente 44 llega al hospital a la unidad Consultorios.
# 43: Paciente 45 llega al hospital a la unidad UCI.
# 44: Al Paciente 35 se le asigno una cama y 4 miembro(s) del personal.
# 44: Paciente 37 es atendido.
# 45: Al Paciente 17 se le ha dado de alta.
# 45: Al Paciente 36 se le asigno una cama y 7 miembro(s) del personal.
# 45: Paciente 38 es atendido.
# 46: Al Paciente 4 se le ha dado de alta.
# 46: Al Paciente 19 se le ha dado de alta.
# 46: Paciente 46 llega al hospital a la unidad UCI.
# 46: Paciente 47 llega al hospital a la unidad Urgencias.
# 46: Paciente 48 llega al hospital a la unidad Urgencias.
# 47: Al Paciente 31 se le asigno una cama y 1 miembro(s) del personal.
# 47: Al Paciente 33 se le asigno una cama y 1 miembro(s) del personal.
# 47: Paciente 39 es atendido.
# 47: Paciente 40 es atendido.
# 48: Al Paciente 15 se le ha dado de alta.
# 48: Al Paciente 34 se le ha dado de alta.
# 50: Al Paciente 22 se le asigno una cama y 1 miembro(s) del personal.
# 50: Paciente 49 llega al hospital a la unidad Urgencias.
# 50: Paciente 50 llega al hospital a la unidad Urgencias.
# 50: Paciente 51 llega al hospital a la unidad Urgencias.
# 50: Paciente 52 llega al hospital a la unidad Consultorios.
# 50: Paciente 53 llega al hospital a la unidad UCI.
# 50: Paciente 41 es atendido.
# 51: Al Paciente 25 se le ha dado de alta.
# 51: Al Paciente 32 se le asigno una cama y 1 miembro(s) del personal.
# 51: Al Paciente 37 se le asigno una cama y 8 miembro(s) del personal.
# 51: Paciente 42 es atendido.
# 51: Paciente 43 es atendido.
# 52: Al Paciente 20 se le ha dado de alta.
# 52: Al Paciente 39 se le asigno una cama y 7 miembro(s) del personal.
# 52: El Paciente 39 necesita cirugía.
# 52: Al Paciente 42 se le asigno una cama y 7 miembro(s) del personal.
# 52: Paciente 44 es atendido.
# 52: Al Paciente 39 se le asignó un kit médico.
# 52: Paciente 45 es atendido.
# 53: Al Paciente 16 se le ha dado de alta.
# 54: Paciente 54 llega al hospital a la unidad Urgencias.
# 54: Paciente 55 llega al hospital a la unidad Urgencias.
# 54: Paciente 56 llega al hospital a la unidad UCI.
# 54: Paciente 57 llega al hospital a la unidad Urgencias.
# 55: Al Paciente 35 se le ha dado de alta.
# 55: Al Paciente 41 se le asigno una cama y 8 miembro(s) del personal.
# 55: Paciente 46 es atendido.
# 56: Al Paciente 21 se le ha dado de alta.
# 56: Al Paciente 27 se le ha dado de alta.
# 57: Al Paciente 43 se le asigno una cama y 5 miembro(s) del personal.
# 57: Al Paciente 45 se le asigno una cama y 8 miembro(s) del personal.
# 57: Al Paciente 46 se le asigno una cama y 7 miembro(s) del personal.
# 57: Paciente 47 es atendido.
# 57: Paciente 48 es atendido.
# 57: Paciente 49 es atendido.
# 59: Al Paciente 40 se le asigno una cama y 1 miembro(s) del personal.
# 59: Paciente 58 llega al hospital a la unidad Urgencias.
# 59: Paciente 59 llega al hospital a la unidad Urgencias.
# 59: Paciente 60 llega al hospital a la unidad Urgencias.
# 59: Paciente 61 llega al hospital a la unidad UCI.
# 59: Paciente 62 llega al hospital a la unidad Consultorios.
# 59: Al Paciente 47 se le asigno una cama y 3 miembro(s) del personal.
# 59: Paciente 50 es atendido.
# 59: Paciente 51 es atendido.
# 60: Al Paciente 33 se le ha dado de alta.
# 62: Al Paciente 29 se le ha dado de alta.
# 62: Al Paciente 32 se le ha dado de alta.
# 62: Al Paciente 50 se le asigno una cama y 6 miembro(s) del personal.
# 62: Al Paciente 51 se le asigno una cama y 5 miembro(s) del personal.
# 62: El Paciente 51 necesita cirugía.
# 62: Paciente 52 es atendido.
# 62: Paciente 53 es atendido.
# 62: Al Paciente 51 se le asignó un kit médico.
# 63: Al Paciente 31 se le ha dado de alta.
# 63: Al Paciente 48 se le asigno una cama y 3 miembro(s) del personal.
# 63: El Paciente 48 necesita cirugía.
# 63: Paciente 63 llega al hospital a la unidad Urgencias.
# 63: Paciente 64 llega al hospital a la unidad Urgencias.
# 63: Paciente 65 llega al hospital a la unidad Urgencias.
# 63: Paciente 66 llega al hospital a la unidad Urgencias.
# 63: Paciente 67 llega al hospital a la unidad UCI.
# 63: Paciente 54 es atendido.
# 64: Al Paciente 43 se le ha dado de alta.
# 64: Al Paciente 49 se le asigno una cama y 5 miembro(s) del personal.
# 64: Paciente 55 es atendido.
# 65: Al Paciente 44 se le asigno una cama y 1 miembro(s) del personal.
# 65: Al Paciente 53 se le asigno una cama y 3 miembro(s) del personal.
# 65: Paciente 56 es atendido.
# 65: Paciente 57 es atendido.
# 66: Al Paciente 54 se le asigno una cama y 4 miembro(s) del personal.
# 66: El Paciente 54 necesita cirugía.
# 66: Al Paciente 56 se le asigno una cama y 7 miembro(s) del personal.
# 66: Paciente 58 es atendido.
# 66: Paciente 59 es atendido.
# 67: Al Paciente 22 se le ha dado de alta.
# 68: Al Paciente 36 se le ha dado de alta.
# 68: Paciente 68 llega al hospital a la unidad UCI.
# 68: Paciente 69 llega al hospital a la unidad Urgencias.
# 69: Al Paciente 38 se le asigno una cama y 1 miembro(s) del personal.
# 69: Al Paciente 52 se le asigno una cama y 1 miembro(s) del personal.
# 69: Al Paciente 57 se le asigno una cama y 7 miembro(s) del personal.
# 69: Al Paciente 59 se le asigno una cama y 4 miembro(s) del personal.
# 69: Paciente 60 es atendido.
# 69: Paciente 61 es atendido.
# 69: Paciente 62 es atendido.
# 69: Paciente 63 es atendido.
# 70: Al Paciente 55 se le asigno una cama y 3 miembro(s) del personal.
# 70: Al Paciente 60 se le asigno una cama y 8 miembro(s) del personal.
# 70: El Paciente 60 necesita cirugía.
# 70: Paciente 64 es atendido.
# 70: Paciente 65 es atendido.
# 72: Cirugía completada para el Paciente 39.
# 72: Paciente 39 se le ha dado de alta.
# 72: Al Paciente 46 se le ha dado de alta.
# 72: Al Paciente 40 se le ha dado de alta.
# 72: Al Paciente 58 se le asigno una cama y 4 miembro(s) del personal.
# 72: El Paciente 58 necesita cirugía.
# 72: Al Paciente 64 se le asigno una cama y 6 miembro(s) del personal.
# 72: El Paciente 64 necesita cirugía.
# 72: Paciente 66 es atendido.
# 72: Al Paciente 48 se le asignó un kit médico.
# 72: Paciente 67 es atendido.
# 73: Paciente 70 llega al hospital a la unidad UCI.
# 73: Paciente 71 llega al hospital a la unidad UCI.
# 73: Paciente 72 llega al hospital a la unidad Urgencias.
# 73: Paciente 73 llega al hospital a la unidad Urgencias.
# 74: Al Paciente 37 se le ha dado de alta.
# 74: Al Paciente 44 se le ha dado de alta.
# 75: Al Paciente 47 se le ha dado de alta.
# 75: Al Paciente 61 se le asigno una cama y 5 miembro(s) del personal.
# 75: Al Paciente 63 se le asigno una cama y 6 miembro(s) del personal.
# 75: El Paciente 63 necesita cirugía.
# 75: Paciente 68 es atendido.
# 75: Paciente 69 es atendido.
# 76: Al Paciente 66 se le asigno una cama y 6 miembro(s) del personal.
# 76: Paciente 70 es atendido.
# 77: Al Paciente 65 se le asigno una cama y 6 miembro(s) del personal.
# 77: Paciente 74 llega al hospital a la unidad Consultorios.
# 77: Paciente 75 llega al hospital a la unidad UCI.
# 77: Paciente 76 llega al hospital a la unidad UCI.
# 77: Paciente 71 es atendido.
# 78: Al Paciente 70 se le asigno una cama y 8 miembro(s) del personal.
# 78: Paciente 72 es atendido.
# 79: Al Paciente 41 se le ha dado de alta.
# 79: Al Paciente 67 se le asigno una cama y 6 miembro(s) del personal.
# 79: Al Paciente 68 se le asigno una cama y 6 miembro(s) del personal.
# 79: Paciente 73 es atendido.
# 79: Paciente 74 es atendido.
# 80: Paciente 77 llega al hospital a la unidad Urgencias.
# 80: Paciente 78 llega al hospital a la unidad UCI.
# 80: Al Paciente 71 se le asigno una cama y 7 miembro(s) del personal.
# 80: Paciente 75 es atendido.
# 81: Al Paciente 69 se le asigno una cama y 5 miembro(s) del personal.
# 81: Paciente 76 es atendido.
# 82: Al Paciente 42 se le ha dado de alta.
# 82: Al Paciente 72 se le asigno una cama y 8 miembro(s) del personal.
# 82: El Paciente 72 necesita cirugía.
# 82: Al Paciente 75 se le asigno una cama y 6 miembro(s) del personal.
# 82: Paciente 77 es atendido.
# 82: Paciente 78 es atendido.
# 83: Al Paciente 49 se le ha dado de alta.
# 83: Paciente 79 llega al hospital a la unidad Consultorios.
# 83: Paciente 80 llega al hospital a la unidad Urgencias.
# 83: Paciente 81 llega al hospital a la unidad UCI.
# 83: Paciente 82 llega al hospital a la unidad Urgencias.
# 83: Paciente 83 llega al hospital a la unidad Urgencias.
# 84: Al Paciente 50 se le ha dado de alta.
# 84: Al Paciente 61 se le ha dado de alta.
# 85: Al Paciente 56 se le ha dado de alta.
# 85: Al Paciente 77 se le asigno una cama y 8 miembro(s) del personal.
# 85: El Paciente 77 necesita cirugía.
# 85: Paciente 84 llega al hospital a la unidad Urgencias.
# 85: Paciente 79 es atendido.
# 86: Al Paciente 45 se le ha dado de alta.
# 86: Al Paciente 73 se le asigno una cama y 6 miembro(s) del personal.
# 86: El Paciente 73 necesita cirugía.
# 86: Paciente 85 llega al hospital a la unidad UCI.
# 86: Paciente 86 llega al hospital a la unidad UCI.
# 86: Paciente 80 es atendido.
# 87: Al Paciente 76 se le asigno una cama y 4 miembro(s) del personal.
# 87: Al Paciente 78 se le asigno una cama y 7 miembro(s) del personal.
# 87: Paciente 87 llega al hospital a la unidad Consultorios.
# 87: Paciente 81 es atendido.
# 87: Paciente 82 es atendido.
# 89: Al Paciente 71 se le ha dado de alta.
# 89: Paciente 88 llega al hospital a la unidad UCI.
# 89: Paciente 89 llega al hospital a la unidad UCI.
# 89: Paciente 90 llega al hospital a la unidad Urgencias.
# 89: Paciente 91 llega al hospital a la unidad Urgencias.
# 89: Paciente 92 llega al hospital a la unidad UCI.
# 90: Al Paciente 38 se le ha dado de alta.
# 90: Al Paciente 80 se le asigno una cama y 4 miembro(s) del personal.
# 90: El Paciente 80 necesita cirugía.
# 90: Paciente 83 es atendido.
# 91: Al Paciente 65 se le ha dado de alta.
# 92: Al Paciente 81 se le asigno una cama y 6 miembro(s) del personal.
# 92: Paciente 84 es atendido.
# 93: Al Paciente 53 se le ha dado de alta.
# 93: Al Paciente 62 se le asigno una cama y 1 miembro(s) del personal.
# 93: Paciente 93 llega al hospital a la unidad Consultorios.
# 93: Paciente 94 llega al hospital a la unidad UCI.
# 93: Paciente 95 llega al hospital a la unidad Urgencias.
# 93: Paciente 96 llega al hospital a la unidad Consultorios.
# 93: Paciente 97 llega al hospital a la unidad UCI.
# 93: Paciente 85 es atendido.
# 94: Al Paciente 52 se le ha dado de alta.
# 94: Al Paciente 76 se le ha dado de alta.
# 94: Al Paciente 82 se le asigno una cama y 6 miembro(s) del personal.
# 94: Paciente 98 llega al hospital a la unidad Urgencias.
# 94: Al Paciente 85 se le asigno una cama y 7 miembro(s) del personal.
# 94: Paciente 86 es atendido.
# 94: Paciente 87 es atendido.
# 95: Al Paciente 79 se le asigno una cama y 1 miembro(s) del personal.
# 95: Al Paciente 83 se le asigno una cama y 3 miembro(s) del personal.
# 95: Al Paciente 84 se le asigno una cama y 8 miembro(s) del personal.
# 95: El Paciente 84 necesita cirugía.
# 95: Paciente 88 es atendido.
# 95: Paciente 89 es atendido.
# 95: Paciente 90 es atendido.
# 96: Paciente 99 llega al hospital a la unidad UCI.
# 96: Paciente 100 llega al hospital a la unidad Urgencias.
# 96: Paciente 101 llega al hospital a la unidad Urgencias.
# 96: Paciente 102 llega al hospital a la unidad UCI.
# 96: Al Paciente 89 se le asigno una cama y 8 miembro(s) del personal.
# 96: Al Paciente 90 se le asigno una cama y 4 miembro(s) del personal.
# 96: Paciente 91 es atendido.
# 96: Paciente 92 es atendido.
# 97: Al Paciente 75 se le ha dado de alta.
# 97: Paciente 103 llega al hospital a la unidad Urgencias.
# 97: Paciente 104 llega al hospital a la unidad Consultorios.
# 97: Paciente 105 llega al hospital a la unidad Consultorios.
# 97: Paciente 106 llega al hospital a la unidad UCI.
# 97: Paciente 107 llega al hospital a la unidad Urgencias.
# 98: Al Paciente 57 se le ha dado de alta.
# 98: Al Paciente 66 se le ha dado de alta.
# 98: Al Paciente 92 se le asigno una cama y 6 miembro(s) del personal.
# 98: Paciente 93 es atendido.
# 99: Al Paciente 59 se le ha dado de alta.
# 99: Al Paciente 68 se le ha dado de alta.
# 99: Al Paciente 69 se le ha dado de alta.
# 100: Al Paciente 55 se le ha dado de alta.
# 100: Al Paciente 86 se le asigno una cama y 8 miembro(s) del personal.
# 100: Paciente 94 es atendido.
# 101: Al Paciente 88 se le asigno una cama y 7 miembro(s) del personal.
# 101: Paciente 108 llega al hospital a la unidad Consultorios.
# 101: Paciente 109 llega al hospital a la unidad Urgencias.
# 101: Paciente 110 llega al hospital a la unidad Urgencias.
# 101: Paciente 111 llega al hospital a la unidad Urgencias.
# 101: Paciente 112 llega al hospital a la unidad Urgencias.
# 101: Paciente 95 es atendido.
# 102: Al Paciente 81 se le ha dado de alta.
# 102: Al Paciente 79 se le ha dado de alta.
# 102: Al Paciente 89 se le ha dado de alta.
# 102: Al Paciente 95 se le asigno una cama y 7 miembro(s) del personal.
# 102: Paciente 96 es atendido.
# 103: Al Paciente 91 se le asigno una cama y 3 miembro(s) del personal.
# 103: Al Paciente 94 se le asigno una cama y 5 miembro(s) del personal.
# 103: Paciente 113 llega al hospital a la unidad Urgencias.
# 103: Paciente 114 llega al hospital a la unidad Urgencias.
# 103: Paciente 97 es atendido.
# 103: Paciente 98 es atendido.
# 104: Al Paciente 67 se le ha dado de alta.
# 104: Al Paciente 74 se le asigno una cama y 1 miembro(s) del personal.
# 104: Paciente 99 es atendido.
# 105: Al Paciente 62 se le ha dado de alta.
# 105: Al Paciente 82 se le ha dado de alta.
# 105: Paciente 115 llega al hospital a la unidad Urgencias.
# 106: Al Paciente 78 se le ha dado de alta.
# 106: Al Paciente 88 se le ha dado de alta.
# 107: Al Paciente 70 se le ha dado de alta.
# 107: Al Paciente 83 se le ha dado de alta.
# 108: Al Paciente 94 se le ha dado de alta.
# 108: Al Paciente 99 se le asigno una cama y 5 miembro(s) del personal.
# 108: Paciente 100 es atendido.
# 109: Al Paciente 97 se le asigno una cama y 8 miembro(s) del personal.
# 109: Al Paciente 98 se le asigno una cama y 5 miembro(s) del personal.
# 109: Al Paciente 100 se le asigno una cama y 7 miembro(s) del personal.
# 109: Paciente 101 es atendido.
# 109: Paciente 102 es atendido.
# 109: Paciente 103 es atendido.
# 110: Al Paciente 87 se le asigno una cama y 1 miembro(s) del personal.
# 110: Al Paciente 93 se le asigno una cama y 1 miembro(s) del personal.
# 110: Paciente 116 llega al hospital a la unidad Consultorios.
# 110: Paciente 104 es atendido.
# 110: Paciente 105 es atendido.
# 111: Al Paciente 101 se le asigno una cama y 6 miembro(s) del personal.
# 111: El Paciente 101 necesita cirugía.
# 111: Paciente 117 llega al hospital a la unidad Urgencias.
# 111: Paciente 118 llega al hospital a la unidad Consultorios.
# 111: Paciente 119 llega al hospital a la unidad Consultorios.
# 111: Paciente 106 es atendido.
# 112: Paciente 120 llega al hospital a la unidad UCI.
# 113: Al Paciente 103 se le asigno una cama y 3 miembro(s) del personal.
# 113: Paciente 107 es atendido.
# 114: Paciente 121 llega al hospital a la unidad UCI.
# 114: Paciente 122 llega al hospital a la unidad Urgencias.
# 114: Paciente 123 llega al hospital a la unidad UCI.
# 115: Al Paciente 85 se le ha dado de alta.
# 115: Al Paciente 92 se le ha dado de alta.
# 115: Al Paciente 96 se le asigno una cama y 1 miembro(s) del personal.
# 115: Al Paciente 97 se le ha dado de alta.
# 115: Al Paciente 107 se le asigno una cama y 5 miembro(s) del personal.
# 115: Paciente 108 es atendido.
# 115: Paciente 109 es atendido.
# 116: Al Paciente 102 se le asigno una cama y 7 miembro(s) del personal.
# 116: Al Paciente 106 se le asigno una cama y 8 miembro(s) del personal.
# 116: Paciente 110 es atendido.
# 116: Paciente 111 es atendido.
# 117: Al Paciente 91 se le ha dado de alta.
# 117: Paciente 124 llega al hospital a la unidad Urgencias.
# 117: Paciente 125 llega al hospital a la unidad Urgencias.
# 117: Paciente 126 llega al hospital a la unidad Consultorios.
# 117: Paciente 127 llega al hospital a la unidad Consultorios.
# 117: Paciente 128 llega al hospital a la unidad Urgencias.
# 117: Al Paciente 109 se le asigno una cama y 8 miembro(s) del personal.
# 117: Paciente 112 es atendido.
# 120: Al Paciente 111 se le asigno una cama y 5 miembro(s) del personal.
# 120: El Paciente 111 necesita cirugía.
# 120: Al Paciente 112 se le asigno una cama y 8 miembro(s) del personal.
# 120: Paciente 113 es atendido.
# 120: Paciente 114 es atendido.
# 121: Cirugía completada para el Paciente 28.
# 121: Paciente 28 se le ha dado de alta.
# 121: Al Paciente 93 se le ha dado de alta.
# 121: Al Paciente 107 se le ha dado de alta.
# 121: Paciente 129 llega al hospital a la unidad Consultorios.
# 121: Paciente 130 llega al hospital a la unidad UCI.
# 121: Paciente 131 llega al hospital a la unidad Urgencias.
# 121: Al Paciente 113 se le asigno una cama y 5 miembro(s) del personal.
# 121: El Paciente 113 necesita cirugía.
# 121: Paciente 115 es atendido.
# 121: Al Paciente 54 se le asignó un kit médico.
# 122: Al Paciente 95 se le ha dado de alta.
# 122: Al Paciente 110 se le asigno una cama y 3 miembro(s) del personal.
# 122: Paciente 116 es atendido.
# 123: Al Paciente 105 se le asigno una cama y 1 miembro(s) del personal.
# 123: Al Paciente 96 se le ha dado de alta.
# 123: Paciente 132 llega al hospital a la unidad Urgencias.
# 123: Paciente 133 llega al hospital a la unidad Urgencias.
# 123: Paciente 134 llega al hospital a la unidad Urgencias.
# 123: Paciente 117 es atendido.
# 124: Al Paciente 90 se le ha dado de alta.
# 124: Al Paciente 102 se le ha dado de alta.
# 124: Al Paciente 106 se le ha dado de alta.
# 124: Al Paciente 115 se le asigno una cama y 6 miembro(s) del personal.
# 124: Paciente 118 es atendido.
# 125: Al Paciente 114 se le asigno una cama y 6 miembro(s) del personal.
# 125: Paciente 119 es atendido.
# 126: Paciente 135 llega al hospital a la unidad Urgencias.
# 126: Paciente 136 llega al hospital a la unidad Urgencias.
# 127: Al Paciente 99 se le ha dado de alta.
# 127: Al Paciente 98 se le ha dado de alta.
# 127: Al Paciente 108 se le asigno una cama y 1 miembro(s) del personal.
# 127: Paciente 137 llega al hospital a la unidad Urgencias.
# 127: Paciente 120 es atendido.
# 128: Al Paciente 117 se le asigno una cama y 4 miembro(s) del personal.
# 128: El Paciente 117 necesita cirugía.
# 128: Paciente 138 llega al hospital a la unidad UCI.
# 128: Paciente 139 llega al hospital a la unidad Urgencias.
# 128: Paciente 140 llega al hospital a la unidad Urgencias.
# 128: Paciente 141 llega al hospital a la unidad UCI.
# 128: Paciente 142 llega al hospital a la unidad UCI.
# 128: Paciente 121 es atendido.
# 129: Al Paciente 86 se le ha dado de alta.
# 129: Al Paciente 116 se le asigno una cama y 1 miembro(s) del personal.
# 129: Paciente 122 es atendido.
# 130: Al Paciente 120 se le asigno una cama y 7 miembro(s) del personal.
# 130: El Paciente 60 murió esperando un kit médico.
# 130: Paciente 123 es atendido.
# 131: Al Paciente 121 se le asigno una cama y 4 miembro(s) del personal.
# 131: Al Paciente 122 se le asigno una cama y 3 miembro(s) del personal.
# 131: Paciente 124 es atendido.
# 131: Paciente 125 es atendido.
# 132: El Paciente 58 murió esperando un kit médico.
# 132: El Paciente 64 murió esperando un kit médico.
# 133: Al Paciente 100 se le ha dado de alta.
# 133: Al Paciente 104 se le asigno una cama y 1 miembro(s) del personal.
# 133: Paciente 143 llega al hospital a la unidad Urgencias.
# 133: Paciente 144 llega al hospital a la unidad Urgencias.
# 133: Paciente 145 llega al hospital a la unidad UCI.
# 133: Paciente 146 llega al hospital a la unidad UCI.
# 133: Paciente 126 es atendido.
# 134: Al Paciente 74 se le ha dado de alta.
# 134: Al Paciente 87 se le ha dado de alta.
# 134: Al Paciente 118 se le asigno una cama y 1 miembro(s) del personal.
# 134: Paciente 127 es atendido.
# 135: Al Paciente 116 se le ha dado de alta.
# 135: Al Paciente 120 se le ha dado de alta.
# 135: Al Paciente 123 se le asigno una cama y 7 miembro(s) del personal.
# 135: Al Paciente 125 se le asigno una cama y 6 miembro(s) del personal.
# 135: El Paciente 63 murió esperando un kit médico.
# 135: Paciente 128 es atendido.
# 135: Paciente 129 es atendido.
# 136: Al Paciente 103 se le ha dado de alta.
# 136: Al Paciente 109 se le ha dado de alta.
# 138: Al Paciente 105 se le ha dado de alta.
# 138: Al Paciente 124 se le asigno una cama y 6 miembro(s) del personal.
# 138: El Paciente 124 necesita cirugía.
# 138: Paciente 147 llega al hospital a la unidad UCI.
# 138: Paciente 148 llega al hospital a la unidad Consultorios.
# 138: Al Paciente 128 se le asigno una cama y 8 miembro(s) del personal.
# 138: El Paciente 128 necesita cirugía.
# 138: Paciente 130 es atendido.
# 138: Paciente 131 es atendido.
# 139: Al Paciente 130 se le asigno una cama y 6 miembro(s) del personal.
# 139: Paciente 132 es atendido.
# 140: Paciente 149 llega al hospital a la unidad Urgencias.
# 140: Paciente 150 llega al hospital a la unidad Consultorios.
# 140: Paciente 151 llega al hospital a la unidad Urgencias.
# 140: Al Paciente 132 se le asigno una cama y 7 miembro(s) del personal.
# 140: Paciente 133 es atendido.
# 141: Al Paciente 112 se le ha dado de alta.
# 141: Paciente 152 llega al hospital a la unidad UCI.
# 141: Paciente 153 llega al hospital a la unidad UCI.
# 141: Paciente 154 llega al hospital a la unidad Urgencias.
# 141: Paciente 155 llega al hospital a la unidad Urgencias.
# 141: Paciente 156 llega al hospital a la unidad UCI.
# 142: Paciente 157 llega al hospital a la unidad Urgencias.
# 142: El Paciente 72 murió esperando un kit médico.
# 145: Al Paciente 131 se le asigno una cama y 5 miembro(s) del personal.
# 145: Al Paciente 133 se le asigno una cama y 5 miembro(s) del personal.
# 145: El Paciente 77 murió esperando un kit médico.
# 145: Paciente 134 es atendido.
# 145: Paciente 135 es atendido.
# 146: Al Paciente 129 se le asigno una cama y 1 miembro(s) del personal.
# 146: Paciente 158 llega al hospital a la unidad Urgencias.
# 146: Paciente 159 llega al hospital a la unidad Urgencias.
# 146: Paciente 160 llega al hospital a la unidad UCI.
# 146: Paciente 161 llega al hospital a la unidad Urgencias.
# 146: Paciente 162 llega al hospital a la unidad Consultorios.
# 146: El Paciente 73 murió esperando un kit médico.
# 146: Paciente 136 es atendido.
# 147: Al Paciente 136 se le asigno una cama y 7 miembro(s) del personal.
# 147: Paciente 137 es atendido.
# 148: Paciente 163 llega al hospital a la unidad UCI.
# 149: Al Paciente 121 se le ha dado de alta.
# 149: Al Paciente 127 se le asigno una cama y 1 miembro(s) del personal.
# 149: Al Paciente 132 se le ha dado de alta.
# 149: Paciente 138 es atendido.
# 150: Al Paciente 114 se le ha dado de alta.
# 150: Al Paciente 119 se le asigno una cama y 1 miembro(s) del personal.
# 150: Al Paciente 122 se le ha dado de alta.
# 150: Al Paciente 137 se le asigno una cama y 7 miembro(s) del personal.
# 150: El Paciente 137 necesita cirugía.
# 150: El Paciente 80 murió esperando un kit médico.
# 150: Paciente 139 es atendido.
# 150: Paciente 140 es atendido.
# 151: Al Paciente 115 se le ha dado de alta.
# 151: Al Paciente 135 se le asigno una cama y 3 miembro(s) del personal.
# 151: Al Paciente 140 se le asigno una cama y 4 miembro(s) del personal.
# 151: El Paciente 140 necesita cirugía.
# 151: Paciente 141 es atendido.
# 151: Paciente 142 es atendido.
# 152: Al Paciente 110 se le ha dado de alta.
# 152: Al Paciente 123 se le ha dado de alta.
# 152: Al Paciente 133 se le ha dado de alta.
# 152: Al Paciente 134 se le asigno una cama y 8 miembro(s) del personal.
# 152: El Paciente 134 necesita cirugía.
# 152: Al Paciente 141 se le asigno una cama y 8 miembro(s) del personal.
# 152: Paciente 143 es atendido.
# 152: Paciente 144 es atendido.
# 153: Paciente 164 llega al hospital a la unidad UCI.
# 154: Al Paciente 108 se le ha dado de alta.
# 154: Al Paciente 126 se le asigno una cama y 1 miembro(s) del personal.
# 154: Al Paciente 118 se le ha dado de alta.
# 154: Al Paciente 131 se le ha dado de alta.
# 154: Al Paciente 138 se le asigno una cama y 8 miembro(s) del personal.
# 154: Paciente 145 es atendido.
# 154: Paciente 146 es atendido.
# 155: El Paciente 84 murió esperando un kit médico.
# 157: Al Paciente 104 se le ha dado de alta.
# 157: Al Paciente 125 se le ha dado de alta.
# 157: Al Paciente 130 se le ha dado de alta.
# 157: Al Paciente 139 se le asigno una cama y 8 miembro(s) del personal.
# 157: El Paciente 139 necesita cirugía.
# 157: Al Paciente 146 se le asigno una cama y 4 miembro(s) del personal.
# 157: Paciente 147 es atendido.
# 157: Paciente 148 es atendido.
# 158: Al Paciente 142 se le asigno una cama y 4 miembro(s) del personal.
# 158: Paciente 165 llega al hospital a la unidad Consultorios.
# 158: Paciente 166 llega al hospital a la unidad Urgencias.
# 158: Paciente 167 llega al hospital a la unidad Urgencias.
# 158: Paciente 168 llega al hospital a la unidad Urgencias.
# 158: Al Paciente 145 se le asigno una cama y 3 miembro(s) del personal.
# 158: Paciente 149 es atendido.
# 158: Paciente 150 es atendido.
# 159: Al Paciente 143 se le asigno una cama y 7 miembro(s) del personal.
# 159: Al Paciente 144 se le asigno una cama y 6 miembro(s) del personal.
# 159: Paciente 169 llega al hospital a la unidad Urgencias.
# 159: Paciente 170 llega al hospital a la unidad UCI.
# 159: Paciente 151 es atendido.
# 159: Paciente 152 es atendido.
# 160: Al Paciente 141 se le ha dado de alta.
# 161: Al Paciente 149 se le asigno una cama y 5 miembro(s) del personal.
# 161: El Paciente 149 necesita cirugía.
# 161: Al Paciente 151 se le asigno una cama y 5 miembro(s) del personal.
# 161: El Paciente 151 necesita cirugía.
# 161: Paciente 153 es atendido.
# 161: Paciente 154 es atendido.
# 162: Al Paciente 135 se le ha dado de alta.
# 162: Paciente 171 llega al hospital a la unidad Urgencias.
# 162: Paciente 172 llega al hospital a la unidad UCI.
# 162: Paciente 173 llega al hospital a la unidad Urgencias.
# 163: Al Paciente 152 se le asigno una cama y 5 miembro(s) del personal.
# 163: Paciente 155 es atendido.
# 164: Al Paciente 138 se le ha dado de alta.
# 164: Al Paciente 147 se le asigno una cama y 3 miembro(s) del personal.
# 164: Al Paciente 154 se le asigno una cama y 7 miembro(s) del personal.
# 164: Paciente 174 llega al hospital a la unidad Urgencias.
# 164: Paciente 175 llega al hospital a la unidad Urgencias.
# 164: Paciente 176 llega al hospital a la unidad Consultorios.
# 164: Paciente 177 llega al hospital a la unidad Urgencias.
# 164: Paciente 178 llega al hospital a la unidad Urgencias.
# 164: Paciente 156 es atendido.
# 164: Paciente 157 es atendido.
# 165: Al Paciente 136 se le ha dado de alta.
# 165: Al Paciente 153 se le asigno una cama y 8 miembro(s) del personal.
# 165: Al Paciente 156 se le asigno una cama y 3 miembro(s) del personal.
# 165: Paciente 158 es atendido.
# 165: Paciente 159 es atendido.
# 166: Paciente 179 llega al hospital a la unidad Urgencias.
# 166: Paciente 180 llega al hospital a la unidad Consultorios.
# 166: Paciente 181 llega al hospital a la unidad UCI.
# 166: Paciente 182 llega al hospital a la unidad Consultorios.
# 166: Paciente 183 llega al hospital a la unidad UCI.
# 167: Al Paciente 142 se le ha dado de alta.
# 167: Al Paciente 155 se le asigno una cama y 7 miembro(s) del personal.
# 167: Al Paciente 157 se le asigno una cama y 6 miembro(s) del personal.
# 167: Paciente 160 es atendido.
# 167: Paciente 161 es atendido.
# 168: Al Paciente 126 se le ha dado de alta.
# 168: Al Paciente 148 se le asigno una cama y 1 miembro(s) del personal.
# 168: Al Paciente 159 se le asigno una cama y 6 miembro(s) del personal.
# 168: El Paciente 159 necesita cirugía.
# 168: Paciente 162 es atendido.
# 168: Paciente 163 es atendido.
# 169: Al Paciente 129 se le ha dado de alta.
# 170: Al Paciente 160 se le asigno una cama y 8 miembro(s) del personal.
# 170: Paciente 164 es atendido.
# 171: Al Paciente 127 se le ha dado de alta.
# 171: Al Paciente 158 se le asigno una cama y 8 miembro(s) del personal.
# 171: Paciente 184 llega al hospital a la unidad Urgencias.
# 171: Paciente 185 llega al hospital a la unidad Consultorios.
# 171: Al Paciente 163 se le asigno una cama y 8 miembro(s) del personal.
# 171: El Paciente 101 murió esperando un kit médico.
# 171: Paciente 165 es atendido.
# 171: Paciente 166 es atendido.
# 172: Al Paciente 146 se le ha dado de alta.
# 172: Al Paciente 161 se le asigno una cama y 6 miembro(s) del personal.
# 172: El Paciente 161 necesita cirugía.
# 172: Paciente 167 es atendido.
# 173: Al Paciente 152 se le ha dado de alta.
# 173: Al Paciente 164 se le asigno una cama y 4 miembro(s) del personal.
# 173: Paciente 168 es atendido.
# 174: Paciente 186 llega al hospital a la unidad Consultorios.
# 174: Paciente 187 llega al hospital a la unidad UCI.
# 174: Paciente 188 llega al hospital a la unidad Urgencias.
# 176: Al Paciente 119 se le ha dado de alta.
# 176: Al Paciente 150 se le asigno una cama y 1 miembro(s) del personal.
# 176: Paciente 189 llega al hospital a la unidad UCI.
# 176: Paciente 169 es atendido.
# 177: Al Paciente 167 se le asigno una cama y 3 miembro(s) del personal.
# 177: El Paciente 167 necesita cirugía.
# 177: Paciente 170 es atendido.
# 178: Al Paciente 144 se le ha dado de alta.
# 178: Al Paciente 166 se le asigno una cama y 5 miembro(s) del personal.
# 178: El Paciente 166 necesita cirugía.
# 178: Paciente 171 es atendido.
# 179: Al Paciente 153 se le ha dado de alta.
# 179: Al Paciente 162 se le asigno una cama y 1 miembro(s) del personal.
# 179: Paciente 172 es atendido.
# 180: Al Paciente 160 se le ha dado de alta.
# 180: Al Paciente 168 se le asigno una cama y 3 miembro(s) del personal.
# 180: El Paciente 168 necesita cirugía.
# 180: Al Paciente 169 se le asigno una cama y 3 miembro(s) del personal.
# 180: El Paciente 169 necesita cirugía.
# 180: El Paciente 111 murió esperando un kit médico.
# 180: Paciente 173 es atendido.
# 180: Paciente 174 es atendido.
# 181: Al Paciente 156 se le ha dado de alta.
# 181: Al Paciente 158 se le ha dado de alta.
# 181: Paciente 190 llega al hospital a la unidad Urgencias.
# 181: Paciente 191 llega al hospital a la unidad Urgencias.
# 181: Paciente 192 llega al hospital a la unidad Urgencias.
# 181: Paciente 193 llega al hospital a la unidad UCI.
# 181: El Paciente 113 murió esperando un kit médico.
# 182: Al Paciente 145 se le ha dado de alta.
# 183: Al Paciente 154 se le ha dado de alta.
# 183: Al Paciente 157 se le ha dado de alta.
# 183: Al Paciente 170 se le asigno una cama y 5 miembro(s) del personal.
# 183: Al Paciente 171 se le asigno una cama y 6 miembro(s) del personal.
# 183: El Paciente 171 necesita cirugía.
# 183: Al Paciente 173 se le asigno una cama y 7 miembro(s) del personal.
# 183: Paciente 194 llega al hospital a la unidad UCI.
# 183: Paciente 195 llega al hospital a la unidad Urgencias.
# 183: Paciente 196 llega al hospital a la unidad UCI.
# 183: Paciente 197 llega al hospital a la unidad Urgencias.
# 183: Paciente 175 es atendido.
# 183: Paciente 176 es atendido.
# 183: Paciente 177 es atendido.
# 184: Al Paciente 172 se le asigno una cama y 4 miembro(s) del personal.
# 184: Paciente 178 es atendido.
# 185: Al Paciente 143 se le ha dado de alta.
# 185: Al Paciente 174 se le asigno una cama y 3 miembro(s) del personal.
# 185: El Paciente 174 necesita cirugía.
# 185: Al Paciente 178 se le asigno una cama y 5 miembro(s) del personal.
# 185: El Paciente 178 necesita cirugía.
# 185: Paciente 179 es atendido.
# 185: Paciente 180 es atendido.
# 187: Al Paciente 147 se le ha dado de alta.
# 187: Al Paciente 165 se le asigno una cama y 1 miembro(s) del personal.
# 187: Paciente 198 llega al hospital a la unidad Urgencias.
# 187: Paciente 199 llega al hospital a la unidad Consultorios.
# 187: Paciente 181 es atendido.
# 188: Al Paciente 163 se le ha dado de alta.
# 188: El Paciente 117 murió esperando un kit médico.
# 190: Al Paciente 148 se le ha dado de alta.
# 190: Al Paciente 173 se le ha dado de alta.
# 190: Al Paciente 175 se le asigno una cama y 8 miembro(s) del personal.
# 190: Al Paciente 177 se le asigno una cama y 7 miembro(s) del personal.
# 190: Paciente 200 llega al hospital a la unidad Urgencias.
# 190: Paciente 201 llega al hospital a la unidad Urgencias.
# 190: Paciente 202 llega al hospital a la unidad Urgencias.
# 190: Paciente 203 llega al hospital a la unidad Urgencias.
# 190: Paciente 204 llega al hospital a la unidad UCI.
# 190: Paciente 182 es atendido.
# 190: Paciente 183 es atendido.
# 191: Al Paciente 176 se le asigno una cama y 1 miembro(s) del personal.
# 191: Paciente 184 es atendido.
# 192: Al Paciente 150 se le ha dado de alta.
# 192: Al Paciente 170 se le ha dado de alta.
# 192: Al Paciente 179 se le asigno una cama y 6 miembro(s) del personal.
# 192: El Paciente 179 necesita cirugía.
# 192: Paciente 185 es atendido.
# 193: Al Paciente 181 se le asigno una cama y 6 miembro(s) del personal.
# 193: Paciente 186 es atendido.
# 194: Al Paciente 155 se le ha dado de alta.
# 194: Paciente 205 llega al hospital a la unidad UCI.
# 194: Paciente 206 llega al hospital a la unidad Urgencias.
# 194: Paciente 207 llega al hospital a la unidad Urgencias.
# 194: Paciente 208 llega al hospital a la unidad Urgencias.
# 194: Al Paciente 183 se le asigno una cama y 7 miembro(s) del personal.
# 194: Paciente 187 es atendido.
# 195: Al Paciente 184 se le asigno una cama y 8 miembro(s) del personal.
# 195: El Paciente 184 necesita cirugía.
# 195: Al Paciente 187 se le asigno una cama y 5 miembro(s) del personal.
# 195: Paciente 188 es atendido.
# 195: Paciente 189 es atendido.
# 196: Al Paciente 177 se le ha dado de alta.
# 198: El Paciente 124 murió esperando un kit médico.
# 198: El Paciente 128 murió esperando un kit médico.
# 199: Paciente 209 llega al hospital a la unidad Urgencias.
# 199: Al Paciente 189 se le asigno una cama y 5 miembro(s) del personal.
# 199: Paciente 190 es atendido.
# 200: Al Paciente 180 se le asigno una cama y 1 miembro(s) del personal.
# 200: Al Paciente 186 se le asigno una cama y 1 miembro(s) del personal.
# 200: Al Paciente 188 se le asigno una cama y 3 miembro(s) del personal.
# 200: El Paciente 188 necesita cirugía.
# 200: Paciente 191 es atendido.
# 200: Paciente 192 es atendido.
# 200: Paciente 193 es atendido.
# 201: Al Paciente 164 se le ha dado de alta.
# 201: Paciente 210 llega al hospital a la unidad Urgencias.
# 201: Paciente 211 llega al hospital a la unidad Urgencias.
# 201: Paciente 212 llega al hospital a la unidad Urgencias.
# 201: Paciente 213 llega al hospital a la unidad Consultorios.
# 202: Al Paciente 182 se le asigno una cama y 1 miembro(s) del personal.
# 202: Paciente 214 llega al hospital a la unidad Consultorios.
# 202: Paciente 215 llega al hospital a la unidad UCI.
# 202: Paciente 194 es atendido.
# 203: Al Paciente 193 se le asigno una cama y 4 miembro(s) del personal.
# 203: Al Paciente 194 se le asigno una cama y 8 miembro(s) del personal.
# 203: Paciente 195 es atendido.
# 203: Paciente 196 es atendido.
# 204: Al Paciente 175 se le ha dado de alta.
# 204: Al Paciente 190 se le asigno una cama y 6 miembro(s) del personal.
# 204: Al Paciente 192 se le asigno una cama y 8 miembro(s) del personal.
# 204: El Paciente 192 necesita cirugía.
# 204: Paciente 197 es atendido.
# 204: Paciente 198 es atendido.
# 206: Cirugía completada para el Paciente 24.
# 206: Paciente 24 se le ha dado de alta.
# 206: Al Paciente 191 se le asigno una cama y 5 miembro(s) del personal.
# 206: El Paciente 191 necesita cirugía.
# 206: Paciente 216 llega al hospital a la unidad Urgencias.
# 206: Paciente 217 llega al hospital a la unidad UCI.
# 206: Paciente 218 llega al hospital a la unidad UCI.
# 206: Paciente 219 llega al hospital a la unidad Urgencias.
# 206: Paciente 220 llega al hospital a la unidad Consultorios.
# 206: Paciente 199 es atendido.
# 206: Al Paciente 137 se le asignó un kit médico.
# 207: Al Paciente 198 se le asigno una cama y 3 miembro(s) del personal.
# 207: El Paciente 198 necesita cirugía.
# 207: Paciente 221 llega al hospital a la unidad Urgencias.
# 207: Paciente 222 llega al hospital a la unidad Urgencias.
# 207: Paciente 223 llega al hospital a la unidad UCI.
# 207: Paciente 224 llega al hospital a la unidad Consultorios.
# 207: Paciente 225 llega al hospital a la unidad Urgencias.
# 207: Paciente 200 es atendido.
# 208: Al Paciente 162 se le ha dado de alta.
# 208: Al Paciente 186 se le ha dado de alta.
# 208: Al Paciente 197 se le asigno una cama y 6 miembro(s) del personal.
# 208: Paciente 201 es atendido.
# 209: Al Paciente 195 se le asigno una cama y 3 miembro(s) del personal.
# 209: Al Paciente 201 se le asigno una cama y 7 miembro(s) del personal.
# 209: El Paciente 201 necesita cirugía.
# 209: Paciente 202 es atendido.
# 209: Paciente 203 es atendido.
# 210: Al Paciente 172 se le ha dado de alta.
# 210: Al Paciente 189 se le ha dado de alta.
# 210: Al Paciente 196 se le asigno una cama y 5 miembro(s) del personal.
# 210: Paciente 204 es atendido.
# 211: Al Paciente 185 se le asigno una cama y 1 miembro(s) del personal.
# 211: Paciente 226 llega al hospital a la unidad UCI.
# 211: Paciente 227 llega al hospital a la unidad Urgencias.
# 211: Paciente 228 llega al hospital a la unidad Urgencias.
# 211: Paciente 229 llega al hospital a la unidad UCI.
# 211: Paciente 230 llega al hospital a la unidad Urgencias.
# 211: Al Paciente 200 se le asigno una cama y 3 miembro(s) del personal.
# 211: El Paciente 200 necesita cirugía.
# 211: Al Paciente 202 se le asigno una cama y 4 miembro(s) del personal.
# 211: Al Paciente 204 se le asigno una cama y 6 miembro(s) del personal.
# 211: El Paciente 140 murió esperando un kit médico.
# 211: Paciente 205 es atendido.
# 211: Paciente 206 es atendido.
# 211: Paciente 207 es atendido.
# 211: Paciente 208 es atendido.
# 212: Al Paciente 190 se le ha dado de alta.
# 212: Paciente 231 llega al hospital a la unidad Urgencias.
# 212: Paciente 232 llega al hospital a la unidad UCI.
# 212: Paciente 233 llega al hospital a la unidad UCI.
# 212: Al Paciente 206 se le asigno una cama y 6 miembro(s) del personal.
# 212: El Paciente 134 murió esperando un kit médico.
# 212: Paciente 209 es atendido.
# 213: Al Paciente 176 se le ha dado de alta.
# 214: Al Paciente 165 se le ha dado de alta.
# 214: Paciente 234 llega al hospital a la unidad Urgencias.
# 214: Paciente 235 llega al hospital a la unidad Urgencias.
# 214: Paciente 236 llega al hospital a la unidad Urgencias.
# 215: Al Paciente 180 se le ha dado de alta.
# 215: Al Paciente 205 se le asigno una cama y 5 miembro(s) del personal.
# 215: Paciente 210 es atendido.
# 216: Al Paciente 203 se le asigno una cama y 4 miembro(s) del personal.
# 216: Al Paciente 207 se le asigno una cama y 8 miembro(s) del personal.
# 216: Paciente 237 llega al hospital a la unidad Consultorios.
# 216: Paciente 211 es atendido.
# 216: Paciente 212 es atendido.
# 217: El Paciente 139 murió esperando un kit médico.
# 218: Al Paciente 208 se le asigno una cama y 5 miembro(s) del personal.
# 218: Al Paciente 209 se le asigno una cama y 7 miembro(s) del personal.
# 218: El Paciente 209 necesita cirugía.
# 218: Paciente 213 es atendido.
# 218: Paciente 214 es atendido.
# 219: Al Paciente 210 se le asigno una cama y 4 miembro(s) del personal.
# 219: Al Paciente 211 se le asigno una cama y 8 miembro(s) del personal.
# 219: El Paciente 211 necesita cirugía.
# 219: Al Paciente 212 se le asigno una cama y 4 miembro(s) del personal.
# 219: Paciente 215 es atendido.
# 219: Paciente 216 es atendido.
# 219: Paciente 217 es atendido.
# 220: Al Paciente 217 se le asigno una cama y 3 miembro(s) del personal.
# 220: Paciente 218 es atendido.
# 221: Paciente 238 llega al hospital a la unidad Urgencias.
# 221: Paciente 239 llega al hospital a la unidad UCI.
# 221: Paciente 240 llega al hospital a la unidad UCI.
# 221: Paciente 241 llega al hospital a la unidad Consultorios.
# 221: Paciente 242 llega al hospital a la unidad Urgencias.
# 221: El Paciente 149 murió esperando un kit médico.
# 221: El Paciente 151 murió esperando un kit médico.
# 222: Al Paciente 215 se le asigno una cama y 4 miembro(s) del personal.
# 222: Paciente 219 es atendido.
# 223: Al Paciente 181 se le ha dado de alta.
# 223: Al Paciente 183 se le ha dado de alta.
# 223: Al Paciente 196 se le ha dado de alta.
# 223: Al Paciente 208 se le ha dado de alta.
# 224: Al Paciente 199 se le asigno una cama y 1 miembro(s) del personal.
# 224: Al Paciente 203 se le ha dado de alta.
# 224: Al Paciente 207 se le ha dado de alta.
# 224: Paciente 220 es atendido.
# 225: Al Paciente 187 se le ha dado de alta.
# 225: Al Paciente 194 se le ha dado de alta.
# 225: Al Paciente 216 se le asigno una cama y 7 miembro(s) del personal.
# 225: El Paciente 216 necesita cirugía.
# 225: Al Paciente 218 se le asigno una cama y 3 miembro(s) del personal.
# 225: Paciente 243 llega al hospital a la unidad UCI.
# 225: Paciente 221 es atendido.
# 225: Paciente 222 es atendido.
# 226: Al Paciente 210 se le ha dado de alta.
# 227: Al Paciente 219 se le asigno una cama y 8 miembro(s) del personal.
# 227: Paciente 223 es atendido.
# 228: Al Paciente 182 se le ha dado de alta.
# 228: Al Paciente 205 se le ha dado de alta.
# 228: Paciente 244 llega al hospital a la unidad Urgencias.
# 228: Paciente 245 llega al hospital a la unidad Urgencias.
# 228: Al Paciente 222 se le asigno una cama y 7 miembro(s) del personal.
# 228: El Paciente 159 murió esperando un kit médico.
# 228: Paciente 224 es atendido.
# 229: Al Paciente 195 se le ha dado de alta.
# 230: Al Paciente 185 se le ha dado de alta.
# 230: Paciente 246 llega al hospital a la unidad Urgencias.
# 230: Paciente 247 llega al hospital a la unidad Urgencias.
# 230: Paciente 248 llega al hospital a la unidad Urgencias.
# 231: Al Paciente 202 se le ha dado de alta.
# 231: Al Paciente 206 se le ha dado de alta.
# 232: Al Paciente 193 se le ha dado de alta.
# 232: Al Paciente 217 se le ha dado de alta.
# 232: Al Paciente 221 se le asigno una cama y 6 miembro(s) del personal.
# 232: El Paciente 161 murió esperando un kit médico.
# 232: Paciente 225 es atendido.
# 233: Al Paciente 204 se le ha dado de alta.
# 233: Al Paciente 223 se le asigno una cama y 8 miembro(s) del personal.
# 233: Al Paciente 222 se le ha dado de alta.
# 233: Paciente 226 es atendido.
# 234: Al Paciente 220 se le asigno una cama y 1 miembro(s) del personal.
# 234: Paciente 249 llega al hospital a la unidad UCI.
# 234: Paciente 250 llega al hospital a la unidad Consultorios.
# 234: Paciente 251 llega al hospital a la unidad Urgencias.
# 234: Paciente 252 llega al hospital a la unidad UCI.
# 234: Al Paciente 225 se le asigno una cama y 5 miembro(s) del personal.
# 234: El Paciente 225 necesita cirugía.
# 234: Paciente 227 es atendido.
# 234: Paciente 228 es atendido.
# 236: Al Paciente 213 se le asigno una cama y 1 miembro(s) del personal.
# 236: Al Paciente 214 se le asigno una cama y 1 miembro(s) del personal.
# 236: Paciente 253 llega al hospital a la unidad Urgencias.
# ...
# 405: Paciente 416 llega al hospital a la unidad Consultorios.
# 405: Paciente 417 llega al hospital a la unidad UCI.
# 405: Paciente 395 es atendido.
# 406: Al Paciente 393 se le asigno una cama y 4 miembro(s) del personal.
# 406: El Paciente 393 necesita cirugía.
# 406: Paciente 396 es atendido.
# 407: Al Paciente 378 se le ha dado de alta.
# 407: Al Paciente 394 se le asigno una cama y 5 miembro(s) del personal.
# 407: El Paciente 394 necesita cirugía.
# 407: Paciente 397 es atendido.
# 408: Paciente 418 llega al hospital a la unidad UCI.
# 408: Paciente 419 llega al hospital a la unidad Urgencias.
# 408: Paciente 420 llega al hospital a la unidad Urgencias.
# 409: Paciente 421 llega al hospital a la unidad Urgencias.
# 409: Paciente 422 llega al hospital a la unidad UCI.
# 409: Paciente 423 llega al hospital a la unidad Urgencias.
# 409: Paciente 424 llega al hospital a la unidad Consultorios.
# 409: Paciente 425 llega al hospital a la unidad Urgencias.
# 410: Al Paciente 391 se le ha dado de alta.
# 410: Al Paciente 395 se le asigno una cama y 7 miembro(s) del personal.
# 410: Al Paciente 396 se le asigno una cama y 3 miembro(s) del personal.
# 410: Paciente 398 es atendido.
# 410: Paciente 399 es atendido.
# 411: Paciente 426 llega al hospital a la unidad Consultorios.
# 411: Paciente 427 llega al hospital a la unidad Consultorios.
# 411: Paciente 428 llega al hospital a la unidad Urgencias.
# 411: Paciente 429 llega al hospital a la unidad Urgencias.
# 412: Al Paciente 376 se le ha dado de alta.
# 412: Al Paciente 377 se le ha dado de alta.
# 412: Al Paciente 398 se le asigno una cama y 5 miembro(s) del personal.
# 412: El Paciente 346 murió esperando un kit médico.
# 412: Paciente 400 es atendido.
# 413: Al Paciente 380 se le ha dado de alta.
# 413: Al Paciente 369 se le ha dado de alta.
# 413: Al Paciente 383 se le ha dado de alta.
# 413: Al Paciente 386 se le ha dado de alta.
# 413: El Paciente 347 murió esperando un kit médico.
# 414: Al Paciente 399 se le asigno una cama y 7 miembro(s) del personal.
# 414: Paciente 401 es atendido.
# 415: Al Paciente 387 se le asigno una cama y 1 miembro(s) del personal.
# 415: Paciente 402 es atendido.
# 416: Al Paciente 388 se le ha dado de alta.
# 416: Paciente 430 llega al hospital a la unidad UCI.
# 416: Paciente 431 llega al hospital a la unidad Urgencias.
# 417: Al Paciente 392 se le asigno una cama y 1 miembro(s) del personal.
# 417: Paciente 403 es atendido.
# 418: Al Paciente 397 se le asigno una cama y 1 miembro(s) del personal.
# 418: El Paciente 353 murió esperando un kit médico.
# 418: Paciente 404 es atendido.
# 419: Al Paciente 375 se le ha dado de alta.
# 420: Al Paciente 389 se le asigno una cama y 1 miembro(s) del personal.
# 420: Al Paciente 401 se le asigno una cama y 6 miembro(s) del personal.
# 420: Paciente 432 llega al hospital a la unidad Urgencias.
# 420: Paciente 433 llega al hospital a la unidad UCI.
# 420: Paciente 434 llega al hospital a la unidad Urgencias.
# 420: Paciente 405 es atendido.
# 420: Paciente 406 es atendido.
# 421: Al Paciente 381 se le ha dado de alta.
# 421: Al Paciente 403 se le asigno una cama y 7 miembro(s) del personal.
# 421: Paciente 407 es atendido.
# 422: Cirugía completada para el Paciente 51.
# 422: Paciente 51 murió tras el procedimiento.
# 422: Al Paciente 404 se le asigno una cama y 4 miembro(s) del personal.
# 422: Paciente 408 es atendido.
# 422: Al Paciente 357 se le asignó un kit médico.
# 423: Al Paciente 405 se le asigno una cama y 4 miembro(s) del personal.
# 423: Paciente 409 es atendido.
# 424: Al Paciente 384 se le ha dado de alta.
# 424: Al Paciente 387 se le ha dado de alta.
# 424: Al Paciente 407 se le asigno una cama y 5 miembro(s) del personal.
# 424: El Paciente 407 necesita cirugía.
# 424: Paciente 410 es atendido.
# 425: Cirugía completada para el Paciente 13.
# 425: Paciente 13 se le ha dado de alta.
# 425: Al Paciente 401 se le ha dado de alta.
# 425: Paciente 435 llega al hospital a la unidad UCI.
# 425: Paciente 436 llega al hospital a la unidad Urgencias.
# 425: Paciente 437 llega al hospital a la unidad UCI.
# 425: Paciente 438 llega al hospital a la unidad Urgencias.
# 425: Al Paciente 364 se le asignó un kit médico.
# 427: Al Paciente 406 se le asigno una cama y 3 miembro(s) del personal.
# 427: El Paciente 406 necesita cirugía.
# 427: Paciente 411 es atendido.
# 428: Al Paciente 400 se le asigno una cama y 1 miembro(s) del personal.
# 428: Al Paciente 408 se le asigno una cama y 7 miembro(s) del personal.
# 428: Al Paciente 409 se le asigno una cama y 5 miembro(s) del personal.
# 428: El Paciente 409 necesita cirugía.
# 428: Paciente 412 es atendido.
# 428: Paciente 413 es atendido.
# 428: Paciente 414 es atendido.
# 429: Al Paciente 411 se le asigno una cama y 8 miembro(s) del personal.
# 429: Paciente 415 es atendido.
# 430: Al Paciente 410 se le asigno una cama y 5 miembro(s) del personal.
# 430: El Paciente 410 necesita cirugía.
# 430: Paciente 439 llega al hospital a la unidad Urgencias.
# 430: Paciente 440 llega al hospital a la unidad UCI.
# 430: Paciente 441 llega al hospital a la unidad Urgencias.
# 430: Al Paciente 412 se le asigno una cama y 5 miembro(s) del personal.
# 430: El Paciente 361 murió esperando un kit médico.
# 430: Paciente 416 es atendido.
# 430: Paciente 417 es atendido.
# 431: Paciente 442 llega al hospital a la unidad Urgencias.
# 431: El Paciente 365 murió esperando un kit médico.
# 432: Al Paciente 414 se le asigno una cama y 7 miembro(s) del personal.
# 432: El Paciente 414 necesita cirugía.
# 432: Paciente 418 es atendido.
# 433: Al Paciente 405 se le ha dado de alta.
# 433: Al Paciente 417 se le asigno una cama y 5 miembro(s) del personal.
# 433: Paciente 419 es atendido.
# 434: Al Paciente 396 se le ha dado de alta.
# 434: Al Paciente 415 se le asigno una cama y 8 miembro(s) del personal.
# 434: Paciente 420 es atendido.
# 435: Al Paciente 404 se le ha dado de alta.
# 435: Al Paciente 413 se le asigno una cama y 3 miembro(s) del personal.
# 435: El Paciente 413 necesita cirugía.
# 435: Paciente 443 llega al hospital a la unidad UCI.
# 435: Paciente 444 llega al hospital a la unidad UCI.
# 435: Paciente 421 es atendido.
# 436: Al Paciente 420 se le asigno una cama y 6 miembro(s) del personal.
# 436: Paciente 422 es atendido.
# 437: Al Paciente 403 se le ha dado de alta.
# 437: Al Paciente 418 se le asigno una cama y 8 miembro(s) del personal.
# 437: Paciente 423 es atendido.
# 438: Al Paciente 399 se le ha dado de alta.
# 438: Al Paciente 419 se le asigno una cama y 4 miembro(s) del personal.
# 438: Paciente 424 es atendido.
# 439: Al Paciente 395 se le ha dado de alta.
# 439: Al Paciente 402 se le asigno una cama y 1 miembro(s) del personal.
# 439: Al Paciente 389 se le ha dado de alta.
# 439: Paciente 445 llega al hospital a la unidad UCI.
# 439: Paciente 425 es atendido.
# 440: Al Paciente 423 se le asigno una cama y 7 miembro(s) del personal.
# 440: Paciente 446 llega al hospital a la unidad Urgencias.
# 440: Paciente 447 llega al hospital a la unidad Urgencias.
# 440: Paciente 448 llega al hospital a la unidad UCI.
# 440: Paciente 426 es atendido.
# 441: Al Paciente 398 se le ha dado de alta.
# 441: Al Paciente 421 se le asigno una cama y 8 miembro(s) del personal.
# 441: El Paciente 421 necesita cirugía.
# 441: Paciente 427 es atendido.
# 442: Al Paciente 425 se le asigno una cama y 6 miembro(s) del personal.
# 442: El Paciente 425 necesita cirugía.
# 442: Paciente 428 es atendido.
# 443: Al Paciente 392 se le ha dado de alta.
# 443: Al Paciente 422 se le asigno una cama y 8 miembro(s) del personal.
# 443: Paciente 429 es atendido.
# 444: Cirugía completada para el Paciente 137.
# 444: Paciente 137 se le ha dado de alta.
# 444: Al Paciente 429 se le asigno una cama y 4 miembro(s) del personal.
# 444: Paciente 430 es atendido.
# 444: Al Paciente 379 se le asignó un kit médico.
# 445: Al Paciente 412 se le ha dado de alta.
# 445: Paciente 449 llega al hospital a la unidad UCI.
# 445: Paciente 450 llega al hospital a la unidad UCI.
# 445: Paciente 451 llega al hospital a la unidad UCI.
# 445: Paciente 452 llega al hospital a la unidad Urgencias.
# 445: Paciente 453 llega al hospital a la unidad UCI.
# 446: Al Paciente 408 se le ha dado de alta.
# 446: Al Paciente 428 se le asigno una cama y 6 miembro(s) del personal.
# 446: Paciente 431 es atendido.
# 447: Al Paciente 397 se le ha dado de alta.
# 447: Al Paciente 415 se le ha dado de alta.
# 449: Al Paciente 418 se le ha dado de alta.
# 449: Al Paciente 430 se le asigno una cama y 6 miembro(s) del personal.
# 449: Paciente 454 llega al hospital a la unidad Urgencias.
# 449: Paciente 455 llega al hospital a la unidad UCI.
# 449: Paciente 456 llega al hospital a la unidad Urgencias.
# 449: Paciente 457 llega al hospital a la unidad UCI.
# 449: Paciente 432 es atendido.
# 450: Al Paciente 400 se le ha dado de alta.
# 450: Al Paciente 416 se le asigno una cama y 1 miembro(s) del personal.
# 450: Al Paciente 424 se le asigno una cama y 1 miembro(s) del personal.
# 450: Al Paciente 427 se le asigno una cama y 1 miembro(s) del personal.
# 450: Al Paciente 431 se le asigno una cama y 3 miembro(s) del personal.
# 450: El Paciente 431 necesita cirugía.
# 450: Paciente 433 es atendido.
# 450: Paciente 434 es atendido.
# 450: Paciente 435 es atendido.
# 450: Paciente 436 es atendido.
# 452: Paciente 458 llega al hospital a la unidad Consultorios.
# 452: Paciente 459 llega al hospital a la unidad UCI.
# 452: Paciente 460 llega al hospital a la unidad Urgencias.
# 452: Paciente 461 llega al hospital a la unidad Urgencias.
# 453: Al Paciente 436 se le asigno una cama y 7 miembro(s) del personal.
# 453: Paciente 437 es atendido.
# 454: Al Paciente 426 se le asigno una cama y 1 miembro(s) del personal.
# 454: Al Paciente 435 se le asigno una cama y 3 miembro(s) del personal.
# 454: Paciente 438 es atendido.
# 454: Paciente 439 es atendido.
# 455: Al Paciente 411 se le ha dado de alta.
# 455: Al Paciente 422 se le ha dado de alta.
# 455: Al Paciente 433 se le asigno una cama y 4 miembro(s) del personal.
# 455: Paciente 440 es atendido.
# 456: Al Paciente 420 se le ha dado de alta.
# 456: Al Paciente 419 se le ha dado de alta.
# 456: Al Paciente 432 se le asigno una cama y 4 miembro(s) del personal.
# 456: Al Paciente 434 se le asigno una cama y 3 miembro(s) del personal.
# 456: El Paciente 434 necesita cirugía.
# 456: Paciente 441 es atendido.
# 456: Paciente 442 es atendido.
# 457: Paciente 462 llega al hospital a la unidad Consultorios.
# 457: Paciente 463 llega al hospital a la unidad Urgencias.
# 457: Paciente 464 llega al hospital a la unidad UCI.
# 457: Paciente 465 llega al hospital a la unidad UCI.
# 457: Paciente 466 llega al hospital a la unidad Urgencias.
# 458: Al Paciente 437 se le asigno una cama y 4 miembro(s) del personal.
# 458: Al Paciente 439 se le asigno una cama y 5 miembro(s) del personal.
# 458: El Paciente 439 necesita cirugía.
# 458: El Paciente 385 murió esperando un kit médico.
# 458: Paciente 443 es atendido.
# 458: Paciente 444 es atendido.
# 459: Al Paciente 429 se le ha dado de alta.
# 459: Al Paciente 440 se le asigno una cama y 8 miembro(s) del personal.
# 459: Al Paciente 444 se le asigno una cama y 6 miembro(s) del personal.
# 459: Paciente 445 es atendido.
# 459: Paciente 446 es atendido.
# 460: Al Paciente 424 se le ha dado de alta.
# 460: Al Paciente 442 se le asigno una cama y 4 miembro(s) del personal.
# 460: Paciente 467 llega al hospital a la unidad Urgencias.
# 460: Paciente 447 es atendido.
# 461: Al Paciente 438 se le asigno una cama y 8 miembro(s) del personal.
# 461: El Paciente 438 necesita cirugía.
# 461: Al Paciente 433 se le ha dado de alta.
# 461: Paciente 448 es atendido.
# 462: Al Paciente 417 se le ha dado de alta.
# 462: Al Paciente 441 se le asigno una cama y 4 miembro(s) del personal.
# 462: El Paciente 441 necesita cirugía.
# 462: Al Paciente 445 se le asigno una cama y 3 miembro(s) del personal.
# 462: Al Paciente 448 se le asigno una cama y 8 miembro(s) del personal.
# 462: Paciente 449 es atendido.
# 462: Paciente 450 es atendido.
# 462: Paciente 451 es atendido.
# 463: Al Paciente 447 se le asigno una cama y 6 miembro(s) del personal.
# 463: El Paciente 447 necesita cirugía.
# 463: Paciente 452 es atendido.
# 464: Paciente 468 llega al hospital a la unidad UCI.
# 464: Paciente 469 llega al hospital a la unidad UCI.
# 464: Paciente 470 llega al hospital a la unidad Urgencias.
# 464: El Paciente 390 murió esperando un kit médico.
# 465: Al Paciente 443 se le asigno una cama y 8 miembro(s) del personal.
# 465: Al Paciente 446 se le asigno una cama y 5 miembro(s) del personal.
# 465: Paciente 453 es atendido.
# 465: Paciente 454 es atendido.
# 466: Al Paciente 423 se le ha dado de alta.
# 466: Al Paciente 430 se le ha dado de alta.
# 466: El Paciente 393 murió esperando un kit médico.
# 467: Al Paciente 402 se le ha dado de alta.
# 467: Al Paciente 449 se le asigno una cama y 3 miembro(s) del personal.
# 467: Al Paciente 452 se le asigno una cama y 3 miembro(s) del personal.
# 467: Al Paciente 454 se le asigno una cama y 7 miembro(s) del personal.
# 467: El Paciente 394 murió esperando un kit médico.
# 467: Paciente 455 es atendido.
# 467: Paciente 456 es atendido.
# 467: Paciente 457 es atendido.
# 468: Al Paciente 437 se le ha dado de alta.
# 468: Al Paciente 440 se le ha dado de alta.
# 468: Al Paciente 450 se le asigno una cama y 3 miembro(s) del personal.
# 468: Al Paciente 451 se le asigno una cama y 3 miembro(s) del personal.
# 468: Paciente 471 llega al hospital a la unidad UCI.
# 468: Paciente 472 llega al hospital a la unidad Urgencias.
# 468: Paciente 473 llega al hospital a la unidad Urgencias.
# 468: Paciente 474 llega al hospital a la unidad Urgencias.
# 468: Al Paciente 455 se le asigno una cama y 3 miembro(s) del personal.
# 468: Paciente 458 es atendido.
# 468: Paciente 459 es atendido.
# 468: Paciente 460 es atendido.
# 469: Paciente 475 llega al hospital a la unidad Urgencias.
# 469: Paciente 476 llega al hospital a la unidad UCI.
# 469: Paciente 477 llega al hospital a la unidad Consultorios.
# 470: Al Paciente 457 se le asigno una cama y 3 miembro(s) del personal.
# 470: Al Paciente 459 se le asigno una cama y 7 miembro(s) del personal.
# 470: Paciente 461 es atendido.
# 470: Paciente 462 es atendido.
# 472: Al Paciente 428 se le ha dado de alta.
# 472: Al Paciente 453 se le asigno una cama y 3 miembro(s) del personal.
# 472: Al Paciente 456 se le asigno una cama y 8 miembro(s) del personal.
# 472: Paciente 478 llega al hospital a la unidad UCI.
# 472: Paciente 479 llega al hospital a la unidad Urgencias.
# 472: Paciente 480 llega al hospital a la unidad UCI.
# 472: Paciente 463 es atendido.
# 472: Paciente 464 es atendido.
# 473: Paciente 481 llega al hospital a la unidad Urgencias.
# 473: Paciente 482 llega al hospital a la unidad Consultorios.
# 473: Paciente 483 llega al hospital a la unidad Urgencias.
# 473: Al Paciente 463 se le asigno una cama y 3 miembro(s) del personal.
# 473: El Paciente 463 necesita cirugía.
# 473: Al Paciente 464 se le asigno una cama y 6 miembro(s) del personal.
# 473: Paciente 465 es atendido.
# 473: Paciente 466 es atendido.
# 474: Al Paciente 416 se le ha dado de alta.
# 474: Al Paciente 460 se le asigno una cama y 6 miembro(s) del personal.
# 474: El Paciente 460 necesita cirugía.
# 474: Al Paciente 461 se le asigno una cama y 8 miembro(s) del personal.
# 474: El Paciente 461 necesita cirugía.
# 474: Paciente 467 es atendido.
# 474: Paciente 468 es atendido.
# 475: Al Paciente 449 se le ha dado de alta.
# 475: Al Paciente 468 se le asigno una cama y 4 miembro(s) del personal.
# 475: Paciente 469 es atendido.
# 476: Al Paciente 448 se le ha dado de alta.
# 476: Al Paciente 451 se le ha dado de alta.
# 476: Paciente 484 llega al hospital a la unidad Urgencias.
# 476: Paciente 485 llega al hospital a la unidad Urgencias.
# 476: Paciente 486 llega al hospital a la unidad Consultorios.
# 476: Paciente 487 llega al hospital a la unidad Urgencias.
# 476: Paciente 488 llega al hospital a la unidad Urgencias.
# 477: Al Paciente 427 se le ha dado de alta.
# 477: Al Paciente 456 se le ha dado de alta.
# 477: Al Paciente 465 se le asigno una cama y 5 miembro(s) del personal.
# 477: Al Paciente 469 se le asigno una cama y 4 miembro(s) del personal.
# 477: Paciente 470 es atendido.
# 477: Paciente 471 es atendido.
# 478: Al Paciente 471 se le asigno una cama y 7 miembro(s) del personal.
# 478: Paciente 472 es atendido.
# 479: Al Paciente 445 se le ha dado de alta.
# 479: Al Paciente 454 se le ha dado de alta.

# %%
lista_pacientes2 = []

def registrar_paciente(paciente_id, unidad, cirugia,alcanzo_cama):
    lista_pacientes2.append({
        "id": paciente_id,
        "unidad": unidad,
        "cirugia": cirugia,
        "alcanzo_cama": alcanzo_cama
    })

# %%
for p in simulacion2.pacientes:
    registrar_paciente(p.id, p.unidad.nombre, p.cirugia, p.alcanzo_cama)

dfPacientes2 = pd.DataFrame(lista_pacientes2)
dfPacientes2
# Out:
#       id        unidad  cirugia  alcanzo_cama
# 0      1           UCI    False          True
# 1      2     Urgencias    False          True
# 2      3           UCI    False          True
# 3      4  Consultorios    False          True
# 4      5  Consultorios    False          True
# ..   ...           ...      ...           ...
# 483  484     Urgencias    False         False
# 484  485     Urgencias    False         False
# 485  486  Consultorios    False         False
# 486  487     Urgencias    False         False
# 487  488     Urgencias    False         False
#
# [488 rows x 4 columns]

# %%
lista_eventos2 = []
for p in simulacion2.pacientes:
    lista_eventos2.append( p.eventos )

dfeventos2 = pd.concat(lista_eventos2)
dfeventos2 = dfeventos2.reset_index()
dfeventos2.drop( ["index"], axis=1, inplace=True )

dfeventos2
# Out:
#        id                    evento  time
# 0       1                   LLEGADA     2
# 1       1                  ATENDIDO     2
# 2       1  ASIGNACION_CAMA_PERSONAL     9
# 3       1                      ALTA    29
# 4       2                   LLEGADA     2
# ...   ...                       ...   ...
# 1860  484                   LLEGADA   476
# 1861  485                   LLEGADA   476
# 1862  486                   LLEGADA   476
# 1863  487                   LLEGADA   476
# 1864  488                   LLEGADA   476
#
# [1865 rows x 3 columns]

# %%
dfeventos2["lag_time"] = dfeventos2.groupby("id")["time"].shift(1)

# %%
# Filtramos y calculamos el tiempo de espera
df2 = dfeventos2.loc[dfeventos2["evento"] == "ATENDIDO", :].copy()
df2["tiempo_espera"] = df2["time"] - df2["lag_time"]

# Merge con la info de pacientes (asegúrate de que 'id' esté en ambos)
df_merged2 = df2.merge(dfPacientes2, on="id", how="inner")

# Agrupamos por unidad y calculamos el promedio
resultado2 = (
    df_merged2
    .groupby("unidad")
    .agg({"tiempo_espera": "mean"})
)

print(resultado2)
# Out:
#               tiempo_espera
# unidad
# Consultorios      12.738095
# UCI               14.111888
# Urgencias         14.861224

# %% [markdown]
# ### Resultado
# Notamos que el tiempo de espera promedio se reduce considerablemente, indicando que había suficiente personal
# médico pero este no era bien aprovechado por el bajo rendimiento laboral de las recepcionistas.

# %% [markdown]
# ### Aumento de personal

# %%
env3 = simpy.Environment()
unidades_settings = [
    {"nombre": "Urgencias", "num_camas": 20, "personal": 60, "num_kits_medicos": 8},
    {"nombre": "UCI", "num_camas": 35, "personal": 50, "num_kits_medicos": 1},
    {"nombre": "Consultorios", "num_camas": 10, "personal": 16, "num_kits_medicos": 1}
]
num_recepcionistas = 2

random.seed(111)

simulacion3 = Simulation(env3, unidades_settings, num_recepcionistas)
env3.run(until=60*8)
# Out:
# 2: Paciente 1 llega al hospital a la unidad Consultorios.
# 2: Paciente 2 llega al hospital a la unidad Consultorios.
# 2: Paciente 3 llega al hospital a la unidad Urgencias.
# 2: Paciente 1 es atendido.
# 2: Paciente 2 es atendido.
# 4: Paciente 4 llega al hospital a la unidad UCI.
# 4: Paciente 5 llega al hospital a la unidad Consultorios.
# 4: Paciente 6 llega al hospital a la unidad Urgencias.
# 4: Paciente 7 llega al hospital a la unidad UCI.
# 4: Paciente 8 llega al hospital a la unidad Urgencias.
# 8: Paciente 9 llega al hospital a la unidad Consultorios.
# 8: Paciente 10 llega al hospital a la unidad Urgencias.
# 8: Paciente 11 llega al hospital a la unidad Urgencias.
# 8: Paciente 12 llega al hospital a la unidad Urgencias.
# 8: Paciente 13 llega al hospital a la unidad Urgencias.
# 12: Paciente 14 llega al hospital a la unidad Urgencias.
# 12: Paciente 15 llega al hospital a la unidad UCI.
# 12: Paciente 16 llega al hospital a la unidad Consultorios.
# 14: Paciente 17 llega al hospital a la unidad Urgencias.
# 14: Paciente 18 llega al hospital a la unidad Urgencias.
# 14: Paciente 19 llega al hospital a la unidad Urgencias.
# 16: Paciente 20 llega al hospital a la unidad UCI.
# 16: Paciente 21 llega al hospital a la unidad Consultorios.
# 16: Paciente 22 llega al hospital a la unidad UCI.
# 16: Paciente 23 llega al hospital a la unidad UCI.
# 16: Paciente 24 llega al hospital a la unidad UCI.
# 20: Paciente 25 llega al hospital a la unidad Urgencias.
# 20: Paciente 26 llega al hospital a la unidad Consultorios.
# 20: Paciente 27 llega al hospital a la unidad UCI.
# 20: Paciente 28 llega al hospital a la unidad Consultorios.
# 21: Al Paciente 1 se le asigno una cama y 1 miembro(s) del personal.
# 21: Paciente 3 es atendido.
# 22: Al Paciente 2 se le asigno una cama y 1 miembro(s) del personal.
# 22: Al Paciente 3 se le asigno una cama y 7 miembro(s) del personal.
# 22: Paciente 4 es atendido.
# 22: Paciente 5 es atendido.
# 24: Paciente 29 llega al hospital a la unidad Consultorios.
# 24: Paciente 30 llega al hospital a la unidad Consultorios.
# 24: Paciente 31 llega al hospital a la unidad Urgencias.
# 26: Al Paciente 4 se le asigno una cama y 5 miembro(s) del personal.
# 26: Paciente 6 es atendido.
# 29: Paciente 32 llega al hospital a la unidad UCI.
# 30: Al Paciente 3 se le ha dado de alta.
# 32: Al Paciente 6 se le asigno una cama y 3 miembro(s) del personal.
# 32: El Paciente 6 necesita cirugía.
# 32: Paciente 7 es atendido.
# 32: Al Paciente 6 se le asignó un kit médico.
# 33: Paciente 33 llega al hospital a la unidad Urgencias.
# 33: Paciente 34 llega al hospital a la unidad Consultorios.
# 33: Paciente 35 llega al hospital a la unidad UCI.
# 35: Al Paciente 5 se le asigno una cama y 1 miembro(s) del personal.
# 35: Paciente 8 es atendido.
# 36: Al Paciente 2 se le ha dado de alta.
# 36: Al Paciente 8 se le asigno una cama y 7 miembro(s) del personal.
# 36: El Paciente 8 necesita cirugía.
# 36: Paciente 9 es atendido.
# 36: Al Paciente 8 se le asignó un kit médico.
# 37: Paciente 36 llega al hospital a la unidad Urgencias.
# 38: Al Paciente 7 se le asigno una cama y 8 miembro(s) del personal.
# 38: Paciente 10 es atendido.
# 41: Paciente 37 llega al hospital a la unidad UCI.
# 41: Paciente 38 llega al hospital a la unidad Consultorios.
# 41: Paciente 39 llega al hospital a la unidad UCI.
# 41: Paciente 40 llega al hospital a la unidad Urgencias.
# 41: Paciente 41 llega al hospital a la unidad Urgencias.
# 43: Al Paciente 10 se le asigno una cama y 6 miembro(s) del personal.
# 43: El Paciente 10 necesita cirugía.
# 43: Paciente 42 llega al hospital a la unidad Urgencias.
# 43: Paciente 43 llega al hospital a la unidad UCI.
# 43: Paciente 44 llega al hospital a la unidad Urgencias.
# 43: Paciente 45 llega al hospital a la unidad Urgencias.
# 43: Paciente 11 es atendido.
# 43: Al Paciente 10 se le asignó un kit médico.
# 47: Al Paciente 9 se le asigno una cama y 1 miembro(s) del personal.
# 47: Al Paciente 11 se le asigno una cama y 8 miembro(s) del personal.
# 47: El Paciente 11 necesita cirugía.
# 47: Paciente 12 es atendido.
# 47: Paciente 13 es atendido.
# 47: Al Paciente 11 se le asignó un kit médico.
# 48: Paciente 46 llega al hospital a la unidad Urgencias.
# 48: Paciente 47 llega al hospital a la unidad Urgencias.
# 49: Al Paciente 12 se le asigno una cama y 7 miembro(s) del personal.
# 49: Al Paciente 13 se le asigno una cama y 7 miembro(s) del personal.
# 49: Paciente 48 llega al hospital a la unidad Consultorios.
# 49: Paciente 49 llega al hospital a la unidad Urgencias.
# 49: Paciente 50 llega al hospital a la unidad Urgencias.
# 49: Paciente 14 es atendido.
# 49: Paciente 15 es atendido.
# 50: Al Paciente 1 se le ha dado de alta.
# 51: Al Paciente 15 se le asigno una cama y 4 miembro(s) del personal.
# 51: Paciente 16 es atendido.
# 52: Al Paciente 9 se le ha dado de alta.
# 53: Paciente 51 llega al hospital a la unidad Urgencias.
# 55: Al Paciente 5 se le ha dado de alta.
# 55: Al Paciente 13 se le ha dado de alta.
# 55: Al Paciente 14 se le asigno una cama y 5 miembro(s) del personal.
# 55: Paciente 17 es atendido.
# 56: Al Paciente 4 se le ha dado de alta.
# 56: Al Paciente 17 se le asigno una cama y 8 miembro(s) del personal.
# 56: Paciente 18 es atendido.
# 57: Paciente 52 llega al hospital a la unidad Consultorios.
# 57: Paciente 53 llega al hospital a la unidad UCI.
# 57: Paciente 54 llega al hospital a la unidad Consultorios.
# 57: Paciente 55 llega al hospital a la unidad UCI.
# 57: Al Paciente 18 se le asigno una cama y 5 miembro(s) del personal.
# 57: El Paciente 18 necesita cirugía.
# 57: Paciente 19 es atendido.
# 57: Al Paciente 18 se le asignó un kit médico.
# 58: Al Paciente 19 se le asigno una cama y 4 miembro(s) del personal.
# 58: Paciente 20 es atendido.
# 59: Paciente 56 llega al hospital a la unidad Consultorios.
# 59: Paciente 57 llega al hospital a la unidad UCI.
# 59: Paciente 58 llega al hospital a la unidad Consultorios.
# 60: Paciente 59 llega al hospital a la unidad UCI.
# 62: Al Paciente 20 se le asigno una cama y 6 miembro(s) del personal.
# 62: Paciente 60 llega al hospital a la unidad Consultorios.
# 62: Paciente 61 llega al hospital a la unidad Urgencias.
# 62: Paciente 62 llega al hospital a la unidad UCI.
# 62: Paciente 63 llega al hospital a la unidad UCI.
# 62: Paciente 21 es atendido.
# 63: Al Paciente 7 se le ha dado de alta.
# 63: Paciente 64 llega al hospital a la unidad UCI.
# 63: Paciente 65 llega al hospital a la unidad Urgencias.
# 63: Paciente 66 llega al hospital a la unidad Urgencias.
# 63: Paciente 67 llega al hospital a la unidad UCI.
# 63: Paciente 68 llega al hospital a la unidad Urgencias.
# 65: Paciente 69 llega al hospital a la unidad Consultorios.
# 65: Paciente 70 llega al hospital a la unidad Urgencias.
# 65: Paciente 71 llega al hospital a la unidad Urgencias.
# 65: Paciente 72 llega al hospital a la unidad UCI.
# 65: Paciente 73 llega al hospital a la unidad Urgencias.
# 66: Al Paciente 14 se le ha dado de alta.
# 68: Al Paciente 12 se le ha dado de alta.
# 69: Paciente 74 llega al hospital a la unidad UCI.
# 69: Paciente 75 llega al hospital a la unidad Urgencias.
# 69: Paciente 76 llega al hospital a la unidad Urgencias.
# 70: Al Paciente 17 se le ha dado de alta.
# 70: Al Paciente 21 se le asigno una cama y 1 miembro(s) del personal.
# 70: Paciente 22 es atendido.
# 73: Al Paciente 16 se le asigno una cama y 1 miembro(s) del personal.
# 73: Paciente 77 llega al hospital a la unidad Urgencias.
# 73: Paciente 78 llega al hospital a la unidad Consultorios.
# 73: Paciente 79 llega al hospital a la unidad Consultorios.
# 73: Paciente 23 es atendido.
# 74: Al Paciente 15 se le ha dado de alta.
# 74: Al Paciente 20 se le ha dado de alta.
# 74: Paciente 80 llega al hospital a la unidad Urgencias.
# 74: Paciente 81 llega al hospital a la unidad UCI.
# 74: Paciente 82 llega al hospital a la unidad UCI.
# 74: Paciente 83 llega al hospital a la unidad Urgencias.
# 74: Paciente 84 llega al hospital a la unidad Urgencias.
# 75: Al Paciente 22 se le asigno una cama y 8 miembro(s) del personal.
# 75: Paciente 85 llega al hospital a la unidad UCI.
# 75: Paciente 86 llega al hospital a la unidad Urgencias.
# 75: Paciente 24 es atendido.
# 76: Paciente 87 llega al hospital a la unidad Urgencias.
# 76: Paciente 88 llega al hospital a la unidad UCI.
# 76: Paciente 89 llega al hospital a la unidad Urgencias.
# 77: Paciente 90 llega al hospital a la unidad Urgencias.
# 77: Paciente 91 llega al hospital a la unidad Urgencias.
# 77: Paciente 92 llega al hospital a la unidad Consultorios.
# 80: Al Paciente 23 se le asigno una cama y 6 miembro(s) del personal.
# 80: Al Paciente 24 se le asigno una cama y 8 miembro(s) del personal.
# 80: Paciente 93 llega al hospital a la unidad UCI.
# 80: Paciente 94 llega al hospital a la unidad Consultorios.
# 80: Paciente 95 llega al hospital a la unidad UCI.
# 80: Paciente 25 es atendido.
# 80: Paciente 26 es atendido.
# 85: Paciente 96 llega al hospital a la unidad UCI.
# 85: Paciente 97 llega al hospital a la unidad Urgencias.
# 85: Paciente 98 llega al hospital a la unidad UCI.
# 85: Paciente 99 llega al hospital a la unidad UCI.
# 85: Paciente 100 llega al hospital a la unidad Consultorios.
# 86: Al Paciente 25 se le asigno una cama y 7 miembro(s) del personal.
# 86: El Paciente 25 necesita cirugía.
# 86: Paciente 101 llega al hospital a la unidad Consultorios.
# 86: Paciente 102 llega al hospital a la unidad Consultorios.
# 86: Paciente 103 llega al hospital a la unidad Urgencias.
# 86: Paciente 104 llega al hospital a la unidad Urgencias.
# 86: Paciente 27 es atendido.
# 86: Al Paciente 25 se le asignó un kit médico.
# 87: Al Paciente 19 se le ha dado de alta.
# 89: Paciente 105 llega al hospital a la unidad Consultorios.
# 90: Al Paciente 23 se le ha dado de alta.
# 90: Al Paciente 26 se le asigno una cama y 1 miembro(s) del personal.
# 90: Paciente 106 llega al hospital a la unidad UCI.
# 90: Paciente 107 llega al hospital a la unidad Urgencias.
# 90: Paciente 108 llega al hospital a la unidad Urgencias.
# 90: Paciente 109 llega al hospital a la unidad Consultorios.
# 90: Paciente 110 llega al hospital a la unidad Urgencias.
# 90: Paciente 28 es atendido.
# 91: Al Paciente 21 se le ha dado de alta.
# 91: Al Paciente 27 se le asigno una cama y 5 miembro(s) del personal.
# 91: Paciente 29 es atendido.
# 95: Paciente 111 llega al hospital a la unidad Consultorios.
# 95: Paciente 112 llega al hospital a la unidad Urgencias.
# 95: Paciente 113 llega al hospital a la unidad UCI.
# 96: Paciente 114 llega al hospital a la unidad Urgencias.
# 96: Paciente 115 llega al hospital a la unidad Urgencias.
# 98: Al Paciente 16 se le ha dado de alta.
# 100: Paciente 116 llega al hospital a la unidad UCI.
# 100: Paciente 117 llega al hospital a la unidad Urgencias.
# 102: Al Paciente 22 se le ha dado de alta.
# 103: Al Paciente 26 se le ha dado de alta.
# 103: Paciente 118 llega al hospital a la unidad UCI.
# 103: Paciente 119 llega al hospital a la unidad Urgencias.
# 105: Al Paciente 29 se le asigno una cama y 1 miembro(s) del personal.
# 105: Paciente 30 es atendido.
# 106: Al Paciente 24 se le ha dado de alta.
# 106: Al Paciente 28 se le asigno una cama y 1 miembro(s) del personal.
# 106: Paciente 31 es atendido.
# 108: Paciente 120 llega al hospital a la unidad Urgencias.
# 108: Paciente 121 llega al hospital a la unidad Consultorios.
# 108: Paciente 122 llega al hospital a la unidad UCI.
# 108: Paciente 123 llega al hospital a la unidad Urgencias.
# 108: Paciente 124 llega al hospital a la unidad Urgencias.
# 112: Al Paciente 31 se le asigno una cama y 3 miembro(s) del personal.
# 112: El Paciente 31 necesita cirugía.
# 112: Paciente 32 es atendido.
# 112: Al Paciente 31 se le asignó un kit médico.
# 113: Paciente 125 llega al hospital a la unidad UCI.
# 113: Paciente 126 llega al hospital a la unidad Urgencias.
# 113: Paciente 127 llega al hospital a la unidad Urgencias.
# 113: Paciente 128 llega al hospital a la unidad Consultorios.
# 115: Paciente 129 llega al hospital a la unidad Urgencias.
# 115: Paciente 130 llega al hospital a la unidad UCI.
# 115: Paciente 131 llega al hospital a la unidad Urgencias.
# 115: Paciente 132 llega al hospital a la unidad Urgencias.
# 116: Al Paciente 32 se le asigno una cama y 6 miembro(s) del personal.
# 116: Paciente 33 es atendido.
# 119: Paciente 133 llega al hospital a la unidad Urgencias.
# 119: Paciente 134 llega al hospital a la unidad Consultorios.
# 120: Al Paciente 27 se le ha dado de alta.
# 122: Al Paciente 30 se le asigno una cama y 1 miembro(s) del personal.
# 122: Al Paciente 33 se le asigno una cama y 7 miembro(s) del personal.
# 122: Paciente 135 llega al hospital a la unidad UCI.
# 122: Paciente 136 llega al hospital a la unidad Urgencias.
# 122: Paciente 137 llega al hospital a la unidad Urgencias.
# 122: Paciente 34 es atendido.
# 122: Paciente 35 es atendido.
# 123: Al Paciente 28 se le ha dado de alta.
# 126: Al Paciente 29 se le ha dado de alta.
# 126: Paciente 138 llega al hospital a la unidad Consultorios.
# 126: Paciente 139 llega al hospital a la unidad Urgencias.
# 128: Al Paciente 35 se le asigno una cama y 7 miembro(s) del personal.
# 128: Paciente 140 llega al hospital a la unidad Consultorios.
# 128: Paciente 141 llega al hospital a la unidad Urgencias.
# 128: Paciente 36 es atendido.
# 130: Paciente 142 llega al hospital a la unidad Urgencias.
# 130: Paciente 143 llega al hospital a la unidad Urgencias.
# 130: Paciente 144 llega al hospital a la unidad Urgencias.
# 133: Paciente 145 llega al hospital a la unidad Consultorios.
# 133: Paciente 146 llega al hospital a la unidad Consultorios.
# 134: Paciente 147 llega al hospital a la unidad Consultorios.
# 135: Al Paciente 34 se le asigno una cama y 1 miembro(s) del personal.
# 135: Al Paciente 36 se le asigno una cama y 8 miembro(s) del personal.
# 135: El Paciente 36 necesita cirugía.
# 135: Paciente 148 llega al hospital a la unidad UCI.
# 135: Paciente 37 es atendido.
# 135: Paciente 38 es atendido.
# 135: Al Paciente 36 se le asignó un kit médico.
# 136: Al Paciente 30 se le ha dado de alta.
# 137: Paciente 149 llega al hospital a la unidad Urgencias.
# 137: Al Paciente 37 se le asigno una cama y 8 miembro(s) del personal.
# 137: Paciente 39 es atendido.
# 138: Paciente 150 llega al hospital a la unidad Consultorios.
# 138: Paciente 151 llega al hospital a la unidad UCI.
# 142: Paciente 152 llega al hospital a la unidad UCI.
# 142: Paciente 153 llega al hospital a la unidad Urgencias.
# 142: Paciente 154 llega al hospital a la unidad Urgencias.
# 142: Paciente 155 llega al hospital a la unidad UCI.
# 143: Al Paciente 39 se le asigno una cama y 8 miembro(s) del personal.
# 143: Paciente 40 es atendido.
# 144: Al Paciente 32 se le ha dado de alta.
# 145: Al Paciente 33 se le ha dado de alta.
# 145: Al Paciente 40 se le asigno una cama y 7 miembro(s) del personal.
# 145: El Paciente 40 necesita cirugía.
# 145: Paciente 41 es atendido.
# 146: Al Paciente 35 se le ha dado de alta.
# 146: Paciente 156 llega al hospital a la unidad Consultorios.
# 146: Paciente 157 llega al hospital a la unidad Consultorios.
# 148: Al Paciente 41 se le asigno una cama y 8 miembro(s) del personal.
# 148: Paciente 42 es atendido.
# 149: Al Paciente 39 se le ha dado de alta.
# 151: Paciente 158 llega al hospital a la unidad UCI.
# 153: Al Paciente 42 se le asigno una cama y 3 miembro(s) del personal.
# 153: El Paciente 42 necesita cirugía.
# 153: Paciente 159 llega al hospital a la unidad Urgencias.
# 153: Paciente 43 es atendido.
# 155: Paciente 160 llega al hospital a la unidad Urgencias.
# 155: Paciente 161 llega al hospital a la unidad Urgencias.
# 155: Paciente 162 llega al hospital a la unidad UCI.
# 156: Al Paciente 38 se le asigno una cama y 1 miembro(s) del personal.
# 156: Paciente 44 es atendido.
# 159: Al Paciente 43 se le asigno una cama y 7 miembro(s) del personal.
# 159: Paciente 45 es atendido.
# 160: Paciente 163 llega al hospital a la unidad Urgencias.
# 160: Paciente 164 llega al hospital a la unidad Urgencias.
# 160: Paciente 165 llega al hospital a la unidad Consultorios.
# 161: Al Paciente 34 se le ha dado de alta.
# 161: Paciente 166 llega al hospital a la unidad Consultorios.
# 162: Al Paciente 44 se le asigno una cama y 4 miembro(s) del personal.
# 162: El Paciente 44 necesita cirugía.
# 162: Paciente 46 es atendido.
# 163: Al Paciente 45 se le asigno una cama y 3 miembro(s) del personal.
# 163: Paciente 47 es atendido.
# 164: Al Paciente 37 se le ha dado de alta.
# 165: Al Paciente 41 se le ha dado de alta.
# 165: Paciente 167 llega al hospital a la unidad Urgencias.
# 165: Paciente 168 llega al hospital a la unidad Urgencias.
# 165: Paciente 169 llega al hospital a la unidad Urgencias.
# 165: Paciente 170 llega al hospital a la unidad Urgencias.
# 166: Cirugía completada para el Paciente 36.
# 166: Paciente 36 murió tras el procedimiento.
# 166: Al Paciente 43 se le ha dado de alta.
# 166: Paciente 171 llega al hospital a la unidad Consultorios.
# 166: Paciente 172 llega al hospital a la unidad Urgencias.
# 166: Paciente 173 llega al hospital a la unidad Urgencias.
# 166: Paciente 174 llega al hospital a la unidad Urgencias.
# 166: Paciente 175 llega al hospital a la unidad UCI.
# 166: Al Paciente 40 se le asignó un kit médico.
# 167: Al Paciente 46 se le asigno una cama y 4 miembro(s) del personal.
# 167: Al Paciente 47 se le asigno una cama y 7 miembro(s) del personal.
# 167: Paciente 48 es atendido.
# 167: Paciente 49 es atendido.
# 169: Paciente 176 llega al hospital a la unidad UCI.
# 170: Al Paciente 49 se le asigno una cama y 6 miembro(s) del personal.
# 170: El Paciente 49 necesita cirugía.
# 170: Paciente 50 es atendido.
# 171: Paciente 177 llega al hospital a la unidad Urgencias.
# 173: Paciente 178 llega al hospital a la unidad UCI.
# 173: Paciente 179 llega al hospital a la unidad UCI.
# 173: Paciente 180 llega al hospital a la unidad Consultorios.
# 174: Al Paciente 47 se le ha dado de alta.
# 176: Paciente 181 llega al hospital a la unidad UCI.
# 176: Paciente 182 llega al hospital a la unidad Urgencias.
# 176: Paciente 183 llega al hospital a la unidad Consultorios.
# 176: Paciente 184 llega al hospital a la unidad UCI.
# 177: Al Paciente 50 se le asigno una cama y 7 miembro(s) del personal.
# 177: El Paciente 50 necesita cirugía.
# 177: Paciente 51 es atendido.
# 179: Paciente 185 llega al hospital a la unidad Urgencias.
# 179: Paciente 186 llega al hospital a la unidad UCI.
# 179: Paciente 187 llega al hospital a la unidad UCI.
# 179: Paciente 188 llega al hospital a la unidad Consultorios.
# 179: Paciente 189 llega al hospital a la unidad UCI.
# 180: Al Paciente 48 se le asigno una cama y 1 miembro(s) del personal.
# 180: Paciente 190 llega al hospital a la unidad Consultorios.
# 180: Paciente 191 llega al hospital a la unidad UCI.
# 180: Paciente 192 llega al hospital a la unidad Urgencias.
# 180: Paciente 193 llega al hospital a la unidad UCI.
# 180: Paciente 194 llega al hospital a la unidad Urgencias.
# 180: Paciente 52 es atendido.
# 181: Al Paciente 45 se le ha dado de alta.
# 181: Al Paciente 51 se le asigno una cama y 7 miembro(s) del personal.
# 181: Paciente 53 es atendido.
# 182: Paciente 195 llega al hospital a la unidad Urgencias.
# 182: Al Paciente 53 se le asigno una cama y 4 miembro(s) del personal.
# 182: Paciente 54 es atendido.
# 184: Al Paciente 38 se le ha dado de alta.
# 185: Paciente 196 llega al hospital a la unidad Consultorios.
# 185: Paciente 197 llega al hospital a la unidad UCI.
# 185: Paciente 198 llega al hospital a la unidad Urgencias.
# 185: Paciente 199 llega al hospital a la unidad Urgencias.
# 185: Paciente 200 llega al hospital a la unidad Urgencias.
# 187: Paciente 201 llega al hospital a la unidad UCI.
# 187: Paciente 202 llega al hospital a la unidad Urgencias.
# 187: Paciente 203 llega al hospital a la unidad Urgencias.
# 188: Paciente 204 llega al hospital a la unidad Urgencias.
# 190: Al Paciente 46 se le ha dado de alta.
# 190: Paciente 205 llega al hospital a la unidad Urgencias.
# 191: Paciente 206 llega al hospital a la unidad Urgencias.
# 191: Paciente 207 llega al hospital a la unidad Urgencias.
# 191: Paciente 208 llega al hospital a la unidad Urgencias.
# 192: Al Paciente 53 se le ha dado de alta.
# 192: Al Paciente 54 se le asigno una cama y 1 miembro(s) del personal.
# 192: Paciente 55 es atendido.
# 196: Paciente 209 llega al hospital a la unidad Urgencias.
# 196: Paciente 210 llega al hospital a la unidad Urgencias.
# 196: Paciente 211 llega al hospital a la unidad Urgencias.
# 196: Al Paciente 55 se le asigno una cama y 6 miembro(s) del personal.
# 196: Paciente 56 es atendido.
# 198: Al Paciente 48 se le ha dado de alta.
# 199: Al Paciente 52 se le asigno una cama y 1 miembro(s) del personal.
# 199: Paciente 57 es atendido.
# 200: Al Paciente 54 se le ha dado de alta.
# 201: Paciente 212 llega al hospital a la unidad Consultorios.
# 201: Paciente 213 llega al hospital a la unidad Urgencias.
# 201: Paciente 214 llega al hospital a la unidad Urgencias.
# 201: Paciente 215 llega al hospital a la unidad Urgencias.
# 201: Al Paciente 57 se le asigno una cama y 5 miembro(s) del personal.
# 201: Paciente 58 es atendido.
# 204: Paciente 216 llega al hospital a la unidad UCI.
# 204: Paciente 217 llega al hospital a la unidad Consultorios.
# 204: Paciente 218 llega al hospital a la unidad Consultorios.
# 205: Al Paciente 51 se le ha dado de alta.
# 205: Paciente 219 llega al hospital a la unidad UCI.
# 205: Paciente 220 llega al hospital a la unidad Urgencias.
# 205: Paciente 221 llega al hospital a la unidad Consultorios.
# 210: Paciente 222 llega al hospital a la unidad Urgencias.
# 212: Al Paciente 56 se le asigno una cama y 1 miembro(s) del personal.
# 212: Paciente 59 es atendido.
# 213: Paciente 223 llega al hospital a la unidad UCI.
# 213: El Paciente 42 murió esperando un kit médico.
# 214: Paciente 224 llega al hospital a la unidad Urgencias.
# 218: Al Paciente 59 se le asigno una cama y 5 miembro(s) del personal.
# 218: Paciente 60 es atendido.
# 219: Al Paciente 57 se le ha dado de alta.
# 219: Paciente 225 llega al hospital a la unidad Urgencias.
# 219: Paciente 226 llega al hospital a la unidad Urgencias.
# 220: Al Paciente 55 se le ha dado de alta.
# 222: Paciente 227 llega al hospital a la unidad Urgencias.
# 222: El Paciente 44 murió esperando un kit médico.
# 223: Al Paciente 52 se le ha dado de alta.
# 224: Paciente 228 llega al hospital a la unidad UCI.
# 226: Al Paciente 58 se le asigno una cama y 1 miembro(s) del personal.
# 226: Paciente 61 es atendido.
# 229: Paciente 229 llega al hospital a la unidad UCI.
# 229: Paciente 230 llega al hospital a la unidad Urgencias.
# 229: Paciente 231 llega al hospital a la unidad Consultorios.
# 229: Paciente 232 llega al hospital a la unidad Urgencias.
# 230: Al Paciente 61 se le asigno una cama y 6 miembro(s) del personal.
# 230: El Paciente 61 necesita cirugía.
# 230: El Paciente 49 murió esperando un kit médico.
# 230: Paciente 62 es atendido.
# 231: Al Paciente 59 se le ha dado de alta.
# 234: Paciente 233 llega al hospital a la unidad Urgencias.
# 234: Paciente 234 llega al hospital a la unidad Urgencias.
# 234: Paciente 235 llega al hospital a la unidad Consultorios.
# 234: Al Paciente 62 se le asigno una cama y 6 miembro(s) del personal.
# 234: Paciente 63 es atendido.
# 237: Paciente 236 llega al hospital a la unidad UCI.
# 237: Paciente 237 llega al hospital a la unidad UCI.
# 237: Paciente 238 llega al hospital a la unidad Urgencias.
# 237: El Paciente 50 murió esperando un kit médico.
# 239: Paciente 239 llega al hospital a la unidad Urgencias.
# 239: Paciente 240 llega al hospital a la unidad Urgencias.
# 240: Al Paciente 63 se le asigno una cama y 7 miembro(s) del personal.
# 240: Paciente 241 llega al hospital a la unidad Urgencias.
# 240: Paciente 242 llega al hospital a la unidad UCI.
# 240: Paciente 243 llega al hospital a la unidad Urgencias.
# 240: Paciente 244 llega al hospital a la unidad UCI.
# 240: Paciente 64 es atendido.
# 241: Al Paciente 56 se le ha dado de alta.
# 241: Al Paciente 64 se le asigno una cama y 7 miembro(s) del personal.
# 241: Paciente 65 es atendido.
# 242: Al Paciente 60 se le asigno una cama y 1 miembro(s) del personal.
# 242: Al Paciente 65 se le asigno una cama y 4 miembro(s) del personal.
# 242: Paciente 66 es atendido.
# 242: Paciente 67 es atendido.
# 245: Paciente 245 llega al hospital a la unidad Consultorios.
# 245: Paciente 246 llega al hospital a la unidad UCI.
# 245: Paciente 247 llega al hospital a la unidad UCI.
# 245: Al Paciente 67 se le asigno una cama y 8 miembro(s) del personal.
# 245: Paciente 68 es atendido.
# 246: Paciente 248 llega al hospital a la unidad UCI.
# 246: Paciente 249 llega al hospital a la unidad Consultorios.
# 247: Al Paciente 58 se le ha dado de alta.
# 247: Al Paciente 66 se le asigno una cama y 7 miembro(s) del personal.
# 247: Paciente 250 llega al hospital a la unidad UCI.
# 247: Paciente 69 es atendido.
# 249: Cirugía completada para el Paciente 25.
# 249: Paciente 25 se le ha dado de alta.
# 249: Al Paciente 68 se le asigno una cama y 5 miembro(s) del personal.
# 249: Paciente 70 es atendido.
# 249: Al Paciente 61 se le asignó un kit médico.
# 251: Al Paciente 62 se le ha dado de alta.
# 251: Al Paciente 60 se le ha dado de alta.
# 251: Al Paciente 67 se le ha dado de alta.
# 252: Paciente 251 llega al hospital a la unidad Consultorios.
# 254: Al Paciente 70 se le asigno una cama y 3 miembro(s) del personal.
# 254: Paciente 71 es atendido.
# 255: Al Paciente 71 se le asigno una cama y 5 miembro(s) del personal.
# 255: Paciente 72 es atendido.
# 256: Al Paciente 65 se le ha dado de alta.
# 256: Paciente 252 llega al hospital a la unidad Urgencias.
# 256: Paciente 253 llega al hospital a la unidad Urgencias.
# 256: Paciente 254 llega al hospital a la unidad Urgencias.
# 256: Paciente 255 llega al hospital a la unidad UCI.
# 256: Paciente 256 llega al hospital a la unidad Urgencias.
# 257: Al Paciente 68 se le ha dado de alta.
# 257: Paciente 257 llega al hospital a la unidad UCI.
# 261: Al Paciente 72 se le asigno una cama y 7 miembro(s) del personal.
# 261: Paciente 73 es atendido.
# 262: Paciente 258 llega al hospital a la unidad Urgencias.
# 262: Paciente 259 llega al hospital a la unidad Consultorios.
# 262: Paciente 260 llega al hospital a la unidad Consultorios.
# 263: Paciente 261 llega al hospital a la unidad Urgencias.
# 263: Paciente 262 llega al hospital a la unidad Consultorios.
# 266: Al Paciente 64 se le ha dado de alta.
# 266: Al Paciente 73 se le asigno una cama y 3 miembro(s) del personal.
# 266: El Paciente 73 necesita cirugía.
# 266: Paciente 263 llega al hospital a la unidad Consultorios.
# 266: Paciente 264 llega al hospital a la unidad UCI.
# 266: Paciente 265 llega al hospital a la unidad Urgencias.
# 266: Paciente 74 es atendido.
# 268: Paciente 266 llega al hospital a la unidad Urgencias.
# 270: Al Paciente 63 se le ha dado de alta.
# 270: Al Paciente 74 se le asigno una cama y 4 miembro(s) del personal.
# 270: Paciente 267 llega al hospital a la unidad Urgencias.
# 270: Paciente 268 llega al hospital a la unidad UCI.
# 270: Paciente 269 llega al hospital a la unidad Urgencias.
# 270: Paciente 270 llega al hospital a la unidad Urgencias.
# 270: Paciente 271 llega al hospital a la unidad Urgencias.
# 270: Paciente 75 es atendido.
# 272: Al Paciente 69 se le asigno una cama y 1 miembro(s) del personal.
# 272: Paciente 272 llega al hospital a la unidad Urgencias.
# 272: Paciente 273 llega al hospital a la unidad Urgencias.
# 272: Paciente 274 llega al hospital a la unidad Consultorios.
# 272: Al Paciente 75 se le asigno una cama y 7 miembro(s) del personal.
# 272: Paciente 76 es atendido.
# 272: Paciente 77 es atendido.
# 274: Paciente 275 llega al hospital a la unidad Consultorios.
# 274: Paciente 276 llega al hospital a la unidad Consultorios.
# 274: Paciente 277 llega al hospital a la unidad Urgencias.
# 275: Al Paciente 77 se le asigno una cama y 7 miembro(s) del personal.
# 275: Paciente 78 es atendido.
# 276: Al Paciente 66 se le ha dado de alta.
# 276: Al Paciente 70 se le ha dado de alta.
# 276: Al Paciente 74 se le ha dado de alta.
# 276: Al Paciente 76 se le asigno una cama y 8 miembro(s) del personal.
# 276: El Paciente 76 necesita cirugía.
# 276: Paciente 79 es atendido.
# 278: Al Paciente 71 se le ha dado de alta.
# 279: Paciente 278 llega al hospital a la unidad Urgencias.
# 279: Paciente 279 llega al hospital a la unidad Urgencias.
# 279: Paciente 280 llega al hospital a la unidad Urgencias.
# 279: Paciente 281 llega al hospital a la unidad Consultorios.
# 279: Paciente 282 llega al hospital a la unidad Urgencias.
# 280: Al Paciente 72 se le ha dado de alta.
# 283: Cirugía completada para el Paciente 40.
# 283: Paciente 40 se le ha dado de alta.
# 283: Paciente 283 llega al hospital a la unidad Urgencias.
# 283: Paciente 284 llega al hospital a la unidad Consultorios.
# 283: Al Paciente 73 se le asignó un kit médico.
# 284: Paciente 285 llega al hospital a la unidad Consultorios.
# 287: Al Paciente 78 se le asigno una cama y 1 miembro(s) del personal.
# 287: Paciente 286 llega al hospital a la unidad Urgencias.
# 287: Paciente 287 llega al hospital a la unidad Consultorios.
# 287: Paciente 288 llega al hospital a la unidad Consultorios.
# 287: Paciente 80 es atendido.
# 288: Al Paciente 79 se le asigno una cama y 1 miembro(s) del personal.
# 288: Paciente 81 es atendido.
# 289: Al Paciente 75 se le ha dado de alta.
# 290: Al Paciente 77 se le ha dado de alta.
# 290: Paciente 289 llega al hospital a la unidad Urgencias.
# 290: Paciente 290 llega al hospital a la unidad UCI.
# 290: Paciente 291 llega al hospital a la unidad Urgencias.
# 293: Al Paciente 80 se le asigno una cama y 7 miembro(s) del personal.
# 293: El Paciente 80 necesita cirugía.
# 293: Al Paciente 81 se le asigno una cama y 3 miembro(s) del personal.
# 293: Paciente 82 es atendido.
# 293: Paciente 83 es atendido.
# 295: Paciente 292 llega al hospital a la unidad Consultorios.
# 295: Paciente 293 llega al hospital a la unidad UCI.
# 295: Al Paciente 83 se le asigno una cama y 4 miembro(s) del personal.
# 295: Paciente 84 es atendido.
# 296: Al Paciente 82 se le asigno una cama y 8 miembro(s) del personal.
# 296: Paciente 85 es atendido.
# 297: Al Paciente 69 se le ha dado de alta.
# 297: Al Paciente 85 se le asigno una cama y 8 miembro(s) del personal.
# 297: Paciente 86 es atendido.
# 298: Paciente 294 llega al hospital a la unidad Consultorios.
# 298: Paciente 295 llega al hospital a la unidad UCI.
# 298: Paciente 296 llega al hospital a la unidad UCI.
# 299: Paciente 297 llega al hospital a la unidad Urgencias.
# 299: Paciente 298 llega al hospital a la unidad UCI.
# 299: Paciente 299 llega al hospital a la unidad UCI.
# 299: Paciente 300 llega al hospital a la unidad Urgencias.
# 299: Paciente 301 llega al hospital a la unidad Consultorios.
# 300: Al Paciente 86 se le asigno una cama y 6 miembro(s) del personal.
# 300: Paciente 302 llega al hospital a la unidad Consultorios.
# 300: Paciente 303 llega al hospital a la unidad Urgencias.
# 300: Paciente 304 llega al hospital a la unidad Urgencias.
# 300: Paciente 87 es atendido.
# 301: Al Paciente 78 se le ha dado de alta.
# 302: Al Paciente 84 se le asigno una cama y 4 miembro(s) del personal.
# 302: El Paciente 84 necesita cirugía.
# 302: Paciente 88 es atendido.
# 304: Cirugía completada para el Paciente 6.
# 304: Paciente 6 se le ha dado de alta.
# 304: Paciente 305 llega al hospital a la unidad Urgencias.
# 304: Paciente 306 llega al hospital a la unidad Urgencias.
# 304: Paciente 307 llega al hospital a la unidad Urgencias.
# 304: Paciente 308 llega al hospital a la unidad Urgencias.
# 304: Paciente 309 llega al hospital a la unidad UCI.
# 304: Al Paciente 76 se le asignó un kit médico.
# 305: Al Paciente 83 se le ha dado de alta.
# 305: Paciente 310 llega al hospital a la unidad UCI.
# 306: Al Paciente 87 se le asigno una cama y 5 miembro(s) del personal.
# 306: Paciente 89 es atendido.
# 307: Al Paciente 88 se le asigno una cama y 6 miembro(s) del personal.
# 307: Paciente 311 llega al hospital a la unidad UCI.
# 307: Paciente 312 llega al hospital a la unidad Urgencias.
# 307: Paciente 313 llega al hospital a la unidad Urgencias.
# 307: Paciente 90 es atendido.
# 311: Al Paciente 86 se le ha dado de alta.
# 312: Al Paciente 89 se le asigno una cama y 3 miembro(s) del personal.
# 312: El Paciente 89 necesita cirugía.
# 312: Paciente 314 llega al hospital a la unidad UCI.
# 312: Paciente 315 llega al hospital a la unidad Urgencias.
# 312: Paciente 316 llega al hospital a la unidad Urgencias.
# 312: Paciente 91 es atendido.
# 313: Al Paciente 79 se le ha dado de alta.
# 313: Al Paciente 85 se le ha dado de alta.
# 314: Al Paciente 90 se le asigno una cama y 3 miembro(s) del personal.
# 314: El Paciente 90 necesita cirugía.
# 314: Al Paciente 91 se le asigno una cama y 8 miembro(s) del personal.
# 314: El Paciente 91 necesita cirugía.
# 314: Paciente 92 es atendido.
# 314: Paciente 93 es atendido.
# 315: Al Paciente 81 se le ha dado de alta.
# 315: Al Paciente 87 se le ha dado de alta.
# 315: Paciente 317 llega al hospital a la unidad Urgencias.
# 315: Paciente 318 llega al hospital a la unidad Urgencias.
# 315: Paciente 319 llega al hospital a la unidad UCI.
# 316: Paciente 320 llega al hospital a la unidad Consultorios.
# 316: Paciente 321 llega al hospital a la unidad UCI.
# 316: Paciente 322 llega al hospital a la unidad Urgencias.
# 316: Paciente 323 llega al hospital a la unidad UCI.
# 316: Paciente 324 llega al hospital a la unidad UCI.
# 317: Paciente 325 llega al hospital a la unidad Consultorios.
# 317: Paciente 326 llega al hospital a la unidad Consultorios.
# 317: Paciente 327 llega al hospital a la unidad Consultorios.
# 319: Al Paciente 82 se le ha dado de alta.
# 320: Paciente 328 llega al hospital a la unidad Consultorios.
# 320: Paciente 329 llega al hospital a la unidad Urgencias.
# 320: Paciente 330 llega al hospital a la unidad UCI.
# 320: Paciente 331 llega al hospital a la unidad UCI.
# 321: Al Paciente 92 se le asigno una cama y 1 miembro(s) del personal.
# 321: Al Paciente 93 se le asigno una cama y 8 miembro(s) del personal.
# 321: Paciente 94 es atendido.
# 321: Paciente 95 es atendido.
# 324: Paciente 332 llega al hospital a la unidad UCI.
# 325: Al Paciente 88 se le ha dado de alta.
# 328: Al Paciente 95 se le asigno una cama y 6 miembro(s) del personal.
# 328: Paciente 333 llega al hospital a la unidad Consultorios.
# 328: Paciente 334 llega al hospital a la unidad UCI.
# 328: Paciente 335 llega al hospital a la unidad UCI.
# 328: Paciente 96 es atendido.
# 330: Cirugía completada para el Paciente 61.
# 330: Paciente 61 se le ha dado de alta.
# 330: Al Paciente 80 se le asignó un kit médico.
# 332: Paciente 336 llega al hospital a la unidad UCI.
# 335: Al Paciente 96 se le asigno una cama y 7 miembro(s) del personal.
# 335: Paciente 337 llega al hospital a la unidad Urgencias.
# 335: Paciente 338 llega al hospital a la unidad Urgencias.
# 335: Paciente 339 llega al hospital a la unidad UCI.
# 335: Paciente 340 llega al hospital a la unidad Consultorios.
# 335: Paciente 97 es atendido.
# 337: Paciente 341 llega al hospital a la unidad Urgencias.
# 337: Paciente 342 llega al hospital a la unidad Consultorios.
# 337: Paciente 343 llega al hospital a la unidad UCI.
# 337: Paciente 344 llega al hospital a la unidad UCI.
# 337: Paciente 345 llega al hospital a la unidad Consultorios.
# 338: Paciente 346 llega al hospital a la unidad Urgencias.
# 338: Paciente 347 llega al hospital a la unidad Urgencias.
# 338: Paciente 348 llega al hospital a la unidad Urgencias.
# 339: Al Paciente 97 se le asigno una cama y 4 miembro(s) del personal.
# 339: Paciente 98 es atendido.
# 340: Al Paciente 94 se le asigno una cama y 1 miembro(s) del personal.
# 340: Paciente 99 es atendido.
# 342: Paciente 349 llega al hospital a la unidad UCI.
# 342: Paciente 350 llega al hospital a la unidad Consultorios.
# 342: Paciente 351 llega al hospital a la unidad Urgencias.
# 342: Paciente 352 llega al hospital a la unidad Consultorios.
# 342: Paciente 353 llega al hospital a la unidad Consultorios.
# 343: Al Paciente 92 se le ha dado de alta.
# 345: Al Paciente 98 se le asigno una cama y 7 miembro(s) del personal.
# 345: Paciente 100 es atendido.
# 346: Al Paciente 95 se le ha dado de alta.
# 346: Cirugía completada para el Paciente 80.
# 346: Paciente 80 se le ha dado de alta.
# 346: Paciente 354 llega al hospital a la unidad Consultorios.
# 346: Paciente 355 llega al hospital a la unidad Consultorios.
# 346: Paciente 356 llega al hospital a la unidad UCI.
# 346: Paciente 357 llega al hospital a la unidad UCI.
# 346: Al Paciente 84 se le asignó un kit médico.
# 347: Cirugía completada para el Paciente 10.
# 347: Paciente 10 se le ha dado de alta.
# 347: Al Paciente 99 se le asigno una cama y 6 miembro(s) del personal.
# 347: Paciente 358 llega al hospital a la unidad Urgencias.
# 347: Paciente 101 es atendido.
# 347: Al Paciente 89 se le asignó un kit médico.
# 348: Paciente 359 llega al hospital a la unidad Consultorios.
# 348: Paciente 360 llega al hospital a la unidad UCI.
# 348: Paciente 361 llega al hospital a la unidad Consultorios.
# 349: Al Paciente 93 se le ha dado de alta.
# 353: Cirugía completada para el Paciente 31.
# 353: Paciente 31 se le ha dado de alta.
# 353: Al Paciente 98 se le ha dado de alta.
# 353: Paciente 362 llega al hospital a la unidad UCI.
# 353: Al Paciente 90 se le asignó un kit médico.
# 357: Al Paciente 100 se le asigno una cama y 1 miembro(s) del personal.
# 357: Paciente 363 llega al hospital a la unidad UCI.
# 357: Paciente 364 llega al hospital a la unidad Urgencias.
# 357: Paciente 365 llega al hospital a la unidad UCI.
# 357: Paciente 366 llega al hospital a la unidad Urgencias.
# 357: Paciente 102 es atendido.
# 358: Al Paciente 96 se le ha dado de alta.
# 361: Paciente 367 llega al hospital a la unidad UCI.
# 361: Paciente 368 llega al hospital a la unidad UCI.
# 361: Paciente 369 llega al hospital a la unidad UCI.
# 361: Paciente 370 llega al hospital a la unidad Urgencias.
# 363: Al Paciente 99 se le ha dado de alta.
# 363: Al Paciente 101 se le asigno una cama y 1 miembro(s) del personal.
# 363: Paciente 103 es atendido.
# 364: Al Paciente 94 se le ha dado de alta.
# 364: Al Paciente 102 se le asigno una cama y 1 miembro(s) del personal.
# 364: Paciente 104 es atendido.
# 365: Paciente 371 llega al hospital a la unidad UCI.
# 365: Paciente 372 llega al hospital a la unidad Consultorios.
# 365: Paciente 373 llega al hospital a la unidad Urgencias.
# 365: Paciente 374 llega al hospital a la unidad Consultorios.
# 365: Al Paciente 103 se le asigno una cama y 4 miembro(s) del personal.
# 365: Al Paciente 104 se le asigno una cama y 6 miembro(s) del personal.
# 365: Paciente 105 es atendido.
# 365: Paciente 106 es atendido.
# 367: Paciente 375 llega al hospital a la unidad UCI.
# 367: Paciente 376 llega al hospital a la unidad Urgencias.
# 367: Paciente 377 llega al hospital a la unidad Urgencias.
# 369: Al Paciente 97 se le ha dado de alta.
# 370: Al Paciente 106 se le asigno una cama y 3 miembro(s) del personal.
# 370: Paciente 107 es atendido.
# 371: Paciente 378 llega al hospital a la unidad UCI.
# 371: Paciente 379 llega al hospital a la unidad Urgencias.
# 371: Paciente 380 llega al hospital a la unidad Urgencias.
# 374: Al Paciente 101 se le ha dado de alta.
# 374: El Paciente 91 murió esperando un kit médico.
# 375: Paciente 381 llega al hospital a la unidad Urgencias.
# 375: Paciente 382 llega al hospital a la unidad UCI.
# 375: Paciente 383 llega al hospital a la unidad UCI.
# 375: Paciente 384 llega al hospital a la unidad UCI.
# 375: Paciente 385 llega al hospital a la unidad UCI.
# 377: Al Paciente 102 se le ha dado de alta.
# 377: Al Paciente 106 se le ha dado de alta.
# 377: Al Paciente 107 se le asigno una cama y 7 miembro(s) del personal.
# 377: El Paciente 107 necesita cirugía.
# 377: Paciente 108 es atendido.
# 379: Paciente 386 llega al hospital a la unidad Urgencias.
# 379: Paciente 387 llega al hospital a la unidad UCI.
# 379: Paciente 388 llega al hospital a la unidad Urgencias.
# 380: Al Paciente 100 se le ha dado de alta.
# 381: Paciente 389 llega al hospital a la unidad Urgencias.
# 381: Paciente 390 llega al hospital a la unidad Consultorios.
# 381: Paciente 391 llega al hospital a la unidad UCI.
# 381: Paciente 392 llega al hospital a la unidad UCI.
# 382: Al Paciente 104 se le ha dado de alta.
# 382: Al Paciente 108 se le asigno una cama y 6 miembro(s) del personal.
# 382: El Paciente 108 necesita cirugía.
# 382: Paciente 393 llega al hospital a la unidad UCI.
# 382: Paciente 109 es atendido.
# 387: Al Paciente 105 se le asigno una cama y 1 miembro(s) del personal.
# 387: Paciente 394 llega al hospital a la unidad Urgencias.
# 387: Paciente 395 llega al hospital a la unidad UCI.
# 387: Paciente 396 llega al hospital a la unidad Consultorios.
# 387: Paciente 110 es atendido.
# 388: Al Paciente 103 se le ha dado de alta.
# 388: Al Paciente 110 se le asigno una cama y 5 miembro(s) del personal.
# 388: Paciente 111 es atendido.
# 390: Paciente 397 llega al hospital a la unidad Urgencias.
# 390: Paciente 398 llega al hospital a la unidad Consultorios.
# 390: Paciente 399 llega al hospital a la unidad Consultorios.
# 390: Paciente 400 llega al hospital a la unidad Urgencias.
# 390: Paciente 401 llega al hospital a la unidad UCI.
# 391: Paciente 402 llega al hospital a la unidad UCI.
# 391: Paciente 403 llega al hospital a la unidad Urgencias.
# 396: Al Paciente 109 se le asigno una cama y 1 miembro(s) del personal.
# 396: Paciente 404 llega al hospital a la unidad UCI.
# 396: Paciente 405 llega al hospital a la unidad Consultorios.
# 396: Paciente 406 llega al hospital a la unidad UCI.
# 396: Paciente 407 llega al hospital a la unidad UCI.
# 396: Paciente 408 llega al hospital a la unidad Urgencias.
# 396: Paciente 112 es atendido.
# 400: Paciente 409 llega al hospital a la unidad UCI.
# 400: Paciente 410 llega al hospital a la unidad Urgencias.
# 400: Paciente 411 llega al hospital a la unidad Consultorios.
# 400: Paciente 412 llega al hospital a la unidad UCI.
# 400: Paciente 413 llega al hospital a la unidad Urgencias.
# 400: Al Paciente 112 se le asigno una cama y 8 miembro(s) del personal.
# 400: Paciente 113 es atendido.
# 401: Al Paciente 111 se le asigno una cama y 1 miembro(s) del personal.
# 401: Paciente 114 es atendido.
# 402: Al Paciente 105 se le ha dado de alta.
# 403: Al Paciente 113 se le asigno una cama y 8 miembro(s) del personal.
# 403: Paciente 115 es atendido.
# 404: Paciente 414 llega al hospital a la unidad Urgencias.
# 404: Paciente 415 llega al hospital a la unidad UCI.
# 406: Al Paciente 114 se le asigno una cama y 6 miembro(s) del personal.
# 406: El Paciente 114 necesita cirugía.
# 406: Paciente 116 es atendido.
# 407: Al Paciente 112 se le ha dado de alta.
# 407: Paciente 416 llega al hospital a la unidad UCI.
# 408: Al Paciente 116 se le asigno una cama y 8 miembro(s) del personal.
# 408: Paciente 117 es atendido.
# 409: Cirugía completada para el Paciente 8.
# 409: Paciente 8 se le ha dado de alta.
# 409: Al Paciente 115 se le asigno una cama y 5 miembro(s) del personal.
# 409: Paciente 118 es atendido.
# 409: Al Paciente 107 se le asignó un kit médico.
# 410: Paciente 417 llega al hospital a la unidad UCI.
# 410: Paciente 418 llega al hospital a la unidad Consultorios.
# 410: Paciente 419 llega al hospital a la unidad Consultorios.
# 412: Al Paciente 110 se le ha dado de alta.
# 412: Paciente 420 llega al hospital a la unidad UCI.
# 412: Paciente 421 llega al hospital a la unidad Urgencias.
# 412: Paciente 422 llega al hospital a la unidad Urgencias.
# 414: Al Paciente 118 se le asigno una cama y 3 miembro(s) del personal.
# 414: Paciente 119 es atendido.
# 415: Cirugía completada para el Paciente 11.
# 415: Paciente 11 se le ha dado de alta.
# 415: Al Paciente 117 se le asigno una cama y 5 miembro(s) del personal.
# 415: El Paciente 117 necesita cirugía.
# 415: Paciente 120 es atendido.
# 415: Al Paciente 108 se le asignó un kit médico.
# 416: Paciente 423 llega al hospital a la unidad Urgencias.
# 416: Paciente 424 llega al hospital a la unidad UCI.
# 416: Paciente 425 llega al hospital a la unidad Urgencias.
# 416: Al Paciente 119 se le asigno una cama y 7 miembro(s) del personal.
# 416: Paciente 121 es atendido.
# 417: Al Paciente 120 se le asigno una cama y 8 miembro(s) del personal.
# 417: Paciente 122 es atendido.
# 418: Al Paciente 113 se le ha dado de alta.
# 418: Al Paciente 122 se le asigno una cama y 3 miembro(s) del personal.
# 418: Paciente 123 es atendido.
# 419: Paciente 426 llega al hospital a la unidad UCI.
# 419: Paciente 427 llega al hospital a la unidad Urgencias.
# 419: Paciente 428 llega al hospital a la unidad Urgencias.
# 420: Al Paciente 123 se le asigno una cama y 5 miembro(s) del personal.
# 420: Paciente 124 es atendido.
# 423: Paciente 429 llega al hospital a la unidad Urgencias.
# 423: Paciente 430 llega al hospital a la unidad UCI.
# 424: Al Paciente 109 se le ha dado de alta.
# 424: Al Paciente 124 se le asigno una cama y 5 miembro(s) del personal.
# 424: El Paciente 124 necesita cirugía.
# 424: Paciente 125 es atendido.
# 425: Al Paciente 121 se le asigno una cama y 1 miembro(s) del personal.
# 425: Paciente 126 es atendido.
# 426: Paciente 431 llega al hospital a la unidad Urgencias.
# 426: Paciente 432 llega al hospital a la unidad Consultorios.
# 426: Paciente 433 llega al hospital a la unidad Urgencias.
# 428: Al Paciente 125 se le asigno una cama y 8 miembro(s) del personal.
# 428: Al Paciente 126 se le asigno una cama y 8 miembro(s) del personal.
# 428: Paciente 127 es atendido.
# 428: Paciente 128 es atendido.
# 429: Paciente 434 llega al hospital a la unidad UCI.
# 429: Paciente 435 llega al hospital a la unidad Urgencias.
# 429: Paciente 436 llega al hospital a la unidad Consultorios.
# 429: Paciente 437 llega al hospital a la unidad UCI.
# 430: Al Paciente 111 se le ha dado de alta.
# 430: Al Paciente 119 se le ha dado de alta.
# 432: Al Paciente 127 se le asigno una cama y 5 miembro(s) del personal.
# 432: El Paciente 127 necesita cirugía.
# 432: Paciente 129 es atendido.
# 433: Al Paciente 129 se le asigno una cama y 3 miembro(s) del personal.
# 433: El Paciente 129 necesita cirugía.
# 433: Paciente 130 es atendido.
# 434: Cirugía completada para el Paciente 108.
# 434: Paciente 108 se le ha dado de alta.
# 434: Paciente 438 llega al hospital a la unidad UCI.
# 434: Paciente 439 llega al hospital a la unidad Urgencias.
# 434: Paciente 440 llega al hospital a la unidad Urgencias.
# 434: Paciente 441 llega al hospital a la unidad Urgencias.
# 434: Al Paciente 114 se le asignó un kit médico.
# 435: Al Paciente 130 se le asigno una cama y 4 miembro(s) del personal.
# 435: Paciente 442 llega al hospital a la unidad Urgencias.
# 435: Paciente 443 llega al hospital a la unidad Urgencias.
# 435: Paciente 131 es atendido.
# 437: Al Paciente 115 se le ha dado de alta.
# 437: Al Paciente 118 se le ha dado de alta.
# 437: Al Paciente 128 se le asigno una cama y 1 miembro(s) del personal.
# 437: Paciente 132 es atendido.
# 438: Al Paciente 116 se le ha dado de alta.
# 438: Al Paciente 132 se le asigno una cama y 7 miembro(s) del personal.
# 438: Paciente 133 es atendido.
# 439: Paciente 444 llega al hospital a la unidad UCI.
# 439: Paciente 445 llega al hospital a la unidad Urgencias.
# 441: Al Paciente 131 se le asigno una cama y 3 miembro(s) del personal.
# 441: Paciente 446 llega al hospital a la unidad Urgencias.
# 441: Paciente 447 llega al hospital a la unidad Urgencias.
# 441: Paciente 448 llega al hospital a la unidad UCI.
# 441: Paciente 449 llega al hospital a la unidad Consultorios.
# 441: Paciente 450 llega al hospital a la unidad Urgencias.
# 441: Paciente 134 es atendido.
# 443: Al Paciente 120 se le ha dado de alta.
# 443: Al Paciente 133 se le asigno una cama y 6 miembro(s) del personal.
# 443: Paciente 135 es atendido.
# 444: Paciente 451 llega al hospital a la unidad UCI.
# 444: Paciente 452 llega al hospital a la unidad Urgencias.
# 445: Paciente 453 llega al hospital a la unidad UCI.
# 446: Al Paciente 122 se le ha dado de alta.
# 448: Al Paciente 123 se le ha dado de alta.
# 449: Al Paciente 132 se le ha dado de alta.
# 450: Al Paciente 135 se le asigno una cama y 5 miembro(s) del personal.
# 450: Paciente 454 llega al hospital a la unidad Urgencias.
# 450: Paciente 136 es atendido.
# 452: Al Paciente 121 se le ha dado de alta.
# 453: Al Paciente 125 se le ha dado de alta.
# 453: Al Paciente 126 se le ha dado de alta.
# 453: Paciente 455 llega al hospital a la unidad UCI.
# 453: Paciente 456 llega al hospital a la unidad Urgencias.
# 454: Al Paciente 136 se le asigno una cama y 4 miembro(s) del personal.
# 454: Paciente 137 es atendido.
# 456: Paciente 457 llega al hospital a la unidad UCI.
# 456: Paciente 458 llega al hospital a la unidad Urgencias.
# 457: Paciente 459 llega al hospital a la unidad Consultorios.
# 457: Paciente 460 llega al hospital a la unidad Urgencias.
# 457: Paciente 461 llega al hospital a la unidad Urgencias.
# 459: Al Paciente 137 se le asigno una cama y 8 miembro(s) del personal.
# 459: Paciente 138 es atendido.
# 461: Al Paciente 128 se le ha dado de alta.
# 462: Al Paciente 130 se le ha dado de alta.
# 462: Paciente 462 llega al hospital a la unidad Urgencias.
# 462: Paciente 463 llega al hospital a la unidad Urgencias.
# 462: Paciente 464 llega al hospital a la unidad UCI.
# 462: Paciente 465 llega al hospital a la unidad Urgencias.
# 462: Paciente 466 llega al hospital a la unidad UCI.
# 463: Al Paciente 133 se le ha dado de alta.
# 466: Al Paciente 134 se le asigno una cama y 1 miembro(s) del personal.
# 466: Paciente 139 es atendido.
# 467: Al Paciente 131 se le ha dado de alta.
# 467: Al Paciente 138 se le asigno una cama y 1 miembro(s) del personal.
# 467: Paciente 467 llega al hospital a la unidad Consultorios.
# 467: Paciente 468 llega al hospital a la unidad UCI.
# 467: Paciente 469 llega al hospital a la unidad UCI.
# 467: Paciente 470 llega al hospital a la unidad Urgencias.
# 467: Paciente 140 es atendido.
# 471: Al Paciente 139 se le asigno una cama y 5 miembro(s) del personal.
# 471: Paciente 141 es atendido.
# 472: Al Paciente 136 se le ha dado de alta.
# 472: Paciente 471 llega al hospital a la unidad UCI.
# 472: Paciente 472 llega al hospital a la unidad Urgencias.
# 472: Paciente 473 llega al hospital a la unidad Consultorios.
# 472: Paciente 474 llega al hospital a la unidad Urgencias.
# 475: Al Paciente 137 se le ha dado de alta.
# 475: Paciente 475 llega al hospital a la unidad Urgencias.
# 475: Paciente 476 llega al hospital a la unidad Urgencias.
# 475: Paciente 477 llega al hospital a la unidad Urgencias.
# 475: El Paciente 117 murió esperando un kit médico.
# 476: Al Paciente 139 se le ha dado de alta.
# 478: Al Paciente 141 se le asigno una cama y 8 miembro(s) del personal.
# 478: Paciente 142 es atendido.

# %%
lista_pacientes3 = []

def registrar_paciente(paciente_id, unidad, cirugia,alcanzo_cama):
    lista_pacientes3.append({
        "id": paciente_id,
        "unidad": unidad,
        "cirugia": cirugia,
        "alcanzo_cama": alcanzo_cama
    })

# %%
for p in simulacion3.pacientes:
    registrar_paciente(p.id, p.unidad.nombre, p.cirugia, p.alcanzo_cama)

dfPacientes3 = pd.DataFrame(lista_pacientes3)
dfPacientes3
# Out:
#       id        unidad  cirugia  alcanzo_cama
# 0      1  Consultorios    False          True
# 1      2  Consultorios    False          True
# 2      3     Urgencias    False          True
# 3      4           UCI    False          True
# 4      5  Consultorios    False          True
# ..   ...           ...      ...           ...
# 472  473  Consultorios    False         False
# 473  474     Urgencias     True         False
# 474  475     Urgencias    False         False
# 475  476     Urgencias     True         False
# 476  477     Urgencias    False         False
#
# [477 rows x 4 columns]

# %%
lista_eventos3 = []
for p in simulacion3.pacientes:
    lista_eventos3.append( p.eventos )

dfeventos3 = pd.concat(lista_eventos3)
dfeventos3 = dfeventos3.reset_index()
dfeventos3.drop( ["index"], axis=1, inplace=True )

dfeventos3
# Out:
#       id                    evento  time
# 0      1                   LLEGADA     2
# 1      1                  ATENDIDO     2
# 2      1  ASIGNACION_CAMA_PERSONAL    21
# 3      1                      ALTA    50
# 4      2                   LLEGADA     2
# ..   ...                       ...   ...
# 898  473                   LLEGADA   472
# 899  474                   LLEGADA   472
# 900  475                   LLEGADA   475
# 901  476                   LLEGADA   475
# 902  477                   LLEGADA   475
#
# [903 rows x 3 columns]

# %%
dfeventos3["lag_time"] = dfeventos3.groupby("id")["time"].shift(1)

# %%
# Filtramos y calculamos el tiempo de espera
df3 = dfeventos3.loc[dfeventos3["evento"] == "ATENDIDO", :].copy()
df3["tiempo_espera"] = df3["time"] - df3["lag_time"]

# Merge con la info de pacientes (asegúrate de que 'id' esté en ambos)
df_merged3 = df3.merge(dfPacientes3, on="id", how="inner")

# Agrupamos por unidad y calculamos el promedio
resultado3 = (
    df_merged3
    .groupby("unidad")
    .agg({"tiempo_espera": "mean"})
)

print(resultado3)
# Out:
#               tiempo_espera
# unidad
# Consultorios     168.470588
# UCI              175.625000
# Urgencias        194.426471

# %% [markdown]
# ## Resultado
# Observamos que el tiempo de espera media se mantiene bastante cercano al original, lo que justifica
# nuestra respuesta anterior, el mal rendimiento de las recepcionistas evita el correcto uso de recursos
# como el del personal médico.
