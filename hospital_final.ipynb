# %% [markdown]
# # Escenario
# La simulación se hará sobre un hospital que contará con las siguientes unidades de atención: Unidad de Cuidados Intensivos (UCI), Unidad de Urgencias, Consultorios. Cada unidad cuenta con recursos limitados: un número específico de camas y un número específico de enfermeras y doctores, y además la Unidad de Urgencias cuenta con un número específico de set de utencilios médicos para cirugías.

# %% [markdown]
# ## Objetivos
# 1. Simular la carga de trabajo de cada unidad del hospital y los tiempos de espera de los pacientes.
# 2. Sacar conclusiones sobre la eficiencia del manejo de los recursos de cada unidad así como de la suficiencia de los mismos.

# %%
import pandas as pd
import numpy as np
import simpy
import random

# %%
class Unidad:
    def __init__(self, env, nombre, num_camas, personal, num_kits_medicos):
        self.env = env
        self.nombre = nombre
        self.num_camas = simpy.Resource(env, capacity=num_camas)
        self.personal = simpy.Resource(env, capacity=personal)
        self.num_kits_medicos = simpy.Resource(env, capacity=num_kits_medicos)

# %%
class Hospital:
    def __init__(self, env, recepcionistas, unidades):
        self.env = env
        self.unidades = unidades
        self.recepcionistas = simpy.Resource(env, capacity=recepcionistas)

# %%
class Paciente:
    def __init__(self, env, id, hospital: Hospital, unidad: Unidad):
        self.env = env
        self.id = id
        self.hospital = hospital
        self.unidad = unidad
        self.cirugia = random.choice([True, False]) if unidad.nombre == "Urgencias" else False
        self.alcanzo_cama = False
        
        self.env.process(self.start())
        self.eventos = pd.DataFrame()
    
    def start(self):
        print(f"{self.env.now}: Paciente {self.id} llega al hospital a la unidad {self.unidad.nombre}.")
        self.eventos = pd.concat([self.eventos, pd.DataFrame({
                "id": [self.id],
                "evento": ["LLEGADA"],
                "time": [self.env.now]
            })])
        
        with self.hospital.recepcionistas.request() as request:
            yield request
            print(f"{self.env.now}: Paciente {self.id} es atendido.")
            self.eventos = pd.concat([self.eventos, pd.DataFrame({
                "id": [self.id],
                "evento": ["ATENDIDO"],
                "time": [self.env.now]
            })])

            if self.unidad.nombre == "Urgencias" or self.unidad.nombre == "UCI":
                tiempo_atencion_inferior = 1
                tiempo_atencion_superior = 7
                cant_personal = random.randint(3, 8)
            else:
                tiempo_atencion_inferior = 7
                tiempo_atencion_superior = 25
                cant_personal = 1 #Solo se necesita un doctor para una consulta general

            # El paciente toma una cama y se le asigna personal
            with self.unidad.num_camas.request() as cama_request:
                yield cama_request
                with self.unidad.personal.request() as personal_request:
                    yield personal_request
                    yield self.env.timeout(random.randint(tiempo_atencion_inferior, tiempo_atencion_superior))
                    print(f"{self.env.now}: Al Paciente {self.id} se le asigno una cama y {cant_personal} miembro(s) del personal.")
                    self.alcanzo_cama = True
                    self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id],
                        "evento": ["ASIGNACION_CAMA_PERSONAL"],
                        "time": [self.env.now]
                    })])

        #Si el paciente es de urgencias y necesita cirugia, espera que se le asigne un kit medico
        if self.cirugia:
            print(f"{self.env.now}: El Paciente {self.id} necesita cirugía.")
            
            # Tiempo máximo que el paciente puede esperar sin morir
            tiempo_max_espera_kit = 60  # en minutos
            tiempo_inicio_espera = self.env.now
        
            with self.unidad.num_kits_medicos.request() as kit_request:
                resultado = yield kit_request | self.env.timeout(tiempo_max_espera_kit)
        
                if kit_request in resultado:
                    # El paciente consiguió el kit a tiempo
                    print(f"{self.env.now}: Al Paciente {self.id} se le asignó un kit médico.")
                    self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id],
                        "evento": ["ASIGNACION_KIT"],
                        "time": [self.env.now]
                    })])
        
                    # Tiempo de cirugía real
                    tiempo_cirugia = random.randint(15, 60 * 8)
                    yield self.env.timeout(tiempo_cirugia)
                    print(f"{self.env.now}: Cirugía completada para el Paciente {self.id}.")
        
                    # ... tras cirugía o recuperación …
                    # decisión probabilística: 90% de alta, 10% de muerte
                    prob_supervivencia = 0.9  
                    if random.random() <= prob_supervivencia:
                        evento_final = "ALTA"
                        mensaje = f"{self.env.now}: Paciente {self.id} se le ha dado de alta."
                    else:
                        evento_final = "MUERTE"
                        mensaje = f"{self.env.now}: Paciente {self.id} murió tras el procedimiento."
                    
                    print(mensaje)
                    self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id],
                        "evento": [evento_final],
                        "time": [self.env.now]
                    })])
                else:
                    # El paciente murió esperando
                    print(f"{self.env.now}: El Paciente {self.id} murió esperando un kit médico.")
                    self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id],
                        "evento": ["MUERTE"],
                        "time": [self.env.now]
                    })])
                    return
        else:
            # Tiempo de recuperación antes del alta
            tiempo_recuperacion = random.randint(5, 30)
            yield self.env.timeout(tiempo_recuperacion)

            print(f"{self.env.now}: Al Paciente {self.id} se le ha dado de alta.")
            self.eventos = pd.concat([self.eventos, pd.DataFrame({
                "id": [self.id],
                "evento": ["ALTA"],
                "time": [self.env.now]
            })])

# %%
class Simulation:
    def __init__(self, env, unidades_settings, recepcionistas):
        self.env = env
        self.unidades = [Unidad(env, u["nombre"], u["num_camas"], u["personal"], u["num_kits_medicos"]) for u in unidades_settings]
        self.hospital = Hospital(env, recepcionistas, self.unidades)
        self.pacientes = []

        self.env.process(self.run_simulation())
    
    def run_simulation(self):
        while True:
            # Generar de 1 a 5 pacientes a la vez
            yield self.env.timeout(random.randint(1, 5))

            for _ in range(random.randint(1, 5)):
                paciente = Paciente(
                    self.env,
                    len(self.pacientes) + 1,
                    self.hospital,
                    #random.choice(self.unidades)
                    np.random.choice(self.unidades, p=[0.5, 0.3, 0.2])
                )
                self.pacientes.append(paciente)

# %% [markdown]
# # Inicio de la simulacion

# %%
env = simpy.Environment()
unidades_settings = [
    {"nombre": "Urgencias", "num_camas": 20, "personal": 30, "num_kits_medicos": 8},
    {"nombre": "UCI", "num_camas": 35, "personal": 25, "num_kits_medicos": 1},
    {"nombre": "Consultorios", "num_camas": 10, "personal": 8, "num_kits_medicos": 1}
]
num_recepcionistas = 2

random.seed(111)

simulacion = Simulation(env, unidades_settings, num_recepcionistas)
env.run(until=60*8)
# Out:
# 2: Paciente 1 llega al hospital a la unidad Urgencias.
# 2: Paciente 2 llega al hospital a la unidad Urgencias.
# 2: Paciente 3 llega al hospital a la unidad Urgencias.
# 2: Paciente 1 es atendido.
# 2: Paciente 2 es atendido.
# 4: Al Paciente 2 se le asigno una cama y 4 miembro(s) del personal.
# 4: El Paciente 2 necesita cirugía.
# 4: Paciente 3 es atendido.
# 4: Al Paciente 2 se le asignó un kit médico.
# 6: Paciente 4 llega al hospital a la unidad UCI.
# 6: Paciente 5 llega al hospital a la unidad Urgencias.
# 8: Al Paciente 1 se le asigno una cama y 7 miembro(s) del personal.
# 8: Paciente 4 es atendido.
# 9: Al Paciente 3 se le asigno una cama y 8 miembro(s) del personal.
# 9: Paciente 5 es atendido.
# 10: Paciente 6 llega al hospital a la unidad Urgencias.
# 10: Paciente 7 llega al hospital a la unidad Urgencias.
# 10: Paciente 8 llega al hospital a la unidad UCI.
# 11: Al Paciente 5 se le asigno una cama y 6 miembro(s) del personal.
# 11: El Paciente 5 necesita cirugía.
# 11: Paciente 6 es atendido.
# 11: Al Paciente 5 se le asignó un kit médico.
# 13: Paciente 9 llega al hospital a la unidad Urgencias.
# 13: Paciente 10 llega al hospital a la unidad Urgencias.
# 14: Al Paciente 4 se le asigno una cama y 6 miembro(s) del personal.
# 14: Paciente 11 llega al hospital a la unidad Urgencias.
# 14: Paciente 12 llega al hospital a la unidad Urgencias.
# 14: Paciente 13 llega al hospital a la unidad UCI.
# 14: Paciente 14 llega al hospital a la unidad UCI.
# 14: Paciente 15 llega al hospital a la unidad UCI.
# 14: Paciente 7 es atendido.
# 15: Paciente 16 llega al hospital a la unidad Urgencias.
# 15: Paciente 17 llega al hospital a la unidad Urgencias.
# 17: Al Paciente 6 se le asigno una cama y 8 miembro(s) del personal.
# 17: Paciente 8 es atendido.
# 18: Al Paciente 7 se le asigno una cama y 5 miembro(s) del personal.
# 18: El Paciente 7 necesita cirugía.
# 18: Paciente 9 es atendido.
# 18: Al Paciente 7 se le asignó un kit médico.
# 20: Paciente 18 llega al hospital a la unidad Consultorios.
# 20: Paciente 19 llega al hospital a la unidad Urgencias.
# 20: Paciente 20 llega al hospital a la unidad UCI.
# 20: Paciente 21 llega al hospital a la unidad Urgencias.
# 20: Paciente 22 llega al hospital a la unidad Urgencias.
# 22: Al Paciente 3 se le ha dado de alta.
# 23: Al Paciente 8 se le asigno una cama y 3 miembro(s) del personal.
# 23: Paciente 10 es atendido.
# 24: Al Paciente 9 se le asigno una cama y 3 miembro(s) del personal.
# 24: Paciente 23 llega al hospital a la unidad Urgencias.
# 24: Paciente 24 llega al hospital a la unidad Urgencias.
# 24: Paciente 25 llega al hospital a la unidad Consultorios.
# 24: Paciente 26 llega al hospital a la unidad Consultorios.
# 24: Paciente 27 llega al hospital a la unidad Consultorios.
# 24: Paciente 11 es atendido.
# 26: Al Paciente 1 se le ha dado de alta.
# 26: Paciente 28 llega al hospital a la unidad Consultorios.
# 26: Paciente 29 llega al hospital a la unidad Urgencias.
# 26: Paciente 30 llega al hospital a la unidad Urgencias.
# 26: Paciente 31 llega al hospital a la unidad UCI.
# 28: Paciente 32 llega al hospital a la unidad Consultorios.
# 28: Paciente 33 llega al hospital a la unidad Urgencias.
# 28: Paciente 34 llega al hospital a la unidad Urgencias.
# 28: Paciente 35 llega al hospital a la unidad UCI.
# 29: Al Paciente 10 se le asigno una cama y 3 miembro(s) del personal.
# 29: Paciente 12 es atendido.
# 30: Al Paciente 11 se le asigno una cama y 6 miembro(s) del personal.
# 30: El Paciente 11 necesita cirugía.
# 30: Paciente 13 es atendido.
# 30: Al Paciente 11 se le asignó un kit médico.
# 32: Al Paciente 4 se le ha dado de alta.
# 33: Paciente 36 llega al hospital a la unidad UCI.
# 33: Paciente 37 llega al hospital a la unidad UCI.
# 33: Paciente 38 llega al hospital a la unidad Consultorios.
# 33: Paciente 39 llega al hospital a la unidad Urgencias.
# 33: Al Paciente 12 se le asigno una cama y 7 miembro(s) del personal.
# 33: Paciente 14 es atendido.
# 35: Al Paciente 13 se le asigno una cama y 7 miembro(s) del personal.
# 35: Al Paciente 14 se le asigno una cama y 8 miembro(s) del personal.
# 35: Paciente 15 es atendido.
# 35: Paciente 16 es atendido.
# 38: Paciente 40 llega al hospital a la unidad Urgencias.
# 38: Paciente 41 llega al hospital a la unidad Consultorios.
# 38: Paciente 42 llega al hospital a la unidad Urgencias.
# 40: Al Paciente 15 se le asigno una cama y 4 miembro(s) del personal.
# 40: Paciente 17 es atendido.
# 41: Al Paciente 16 se le asigno una cama y 7 miembro(s) del personal.
# 41: Paciente 18 es atendido.
# 42: Paciente 43 llega al hospital a la unidad Consultorios.
# 42: Paciente 44 llega al hospital a la unidad Urgencias.
# 42: Paciente 45 llega al hospital a la unidad Urgencias.
# 42: Paciente 46 llega al hospital a la unidad Consultorios.
# 42: Paciente 47 llega al hospital a la unidad Consultorios.
# 44: Al Paciente 13 se le ha dado de alta.
# 45: Al Paciente 8 se le ha dado de alta.
# 45: Paciente 48 llega al hospital a la unidad UCI.
# 45: Paciente 49 llega al hospital a la unidad Consultorios.
# 46: Al Paciente 15 se le ha dado de alta.
# 47: Al Paciente 6 se le ha dado de alta.
# 47: Al Paciente 17 se le asigno una cama y 5 miembro(s) del personal.
# 47: El Paciente 17 necesita cirugía.
# 47: Paciente 50 llega al hospital a la unidad Urgencias.
# 47: Paciente 51 llega al hospital a la unidad Urgencias.
# 47: Paciente 52 llega al hospital a la unidad Urgencias.
# 47: Paciente 53 llega al hospital a la unidad UCI.
# 47: Paciente 54 llega al hospital a la unidad Urgencias.
# 47: Paciente 19 es atendido.
# 47: Al Paciente 17 se le asignó un kit médico.
# 49: Paciente 55 llega al hospital a la unidad Urgencias.
# 49: Paciente 56 llega al hospital a la unidad UCI.
# 49: Paciente 57 llega al hospital a la unidad Urgencias.
# 50: Al Paciente 9 se le ha dado de alta.
# 50: Al Paciente 18 se le asigno una cama y 1 miembro(s) del personal.
# 50: Al Paciente 19 se le asigno una cama y 8 miembro(s) del personal.
# 50: Paciente 20 es atendido.
# 50: Paciente 21 es atendido.
# 51: Paciente 58 llega al hospital a la unidad UCI.
# 51: Al Paciente 21 se le asigno una cama y 6 miembro(s) del personal.
# 51: Paciente 22 es atendido.
# 53: Al Paciente 20 se le asigno una cama y 6 miembro(s) del personal.
# 53: Paciente 59 llega al hospital a la unidad Urgencias.
# 53: Paciente 60 llega al hospital a la unidad Urgencias.
# 53: Paciente 61 llega al hospital a la unidad Consultorios.
# 53: Paciente 62 llega al hospital a la unidad UCI.
# 53: Paciente 63 llega al hospital a la unidad Consultorios.
# 53: Paciente 23 es atendido.
# 54: Paciente 64 llega al hospital a la unidad UCI.
# 54: Paciente 65 llega al hospital a la unidad Consultorios.
# 54: Paciente 66 llega al hospital a la unidad Urgencias.
# 56: Al Paciente 23 se le asigno una cama y 7 miembro(s) del personal.
# 56: El Paciente 23 necesita cirugía.
# 56: Paciente 67 llega al hospital a la unidad Urgencias.
# 56: Paciente 68 llega al hospital a la unidad Consultorios.
# 56: Paciente 69 llega al hospital a la unidad UCI.
# 56: Paciente 70 llega al hospital a la unidad Urgencias.
# 56: Paciente 71 llega al hospital a la unidad UCI.
# 56: Paciente 24 es atendido.
# 56: Al Paciente 23 se le asignó un kit médico.
# 57: Al Paciente 12 se le ha dado de alta.
# 57: Al Paciente 19 se le ha dado de alta.
# 57: Al Paciente 22 se le asigno una cama y 6 miembro(s) del personal.
# 57: Paciente 25 es atendido.
# 58: Al Paciente 10 se le ha dado de alta.
# 58: Paciente 72 llega al hospital a la unidad UCI.
# 58: Paciente 73 llega al hospital a la unidad Urgencias.
# 59: Al Paciente 24 se le asigno una cama y 6 miembro(s) del personal.
# 59: El Paciente 24 necesita cirugía.
# 59: Paciente 26 es atendido.
# 59: Al Paciente 24 se le asignó un kit médico.
# 61: Al Paciente 18 se le ha dado de alta.
# 63: Al Paciente 21 se le ha dado de alta.
# 63: Paciente 74 llega al hospital a la unidad Consultorios.
# 63: Paciente 75 llega al hospital a la unidad UCI.
# 63: Paciente 76 llega al hospital a la unidad Urgencias.
# 64: Al Paciente 14 se le ha dado de alta.
# 64: Paciente 77 llega al hospital a la unidad UCI.
# 64: Paciente 78 llega al hospital a la unidad UCI.
# 64: Paciente 79 llega al hospital a la unidad Consultorios.
# 64: Paciente 80 llega al hospital a la unidad Urgencias.
# 66: Al Paciente 16 se le ha dado de alta.
# 69: Paciente 81 llega al hospital a la unidad Urgencias.
# 69: Paciente 82 llega al hospital a la unidad Consultorios.
# 69: Paciente 83 llega al hospital a la unidad UCI.
# 69: Paciente 84 llega al hospital a la unidad Urgencias.
# 69: Paciente 85 llega al hospital a la unidad UCI.
# 70: Paciente 86 llega al hospital a la unidad Urgencias.
# 70: Paciente 87 llega al hospital a la unidad UCI.
# 71: Paciente 88 llega al hospital a la unidad Urgencias.
# 71: Paciente 89 llega al hospital a la unidad Urgencias.
# 71: Paciente 90 llega al hospital a la unidad Urgencias.
# 71: Paciente 91 llega al hospital a la unidad UCI.
# 71: Paciente 92 llega al hospital a la unidad Consultorios.
# 72: Paciente 93 llega al hospital a la unidad Urgencias.
# 72: Paciente 94 llega al hospital a la unidad UCI.
# 72: Paciente 95 llega al hospital a la unidad UCI.
# 73: Paciente 96 llega al hospital a la unidad Consultorios.
# 73: Paciente 97 llega al hospital a la unidad Consultorios.
# 73: Paciente 98 llega al hospital a la unidad UCI.
# 75: Paciente 99 llega al hospital a la unidad Urgencias.
# 75: Paciente 100 llega al hospital a la unidad Urgencias.
# 75: Paciente 101 llega al hospital a la unidad UCI.
# 76: Paciente 102 llega al hospital a la unidad Consultorios.
# 76: Paciente 103 llega al hospital a la unidad UCI.
# 76: Paciente 104 llega al hospital a la unidad UCI.
# 76: Paciente 105 llega al hospital a la unidad UCI.
# 79: Paciente 106 llega al hospital a la unidad UCI.
# 79: Paciente 107 llega al hospital a la unidad UCI.
# 79: Paciente 108 llega al hospital a la unidad Urgencias.
# 79: Paciente 109 llega al hospital a la unidad Urgencias.
# 81: Al Paciente 22 se le ha dado de alta.
# 81: Al Paciente 25 se le asigno una cama y 1 miembro(s) del personal.
# 81: Paciente 27 es atendido.
# 82: Paciente 110 llega al hospital a la unidad Consultorios.
# 83: Al Paciente 20 se le ha dado de alta.
# 84: Al Paciente 26 se le asigno una cama y 1 miembro(s) del personal.
# 84: Paciente 28 es atendido.
# 85: Paciente 111 llega al hospital a la unidad Consultorios.
# 85: Paciente 112 llega al hospital a la unidad UCI.
# 89: Paciente 113 llega al hospital a la unidad Urgencias.
# 89: Paciente 114 llega al hospital a la unidad UCI.
# 89: Paciente 115 llega al hospital a la unidad Urgencias.
# 89: Paciente 116 llega al hospital a la unidad Urgencias.
# 89: Paciente 117 llega al hospital a la unidad Urgencias.
# 90: Al Paciente 27 se le asigno una cama y 1 miembro(s) del personal.
# 90: Paciente 118 llega al hospital a la unidad UCI.
# 90: Paciente 119 llega al hospital a la unidad UCI.
# 90: Paciente 29 es atendido.
# 91: Al Paciente 28 se le asigno una cama y 1 miembro(s) del personal.
# 91: Al Paciente 29 se le asigno una cama y 7 miembro(s) del personal.
# 91: El Paciente 29 necesita cirugía.
# 91: Paciente 30 es atendido.
# 91: Paciente 31 es atendido.
# 91: Al Paciente 29 se le asignó un kit médico.
# 94: Al Paciente 31 se le asigno una cama y 4 miembro(s) del personal.
# 94: Paciente 32 es atendido.
# 95: Paciente 120 llega al hospital a la unidad Urgencias.
# 95: Paciente 121 llega al hospital a la unidad UCI.
# 95: Paciente 122 llega al hospital a la unidad UCI.
# 95: Paciente 123 llega al hospital a la unidad Urgencias.
# 95: Paciente 124 llega al hospital a la unidad Consultorios.
# 96: Paciente 125 llega al hospital a la unidad UCI.
# 96: Paciente 126 llega al hospital a la unidad Urgencias.
# 96: Paciente 127 llega al hospital a la unidad Urgencias.
# 96: Paciente 128 llega al hospital a la unidad Consultorios.
# 96: Paciente 129 llega al hospital a la unidad UCI.
# 97: Al Paciente 30 se le asigno una cama y 6 miembro(s) del personal.
# 97: Paciente 33 es atendido.
# 98: Paciente 130 llega al hospital a la unidad UCI.
# 98: Paciente 131 llega al hospital a la unidad UCI.
# 98: Paciente 132 llega al hospital a la unidad UCI.
# 98: Paciente 133 llega al hospital a la unidad Consultorios.
# 101: Al Paciente 33 se le asigno una cama y 6 miembro(s) del personal.
# 101: El Paciente 33 necesita cirugía.
# 101: Paciente 34 es atendido.
# 102: Paciente 134 llega al hospital a la unidad UCI.
# 102: Paciente 135 llega al hospital a la unidad UCI.
# 103: Al Paciente 25 se le ha dado de alta.
# 104: Paciente 136 llega al hospital a la unidad Urgencias.
# 104: Paciente 137 llega al hospital a la unidad Consultorios.
# 104: Paciente 138 llega al hospital a la unidad Consultorios.
# 104: Paciente 139 llega al hospital a la unidad UCI.
# 105: Al Paciente 26 se le ha dado de alta.
# 106: Al Paciente 31 se le ha dado de alta.
# 107: Al Paciente 34 se le asigno una cama y 6 miembro(s) del personal.
# 107: El Paciente 34 necesita cirugía.
# 107: Paciente 35 es atendido.
# 108: Al Paciente 28 se le ha dado de alta.
# 108: Paciente 140 llega al hospital a la unidad UCI.
# 108: Paciente 141 llega al hospital a la unidad Urgencias.
# 108: Paciente 142 llega al hospital a la unidad Consultorios.
# 108: Paciente 143 llega al hospital a la unidad UCI.
# 108: Paciente 144 llega al hospital a la unidad UCI.
# 111: Al Paciente 35 se le asigno una cama y 5 miembro(s) del personal.
# 111: Paciente 145 llega al hospital a la unidad Consultorios.
# 111: Paciente 146 llega al hospital a la unidad UCI.
# 111: Paciente 147 llega al hospital a la unidad UCI.
# 111: Paciente 36 es atendido.
# 114: Al Paciente 32 se le asigno una cama y 1 miembro(s) del personal.
# 114: Paciente 37 es atendido.
# 116: Paciente 148 llega al hospital a la unidad Urgencias.
# 116: Paciente 149 llega al hospital a la unidad Consultorios.
# 116: Paciente 150 llega al hospital a la unidad Consultorios.
# 116: Paciente 151 llega al hospital a la unidad Urgencias.
# 118: Al Paciente 27 se le ha dado de alta.
# 118: Al Paciente 30 se le ha dado de alta.
# 118: Al Paciente 36 se le asigno una cama y 5 miembro(s) del personal.
# 118: Paciente 152 llega al hospital a la unidad Urgencias.
# 118: Paciente 153 llega al hospital a la unidad Urgencias.
# 118: Paciente 38 es atendido.
# 120: Al Paciente 37 se le asigno una cama y 6 miembro(s) del personal.
# 120: Paciente 39 es atendido.
# 122: Paciente 154 llega al hospital a la unidad Urgencias.
# 122: Paciente 155 llega al hospital a la unidad Urgencias.
# 122: Paciente 156 llega al hospital a la unidad Urgencias.
# 122: Paciente 157 llega al hospital a la unidad Urgencias.
# 122: Paciente 158 llega al hospital a la unidad UCI.
# 124: Cirugía completada para el Paciente 17.
# 124: Paciente 17 se le ha dado de alta.
# 124: Paciente 159 llega al hospital a la unidad UCI.
# 124: Al Paciente 33 se le asignó un kit médico.
# 125: Al Paciente 35 se le ha dado de alta.
# 125: Paciente 160 llega al hospital a la unidad Urgencias.
# 126: Al Paciente 39 se le asigno una cama y 5 miembro(s) del personal.
# 126: El Paciente 39 necesita cirugía.
# 126: Paciente 161 llega al hospital a la unidad UCI.
# 126: Paciente 162 llega al hospital a la unidad Urgencias.
# 126: Paciente 40 es atendido.
# 127: Paciente 163 llega al hospital a la unidad UCI.
# 127: Paciente 164 llega al hospital a la unidad UCI.
# 127: Al Paciente 40 se le asigno una cama y 6 miembro(s) del personal.
# 127: Paciente 41 es atendido.
# 131: Al Paciente 36 se le ha dado de alta.
# 131: Paciente 165 llega al hospital a la unidad Consultorios.
# 131: Paciente 166 llega al hospital a la unidad Urgencias.
# 131: Paciente 167 llega al hospital a la unidad UCI.
# 131: Paciente 168 llega al hospital a la unidad Urgencias.
# 131: Paciente 169 llega al hospital a la unidad Urgencias.
# 132: Al Paciente 38 se le asigno una cama y 1 miembro(s) del personal.
# 132: Paciente 170 llega al hospital a la unidad Consultorios.
# 132: Paciente 171 llega al hospital a la unidad Urgencias.
# 132: Paciente 42 es atendido.
# 134: Paciente 172 llega al hospital a la unidad Urgencias.
# 136: Al Paciente 42 se le asigno una cama y 7 miembro(s) del personal.
# 136: El Paciente 42 necesita cirugía.
# 136: Paciente 173 llega al hospital a la unidad Consultorios.
# 136: Paciente 43 es atendido.
# 140: Al Paciente 32 se le ha dado de alta.
# 140: Paciente 174 llega al hospital a la unidad Urgencias.
# 140: Paciente 175 llega al hospital a la unidad Consultorios.
# 140: Paciente 176 llega al hospital a la unidad Urgencias.
# 140: Paciente 177 llega al hospital a la unidad Urgencias.
# 140: Paciente 178 llega al hospital a la unidad Consultorios.
# 145: Al Paciente 37 se le ha dado de alta.
# 145: Paciente 179 llega al hospital a la unidad UCI.
# 145: Paciente 180 llega al hospital a la unidad Urgencias.
# 146: Paciente 181 llega al hospital a la unidad Urgencias.
# 146: Paciente 182 llega al hospital a la unidad UCI.
# 146: Paciente 183 llega al hospital a la unidad Urgencias.
# 146: Paciente 184 llega al hospital a la unidad UCI.
# 147: Al Paciente 40 se le ha dado de alta.
# 147: Paciente 185 llega al hospital a la unidad Consultorios.
# 148: Paciente 186 llega al hospital a la unidad UCI.
# 148: Paciente 187 llega al hospital a la unidad Consultorios.
# 148: Paciente 188 llega al hospital a la unidad UCI.
# 148: Paciente 189 llega al hospital a la unidad Urgencias.
# 150: Al Paciente 41 se le asigno una cama y 1 miembro(s) del personal.
# 150: Al Paciente 43 se le asigno una cama y 1 miembro(s) del personal.
# 150: Paciente 44 es atendido.
# 150: Paciente 45 es atendido.
# 152: Al Paciente 45 se le asigno una cama y 6 miembro(s) del personal.
# 152: Paciente 46 es atendido.
# 153: Al Paciente 38 se le ha dado de alta.
# 153: Paciente 190 llega al hospital a la unidad Urgencias.
# 153: Paciente 191 llega al hospital a la unidad Consultorios.
# 153: Paciente 192 llega al hospital a la unidad UCI.
# 154: Al Paciente 44 se le asigno una cama y 6 miembro(s) del personal.
# 154: El Paciente 44 necesita cirugía.
# 154: Paciente 47 es atendido.
# 158: Paciente 193 llega al hospital a la unidad UCI.
# 158: Paciente 194 llega al hospital a la unidad Consultorios.
# 158: Paciente 195 llega al hospital a la unidad Urgencias.
# 160: Paciente 196 llega al hospital a la unidad Consultorios.
# 160: Paciente 197 llega al hospital a la unidad UCI.
# 160: Paciente 198 llega al hospital a la unidad UCI.
# 162: Paciente 199 llega al hospital a la unidad UCI.
# 162: Paciente 200 llega al hospital a la unidad Urgencias.
# 162: Paciente 201 llega al hospital a la unidad Urgencias.
# 162: Paciente 202 llega al hospital a la unidad UCI.
# 162: Paciente 203 llega al hospital a la unidad Urgencias.
# 165: Paciente 204 llega al hospital a la unidad Urgencias.
# 167: Al Paciente 46 se le asigno una cama y 1 miembro(s) del personal.
# 167: El Paciente 34 murió esperando un kit médico.
# 167: Paciente 48 es atendido.
# 168: Al Paciente 41 se le ha dado de alta.
# 170: Paciente 205 llega al hospital a la unidad Urgencias.
# 170: Paciente 206 llega al hospital a la unidad Urgencias.
# 171: Al Paciente 43 se le ha dado de alta.
# 171: Al Paciente 48 se le asigno una cama y 3 miembro(s) del personal.
# 171: Paciente 49 es atendido.
# 174: Paciente 207 llega al hospital a la unidad Consultorios.
# 174: Paciente 208 llega al hospital a la unidad UCI.
# 174: Paciente 209 llega al hospital a la unidad Urgencias.
# 174: Paciente 210 llega al hospital a la unidad UCI.
# 174: Paciente 211 llega al hospital a la unidad UCI.
# 177: Al Paciente 48 se le ha dado de alta.
# 179: Al Paciente 47 se le asigno una cama y 1 miembro(s) del personal.
# 179: Paciente 212 llega al hospital a la unidad UCI.
# 179: Paciente 50 es atendido.
# 181: Al Paciente 45 se le ha dado de alta.
# 183: Paciente 213 llega al hospital a la unidad Urgencias.
# 183: Paciente 214 llega al hospital a la unidad Urgencias.
# 183: Paciente 215 llega al hospital a la unidad Consultorios.
# 183: Paciente 216 llega al hospital a la unidad Consultorios.
# 184: Al Paciente 47 se le ha dado de alta.
# 186: Al Paciente 50 se le asigno una cama y 7 miembro(s) del personal.
# 186: El Paciente 39 murió esperando un kit médico.
# 186: Paciente 51 es atendido.
# 187: Al Paciente 49 se le asigno una cama y 1 miembro(s) del personal.
# 187: Paciente 217 llega al hospital a la unidad Urgencias.
# 187: Paciente 218 llega al hospital a la unidad UCI.
# 187: Paciente 219 llega al hospital a la unidad Urgencias.
# 187: Paciente 220 llega al hospital a la unidad Urgencias.
# 187: Paciente 221 llega al hospital a la unidad Urgencias.
# 187: Al Paciente 51 se le asigno una cama y 4 miembro(s) del personal.
# 187: El Paciente 51 necesita cirugía.
# 187: Paciente 52 es atendido.
# 187: Paciente 53 es atendido.
# 192: Paciente 222 llega al hospital a la unidad Urgencias.
# 192: Paciente 223 llega al hospital a la unidad Urgencias.
# 192: Paciente 224 llega al hospital a la unidad Urgencias.
# 192: Al Paciente 52 se le asigno una cama y 3 miembro(s) del personal.
# 192: Paciente 54 es atendido.
# 193: Al Paciente 46 se le ha dado de alta.
# 194: Al Paciente 49 se le ha dado de alta.
# 194: Al Paciente 53 se le asigno una cama y 4 miembro(s) del personal.
# 194: Paciente 55 es atendido.
# 195: Paciente 225 llega al hospital a la unidad Urgencias.
# 195: Paciente 226 llega al hospital a la unidad Urgencias.
# 196: Paciente 227 llega al hospital a la unidad UCI.
# 196: El Paciente 42 murió esperando un kit médico.
# 198: Al Paciente 54 se le asigno una cama y 3 miembro(s) del personal.
# 198: Paciente 56 es atendido.
# 199: Al Paciente 55 se le asigno una cama y 7 miembro(s) del personal.
# 199: El Paciente 55 necesita cirugía.
# 199: Paciente 228 llega al hospital a la unidad UCI.
# 199: Paciente 229 llega al hospital a la unidad Urgencias.
# 199: Paciente 57 es atendido.
# 200: Al Paciente 52 se le ha dado de alta.
# 203: Cirugía completada para el Paciente 29.
# 203: Paciente 29 se le ha dado de alta.
# 203: Al Paciente 56 se le asigno una cama y 6 miembro(s) del personal.
# 203: Al Paciente 57 se le asigno una cama y 3 miembro(s) del personal.
# 203: Paciente 58 es atendido.
# 203: Paciente 59 es atendido.
# 203: Al Paciente 44 se le asignó un kit médico.
# 204: Paciente 230 llega al hospital a la unidad UCI.
# 204: Paciente 231 llega al hospital a la unidad Urgencias.
# 204: Paciente 232 llega al hospital a la unidad Urgencias.
# 208: Al Paciente 58 se le asigno una cama y 5 miembro(s) del personal.
# 208: Al Paciente 59 se le asigno una cama y 6 miembro(s) del personal.
# 208: El Paciente 59 necesita cirugía.
# 208: Paciente 233 llega al hospital a la unidad Consultorios.
# 208: Paciente 234 llega al hospital a la unidad UCI.
# 208: Paciente 235 llega al hospital a la unidad Consultorios.
# 208: Paciente 60 es atendido.
# 208: Paciente 61 es atendido.
# 209: Paciente 236 llega al hospital a la unidad Urgencias.
# 209: Paciente 237 llega al hospital a la unidad Urgencias.
# 209: Paciente 238 llega al hospital a la unidad Urgencias.
# 209: Paciente 239 llega al hospital a la unidad Urgencias.
# 209: Paciente 240 llega al hospital a la unidad Consultorios.
# 210: Al Paciente 50 se le ha dado de alta.
# 211: Al Paciente 60 se le asigno una cama y 5 miembro(s) del personal.
# 211: El Paciente 60 necesita cirugía.
# 211: Paciente 62 es atendido.
# 212: Al Paciente 62 se le asigno una cama y 8 miembro(s) del personal.
# 212: Paciente 63 es atendido.
# 214: Paciente 241 llega al hospital a la unidad Urgencias.
# 214: Paciente 242 llega al hospital a la unidad Urgencias.
# 215: Paciente 243 llega al hospital a la unidad Urgencias.
# 216: Al Paciente 56 se le ha dado de alta.
# 216: Paciente 244 llega al hospital a la unidad Urgencias.
# 216: Paciente 245 llega al hospital a la unidad UCI.
# 216: Paciente 246 llega al hospital a la unidad Consultorios.
# 216: Paciente 247 llega al hospital a la unidad UCI.
# 216: Paciente 248 llega al hospital a la unidad Urgencias.
# 218: Paciente 249 llega al hospital a la unidad UCI.
# 218: Paciente 250 llega al hospital a la unidad Urgencias.
# 218: Paciente 251 llega al hospital a la unidad UCI.
# 218: Paciente 252 llega al hospital a la unidad UCI.
# 218: Paciente 253 llega al hospital a la unidad Urgencias.
# 219: Paciente 254 llega al hospital a la unidad UCI.
# 221: Paciente 255 llega al hospital a la unidad Urgencias.
# 224: Al Paciente 53 se le ha dado de alta.
# 224: Al Paciente 57 se le ha dado de alta.
# 225: Al Paciente 54 se le ha dado de alta.
# 225: Paciente 256 llega al hospital a la unidad Urgencias.
# 225: Paciente 257 llega al hospital a la unidad UCI.
# 225: Paciente 258 llega al hospital a la unidad Urgencias.
# 225: Paciente 259 llega al hospital a la unidad Urgencias.
# 228: Al Paciente 61 se le asigno una cama y 1 miembro(s) del personal.
# 228: Paciente 64 es atendido.
# 229: Paciente 260 llega al hospital a la unidad Urgencias.
# 229: Paciente 261 llega al hospital a la unidad Urgencias.
# 229: Paciente 262 llega al hospital a la unidad Urgencias.
# 229: Paciente 263 llega al hospital a la unidad Urgencias.
# 231: Paciente 264 llega al hospital a la unidad Urgencias.
# 231: Paciente 265 llega al hospital a la unidad Consultorios.
# 233: Al Paciente 64 se le asigno una cama y 7 miembro(s) del personal.
# 233: Paciente 65 es atendido.
# 234: Cirugía completada para el Paciente 2.
# 234: Paciente 2 se le ha dado de alta.
# 234: Al Paciente 51 se le asignó un kit médico.
# 235: Al Paciente 58 se le ha dado de alta.
# 235: Paciente 266 llega al hospital a la unidad Urgencias.
# 237: Al Paciente 62 se le ha dado de alta.
# 237: Al Paciente 63 se le asigno una cama y 1 miembro(s) del personal.
# 237: Paciente 66 es atendido.
# 240: Paciente 267 llega al hospital a la unidad Urgencias.
# 240: Paciente 268 llega al hospital a la unidad UCI.
# 241: Al Paciente 65 se le asigno una cama y 1 miembro(s) del personal.
# 241: Paciente 67 es atendido.
# 242: Paciente 269 llega al hospital a la unidad Urgencias.
# 242: Paciente 270 llega al hospital a la unidad UCI.
# 242: Paciente 271 llega al hospital a la unidad Urgencias.
# 242: Paciente 272 llega al hospital a la unidad Consultorios.
# 242: Paciente 273 llega al hospital a la unidad UCI.
# 243: Paciente 274 llega al hospital a la unidad Urgencias.
# 244: Al Paciente 61 se le ha dado de alta.
# 244: Al Paciente 66 se le asigno una cama y 3 miembro(s) del personal.
# 244: Paciente 68 es atendido.
# 247: Al Paciente 67 se le asigno una cama y 7 miembro(s) del personal.
# 247: Paciente 275 llega al hospital a la unidad Consultorios.
# 247: Paciente 69 es atendido.
# 248: Cirugía completada para el Paciente 7.
# 248: Paciente 7 se le ha dado de alta.
# 248: Al Paciente 55 se le asignó un kit médico.
# 249: Al Paciente 64 se le ha dado de alta.
# 250: Al Paciente 69 se le asigno una cama y 7 miembro(s) del personal.
# 250: Paciente 70 es atendido.
# 252: Paciente 276 llega al hospital a la unidad Consultorios.
# 252: Paciente 277 llega al hospital a la unidad Urgencias.
# 252: Paciente 278 llega al hospital a la unidad Urgencias.
# 252: Paciente 279 llega al hospital a la unidad UCI.
# 252: Paciente 280 llega al hospital a la unidad Consultorios.
# 252: Al Paciente 70 se le asigno una cama y 3 miembro(s) del personal.
# 252: Paciente 71 es atendido.
# 253: Al Paciente 66 se le ha dado de alta.
# 253: Al Paciente 68 se le asigno una cama y 1 miembro(s) del personal.
# 253: Paciente 72 es atendido.
# 255: Cirugía completada para el Paciente 23.
# 255: Paciente 23 se le ha dado de alta.
# 255: Al Paciente 65 se le ha dado de alta.
# 255: Al Paciente 59 se le asignó un kit médico.
# 257: Paciente 281 llega al hospital a la unidad Urgencias.
# 257: Paciente 282 llega al hospital a la unidad Consultorios.
# 257: Al Paciente 71 se le asigno una cama y 3 miembro(s) del personal.
# 257: Paciente 73 es atendido.
# 258: Al Paciente 72 se le asigno una cama y 8 miembro(s) del personal.
# 258: Al Paciente 73 se le asigno una cama y 4 miembro(s) del personal.
# 258: Paciente 74 es atendido.
# 258: Paciente 75 es atendido.
# 259: Paciente 283 llega al hospital a la unidad Urgencias.
# 260: Al Paciente 63 se le ha dado de alta.
# 261: Paciente 284 llega al hospital a la unidad Urgencias.
# 265: Al Paciente 75 se le asigno una cama y 7 miembro(s) del personal.
# 265: Paciente 285 llega al hospital a la unidad Urgencias.
# 265: Paciente 286 llega al hospital a la unidad UCI.
# 265: Paciente 287 llega al hospital a la unidad Consultorios.
# 265: Paciente 76 es atendido.
# 266: Al Paciente 70 se le ha dado de alta.
# 266: Al Paciente 73 se le ha dado de alta.
# 267: Paciente 288 llega al hospital a la unidad UCI.
# 269: Al Paciente 76 se le asigno una cama y 4 miembro(s) del personal.
# 269: Paciente 289 llega al hospital a la unidad Urgencias.
# 269: Paciente 290 llega al hospital a la unidad Urgencias.
# 269: Paciente 77 es atendido.
# 271: El Paciente 60 murió esperando un kit médico.
# 272: Cirugía completada para el Paciente 44.
# 272: Paciente 44 murió tras el procedimiento.
# 272: Paciente 291 llega al hospital a la unidad Urgencias.
# 272: Paciente 292 llega al hospital a la unidad Consultorios.
# 272: Paciente 293 llega al hospital a la unidad UCI.
# 272: Paciente 294 llega al hospital a la unidad Urgencias.
# 275: Al Paciente 68 se le ha dado de alta.
# 275: Al Paciente 77 se le asigno una cama y 5 miembro(s) del personal.
# 275: Paciente 295 llega al hospital a la unidad Urgencias.
# 275: Paciente 296 llega al hospital a la unidad Urgencias.
# 275: Paciente 297 llega al hospital a la unidad Consultorios.
# 275: Paciente 78 es atendido.
# 276: Al Paciente 67 se le ha dado de alta.
# 278: Al Paciente 78 se le asigno una cama y 6 miembro(s) del personal.
# 278: Paciente 79 es atendido.
# 279: Al Paciente 69 se le ha dado de alta.
# 279: Al Paciente 74 se le asigno una cama y 1 miembro(s) del personal.
# 279: Al Paciente 75 se le ha dado de alta.
# 279: Paciente 80 es atendido.
# 280: Paciente 298 llega al hospital a la unidad Urgencias.
# 280: Paciente 299 llega al hospital a la unidad Urgencias.
# 280: Paciente 300 llega al hospital a la unidad Urgencias.
# 284: Al Paciente 80 se le asigno una cama y 4 miembro(s) del personal.
# 284: El Paciente 80 necesita cirugía.
# 284: Paciente 81 es atendido.
# 284: Al Paciente 80 se le asignó un kit médico.
# 285: Al Paciente 71 se le ha dado de alta.
# 285: Paciente 301 llega al hospital a la unidad Urgencias.
# 285: Paciente 302 llega al hospital a la unidad Urgencias.
# 285: Paciente 303 llega al hospital a la unidad UCI.
# 285: Paciente 304 llega al hospital a la unidad UCI.
# 285: Paciente 305 llega al hospital a la unidad UCI.
# 287: Al Paciente 72 se le ha dado de alta.
# 288: Al Paciente 77 se le ha dado de alta.
# 289: Paciente 306 llega al hospital a la unidad Urgencias.
# 289: Paciente 307 llega al hospital a la unidad Urgencias.
# 290: Al Paciente 81 se le asigno una cama y 6 miembro(s) del personal.
# 290: Paciente 82 es atendido.
# 293: Paciente 308 llega al hospital a la unidad Urgencias.
# 293: Paciente 309 llega al hospital a la unidad UCI.
# 293: Paciente 310 llega al hospital a la unidad UCI.
# 294: Al Paciente 76 se le ha dado de alta.
# 294: Al Paciente 78 se le ha dado de alta.
# 297: Al Paciente 81 se le ha dado de alta.
# 297: Paciente 311 llega al hospital a la unidad Urgencias.
# 297: Paciente 312 llega al hospital a la unidad Urgencias.
# 297: Paciente 313 llega al hospital a la unidad Urgencias.
# 300: Paciente 314 llega al hospital a la unidad UCI.
# 300: Paciente 315 llega al hospital a la unidad UCI.
# 300: Paciente 316 llega al hospital a la unidad UCI.
# 300: Paciente 317 llega al hospital a la unidad UCI.
# 300: Paciente 318 llega al hospital a la unidad Urgencias.
# 302: Al Paciente 74 se le ha dado de alta.
# 303: Al Paciente 79 se le asigno una cama y 1 miembro(s) del personal.
# 303: Paciente 319 llega al hospital a la unidad Urgencias.
# 303: Paciente 320 llega al hospital a la unidad Urgencias.
# 303: Paciente 83 es atendido.
# 305: Al Paciente 82 se le asigno una cama y 1 miembro(s) del personal.
# 305: Paciente 321 llega al hospital a la unidad Consultorios.
# 305: Paciente 322 llega al hospital a la unidad UCI.
# 305: Paciente 323 llega al hospital a la unidad Urgencias.
# 305: Paciente 84 es atendido.
# 308: Paciente 324 llega al hospital a la unidad Urgencias.
# 309: Al Paciente 83 se le asigno una cama y 7 miembro(s) del personal.
# 309: Paciente 85 es atendido.
# 310: Al Paciente 82 se le ha dado de alta.
# 311: Paciente 325 llega al hospital a la unidad Urgencias.
# 311: Paciente 326 llega al hospital a la unidad Urgencias.
# 311: Paciente 327 llega al hospital a la unidad Urgencias.
# 312: Al Paciente 84 se le asigno una cama y 5 miembro(s) del personal.
# 312: El Paciente 84 necesita cirugía.
# 312: Paciente 86 es atendido.
# 313: Al Paciente 79 se le ha dado de alta.
# 314: Al Paciente 83 se le ha dado de alta.
# 314: Paciente 328 llega al hospital a la unidad UCI.
# 314: Paciente 329 llega al hospital a la unidad Consultorios.
# 314: Paciente 330 llega al hospital a la unidad Urgencias.
# 314: Paciente 331 llega al hospital a la unidad Urgencias.
# 316: Al Paciente 85 se le asigno una cama y 4 miembro(s) del personal.
# 316: Paciente 87 es atendido.
# 317: Paciente 332 llega al hospital a la unidad Consultorios.
# 317: Paciente 333 llega al hospital a la unidad UCI.
# 317: Paciente 334 llega al hospital a la unidad UCI.
# 317: Paciente 335 llega al hospital a la unidad UCI.
# 318: Paciente 336 llega al hospital a la unidad UCI.
# 319: Al Paciente 86 se le asigno una cama y 8 miembro(s) del personal.
# 319: Paciente 88 es atendido.
# 320: Paciente 337 llega al hospital a la unidad Consultorios.
# 320: Paciente 338 llega al hospital a la unidad Urgencias.
# 320: Paciente 339 llega al hospital a la unidad Urgencias.
# 320: Paciente 340 llega al hospital a la unidad Urgencias.
# 323: Al Paciente 87 se le asigno una cama y 6 miembro(s) del personal.
# 323: Paciente 89 es atendido.
# 325: Al Paciente 88 se le asigno una cama y 3 miembro(s) del personal.
# 325: Paciente 341 llega al hospital a la unidad UCI.
# 325: Paciente 342 llega al hospital a la unidad UCI.
# 325: Paciente 343 llega al hospital a la unidad Consultorios.
# 325: Paciente 90 es atendido.
# 326: Paciente 344 llega al hospital a la unidad UCI.
# 326: Paciente 345 llega al hospital a la unidad Urgencias.
# 326: Paciente 346 llega al hospital a la unidad Urgencias.
# 328: Al Paciente 86 se le ha dado de alta.
# 329: Paciente 347 llega al hospital a la unidad UCI.
# 329: Paciente 348 llega al hospital a la unidad UCI.
# 329: Paciente 349 llega al hospital a la unidad Urgencias.
# 329: Paciente 350 llega al hospital a la unidad Consultorios.
# 330: Al Paciente 89 se le asigno una cama y 3 miembro(s) del personal.
# 330: Paciente 351 llega al hospital a la unidad UCI.
# 330: Paciente 352 llega al hospital a la unidad Consultorios.
# 330: Paciente 91 es atendido.
# 331: Paciente 353 llega al hospital a la unidad Urgencias.
# 331: Paciente 354 llega al hospital a la unidad UCI.
# 331: Paciente 355 llega al hospital a la unidad Consultorios.
# 332: Al Paciente 90 se le asigno una cama y 6 miembro(s) del personal.
# 332: El Paciente 90 necesita cirugía.
# 332: Paciente 92 es atendido.
# 336: Al Paciente 91 se le asigno una cama y 5 miembro(s) del personal.
# 336: Paciente 356 llega al hospital a la unidad Consultorios.
# 336: Paciente 357 llega al hospital a la unidad Consultorios.
# 336: Paciente 358 llega al hospital a la unidad Consultorios.
# 336: Paciente 359 llega al hospital a la unidad UCI.
# 336: Paciente 360 llega al hospital a la unidad Urgencias.
# 336: Paciente 93 es atendido.
# 339: Al Paciente 85 se le ha dado de alta.
# 340: Paciente 361 llega al hospital a la unidad UCI.
# 340: Paciente 362 llega al hospital a la unidad Urgencias.
# 340: Paciente 363 llega al hospital a la unidad Consultorios.
# 340: Paciente 364 llega al hospital a la unidad UCI.
# 340: Al Paciente 93 se le asigno una cama y 3 miembro(s) del personal.
# 340: El Paciente 93 necesita cirugía.
# 340: Paciente 94 es atendido.
# 344: Al Paciente 92 se le asigno una cama y 1 miembro(s) del personal.
# 344: Paciente 365 llega al hospital a la unidad Urgencias.
# 344: Paciente 366 llega al hospital a la unidad Consultorios.
# 344: Paciente 367 llega al hospital a la unidad Urgencias.
# 344: Paciente 95 es atendido.
# 347: Al Paciente 94 se le asigno una cama y 7 miembro(s) del personal.
# 347: Paciente 368 llega al hospital a la unidad Urgencias.
# 347: Paciente 369 llega al hospital a la unidad UCI.
# 347: Paciente 96 es atendido.
# 348: Al Paciente 95 se le asigno una cama y 7 miembro(s) del personal.
# 348: Paciente 97 es atendido.
# 349: Paciente 370 llega al hospital a la unidad UCI.
# 351: Al Paciente 88 se le ha dado de alta.
# 352: Al Paciente 87 se le ha dado de alta.
# 352: Paciente 371 llega al hospital a la unidad UCI.
# 352: Paciente 372 llega al hospital a la unidad Urgencias.
# 353: Al Paciente 91 se le ha dado de alta.
# 354: Al Paciente 89 se le ha dado de alta.
# 355: Al Paciente 94 se le ha dado de alta.
# 355: Paciente 373 llega al hospital a la unidad Urgencias.
# 355: Paciente 374 llega al hospital a la unidad Urgencias.
# 355: Paciente 375 llega al hospital a la unidad UCI.
# 355: Paciente 376 llega al hospital a la unidad Consultorios.
# 359: Paciente 377 llega al hospital a la unidad Urgencias.
# 363: Paciente 378 llega al hospital a la unidad Urgencias.
# 365: Al Paciente 97 se le asigno una cama y 1 miembro(s) del personal.
# 365: Paciente 98 es atendido.
# 366: Paciente 379 llega al hospital a la unidad Consultorios.
# 369: Al Paciente 96 se le asigno una cama y 1 miembro(s) del personal.
# 369: Al Paciente 95 se le ha dado de alta.
# 369: Al Paciente 98 se le asigno una cama y 3 miembro(s) del personal.
# 369: Paciente 99 es atendido.
# 369: Paciente 100 es atendido.
# 370: Paciente 380 llega al hospital a la unidad UCI.
# 371: Al Paciente 99 se le asigno una cama y 5 miembro(s) del personal.
# 371: El Paciente 99 necesita cirugía.
# 371: Paciente 101 es atendido.
# 372: Al Paciente 100 se le asigno una cama y 7 miembro(s) del personal.
# 372: El Paciente 84 murió esperando un kit médico.
# 372: Paciente 102 es atendido.
# 374: Al Paciente 92 se le ha dado de alta.
# 374: Paciente 381 llega al hospital a la unidad Urgencias.
# 374: Paciente 382 llega al hospital a la unidad UCI.
# 374: Paciente 383 llega al hospital a la unidad Consultorios.
# 374: Paciente 384 llega al hospital a la unidad Consultorios.
# 376: Al Paciente 101 se le asigno una cama y 5 miembro(s) del personal.
# 376: Paciente 103 es atendido.
# 378: Paciente 385 llega al hospital a la unidad Urgencias.
# 378: Paciente 386 llega al hospital a la unidad Urgencias.
# 378: Paciente 387 llega al hospital a la unidad Consultorios.
# 378: Paciente 388 llega al hospital a la unidad Urgencias.
# 378: Paciente 389 llega al hospital a la unidad UCI.
# 380: Paciente 390 llega al hospital a la unidad Urgencias.
# 380: Paciente 391 llega al hospital a la unidad Urgencias.
# 381: Al Paciente 101 se le ha dado de alta.
# 381: Paciente 392 llega al hospital a la unidad Urgencias.
# 381: Paciente 393 llega al hospital a la unidad Urgencias.
# 381: Paciente 394 llega al hospital a la unidad UCI.
# 381: Paciente 395 llega al hospital a la unidad Urgencias.
# 382: Paciente 396 llega al hospital a la unidad UCI.
# 382: Paciente 397 llega al hospital a la unidad Urgencias.
# 382: Paciente 398 llega al hospital a la unidad Urgencias.
# 382: Paciente 399 llega al hospital a la unidad UCI.
# 383: Al Paciente 96 se le ha dado de alta.
# 383: Al Paciente 103 se le asigno una cama y 6 miembro(s) del personal.
# 383: Paciente 104 es atendido.
# 385: Paciente 400 llega al hospital a la unidad Urgencias.
# 385: Paciente 401 llega al hospital a la unidad UCI.
# 385: Paciente 402 llega al hospital a la unidad Consultorios.
# 387: Paciente 403 llega al hospital a la unidad Consultorios.
# 387: Paciente 404 llega al hospital a la unidad UCI.
# 387: Paciente 405 llega al hospital a la unidad Urgencias.
# 387: Paciente 406 llega al hospital a la unidad Urgencias.
# 388: Al Paciente 104 se le asigno una cama y 3 miembro(s) del personal.
# 388: Paciente 105 es atendido.
# 390: Al Paciente 105 se le asigno una cama y 5 miembro(s) del personal.
# 390: Paciente 106 es atendido.
# 391: Paciente 407 llega al hospital a la unidad Consultorios.
# 392: Al Paciente 100 se le ha dado de alta.
# 392: Paciente 408 llega al hospital a la unidad Consultorios.
# 392: El Paciente 90 murió esperando un kit médico.
# 393: Al Paciente 97 se le ha dado de alta.
# 394: Al Paciente 98 se le ha dado de alta.
# 394: Al Paciente 106 se le asigno una cama y 4 miembro(s) del personal.
# 394: Paciente 107 es atendido.
# 396: Cirugía completada para el Paciente 11.
# 396: Paciente 11 se le ha dado de alta.
# 396: Al Paciente 102 se le asigno una cama y 1 miembro(s) del personal.
# 396: Paciente 108 es atendido.
# 396: Al Paciente 93 se le asignó un kit médico.
# 397: Paciente 409 llega al hospital a la unidad UCI.
# 397: Paciente 410 llega al hospital a la unidad Urgencias.
# 397: Paciente 411 llega al hospital a la unidad Urgencias.
# 397: Paciente 412 llega al hospital a la unidad UCI.
# 397: Paciente 413 llega al hospital a la unidad Consultorios.
# 397: Al Paciente 107 se le asigno una cama y 4 miembro(s) del personal.
# 397: Al Paciente 108 se le asigno una cama y 5 miembro(s) del personal.
# 397: Paciente 109 es atendido.
# 397: Paciente 110 es atendido.
# 398: Al Paciente 109 se le asigno una cama y 4 miembro(s) del personal.
# 398: Paciente 111 es atendido.
# 400: Al Paciente 103 se le ha dado de alta.
# 400: Paciente 414 llega al hospital a la unidad UCI.
# 400: Paciente 415 llega al hospital a la unidad Consultorios.
# 400: Paciente 416 llega al hospital a la unidad Urgencias.
# 400: Paciente 417 llega al hospital a la unidad Urgencias.
# 401: Al Paciente 102 se le ha dado de alta.
# 401: Paciente 418 llega al hospital a la unidad UCI.
# 401: Paciente 419 llega al hospital a la unidad Consultorios.
# 401: Paciente 420 llega al hospital a la unidad UCI.
# 401: Paciente 421 llega al hospital a la unidad UCI.
# 402: Paciente 422 llega al hospital a la unidad Urgencias.
# 402: Paciente 423 llega al hospital a la unidad Urgencias.
# 402: Paciente 424 llega al hospital a la unidad Urgencias.
# 403: Al Paciente 105 se le ha dado de alta.
# 403: Al Paciente 108 se le ha dado de alta.
# 404: Paciente 425 llega al hospital a la unidad Consultorios.
# 407: Cirugía completada para el Paciente 24.
# 407: Paciente 24 se le ha dado de alta.
# 407: Paciente 426 llega al hospital a la unidad UCI.
# 407: Paciente 427 llega al hospital a la unidad Consultorios.
# 407: Al Paciente 99 se le asignó un kit médico.
# 408: Paciente 428 llega al hospital a la unidad Urgencias.
# 408: Paciente 429 llega al hospital a la unidad Urgencias.
# 408: Paciente 430 llega al hospital a la unidad Urgencias.
# 410: Al Paciente 104 se le ha dado de alta.
# 412: Paciente 431 llega al hospital a la unidad Urgencias.
# 412: Paciente 432 llega al hospital a la unidad Urgencias.
# 412: Paciente 433 llega al hospital a la unidad Urgencias.
# 412: Paciente 434 llega al hospital a la unidad Consultorios.
# 412: Paciente 435 llega al hospital a la unidad Consultorios.
# 415: Cirugía completada para el Paciente 5.
# 415: Paciente 5 se le ha dado de alta.
# 415: Paciente 436 llega al hospital a la unidad UCI.
# 415: Paciente 437 llega al hospital a la unidad Urgencias.
# 415: Paciente 438 llega al hospital a la unidad UCI.
# 415: Paciente 439 llega al hospital a la unidad Consultorios.
# 417: Al Paciente 111 se le asigno una cama y 1 miembro(s) del personal.
# 417: Paciente 440 llega al hospital a la unidad UCI.
# 417: Paciente 112 es atendido.
# 419: Paciente 441 llega al hospital a la unidad UCI.
# 419: Paciente 442 llega al hospital a la unidad Urgencias.
# 420: Al Paciente 106 se le ha dado de alta.
# 420: Al Paciente 112 se le asigno una cama y 8 miembro(s) del personal.
# 420: Paciente 113 es atendido.
# 421: Al Paciente 110 se le asigno una cama y 1 miembro(s) del personal.
# 421: Paciente 114 es atendido.
# 422: Paciente 443 llega al hospital a la unidad UCI.
# 422: Paciente 444 llega al hospital a la unidad UCI.
# 422: Paciente 445 llega al hospital a la unidad Urgencias.
# 425: Al Paciente 107 se le ha dado de alta.
# 425: Paciente 446 llega al hospital a la unidad Urgencias.
# 425: Paciente 447 llega al hospital a la unidad Urgencias.
# 425: Paciente 448 llega al hospital a la unidad Urgencias.
# 426: Al Paciente 109 se le ha dado de alta.
# 426: Al Paciente 113 se le asigno una cama y 3 miembro(s) del personal.
# 426: Paciente 115 es atendido.
# 427: Al Paciente 114 se le asigno una cama y 3 miembro(s) del personal.
# 427: Paciente 116 es atendido.
# 429: Al Paciente 110 se le ha dado de alta.
# 429: Paciente 449 llega al hospital a la unidad Urgencias.
# 429: Paciente 450 llega al hospital a la unidad Urgencias.
# 429: Paciente 451 llega al hospital a la unidad Urgencias.
# 429: Paciente 452 llega al hospital a la unidad Urgencias.
# 430: Al Paciente 116 se le asigno una cama y 5 miembro(s) del personal.
# 430: Paciente 117 es atendido.
# 431: Al Paciente 115 se le asigno una cama y 8 miembro(s) del personal.
# 431: El Paciente 115 necesita cirugía.
# 431: Paciente 118 es atendido.
# 431: Al Paciente 115 se le asignó un kit médico.
# 432: Paciente 453 llega al hospital a la unidad Urgencias.
# 432: Paciente 454 llega al hospital a la unidad Urgencias.
# 432: Paciente 455 llega al hospital a la unidad Urgencias.
# 432: Paciente 456 llega al hospital a la unidad UCI.
# 433: Al Paciente 117 se le asigno una cama y 8 miembro(s) del personal.
# 433: Paciente 119 es atendido.
# 434: Al Paciente 112 se le ha dado de alta.
# 434: Paciente 457 llega al hospital a la unidad UCI.
# 434: Paciente 458 llega al hospital a la unidad Urgencias.
# 434: Paciente 459 llega al hospital a la unidad Urgencias.
# 434: Paciente 460 llega al hospital a la unidad UCI.
# 435: Al Paciente 113 se le ha dado de alta.
# 437: Al Paciente 118 se le asigno una cama y 6 miembro(s) del personal.
# 437: Paciente 120 es atendido.
# 439: Al Paciente 119 se le asigno una cama y 3 miembro(s) del personal.
# 439: Paciente 461 llega al hospital a la unidad Urgencias.
# 439: Paciente 462 llega al hospital a la unidad Urgencias.
# 439: Paciente 463 llega al hospital a la unidad Urgencias.
# 439: Paciente 464 llega al hospital a la unidad UCI.
# 439: Paciente 121 es atendido.
# 443: Al Paciente 111 se le ha dado de alta.
# 443: Paciente 465 llega al hospital a la unidad UCI.
# 443: Paciente 466 llega al hospital a la unidad Urgencias.
# 443: Paciente 467 llega al hospital a la unidad Consultorios.
# 443: Paciente 468 llega al hospital a la unidad Consultorios.
# 443: Paciente 469 llega al hospital a la unidad Urgencias.
# 444: Al Paciente 118 se le ha dado de alta.
# 444: Al Paciente 120 se le asigno una cama y 8 miembro(s) del personal.
# 444: Paciente 122 es atendido.
# 445: Al Paciente 117 se le ha dado de alta.
# 445: Al Paciente 121 se le asigno una cama y 3 miembro(s) del personal.
# 445: Paciente 123 es atendido.
# 446: Al Paciente 122 se le asigno una cama y 4 miembro(s) del personal.
# 446: Paciente 124 es atendido.
# 447: Al Paciente 119 se le ha dado de alta.
# 447: Paciente 470 llega al hospital a la unidad Urgencias.
# 450: Al Paciente 123 se le asigno una cama y 8 miembro(s) del personal.
# 450: Paciente 471 llega al hospital a la unidad Consultorios.
# 450: Paciente 472 llega al hospital a la unidad Urgencias.
# 450: Paciente 473 llega al hospital a la unidad UCI.
# 450: Paciente 474 llega al hospital a la unidad Urgencias.
# 450: Paciente 475 llega al hospital a la unidad UCI.
# 450: Paciente 125 es atendido.
# 451: Al Paciente 125 se le asigno una cama y 4 miembro(s) del personal.
# 451: Paciente 126 es atendido.
# 452: Paciente 476 llega al hospital a la unidad Consultorios.
# 455: Al Paciente 116 se le ha dado de alta.
# 456: Al Paciente 114 se le ha dado de alta.
# 456: Paciente 477 llega al hospital a la unidad Urgencias.
# 456: Paciente 478 llega al hospital a la unidad UCI.
# 456: Paciente 479 llega al hospital a la unidad Urgencias.
# 457: Al Paciente 121 se le ha dado de alta.
# 458: Al Paciente 126 se le asigno una cama y 7 miembro(s) del personal.
# 458: Paciente 480 llega al hospital a la unidad UCI.
# 458: Paciente 481 llega al hospital a la unidad Consultorios.
# 458: Paciente 482 llega al hospital a la unidad UCI.
# 458: Paciente 127 es atendido.
# 459: Al Paciente 125 se le ha dado de alta.
# 462: Paciente 483 llega al hospital a la unidad Urgencias.
# 462: Paciente 484 llega al hospital a la unidad Urgencias.
# 463: Al Paciente 124 se le asigno una cama y 1 miembro(s) del personal.
# 463: Al Paciente 127 se le asigno una cama y 8 miembro(s) del personal.
# 463: Paciente 128 es atendido.
# 463: Paciente 129 es atendido.
# 464: Al Paciente 126 se le ha dado de alta.
# 465: Al Paciente 120 se le ha dado de alta.
# 465: Paciente 485 llega al hospital a la unidad Urgencias.
# 466: Al Paciente 129 se le asigno una cama y 3 miembro(s) del personal.
# 466: Paciente 486 llega al hospital a la unidad Consultorios.
# 466: Paciente 487 llega al hospital a la unidad Urgencias.
# 466: Paciente 488 llega al hospital a la unidad UCI.
# 466: Paciente 489 llega al hospital a la unidad UCI.
# 466: Paciente 490 llega al hospital a la unidad Urgencias.
# 466: Paciente 130 es atendido.
# 470: Al Paciente 130 se le asigno una cama y 5 miembro(s) del personal.
# 470: Paciente 131 es atendido.
# 471: Paciente 491 llega al hospital a la unidad UCI.
# 473: Al Paciente 122 se le ha dado de alta.
# 473: Al Paciente 131 se le asigno una cama y 7 miembro(s) del personal.
# 473: Paciente 132 es atendido.
# 475: Paciente 492 llega al hospital a la unidad Urgencias.
# 475: Paciente 493 llega al hospital a la unidad Urgencias.
# 475: Paciente 494 llega al hospital a la unidad Urgencias.
# 476: Al Paciente 132 se le asigno una cama y 3 miembro(s) del personal.
# 476: Paciente 133 es atendido.
# 478: Cirugía completada para el Paciente 115.
# 478: Paciente 115 se le ha dado de alta.
# 478: Al Paciente 127 se le ha dado de alta.

# %% [markdown]
# # 4. Recolección de Datos

# %% [markdown]
# ## Preguntas a responder:
# 1. ¿Cuál fue el tiempo promedio de espera por unidad?
#
# 2. ¿Qué unidad estuvo más congestionada?
#
# 3. ¿Cuántos pacientes no fueron atendidos por falta de recursos?
#
# 4. ¿Cuál fue el total de pacientes atendidos?
#
# 5. ¿Cuál es la cantidad y  % de pacientes que vienen a cada unidad?
#
# 6. ¿Qué impacto tuvo cambiar el número de recepcionistas o personal médico?

# %% [markdown]
# ### Construcción del dataframe de perfil de paciente

# %%
lista_pacientes = []

def registrar_paciente(paciente_id, unidad, cirugia,alcanzo_cama):
    lista_pacientes.append({
        "id": paciente_id,
        "unidad": unidad,
        "cirugia": cirugia,
        "alcanzo_cama": alcanzo_cama
    })

# %%
for p in simulacion.pacientes:
    registrar_paciente(p.id, p.unidad.nombre, p.cirugia, p.alcanzo_cama)

dfPacientes = pd.DataFrame(lista_pacientes)
dfPacientes
# Out:
#       id     unidad  cirugia  alcanzo_cama
# 0      1  Urgencias    False          True
# 1      2  Urgencias     True          True
# 2      3  Urgencias    False          True
# 3      4        UCI    False          True
# 4      5  Urgencias     True          True
# ..   ...        ...      ...           ...
# 489  490  Urgencias    False         False
# 490  491        UCI    False         False
# 491  492  Urgencias    False         False
# 492  493  Urgencias     True         False
# 493  494  Urgencias    False         False
#
# [494 rows x 4 columns]

# %% [markdown]
# ### Construcción del dataframe de eventos

# %%
lista_eventos = []
for p in simulacion.pacientes:
    lista_eventos.append( p.eventos )

dfeventos = pd.concat(lista_eventos)
dfeventos = dfeventos.reset_index()
dfeventos.drop( ["index"], axis=1, inplace=True )

dfeventos
# Out:
#       id                    evento  time
# 0      1                   LLEGADA     2
# 1      1                  ATENDIDO     2
# 2      1  ASIGNACION_CAMA_PERSONAL     8
# 3      1                      ALTA    26
# 4      2                   LLEGADA     2
# ..   ...                       ...   ...
# 888  490                   LLEGADA   466
# 889  491                   LLEGADA   471
# 890  492                   LLEGADA   475
# 891  493                   LLEGADA   475
# 892  494                   LLEGADA   475
#
# [893 rows x 3 columns]

# %%
dfPacientes.loc[ dfPacientes["id"] == 1 , : ]
# Out:
#    id     unidad  cirugia  alcanzo_cama
# 0   1  Urgencias    False          True

# %%
dfeventos.loc[ dfeventos["id"] == 1 , : ]
# Out:
#    id                    evento  time
# 0   1                   LLEGADA     2
# 1   1                  ATENDIDO     2
# 2   1  ASIGNACION_CAMA_PERSONAL     8
# 3   1                      ALTA    26

# %% [markdown]
# ## 1. ¿Cuál fue el tiempo promedio de espera por unidad?

# %%
dfeventos["lag_time"] = dfeventos.groupby("id")["time"].shift(1)

# %%
# Filtramos y calculamos el tiempo de espera
df1 = dfeventos.loc[dfeventos["evento"] == "ATENDIDO", :].copy()
df1["tiempo_espera"] = df1["time"] - df1["lag_time"]

# Merge con la info de pacientes (asegúrate de que 'id' esté en ambos)
df_merged = df1.merge(dfPacientes, on="id", how="inner")

# Agrupamos por unidad y calculamos el promedio
resultado = (
    df_merged
    .groupby("unidad")
    .agg({"tiempo_espera": "mean"})
)

print(resultado)
# Out:
#               tiempo_espera
# unidad
# Consultorios     179.535714
# UCI              217.717391
# Urgencias        152.949153

# %% [markdown]
# ## 2. ¿Qué unidad estuvo más congestionada?

# %%
# Nombre de la unidad con mayor espera
unidad_max = resultado["tiempo_espera"].idxmax()

# Valor de la espera media más alta
espera_max = resultado["tiempo_espera"].max()
print (f'La unidad más congestionada basandonos en su tiempo medio de atención es {unidad_max} \ncon un tiempo de espera de {espera_max}')
# Out:
# La unidad más congestionada basandonos en su tiempo medio de atención es UCI
# con un tiempo de espera de 217.7173913043478

# %% [markdown]
# ## 3. ¿Cuántos pacientes no fueron atendidos por falta de recursos?

# %%
# 1. Pacientes totales que intentaron ser atendidos
todos = set(dfeventos["id"].unique())

# 2. Pacientes que sí consiguieron cama/personal
con_cama = set(dfeventos.loc[dfeventos["evento"] == "ASIGNACION_CAMA_PERSONAL", "id"].unique())

# 3. Pacientes que nunca obtuvieron cama
sin_cama = todos - con_cama

# 4. Pacientes que murieron esperando kit (sin haberse asignado uno)
muertes = set(dfeventos.loc[dfeventos["evento"] == "MUERTE", "id"].unique())
con_kit = set(dfeventos.loc[dfeventos["evento"] == "ASIGNACION_KIT", "id"].unique())
muertes_por_kit = muertes - con_kit

print(f"Pacientes sin cama asignada: {len(sin_cama)}")
print(f"Pacientes que murieron por falta de kits: {len(muertes_por_kit)}")
print(f"Total no atendidos por falta de recursos: {len(sin_cama) + len(muertes_por_kit)}")
# Out:
# Pacientes sin cama asignada: 363
# Pacientes que murieron por falta de kits: 6
# Total no atendidos por falta de recursos: 369

# %% [markdown]
# ### 4. ¿Cuál fue el total de pacientes atentidos y cuantos quedaron en recepción?

# %%
# Filtrar eventos de tipo 'ATENDIDO'
df_atendidos = dfeventos[dfeventos["evento"] == "ATENDIDO"]

# Contar cuántos pacientes únicos fueron atendidos
total_atendidos = df_atendidos["id"].nunique()

print(f"Total de pacientes atendidos: {total_atendidos}")
print(f"Total de pacientes esperando en recepción o cama: {(len(todos)-total_atendidos)
}")
# Out:
# Total de pacientes atendidos: 133
# Total de pacientes esperando en recepción o cama: 361

# %% [markdown]
# ### 5. ¿Cuál es la cantidad y % de pacientes que vienen a cada unidad?

# %%
df_unique = dfPacientes[['id', 'unidad']].drop_duplicates()


df_stats = (
    df_unique['unidad']
    .value_counts()
    .rename_axis('unidad')
    .reset_index(name='total')
)
df_stats['porcentaje'] = df_stats['total'] / df_stats['total'].sum() * 100

print(df_stats)
# Out:
#          unidad  total  porcentaje
# 0     Urgencias    241   48.785425
# 1           UCI    157   31.781377
# 2  Consultorios     96   19.433198

# %% [markdown]
# ## 5.¿Qué impacto tuvo cambiar el número de recepcionistas o personal médico?

# %% [markdown]
# ### Aumento de recepcionistas

# %%
env2 = simpy.Environment()
unidades_settings = [
    {"nombre": "Urgencias", "num_camas": 20, "personal": 30, "num_kits_medicos": 8},
    {"nombre": "UCI", "num_camas": 35, "personal": 25, "num_kits_medicos": 1},
    {"nombre": "Consultorios", "num_camas": 10, "personal": 8, "num_kits_medicos": 1}
]
num_recepcionistas = 6

#random.seed(111)

simulacion2 = Simulation(env2, unidades_settings, num_recepcionistas)
env2.run(until=60*8)
# Out:
# 2: Paciente 1 llega al hospital a la unidad Urgencias.
# 2: Paciente 2 llega al hospital a la unidad UCI.
# 2: Paciente 3 llega al hospital a la unidad Urgencias.
# 2: Paciente 4 llega al hospital a la unidad Urgencias.
# 2: Paciente 5 llega al hospital a la unidad UCI.
# 2: Paciente 1 es atendido.
# 2: Paciente 2 es atendido.
# 2: Paciente 3 es atendido.
# 2: Paciente 4 es atendido.
# 2: Paciente 5 es atendido.
# 4: Al Paciente 3 se le asigno una cama y 4 miembro(s) del personal.
# 4: El Paciente 3 necesita cirugía.
# 4: Al Paciente 3 se le asignó un kit médico.
# 6: Paciente 6 llega al hospital a la unidad Urgencias.
# 6: Paciente 6 es atendido.
# 7: Al Paciente 2 se le asigno una cama y 4 miembro(s) del personal.
# 7: Paciente 7 llega al hospital a la unidad UCI.
# 7: Paciente 8 llega al hospital a la unidad UCI.
# 7: Paciente 7 es atendido.
# 7: Paciente 8 es atendido.
# 8: Al Paciente 1 se le asigno una cama y 8 miembro(s) del personal.
# 8: Al Paciente 4 se le asigno una cama y 6 miembro(s) del personal.
# 8: El Paciente 4 necesita cirugía.
# 8: Al Paciente 5 se le asigno una cama y 8 miembro(s) del personal.
# 8: Al Paciente 6 se le asigno una cama y 6 miembro(s) del personal.
# 8: El Paciente 6 necesita cirugía.
# 8: Al Paciente 4 se le asignó un kit médico.
# 8: Al Paciente 6 se le asignó un kit médico.
# 9: Al Paciente 7 se le asigno una cama y 6 miembro(s) del personal.
# 9: Al Paciente 8 se le asigno una cama y 6 miembro(s) del personal.
# 11: Paciente 9 llega al hospital a la unidad Urgencias.
# 11: Paciente 10 llega al hospital a la unidad UCI.
# 11: Paciente 9 es atendido.
# 11: Paciente 10 es atendido.
# 12: Al Paciente 9 se le asigno una cama y 4 miembro(s) del personal.
# 14: Al Paciente 10 se le asigno una cama y 6 miembro(s) del personal.
# 16: Al Paciente 5 se le ha dado de alta.
# 16: Paciente 11 llega al hospital a la unidad Urgencias.
# 16: Paciente 12 llega al hospital a la unidad Urgencias.
# 16: Paciente 13 llega al hospital a la unidad Urgencias.
# 16: Paciente 14 llega al hospital a la unidad Urgencias.
# 16: Paciente 11 es atendido.
# 16: Paciente 12 es atendido.
# 16: Paciente 13 es atendido.
# 16: Paciente 14 es atendido.
# 17: Paciente 15 llega al hospital a la unidad Urgencias.
# 17: Al Paciente 11 se le asigno una cama y 3 miembro(s) del personal.
# 17: El Paciente 11 necesita cirugía.
# 17: Al Paciente 14 se le asigno una cama y 3 miembro(s) del personal.
# 17: El Paciente 14 necesita cirugía.
# 17: Paciente 15 es atendido.
# 17: Al Paciente 11 se le asignó un kit médico.
# 17: Al Paciente 14 se le asignó un kit médico.
# 18: Al Paciente 12 se le asigno una cama y 8 miembro(s) del personal.
# 19: Al Paciente 8 se le ha dado de alta.
# 20: Al Paciente 7 se le ha dado de alta.
# 20: Al Paciente 13 se le asigno una cama y 5 miembro(s) del personal.
# 20: El Paciente 13 necesita cirugía.
# 20: Al Paciente 13 se le asignó un kit médico.
# 21: Al Paciente 15 se le asigno una cama y 3 miembro(s) del personal.
# 22: Paciente 16 llega al hospital a la unidad Consultorios.
# 22: Paciente 17 llega al hospital a la unidad UCI.
# 22: Paciente 18 llega al hospital a la unidad UCI.
# 22: Paciente 19 llega al hospital a la unidad Urgencias.
# 22: Paciente 20 llega al hospital a la unidad UCI.
# 22: Paciente 16 es atendido.
# 22: Paciente 17 es atendido.
# 22: Paciente 18 es atendido.
# 22: Paciente 19 es atendido.
# 22: Paciente 20 es atendido.
# 23: Al Paciente 12 se le ha dado de alta.
# 23: Al Paciente 17 se le asigno una cama y 7 miembro(s) del personal.
# 24: Al Paciente 18 se le asigno una cama y 4 miembro(s) del personal.
# 24: Al Paciente 19 se le asigno una cama y 3 miembro(s) del personal.
# 25: Paciente 21 llega al hospital a la unidad UCI.
# 25: Paciente 22 llega al hospital a la unidad UCI.
# 25: Paciente 23 llega al hospital a la unidad UCI.
# 25: Paciente 21 es atendido.
# 25: Paciente 22 es atendido.
# 25: Paciente 23 es atendido.
# 26: Al Paciente 23 se le asigno una cama y 3 miembro(s) del personal.
# 27: Al Paciente 2 se le ha dado de alta.
# 27: Al Paciente 20 se le asigno una cama y 7 miembro(s) del personal.
# 27: Paciente 24 llega al hospital a la unidad Urgencias.
# 27: Paciente 24 es atendido.
# 28: Al Paciente 21 se le asigno una cama y 8 miembro(s) del personal.
# 29: Al Paciente 24 se le asigno una cama y 5 miembro(s) del personal.
# 29: El Paciente 24 necesita cirugía.
# 29: Al Paciente 24 se le asignó un kit médico.
# 30: Al Paciente 9 se le ha dado de alta.
# 30: Al Paciente 22 se le asigno una cama y 4 miembro(s) del personal.
# 30: Paciente 25 llega al hospital a la unidad UCI.
# 30: Paciente 26 llega al hospital a la unidad Consultorios.
# 30: Paciente 25 es atendido.
# 30: Paciente 26 es atendido.
# 31: Al Paciente 19 se le ha dado de alta.
# 32: Paciente 27 llega al hospital a la unidad Urgencias.
# 32: Paciente 27 es atendido.
# 34: Al Paciente 1 se le ha dado de alta.
# 34: Paciente 28 llega al hospital a la unidad Urgencias.
# 34: Paciente 29 llega al hospital a la unidad Urgencias.
# 34: Paciente 30 llega al hospital a la unidad Urgencias.
# 34: Paciente 31 llega al hospital a la unidad UCI.
# 34: Paciente 32 llega al hospital a la unidad UCI.
# 34: Al Paciente 27 se le asigno una cama y 6 miembro(s) del personal.
# 34: Paciente 28 es atendido.
# 34: Paciente 29 es atendido.
# 34: Paciente 30 es atendido.
# 35: Al Paciente 10 se le ha dado de alta.
# 36: Al Paciente 25 se le asigno una cama y 7 miembro(s) del personal.
# 36: Paciente 31 es atendido.
# 37: Al Paciente 16 se le asigno una cama y 1 miembro(s) del personal.
# 37: Al Paciente 31 se le asigno una cama y 3 miembro(s) del personal.
# 37: Paciente 32 es atendido.
# 38: Paciente 33 llega al hospital a la unidad UCI.
# 38: Paciente 34 llega al hospital a la unidad Urgencias.
# 38: Paciente 35 llega al hospital a la unidad UCI.
# 38: Al Paciente 29 se le asigno una cama y 7 miembro(s) del personal.
# 38: El Paciente 29 necesita cirugía.
# 38: Al Paciente 30 se le asigno una cama y 6 miembro(s) del personal.
# 38: El Paciente 30 necesita cirugía.
# 38: Paciente 33 es atendido.
# 38: Paciente 34 es atendido.
# 38: Al Paciente 29 se le asignó un kit médico.
# 38: Paciente 35 es atendido.
# 39: Cirugía completada para el Paciente 6.
# 39: Paciente 6 se le ha dado de alta.
# 39: Al Paciente 28 se le asigno una cama y 7 miembro(s) del personal.
# 39: El Paciente 28 necesita cirugía.
# 39: Al Paciente 34 se le asigno una cama y 3 miembro(s) del personal.
# 39: Al Paciente 30 se le asignó un kit médico.
# 40: Al Paciente 22 se le ha dado de alta.
# 40: Paciente 36 llega al hospital a la unidad Consultorios.
# 40: Paciente 37 llega al hospital a la unidad Consultorios.
# 40: Paciente 38 llega al hospital a la unidad Urgencias.
# 40: Paciente 39 llega al hospital a la unidad UCI.
# 40: Paciente 36 es atendido.
# 40: Paciente 37 es atendido.
# 41: Al Paciente 33 se le asigno una cama y 7 miembro(s) del personal.
# 41: Paciente 38 es atendido.
# 43: Al Paciente 17 se le ha dado de alta.
# 43: Al Paciente 21 se le ha dado de alta.
# 44: Cirugía completada para el Paciente 4.
# 44: Paciente 4 se le ha dado de alta.
# 44: Al Paciente 32 se le asigno una cama y 8 miembro(s) del personal.
# 44: Paciente 39 es atendido.
# 44: Al Paciente 28 se le asignó un kit médico.
# 45: Al Paciente 27 se le ha dado de alta.
# 45: Al Paciente 35 se le asigno una cama y 8 miembro(s) del personal.
# 45: Paciente 40 llega al hospital a la unidad Urgencias.
# 45: Paciente 40 es atendido.
# 46: Al Paciente 18 se le ha dado de alta.
# 46: Al Paciente 20 se le ha dado de alta.
# 47: Al Paciente 38 se le asigno una cama y 3 miembro(s) del personal.
# 47: Al Paciente 39 se le asigno una cama y 5 miembro(s) del personal.
# 47: Paciente 41 llega al hospital a la unidad Urgencias.
# 47: Paciente 42 llega al hospital a la unidad Urgencias.
# 47: Paciente 43 llega al hospital a la unidad Urgencias.
# 47: Paciente 44 llega al hospital a la unidad UCI.
# 47: Paciente 41 es atendido.
# 47: Paciente 42 es atendido.
# 48: Al Paciente 15 se le ha dado de alta.
# 48: Al Paciente 42 se le asigno una cama y 4 miembro(s) del personal.
# 48: Paciente 43 es atendido.
# 49: Cirugía completada para el Paciente 3.
# 49: Paciente 3 se le ha dado de alta.
# 49: Al Paciente 26 se le asigno una cama y 1 miembro(s) del personal.
# 49: Al Paciente 36 se le asigno una cama y 1 miembro(s) del personal.
# 49: Al Paciente 40 se le asigno una cama y 3 miembro(s) del personal.
# 49: Paciente 44 es atendido.
# 50: Al Paciente 25 se le ha dado de alta.
# 50: Al Paciente 32 se le ha dado de alta.
# 50: Al Paciente 41 se le asigno una cama y 8 miembro(s) del personal.
# 50: Al Paciente 43 se le asigno una cama y 4 miembro(s) del personal.
# 50: Al Paciente 44 se le asigno una cama y 4 miembro(s) del personal.
# 51: Al Paciente 23 se le ha dado de alta.
# 51: Paciente 45 llega al hospital a la unidad Urgencias.
# 51: Paciente 45 es atendido.
# 52: Al Paciente 34 se le ha dado de alta.
# 52: Al Paciente 37 se le asigno una cama y 1 miembro(s) del personal.
# 54: Al Paciente 33 se le ha dado de alta.
# 54: Al Paciente 39 se le ha dado de alta.
# 54: Paciente 46 llega al hospital a la unidad UCI.
# 54: Paciente 47 llega al hospital a la unidad Urgencias.
# 54: Al Paciente 45 se le asigno una cama y 5 miembro(s) del personal.
# 54: El Paciente 45 necesita cirugía.
# 54: Paciente 46 es atendido.
# 54: Paciente 47 es atendido.
# 54: Al Paciente 45 se le asignó un kit médico.
# 55: Al Paciente 44 se le ha dado de alta.
# 58: Al Paciente 16 se le ha dado de alta.
# 58: Paciente 48 llega al hospital a la unidad Urgencias.
# 58: Paciente 49 llega al hospital a la unidad UCI.
# 58: Paciente 50 llega al hospital a la unidad Urgencias.
# 58: Paciente 48 es atendido.
# 58: Paciente 49 es atendido.
# 58: Paciente 50 es atendido.
# 59: Cirugía completada para el Paciente 11.
# 59: Paciente 11 se le ha dado de alta.
# 59: Al Paciente 46 se le asigno una cama y 5 miembro(s) del personal.
# 59: Paciente 51 llega al hospital a la unidad UCI.
# 59: Paciente 52 llega al hospital a la unidad Urgencias.
# 59: Paciente 53 llega al hospital a la unidad UCI.
# 59: Paciente 54 llega al hospital a la unidad Consultorios.
# 59: Paciente 51 es atendido.
# 59: Paciente 52 es atendido.
# 60: Al Paciente 47 se le asigno una cama y 4 miembro(s) del personal.
# 60: Paciente 53 es atendido.
# 61: Al Paciente 38 se le ha dado de alta.
# 61: Al Paciente 48 se le asigno una cama y 7 miembro(s) del personal.
# 61: El Paciente 48 necesita cirugía.
# 61: Paciente 54 es atendido.
# 61: Al Paciente 48 se le asignó un kit médico.
# 62: Al Paciente 50 se le asigno una cama y 5 miembro(s) del personal.
# 62: El Paciente 50 necesita cirugía.
# 62: Al Paciente 51 se le asigno una cama y 4 miembro(s) del personal.
# 63: Al Paciente 26 se le ha dado de alta.
# 64: Al Paciente 49 se le asigno una cama y 5 miembro(s) del personal.
# 64: Paciente 55 llega al hospital a la unidad UCI.
# 64: Paciente 56 llega al hospital a la unidad Urgencias.
# 64: Paciente 57 llega al hospital a la unidad Consultorios.
# 64: Paciente 55 es atendido.
# 64: Paciente 56 es atendido.
# 64: Paciente 57 es atendido.
# 65: Al Paciente 31 se le ha dado de alta.
# 66: Al Paciente 52 se le asigno una cama y 7 miembro(s) del personal.
# 66: Al Paciente 47 se le ha dado de alta.
# 66: Paciente 58 llega al hospital a la unidad Consultorios.
# 66: Paciente 59 llega al hospital a la unidad Urgencias.
# 66: Paciente 60 llega al hospital a la unidad Consultorios.
# 66: Al Paciente 56 se le asigno una cama y 4 miembro(s) del personal.
# 66: El Paciente 56 necesita cirugía.
# 66: Paciente 58 es atendido.
# 66: Paciente 59 es atendido.
# 67: Al Paciente 42 se le ha dado de alta.
# 67: Al Paciente 40 se le ha dado de alta.
# 67: Al Paciente 53 se le asigno una cama y 3 miembro(s) del personal.
# 67: Al Paciente 59 se le asigno una cama y 4 miembro(s) del personal.
# 67: El Paciente 59 necesita cirugía.
# 67: Paciente 60 es atendido.
# 68: Al Paciente 55 se le asigno una cama y 6 miembro(s) del personal.
# 68: Paciente 61 llega al hospital a la unidad Urgencias.
# 68: Paciente 62 llega al hospital a la unidad Urgencias.
# 68: Paciente 61 es atendido.
# 68: Paciente 62 es atendido.
# 69: Al Paciente 41 se le ha dado de alta.
# 70: Al Paciente 43 se le ha dado de alta.
# 71: Al Paciente 61 se le asigno una cama y 7 miembro(s) del personal.
# 71: El Paciente 61 necesita cirugía.
# 71: Al Paciente 62 se le asigno una cama y 5 miembro(s) del personal.
# 72: Al Paciente 37 se le ha dado de alta.
# 72: Paciente 63 llega al hospital a la unidad Consultorios.
# 72: Paciente 63 es atendido.
# 73: Al Paciente 46 se le ha dado de alta.
# 74: Al Paciente 35 se le ha dado de alta.
# 75: Al Paciente 36 se le ha dado de alta.
# 75: Al Paciente 57 se le asigno una cama y 1 miembro(s) del personal.
# 77: Al Paciente 52 se le ha dado de alta.
# 77: Paciente 64 llega al hospital a la unidad Urgencias.
# 77: Paciente 65 llega al hospital a la unidad Urgencias.
# 77: Paciente 64 es atendido.
# 77: Paciente 65 es atendido.
# 78: Al Paciente 53 se le ha dado de alta.
# 78: Al Paciente 60 se le asigno una cama y 1 miembro(s) del personal.
# 80: Al Paciente 57 se le ha dado de alta.
# 80: Al Paciente 65 se le asigno una cama y 7 miembro(s) del personal.
# 80: El Paciente 65 necesita cirugía.
# 81: Al Paciente 54 se le asigno una cama y 1 miembro(s) del personal.
# 81: Al Paciente 51 se le ha dado de alta.
# 81: Al Paciente 49 se le ha dado de alta.
# 81: Al Paciente 55 se le ha dado de alta.
# 81: Al Paciente 64 se le asigno una cama y 8 miembro(s) del personal.
# 82: Al Paciente 63 se le asigno una cama y 1 miembro(s) del personal.
# 82: Paciente 66 llega al hospital a la unidad Urgencias.
# 82: Paciente 67 llega al hospital a la unidad Urgencias.
# 82: Paciente 68 llega al hospital a la unidad UCI.
# 82: Paciente 69 llega al hospital a la unidad Urgencias.
# 82: Paciente 70 llega al hospital a la unidad Urgencias.
# 82: Paciente 66 es atendido.
# 82: Paciente 67 es atendido.
# 82: Paciente 68 es atendido.
# 82: Paciente 69 es atendido.
# 82: Paciente 70 es atendido.
# 83: Paciente 71 llega al hospital a la unidad UCI.
# 83: Paciente 72 llega al hospital a la unidad Urgencias.
# 83: Paciente 73 llega al hospital a la unidad UCI.
# 83: Paciente 74 llega al hospital a la unidad Urgencias.
# 83: Paciente 75 llega al hospital a la unidad UCI.
# 83: Al Paciente 70 se le asigno una cama y 6 miembro(s) del personal.
# 83: Paciente 71 es atendido.
# 84: Al Paciente 68 se le asigno una cama y 3 miembro(s) del personal.
# 84: Paciente 72 es atendido.
# 85: Al Paciente 69 se le asigno una cama y 6 miembro(s) del personal.
# 85: El Paciente 69 necesita cirugía.
# 85: Paciente 73 es atendido.
# 87: Al Paciente 58 se le asigno una cama y 1 miembro(s) del personal.
# 87: Al Paciente 64 se le ha dado de alta.
# 87: Al Paciente 66 se le asigno una cama y 3 miembro(s) del personal.
# 87: El Paciente 66 necesita cirugía.
# 87: Paciente 74 es atendido.
# 87: Paciente 75 es atendido.
# 88: Al Paciente 67 se le asigno una cama y 7 miembro(s) del personal.
# 88: Paciente 76 llega al hospital a la unidad Consultorios.
# 88: Paciente 77 llega al hospital a la unidad UCI.
# 88: Al Paciente 71 se le asigno una cama y 6 miembro(s) del personal.
# 88: Al Paciente 73 se le asigno una cama y 7 miembro(s) del personal.
# 88: Paciente 76 es atendido.
# 88: Paciente 77 es atendido.
# 89: Cirugía completada para el Paciente 28.
# 89: Paciente 28 se le ha dado de alta.
# 89: Al Paciente 50 se le asignó un kit médico.
# 90: Al Paciente 72 se le asigno una cama y 4 miembro(s) del personal.
# 90: Al Paciente 74 se le asigno una cama y 8 miembro(s) del personal.
# 90: Al Paciente 77 se le asigno una cama y 8 miembro(s) del personal.
# 92: Al Paciente 58 se le ha dado de alta.
# 92: Al Paciente 75 se le asigno una cama y 5 miembro(s) del personal.
# 92: Paciente 78 llega al hospital a la unidad UCI.
# 92: Paciente 79 llega al hospital a la unidad Consultorios.
# 92: Paciente 80 llega al hospital a la unidad Urgencias.
# 92: Paciente 78 es atendido.
# 92: Paciente 79 es atendido.
# 92: Paciente 80 es atendido.
# 94: Al Paciente 54 se le ha dado de alta.
# 95: Al Paciente 62 se le ha dado de alta.
# 95: Al Paciente 80 se le asigno una cama y 8 miembro(s) del personal.
# 97: Paciente 81 llega al hospital a la unidad Urgencias.
# 97: Paciente 82 llega al hospital a la unidad Urgencias.
# 97: Paciente 83 llega al hospital a la unidad Consultorios.
# 97: Paciente 84 llega al hospital a la unidad UCI.
# 97: Paciente 85 llega al hospital a la unidad Urgencias.
# 97: Paciente 81 es atendido.
# 97: Paciente 82 es atendido.
# 97: Paciente 83 es atendido.
# 98: Al Paciente 81 se le asigno una cama y 8 miembro(s) del personal.
# 98: Paciente 84 es atendido.
# 99: Al Paciente 76 se le asigno una cama y 1 miembro(s) del personal.
# 99: Al Paciente 78 se le asigno una cama y 7 miembro(s) del personal.
# 99: Al Paciente 84 se le asigno una cama y 5 miembro(s) del personal.
# 99: Paciente 85 es atendido.
# 100: Al Paciente 72 se le ha dado de alta.
# 102: Paciente 86 llega al hospital a la unidad Urgencias.
# 102: Paciente 87 llega al hospital a la unidad Urgencias.
# 102: Paciente 88 llega al hospital a la unidad UCI.
# 102: Paciente 86 es atendido.
# 102: Paciente 87 es atendido.
# 103: Al Paciente 63 se le ha dado de alta.
# 104: Al Paciente 82 se le asigno una cama y 3 miembro(s) del personal.
# 104: Al Paciente 85 se le asigno una cama y 4 miembro(s) del personal.
# 104: Paciente 88 es atendido.
# 105: Al Paciente 84 se le ha dado de alta.
# 105: Al Paciente 87 se le asigno una cama y 5 miembro(s) del personal.
# 106: Al Paciente 60 se le ha dado de alta.
# 106: Paciente 89 llega al hospital a la unidad Urgencias.
# 106: Paciente 90 llega al hospital a la unidad Urgencias.
# 106: Paciente 91 llega al hospital a la unidad Urgencias.
# 106: Paciente 92 llega al hospital a la unidad UCI.
# 106: Paciente 89 es atendido.
# 106: Paciente 90 es atendido.
# 107: Al Paciente 71 se le ha dado de alta.
# 107: Al Paciente 88 se le asigno una cama y 6 miembro(s) del personal.
# 107: Paciente 91 es atendido.
# 108: Al Paciente 80 se le ha dado de alta.
# 109: Al Paciente 86 se le asigno una cama y 5 miembro(s) del personal.
# 109: El Paciente 86 necesita cirugía.
# 109: Paciente 93 llega al hospital a la unidad UCI.
# 109: Paciente 94 llega al hospital a la unidad Urgencias.
# 109: Paciente 95 llega al hospital a la unidad Urgencias.
# 109: Paciente 96 llega al hospital a la unidad Urgencias.
# 109: Al Paciente 90 se le asigno una cama y 8 miembro(s) del personal.
# 109: El Paciente 90 necesita cirugía.
# 109: Paciente 92 es atendido.
# 109: Paciente 93 es atendido.
# 111: Al Paciente 81 se le ha dado de alta.
# 111: Al Paciente 78 se le ha dado de alta.
# 111: Al Paciente 87 se le ha dado de alta.
# 111: Al Paciente 92 se le asigno una cama y 8 miembro(s) del personal.
# 111: Paciente 94 es atendido.
# 112: Al Paciente 70 se le ha dado de alta.
# 112: Al Paciente 68 se le ha dado de alta.
# 113: Al Paciente 79 se le asigno una cama y 1 miembro(s) del personal.
# 113: Al Paciente 89 se le asigno una cama y 7 miembro(s) del personal.
# 113: El Paciente 89 necesita cirugía.
# 113: Al Paciente 91 se le asigno una cama y 5 miembro(s) del personal.
# 113: Paciente 97 llega al hospital a la unidad Urgencias.
# 113: Paciente 98 llega al hospital a la unidad Urgencias.
# 113: Paciente 99 llega al hospital a la unidad UCI.
# 113: Paciente 100 llega al hospital a la unidad Consultorios.
# 113: Paciente 101 llega al hospital a la unidad Urgencias.
# 113: Al Paciente 93 se le asigno una cama y 4 miembro(s) del personal.
# 113: Paciente 95 es atendido.
# 113: Paciente 96 es atendido.
# 113: Paciente 97 es atendido.
# 113: Paciente 98 es atendido.
# 114: Al Paciente 73 se le ha dado de alta.
# 114: Al Paciente 75 se le ha dado de alta.
# 114: Al Paciente 97 se le asigno una cama y 7 miembro(s) del personal.
# 114: Paciente 99 es atendido.
# 117: Paciente 102 llega al hospital a la unidad Consultorios.
# 117: Paciente 103 llega al hospital a la unidad UCI.
# 117: Paciente 104 llega al hospital a la unidad Urgencias.
# 117: Al Paciente 96 se le asigno una cama y 5 miembro(s) del personal.
# 117: El Paciente 96 necesita cirugía.
# 117: Paciente 100 es atendido.
# 118: Al Paciente 67 se le ha dado de alta.
# 118: Al Paciente 74 se le ha dado de alta.
# 118: Al Paciente 94 se le asigno una cama y 5 miembro(s) del personal.
# 118: El Paciente 94 necesita cirugía.
# 118: Paciente 101 es atendido.
# 119: Paciente 105 llega al hospital a la unidad Urgencias.
# 119: Paciente 106 llega al hospital a la unidad UCI.
# 119: Paciente 107 llega al hospital a la unidad Urgencias.
# 119: Paciente 108 llega al hospital a la unidad Urgencias.
# 119: Al Paciente 101 se le asigno una cama y 5 miembro(s) del personal.
# 119: Paciente 102 es atendido.
# 120: Al Paciente 77 se le ha dado de alta.
# 120: Al Paciente 83 se le asigno una cama y 1 miembro(s) del personal.
# 120: Al Paciente 95 se le asigno una cama y 4 miembro(s) del personal.
# 120: El Paciente 95 necesita cirugía.
# 120: Al Paciente 98 se le asigno una cama y 3 miembro(s) del personal.
# 120: El Paciente 98 necesita cirugía.
# 120: Paciente 103 es atendido.
# 120: Paciente 104 es atendido.
# 120: Paciente 105 es atendido.
# 121: Al Paciente 93 se le ha dado de alta.
# 121: Al Paciente 99 se le asigno una cama y 7 miembro(s) del personal.
# 121: Paciente 109 llega al hospital a la unidad Urgencias.
# 121: Paciente 110 llega al hospital a la unidad Consultorios.
# 121: Paciente 111 llega al hospital a la unidad Urgencias.
# 121: Paciente 106 es atendido.
# 123: Al Paciente 92 se le ha dado de alta.
# 125: Al Paciente 82 se le ha dado de alta.
# 125: Al Paciente 100 se le asigno una cama y 1 miembro(s) del personal.
# 125: Al Paciente 104 se le asigno una cama y 6 miembro(s) del personal.
# 125: El Paciente 104 necesita cirugía.
# 125: Paciente 112 llega al hospital a la unidad Urgencias.
# 125: Paciente 113 llega al hospital a la unidad UCI.
# 125: Paciente 114 llega al hospital a la unidad Urgencias.
# 125: Paciente 115 llega al hospital a la unidad UCI.
# 125: Paciente 107 es atendido.
# 125: Paciente 108 es atendido.
# 126: Al Paciente 103 se le asigno una cama y 3 miembro(s) del personal.
# 126: El Paciente 56 murió esperando un kit médico.
# 126: Paciente 109 es atendido.
# 127: Al Paciente 79 se le ha dado de alta.
# 127: Al Paciente 91 se le ha dado de alta.
# 127: Al Paciente 105 se le asigno una cama y 6 miembro(s) del personal.
# 127: Al Paciente 106 se le asigno una cama y 7 miembro(s) del personal.
# 127: El Paciente 59 murió esperando un kit médico.
# 127: Paciente 110 es atendido.
# 127: Paciente 111 es atendido.
# 128: Al Paciente 76 se le ha dado de alta.
# 128: Al Paciente 109 se le asigno una cama y 6 miembro(s) del personal.
# 128: Paciente 112 es atendido.
# 129: Paciente 116 llega al hospital a la unidad Consultorios.
# 129: Paciente 117 llega al hospital a la unidad Urgencias.
# 129: Paciente 118 llega al hospital a la unidad Consultorios.
# 129: Paciente 119 llega al hospital a la unidad Consultorios.
# 129: Paciente 120 llega al hospital a la unidad UCI.
# 130: Al Paciente 101 se le ha dado de alta.
# 130: Al Paciente 83 se le ha dado de alta.
# 130: Al Paciente 108 se le asigno una cama y 5 miembro(s) del personal.
# 130: Paciente 121 llega al hospital a la unidad Consultorios.
# 130: Paciente 122 llega al hospital a la unidad Consultorios.
# 130: Paciente 123 llega al hospital a la unidad UCI.
# 130: Paciente 124 llega al hospital a la unidad Consultorios.
# 130: Paciente 113 es atendido.
# 131: Al Paciente 112 se le asigno una cama y 8 miembro(s) del personal.
# 131: El Paciente 61 murió esperando un kit médico.
# 131: Paciente 114 es atendido.
# 132: Al Paciente 99 se le ha dado de alta.
# 132: Al Paciente 107 se le asigno una cama y 5 miembro(s) del personal.
# 132: Al Paciente 111 se le asigno una cama y 7 miembro(s) del personal.
# 132: Paciente 125 llega al hospital a la unidad Urgencias.
# 132: Paciente 126 llega al hospital a la unidad UCI.
# 132: Paciente 127 llega al hospital a la unidad Consultorios.
# 132: Al Paciente 113 se le asigno una cama y 6 miembro(s) del personal.
# 132: Paciente 115 es atendido.
# 132: Paciente 116 es atendido.
# 132: Paciente 117 es atendido.
# 133: Al Paciente 85 se le ha dado de alta.
# 133: Al Paciente 88 se le ha dado de alta.
# 133: Al Paciente 106 se le ha dado de alta.
# 134: Al Paciente 114 se le asigno una cama y 5 miembro(s) del personal.
# 134: Paciente 118 es atendido.
# 135: Al Paciente 103 se le ha dado de alta.
# 135: Paciente 128 llega al hospital a la unidad Consultorios.
# 135: Paciente 129 llega al hospital a la unidad Urgencias.
# 135: Paciente 130 llega al hospital a la unidad Urgencias.
# 135: Paciente 131 llega al hospital a la unidad UCI.
# 135: Paciente 132 llega al hospital a la unidad Consultorios.
# 135: Al Paciente 117 se le asigno una cama y 6 miembro(s) del personal.
# 135: Paciente 119 es atendido.
# 137: Al Paciente 111 se le ha dado de alta.
# 137: Paciente 133 llega al hospital a la unidad Urgencias.
# 138: Al Paciente 105 se le ha dado de alta.
# 138: Paciente 134 llega al hospital a la unidad UCI.
# 138: Paciente 135 llega al hospital a la unidad UCI.
# 139: Al Paciente 115 se le asigno una cama y 7 miembro(s) del personal.
# 139: Paciente 120 es atendido.
# 140: El Paciente 65 murió esperando un kit médico.
# 141: Al Paciente 100 se le ha dado de alta.
# 143: Al Paciente 97 se le ha dado de alta.
# 143: Al Paciente 102 se le asigno una cama y 1 miembro(s) del personal.
# 143: Paciente 136 llega al hospital a la unidad UCI.
# 143: Paciente 137 llega al hospital a la unidad Consultorios.
# 143: Paciente 138 llega al hospital a la unidad Urgencias.
# 143: Paciente 121 es atendido.
# 144: Al Paciente 110 se le asigno una cama y 1 miembro(s) del personal.
# 144: Al Paciente 116 se le asigno una cama y 1 miembro(s) del personal.
# 144: Al Paciente 117 se le ha dado de alta.
# 144: Paciente 122 es atendido.
# 144: Paciente 123 es atendido.
# 145: Al Paciente 118 se le asigno una cama y 1 miembro(s) del personal.
# 145: Al Paciente 115 se le ha dado de alta.
# 145: Al Paciente 123 se le asigno una cama y 5 miembro(s) del personal.
# 145: El Paciente 69 murió esperando un kit médico.
# 145: Paciente 124 es atendido.
# 145: Paciente 125 es atendido.
# 146: Al Paciente 120 se le asigno una cama y 8 miembro(s) del personal.
# 146: Paciente 139 llega al hospital a la unidad UCI.
# 146: Paciente 140 llega al hospital a la unidad UCI.
# 146: Paciente 141 llega al hospital a la unidad Urgencias.
# 146: Paciente 142 llega al hospital a la unidad Urgencias.
# 146: Paciente 126 es atendido.
# 147: El Paciente 66 murió esperando un kit médico.
# 149: Al Paciente 109 se le ha dado de alta.
# 149: Al Paciente 110 se le ha dado de alta.
# 149: Paciente 143 llega al hospital a la unidad Urgencias.
# 149: Paciente 144 llega al hospital a la unidad Urgencias.
# 150: Al Paciente 119 se le asigno una cama y 1 miembro(s) del personal.
# 150: Paciente 127 es atendido.
# 151: Al Paciente 107 se le ha dado de alta.
# 151: Al Paciente 113 se le ha dado de alta.
# 151: Al Paciente 114 se le ha dado de alta.
# 152: Al Paciente 116 se le ha dado de alta.
# 152: Al Paciente 125 se le asigno una cama y 5 miembro(s) del personal.
# 152: El Paciente 125 necesita cirugía.
# 152: Al Paciente 126 se le asigno una cama y 4 miembro(s) del personal.
# 152: Paciente 128 es atendido.
# 152: Paciente 129 es atendido.
# 153: Paciente 145 llega al hospital a la unidad Consultorios.
# 153: Paciente 146 llega al hospital a la unidad Urgencias.
# 153: Paciente 147 llega al hospital a la unidad UCI.
# 154: Al Paciente 123 se le ha dado de alta.
# 155: Al Paciente 108 se le ha dado de alta.
# 155: Al Paciente 112 se le ha dado de alta.
# 158: Al Paciente 102 se le ha dado de alta.
# 158: Al Paciente 129 se le asigno una cama y 7 miembro(s) del personal.
# 158: El Paciente 129 necesita cirugía.
# 158: Paciente 148 llega al hospital a la unidad Urgencias.
# 158: Paciente 149 llega al hospital a la unidad Urgencias.
# 158: Paciente 150 llega al hospital a la unidad Urgencias.
# 158: Paciente 151 llega al hospital a la unidad Urgencias.
# 158: Paciente 130 es atendido.
# 160: Al Paciente 124 se le asigno una cama y 1 miembro(s) del personal.
# 160: Paciente 131 es atendido.
# 163: Al Paciente 118 se le ha dado de alta.
# 163: Paciente 152 llega al hospital a la unidad Consultorios.
# 164: Al Paciente 131 se le asigno una cama y 6 miembro(s) del personal.
# 164: Paciente 132 es atendido.
# 165: Al Paciente 130 se le asigno una cama y 6 miembro(s) del personal.
# 165: Paciente 133 es atendido.
# 166: Al Paciente 121 se le asigno una cama y 1 miembro(s) del personal.
# 166: Paciente 153 llega al hospital a la unidad UCI.
# 166: Paciente 154 llega al hospital a la unidad Urgencias.
# 166: Paciente 155 llega al hospital a la unidad Urgencias.
# 166: Al Paciente 133 se le asigno una cama y 4 miembro(s) del personal.
# 166: El Paciente 133 necesita cirugía.
# 166: Paciente 134 es atendido.
# 166: Paciente 135 es atendido.
# 168: Al Paciente 119 se le ha dado de alta.
# 168: Al Paciente 126 se le ha dado de alta.
# 168: Al Paciente 134 se le asigno una cama y 5 miembro(s) del personal.
# 168: Paciente 136 es atendido.
# 169: Al Paciente 122 se le asigno una cama y 1 miembro(s) del personal.
# 169: Paciente 156 llega al hospital a la unidad Urgencias.
# 169: El Paciente 86 murió esperando un kit médico.
# 169: El Paciente 90 murió esperando un kit médico.
# 169: Paciente 137 es atendido.
# 170: Cirugía completada para el Paciente 30.
# 170: Paciente 30 se le ha dado de alta.
# 170: Al Paciente 124 se le ha dado de alta.
# 170: Al Paciente 89 se le asignó un kit médico.
# 172: Al Paciente 135 se le asigno una cama y 7 miembro(s) del personal.
# 172: Paciente 138 es atendido.
# 173: Al Paciente 120 se le ha dado de alta.
# 173: Al Paciente 136 se le asigno una cama y 5 miembro(s) del personal.
# 173: Paciente 157 llega al hospital a la unidad Urgencias.
# 173: Paciente 158 llega al hospital a la unidad UCI.
# 173: Paciente 159 llega al hospital a la unidad Urgencias.
# 173: Paciente 139 es atendido.
# 174: Al Paciente 127 se le asigno una cama y 1 miembro(s) del personal.
# 174: Paciente 140 es atendido.
# 176: Al Paciente 128 se le asigno una cama y 1 miembro(s) del personal.
# 176: Paciente 141 es atendido.
# 177: Al Paciente 132 se le asigno una cama y 1 miembro(s) del personal.
# 177: Al Paciente 138 se le asigno una cama y 4 miembro(s) del personal.
# 177: Paciente 160 llega al hospital a la unidad Urgencias.
# 177: Paciente 161 llega al hospital a la unidad UCI.
# 177: Paciente 162 llega al hospital a la unidad Urgencias.
# 177: El Paciente 96 murió esperando un kit médico.
# 177: Paciente 142 es atendido.
# 177: Paciente 143 es atendido.
# 178: Al Paciente 134 se le ha dado de alta.
# 178: Al Paciente 141 se le asigno una cama y 4 miembro(s) del personal.
# 178: El Paciente 141 necesita cirugía.
# 178: Paciente 163 llega al hospital a la unidad UCI.
# 178: Paciente 164 llega al hospital a la unidad UCI.
# 178: Paciente 165 llega al hospital a la unidad Consultorios.
# 178: Paciente 166 llega al hospital a la unidad Urgencias.
# 178: Paciente 167 llega al hospital a la unidad Urgencias.
# 178: El Paciente 94 murió esperando un kit médico.
# 178: Paciente 144 es atendido.
# 179: Cirugía completada para el Paciente 14.
# 179: Paciente 14 se le ha dado de alta.
# 179: Al Paciente 121 se le ha dado de alta.
# 179: Al Paciente 139 se le asigno una cama y 8 miembro(s) del personal.
# 179: Paciente 145 es atendido.
# 179: Al Paciente 95 se le asignó un kit médico.
# 180: El Paciente 98 murió esperando un kit médico.
# 181: Al Paciente 131 se le ha dado de alta.
# 181: Al Paciente 140 se le asigno una cama y 5 miembro(s) del personal.
# 181: Al Paciente 142 se le asigno una cama y 7 miembro(s) del personal.
# 181: El Paciente 142 necesita cirugía.
# 181: Paciente 146 es atendido.
# 181: Paciente 147 es atendido.
# 182: Al Paciente 132 se le ha dado de alta.
# 182: Paciente 168 llega al hospital a la unidad Urgencias.
# 182: Paciente 169 llega al hospital a la unidad Urgencias.
# 183: Al Paciente 143 se le asigno una cama y 5 miembro(s) del personal.
# 183: Paciente 148 es atendido.
# 184: Al Paciente 144 se le asigno una cama y 4 miembro(s) del personal.
# 184: El Paciente 144 necesita cirugía.
# 184: Al Paciente 146 se le asigno una cama y 4 miembro(s) del personal.
# 184: Paciente 149 es atendido.
# 184: Paciente 150 es atendido.
# 185: Al Paciente 122 se le ha dado de alta.
# 185: Al Paciente 147 se le asigno una cama y 7 miembro(s) del personal.
# 185: El Paciente 104 murió esperando un kit médico.
# 185: Paciente 151 es atendido.
# 186: Al Paciente 130 se le ha dado de alta.
# 186: Paciente 170 llega al hospital a la unidad UCI.
# 186: Al Paciente 148 se le asigno una cama y 8 miembro(s) del personal.
# 186: El Paciente 148 necesita cirugía.
# 186: Paciente 152 es atendido.
# 187: Al Paciente 151 se le asigno una cama y 7 miembro(s) del personal.
# 187: Paciente 153 es atendido.
# 188: Cirugía completada para el Paciente 24.
# 188: Paciente 24 se le ha dado de alta.
# 188: Al Paciente 153 se le asigno una cama y 4 miembro(s) del personal.
# 188: Paciente 154 es atendido.
# 188: Al Paciente 125 se le asignó un kit médico.
# 189: Al Paciente 137 se le asigno una cama y 1 miembro(s) del personal.
# 189: Al Paciente 149 se le asigno una cama y 7 miembro(s) del personal.
# 189: El Paciente 149 necesita cirugía.
# 189: Al Paciente 150 se le asigno una cama y 5 miembro(s) del personal.
# 189: El Paciente 150 necesita cirugía.
# 189: Paciente 155 es atendido.
# 189: Paciente 156 es atendido.
# 189: Paciente 157 es atendido.
# 190: Paciente 171 llega al hospital a la unidad Urgencias.
# 190: Paciente 172 llega al hospital a la unidad UCI.
# 190: Paciente 173 llega al hospital a la unidad Urgencias.
# 190: Paciente 174 llega al hospital a la unidad Urgencias.
# 191: Al Paciente 136 se le ha dado de alta.
# 192: Al Paciente 138 se le ha dado de alta.
# 192: Al Paciente 156 se le asigno una cama y 7 miembro(s) del personal.
# 192: Paciente 158 es atendido.
# 193: Al Paciente 154 se le asigno una cama y 6 miembro(s) del personal.
# 193: Paciente 159 es atendido.
# 194: Paciente 175 llega al hospital a la unidad UCI.
# 194: Paciente 176 llega al hospital a la unidad Consultorios.
# 196: Al Paciente 143 se le ha dado de alta.
# 196: Al Paciente 155 se le asigno una cama y 8 miembro(s) del personal.
# 196: Al Paciente 157 se le asigno una cama y 7 miembro(s) del personal.
# 196: El Paciente 157 necesita cirugía.
# 196: Al Paciente 159 se le asigno una cama y 5 miembro(s) del personal.
# 196: El Paciente 159 necesita cirugía.
# 196: Paciente 160 es atendido.
# 196: Paciente 161 es atendido.
# 196: Paciente 162 es atendido.
# 197: Al Paciente 135 se le ha dado de alta.
# 197: Al Paciente 139 se le ha dado de alta.
# 197: Al Paciente 147 se le ha dado de alta.
# 197: Al Paciente 158 se le asigno una cama y 6 miembro(s) del personal.
# 197: Al Paciente 161 se le asigno una cama y 4 miembro(s) del personal.
# 197: Paciente 163 es atendido.
# 197: Paciente 164 es atendido.
# 198: Al Paciente 127 se le ha dado de alta.
# 198: Al Paciente 164 se le asigno una cama y 5 miembro(s) del personal.
# 198: Paciente 165 es atendido.
# 199: Al Paciente 151 se le ha dado de alta.
# 199: Paciente 177 llega al hospital a la unidad Consultorios.
# 199: Paciente 178 llega al hospital a la unidad Consultorios.
# 199: Paciente 179 llega al hospital a la unidad Urgencias.
# 199: Paciente 180 llega al hospital a la unidad Consultorios.
# 199: Paciente 181 llega al hospital a la unidad Urgencias.
# 201: Al Paciente 145 se le asigno una cama y 1 miembro(s) del personal.
# 201: Al Paciente 162 se le asigno una cama y 3 miembro(s) del personal.
# 201: Al Paciente 163 se le asigno una cama y 6 miembro(s) del personal.
# 201: Paciente 166 es atendido.
# 201: Paciente 167 es atendido.
# 201: Paciente 168 es atendido.
# 203: Al Paciente 153 se le ha dado de alta.
# 203: Al Paciente 160 se le asigno una cama y 8 miembro(s) del personal.
# 203: Paciente 182 llega al hospital a la unidad Urgencias.
# 203: Paciente 183 llega al hospital a la unidad Consultorios.
# 203: Paciente 184 llega al hospital a la unidad Urgencias.
# 203: Paciente 185 llega al hospital a la unidad UCI.
# 203: Paciente 186 llega al hospital a la unidad UCI.
# 203: Paciente 169 es atendido.
# 205: Al Paciente 146 se le ha dado de alta.
# 205: Al Paciente 152 se le asigno una cama y 1 miembro(s) del personal.
# 205: Al Paciente 166 se le asigno una cama y 4 miembro(s) del personal.
# 205: El Paciente 166 necesita cirugía.
# 205: Paciente 187 llega al hospital a la unidad UCI.
# 205: Paciente 170 es atendido.
# 205: Paciente 171 es atendido.
# 206: Al Paciente 128 se le ha dado de alta.
# 206: Al Paciente 155 se le ha dado de alta.
# 206: Al Paciente 167 se le asigno una cama y 4 miembro(s) del personal.
# 206: Al Paciente 168 se le asigno una cama y 8 miembro(s) del personal.
# 206: El Paciente 168 necesita cirugía.
# 206: Paciente 172 es atendido.
# 206: Paciente 173 es atendido.
# 207: Al Paciente 145 se le ha dado de alta.
# 207: Al Paciente 169 se le asigno una cama y 8 miembro(s) del personal.
# 207: El Paciente 169 necesita cirugía.
# 207: Paciente 188 llega al hospital a la unidad UCI.
# 207: Paciente 174 es atendido.
# 208: Paciente 189 llega al hospital a la unidad Urgencias.
# 208: Paciente 190 llega al hospital a la unidad Consultorios.
# 208: Paciente 191 llega al hospital a la unidad Urgencias.
# 209: Al Paciente 140 se le ha dado de alta.
# 210: Al Paciente 165 se le asigno una cama y 1 miembro(s) del personal.
# 210: Al Paciente 160 se le ha dado de alta.
# 210: Paciente 175 es atendido.
# 211: Al Paciente 137 se le ha dado de alta.
# 211: Al Paciente 174 se le asigno una cama y 6 miembro(s) del personal.
# 211: Paciente 192 llega al hospital a la unidad UCI.
# 211: Paciente 193 llega al hospital a la unidad Urgencias.
# 211: Paciente 194 llega al hospital a la unidad UCI.
# 211: Paciente 195 llega al hospital a la unidad Urgencias.
# 211: Paciente 196 llega al hospital a la unidad Urgencias.
# 211: Paciente 176 es atendido.
# 212: Al Paciente 170 se le asigno una cama y 7 miembro(s) del personal.
# 212: Al Paciente 171 se le asigno una cama y 3 miembro(s) del personal.
# 212: El Paciente 171 necesita cirugía.
# 212: Al Paciente 172 se le asigno una cama y 5 miembro(s) del personal.
# 212: Al Paciente 173 se le asigno una cama y 8 miembro(s) del personal.
# 212: Paciente 177 es atendido.
# 212: Paciente 178 es atendido.
# 212: Paciente 179 es atendido.
# 212: Paciente 180 es atendido.
# 213: Al Paciente 179 se le asigno una cama y 3 miembro(s) del personal.
# 213: El Paciente 179 necesita cirugía.
# 213: Paciente 181 es atendido.
# 214: Al Paciente 181 se le asigno una cama y 4 miembro(s) del personal.
# 214: Paciente 182 es atendido.
# 215: Al Paciente 182 se le asigno una cama y 3 miembro(s) del personal.
# 215: El Paciente 182 necesita cirugía.
# 215: Paciente 183 es atendido.
# 216: Paciente 197 llega al hospital a la unidad Urgencias.
# 216: Paciente 198 llega al hospital a la unidad UCI.
# 216: Paciente 199 llega al hospital a la unidad Urgencias.
# 217: Al Paciente 175 se le asigno una cama y 3 miembro(s) del personal.
# 217: Paciente 184 es atendido.
# 218: Al Paciente 165 se le ha dado de alta.
# 218: Al Paciente 174 se le ha dado de alta.
# 218: Paciente 200 llega al hospital a la unidad UCI.
# 218: Paciente 201 llega al hospital a la unidad Urgencias.
# 218: Paciente 202 llega al hospital a la unidad Urgencias.
# 218: Paciente 203 llega al hospital a la unidad Urgencias.
# 218: Paciente 204 llega al hospital a la unidad Urgencias.
# 218: Al Paciente 184 se le asigno una cama y 5 miembro(s) del personal.
# 218: El Paciente 129 murió esperando un kit médico.
# 218: Paciente 185 es atendido.
# 219: Al Paciente 156 se le ha dado de alta.
# 219: Al Paciente 164 se le ha dado de alta.
# 220: Al Paciente 154 se le ha dado de alta.
# 220: Al Paciente 163 se le ha dado de alta.
# 221: Al Paciente 158 se le ha dado de alta.
# 221: Al Paciente 167 se le ha dado de alta.
# 221: Paciente 205 llega al hospital a la unidad Urgencias.
# 221: Paciente 206 llega al hospital a la unidad Urgencias.
# 221: Paciente 207 llega al hospital a la unidad Urgencias.
# 221: Paciente 208 llega al hospital a la unidad Urgencias.
# 223: Al Paciente 178 se le asigno una cama y 1 miembro(s) del personal.
# 223: Paciente 186 es atendido.
# 224: Al Paciente 185 se le asigno una cama y 8 miembro(s) del personal.
# 224: Al Paciente 186 se le asigno una cama y 3 miembro(s) del personal.
# 224: Paciente 187 es atendido.
# 224: Paciente 188 es atendido.
# 225: Al Paciente 161 se le ha dado de alta.
# 225: Paciente 209 llega al hospital a la unidad Urgencias.
# 225: Paciente 210 llega al hospital a la unidad UCI.
# 225: Paciente 211 llega al hospital a la unidad Urgencias.
# 225: Al Paciente 187 se le asigno una cama y 3 miembro(s) del personal.
# 225: Paciente 189 es atendido.
# 226: El Paciente 133 murió esperando un kit médico.
# 227: Al Paciente 162 se le ha dado de alta.
# 227: Al Paciente 176 se le asigno una cama y 1 miembro(s) del personal.
# 227: Al Paciente 188 se le asigno una cama y 5 miembro(s) del personal.
# 227: Paciente 212 llega al hospital a la unidad Consultorios.
# 227: Paciente 213 llega al hospital a la unidad Consultorios.
# 227: Paciente 214 llega al hospital a la unidad Urgencias.
# 227: Paciente 215 llega al hospital a la unidad UCI.
# 227: Paciente 216 llega al hospital a la unidad Urgencias.
# 227: Al Paciente 189 se le asigno una cama y 3 miembro(s) del personal.
# 227: El Paciente 189 necesita cirugía.
# 227: Paciente 190 es atendido.
# 227: Paciente 191 es atendido.
# 227: Paciente 192 es atendido.
# 229: Al Paciente 186 se le ha dado de alta.
# 230: Paciente 217 llega al hospital a la unidad Urgencias.
# 231: Al Paciente 170 se le ha dado de alta.
# 232: Al Paciente 192 se le asigno una cama y 7 miembro(s) del personal.
# 232: Paciente 193 es atendido.
# 233: Al Paciente 180 se le asigno una cama y 1 miembro(s) del personal.
# 233: Paciente 194 es atendido.
# 234: Al Paciente 191 se le asigno una cama y 7 miembro(s) del personal.
# 234: Al Paciente 194 se le asigno una cama y 5 miembro(s) del personal.
# 234: Paciente 195 es atendido.
# 234: Paciente 196 es atendido.
# 235: Al Paciente 152 se le ha dado de alta.
# 235: Al Paciente 177 se le asigno una cama y 1 miembro(s) del personal.
# 235: Paciente 218 llega al hospital a la unidad Urgencias.
# 235: Paciente 219 llega al hospital a la unidad Urgencias.
# 235: Paciente 220 llega al hospital a la unidad Urgencias.
# 235: Al Paciente 193 se le asigno una cama y 3 miembro(s) del personal.
# 235: El Paciente 193 necesita cirugía.
# 235: Paciente 197 es atendido.
# 235: Paciente 198 es atendido.
# 236: Al Paciente 173 se le ha dado de alta.
# 236: Al Paciente 187 se le ha dado de alta.
# 237: Al Paciente 175 se le ha dado de alta.
# 237: Al Paciente 176 se le ha dado de alta.
# 237: Al Paciente 196 se le asigno una cama y 6 miembro(s) del personal.
# 237: Al Paciente 197 se le asigno una cama y 7 miembro(s) del personal.
# 237: El Paciente 197 necesita cirugía.
# 237: Paciente 199 es atendido.
# 237: Paciente 200 es atendido.
# 238: Al Paciente 183 se le asigno una cama y 1 miembro(s) del personal.
# 238: Al Paciente 188 se le ha dado de alta.
# 238: Al Paciente 198 se le asigno una cama y 7 miembro(s) del personal.
# 238: El Paciente 141 murió esperando un kit médico.
# 238: Paciente 201 es atendido.
# 238: Paciente 202 es atendido.
# 239: Al Paciente 181 se le ha dado de alta.
# 239: Paciente 221 llega al hospital a la unidad Urgencias.
# 240: Al Paciente 195 se le asigno una cama y 8 miembro(s) del personal.
# 240: Al Paciente 201 se le asigno una cama y 8 miembro(s) del personal.
# 240: Al Paciente 202 se le asigno una cama y 7 miembro(s) del personal.
# 240: El Paciente 202 necesita cirugía.
# 240: Paciente 203 es atendido.
# 240: Paciente 204 es atendido.
# 240: Paciente 205 es atendido.
# 241: Al Paciente 172 se le ha dado de alta.
# 241: Al Paciente 185 se le ha dado de alta.
# 241: Al Paciente 200 se le asigno una cama y 7 miembro(s) del personal.
# 241: Paciente 222 llega al hospital a la unidad Consultorios.
# 241: Paciente 223 llega al hospital a la unidad UCI.
# 241: Paciente 224 llega al hospital a la unidad Urgencias.
# 241: Paciente 225 llega al hospital a la unidad UCI.
# 241: El Paciente 142 murió esperando un kit médico.
# 241: Paciente 206 es atendido.
# 242: Al Paciente 196 se le ha dado de alta.
# 242: Al Paciente 199 se le asigno una cama y 7 miembro(s) del personal.
# 242: Al Paciente 204 se le asigno una cama y 6 miembro(s) del personal.
# 242: El Paciente 204 necesita cirugía.
# 242: Paciente 207 es atendido.
# 242: Paciente 208 es atendido.
# 244: Al Paciente 190 se le asigno una cama y 1 miembro(s) del personal.
# 244: Al Paciente 208 se le asigno una cama y 5 miembro(s) del personal.
# 244: El Paciente 144 murió esperando un kit médico.
# 244: Paciente 209 es atendido.
# 244: Paciente 210 es atendido.
# 245: Al Paciente 205 se le asigno una cama y 4 miembro(s) del personal.
# 245: El Paciente 205 necesita cirugía.
# 245: Paciente 226 llega al hospital a la unidad Urgencias.
# 245: Paciente 211 es atendido.
# 246: Al Paciente 184 se le ha dado de alta.
# 246: Al Paciente 206 se le asigno una cama y 4 miembro(s) del personal.
# 246: El Paciente 206 necesita cirugía.
# 246: El Paciente 148 murió esperando un kit médico.
# 246: Paciente 212 es atendido.
# 247: Al Paciente 192 se le ha dado de alta.
# 247: Al Paciente 183 se le ha dado de alta.
# 247: Al Paciente 203 se le asigno una cama y 8 miembro(s) del personal.
# 247: Paciente 227 llega al hospital a la unidad UCI.
# 247: Paciente 228 llega al hospital a la unidad UCI.
# 247: Paciente 213 es atendido.
# 248: Al Paciente 191 se le ha dado de alta.
# 248: Al Paciente 211 se le asigno una cama y 7 miembro(s) del personal.
# 248: Paciente 229 llega al hospital a la unidad Urgencias.
# 248: Paciente 214 es atendido.
# 249: Al Paciente 199 se le ha dado de alta.
# 249: Al Paciente 207 se le asigno una cama y 3 miembro(s) del personal.
# 249: El Paciente 207 necesita cirugía.
# 249: Al Paciente 209 se le asigno una cama y 4 miembro(s) del personal.
# 249: Al Paciente 210 se le asigno una cama y 3 miembro(s) del personal.
# 249: Paciente 230 llega al hospital a la unidad Urgencias.
# 249: Paciente 231 llega al hospital a la unidad UCI.
# 249: Paciente 232 llega al hospital a la unidad Urgencias.
# 249: Al Paciente 214 se le asigno una cama y 3 miembro(s) del personal.
# 249: El Paciente 149 murió esperando un kit médico.
# 249: El Paciente 150 murió esperando un kit médico.
# 249: Paciente 215 es atendido.
# 249: Paciente 216 es atendido.
# 249: Paciente 217 es atendido.
# 249: Paciente 218 es atendido.
# 250: Al Paciente 217 se le asigno una cama y 7 miembro(s) del personal.
# 250: Paciente 219 es atendido.
# 251: Al Paciente 215 se le asigno una cama y 3 miembro(s) del personal.
# 251: Al Paciente 218 se le asigno una cama y 6 miembro(s) del personal.
# 251: Paciente 220 es atendido.
# 251: Paciente 221 es atendido.
# 252: Al Paciente 216 se le asigno una cama y 6 miembro(s) del personal.
# 252: Paciente 222 es atendido.
# 253: Al Paciente 178 se le ha dado de alta.
# 253: Al Paciente 208 se le ha dado de alta.
# 253: Al Paciente 212 se le asigno una cama y 1 miembro(s) del personal.
# 253: Al Paciente 220 se le asigno una cama y 4 miembro(s) del personal.
# 253: Paciente 223 es atendido.
# 253: Paciente 224 es atendido.
# 254: Al Paciente 177 se le ha dado de alta.
# 254: Al Paciente 190 se le ha dado de alta.
# 254: Paciente 233 llega al hospital a la unidad UCI.
# 254: Paciente 234 llega al hospital a la unidad UCI.
# 254: Paciente 235 llega al hospital a la unidad Urgencias.
# 254: Paciente 236 llega al hospital a la unidad UCI.
# 254: Al Paciente 221 se le asigno una cama y 4 miembro(s) del personal.
# 254: Al Paciente 223 se le asigno una cama y 7 miembro(s) del personal.
# 254: Paciente 225 es atendido.
# 254: Paciente 226 es atendido.
# 255: Al Paciente 226 se le asigno una cama y 8 miembro(s) del personal.
# 255: Paciente 227 es atendido.
# 256: Al Paciente 219 se le asigno una cama y 8 miembro(s) del personal.
# 256: El Paciente 219 necesita cirugía.
# 256: El Paciente 157 murió esperando un kit médico.
# 256: El Paciente 159 murió esperando un kit médico.
# 256: Paciente 228 es atendido.
# 257: Al Paciente 224 se le asigno una cama y 5 miembro(s) del personal.
# 257: Paciente 237 llega al hospital a la unidad Urgencias.
# 257: Paciente 238 llega al hospital a la unidad Urgencias.
# 257: Paciente 239 llega al hospital a la unidad UCI.
# 257: Paciente 240 llega al hospital a la unidad UCI.
# 257: Al Paciente 228 se le asigno una cama y 5 miembro(s) del personal.
# 257: Paciente 229 es atendido.
# 257: Paciente 230 es atendido.
# 259: Al Paciente 180 se le ha dado de alta.
# 259: Al Paciente 195 se le ha dado de alta.
# 259: Al Paciente 227 se le asigno una cama y 7 miembro(s) del personal.
# 259: Al Paciente 230 se le asigno una cama y 5 miembro(s) del personal.
# 259: El Paciente 230 necesita cirugía.
# 259: Paciente 231 es atendido.
# 259: Paciente 232 es atendido.
# 260: Al Paciente 213 se le asigno una cama y 1 miembro(s) del personal.
# 260: Al Paciente 218 se le ha dado de alta.
# 260: Al Paciente 225 se le asigno una cama y 3 miembro(s) del personal.
# ...
# 408: Al Paciente 373 se le asigno una cama y 5 miembro(s) del personal.
# 408: Al Paciente 376 se le asigno una cama y 3 miembro(s) del personal.
# 408: Paciente 378 es atendido.
# 408: Paciente 379 es atendido.
# 409: Al Paciente 370 se le asigno una cama y 4 miembro(s) del personal.
# 409: El Paciente 370 necesita cirugía.
# 409: Paciente 390 llega al hospital a la unidad Urgencias.
# 409: Paciente 391 llega al hospital a la unidad UCI.
# 409: Paciente 392 llega al hospital a la unidad UCI.
# 409: Paciente 380 es atendido.
# 410: Al Paciente 377 se le asigno una cama y 4 miembro(s) del personal.
# 410: El Paciente 377 necesita cirugía.
# 410: Paciente 381 es atendido.
# 411: Al Paciente 355 se le ha dado de alta.
# 411: Al Paciente 344 se le ha dado de alta.
# 411: Al Paciente 372 se le asigno una cama y 7 miembro(s) del personal.
# 411: El Paciente 372 necesita cirugía.
# 411: Paciente 393 llega al hospital a la unidad Urgencias.
# 411: Paciente 394 llega al hospital a la unidad Urgencias.
# 411: Paciente 395 llega al hospital a la unidad UCI.
# 411: Paciente 396 llega al hospital a la unidad UCI.
# 411: Paciente 382 es atendido.
# 412: Al Paciente 382 se le asigno una cama y 6 miembro(s) del personal.
# 412: Paciente 383 es atendido.
# 413: Al Paciente 352 se le ha dado de alta.
# 413: Al Paciente 379 se le asigno una cama y 8 miembro(s) del personal.
# 413: Paciente 384 es atendido.
# 414: Al Paciente 348 se le ha dado de alta.
# 414: Al Paciente 378 se le asigno una cama y 4 miembro(s) del personal.
# 414: Al Paciente 381 se le asigno una cama y 7 miembro(s) del personal.
# 414: El Paciente 381 necesita cirugía.
# 414: Paciente 385 es atendido.
# 414: Paciente 386 es atendido.
# 416: Al Paciente 365 se le asigno una cama y 1 miembro(s) del personal.
# 416: Al Paciente 380 se le asigno una cama y 8 miembro(s) del personal.
# 416: Paciente 397 llega al hospital a la unidad UCI.
# 416: Paciente 398 llega al hospital a la unidad Urgencias.
# 416: Paciente 399 llega al hospital a la unidad Consultorios.
# 416: Paciente 400 llega al hospital a la unidad UCI.
# 416: Paciente 387 es atendido.
# 416: Paciente 388 es atendido.
# 417: Al Paciente 368 se le ha dado de alta.
# 417: Al Paciente 384 se le asigno una cama y 7 miembro(s) del personal.
# 417: Al Paciente 386 se le asigno una cama y 5 miembro(s) del personal.
# 417: Paciente 389 es atendido.
# 417: Paciente 390 es atendido.
# 418: Al Paciente 351 se le ha dado de alta.
# 418: Al Paciente 376 se le ha dado de alta.
# 418: Al Paciente 388 se le asigno una cama y 3 miembro(s) del personal.
# 418: Al Paciente 390 se le asigno una cama y 5 miembro(s) del personal.
# 418: El Paciente 333 murió esperando un kit médico.
# 418: Paciente 391 es atendido.
# 418: Paciente 392 es atendido.
# 419: Al Paciente 363 se le ha dado de alta.
# 419: Al Paciente 383 se le asigno una cama y 1 miembro(s) del personal.
# 419: Paciente 393 es atendido.
# 420: Al Paciente 364 se le ha dado de alta.
# 420: Al Paciente 385 se le asigno una cama y 4 miembro(s) del personal.
# 420: Al Paciente 392 se le asigno una cama y 7 miembro(s) del personal.
# 420: Paciente 394 es atendido.
# 420: Paciente 395 es atendido.
# 421: Al Paciente 356 se le ha dado de alta.
# 421: Al Paciente 374 se le ha dado de alta.
# 421: Al Paciente 380 se le ha dado de alta.
# 421: Paciente 401 llega al hospital a la unidad Urgencias.
# 421: Paciente 402 llega al hospital a la unidad UCI.
# 421: Paciente 403 llega al hospital a la unidad Consultorios.
# 421: Paciente 404 llega al hospital a la unidad Urgencias.
# 421: Paciente 405 llega al hospital a la unidad Consultorios.
# 422: Al Paciente 389 se le asigno una cama y 5 miembro(s) del personal.
# 422: Al Paciente 391 se le asigno una cama y 3 miembro(s) del personal.
# 422: Paciente 396 es atendido.
# 422: Paciente 397 es atendido.
# 423: Al Paciente 395 se le asigno una cama y 8 miembro(s) del personal.
# 423: Paciente 406 llega al hospital a la unidad UCI.
# 423: Paciente 407 llega al hospital a la unidad Urgencias.
# 423: Al Paciente 397 se le asigno una cama y 8 miembro(s) del personal.
# 423: Paciente 398 es atendido.
# 423: Paciente 399 es atendido.
# 425: Cirugía completada para el Paciente 29.
# 425: Paciente 29 se le ha dado de alta.
# 425: Al Paciente 343 se le asignó un kit médico.
# 426: Al Paciente 373 se le ha dado de alta.
# 426: Al Paciente 393 se le asigno una cama y 4 miembro(s) del personal.
# 426: El Paciente 393 necesita cirugía.
# 426: Al Paciente 394 se le asigno una cama y 6 miembro(s) del personal.
# 426: El Paciente 394 necesita cirugía.
# 426: Paciente 400 es atendido.
# 426: Paciente 401 es atendido.
# 427: Al Paciente 361 se le ha dado de alta.
# 427: Al Paciente 378 se le ha dado de alta.
# 427: Al Paciente 388 se le ha dado de alta.
# 428: Al Paciente 367 se le ha dado de alta.
# 428: Al Paciente 366 se le ha dado de alta.
# 428: Al Paciente 375 se le ha dado de alta.
# 428: Paciente 408 llega al hospital a la unidad Consultorios.
# 428: Paciente 409 llega al hospital a la unidad Urgencias.
# 428: Paciente 410 llega al hospital a la unidad UCI.
# 429: Al Paciente 357 se le ha dado de alta.
# 429: Al Paciente 396 se le asigno una cama y 3 miembro(s) del personal.
# 429: Paciente 411 llega al hospital a la unidad Consultorios.
# 429: Paciente 402 es atendido.
# 430: Al Paciente 398 se le asigno una cama y 6 miembro(s) del personal.
# 430: El Paciente 398 necesita cirugía.
# 430: Al Paciente 401 se le asigno una cama y 6 miembro(s) del personal.
# 430: Paciente 403 es atendido.
# 430: Paciente 404 es atendido.
# 431: Cirugía completada para el Paciente 50.
# 431: Paciente 50 se le ha dado de alta.
# 431: Paciente 412 llega al hospital a la unidad UCI.
# 431: Paciente 413 llega al hospital a la unidad Urgencias.
# 431: Paciente 414 llega al hospital a la unidad Urgencias.
# 431: Al Paciente 347 se le asignó un kit médico.
# 432: Al Paciente 379 se le ha dado de alta.
# 432: Al Paciente 387 se le asigno una cama y 1 miembro(s) del personal.
# 432: Al Paciente 400 se le asigno una cama y 5 miembro(s) del personal.
# 432: Paciente 405 es atendido.
# 432: Paciente 406 es atendido.
# 433: Al Paciente 362 se le ha dado de alta.
# 433: Al Paciente 382 se le ha dado de alta.
# 433: Paciente 415 llega al hospital a la unidad Consultorios.
# 433: Paciente 416 llega al hospital a la unidad Urgencias.
# 433: Paciente 417 llega al hospital a la unidad Urgencias.
# 433: Paciente 418 llega al hospital a la unidad Urgencias.
# 434: Al Paciente 391 se le ha dado de alta.
# 434: Paciente 419 llega al hospital a la unidad Consultorios.
# 435: Al Paciente 402 se le asigno una cama y 6 miembro(s) del personal.
# 435: Al Paciente 404 se le asigno una cama y 3 miembro(s) del personal.
# 435: Paciente 407 es atendido.
# 435: Paciente 408 es atendido.
# 436: Al Paciente 384 se le ha dado de alta.
# 436: Paciente 420 llega al hospital a la unidad Consultorios.
# 437: Cirugía completada para el Paciente 48.
# 437: Paciente 48 se le ha dado de alta.
# 437: Al Paciente 392 se le ha dado de alta.
# 437: Al Paciente 350 se le asignó un kit médico.
# 438: Cirugía completada para el Paciente 45.
# 438: Paciente 45 se le ha dado de alta.
# 438: Al Paciente 385 se le ha dado de alta.
# 438: Al Paciente 403 se le asigno una cama y 1 miembro(s) del personal.
# 438: Al Paciente 406 se le asigno una cama y 4 miembro(s) del personal.
# 438: Paciente 409 es atendido.
# 438: Paciente 410 es atendido.
# 438: Al Paciente 353 se le asignó un kit médico.
# 439: Al Paciente 365 se le ha dado de alta.
# 439: Al Paciente 397 se le ha dado de alta.
# 439: Al Paciente 399 se le asigno una cama y 1 miembro(s) del personal.
# 439: Paciente 421 llega al hospital a la unidad Consultorios.
# 439: Paciente 411 es atendido.
# 440: Al Paciente 387 se le ha dado de alta.
# 440: Al Paciente 409 se le asigno una cama y 6 miembro(s) del personal.
# 440: Paciente 422 llega al hospital a la unidad Urgencias.
# 440: Paciente 423 llega al hospital a la unidad UCI.
# 440: Paciente 424 llega al hospital a la unidad UCI.
# 440: Paciente 425 llega al hospital a la unidad UCI.
# 440: Paciente 412 es atendido.
# 441: Al Paciente 390 se le ha dado de alta.
# 442: Al Paciente 407 se le asigno una cama y 3 miembro(s) del personal.
# 442: El Paciente 407 necesita cirugía.
# 442: Al Paciente 412 se le asigno una cama y 6 miembro(s) del personal.
# 442: Paciente 413 es atendido.
# 442: Paciente 414 es atendido.
# 443: Al Paciente 383 se le ha dado de alta.
# 443: Al Paciente 408 se le asigno una cama y 1 miembro(s) del personal.
# 443: Paciente 426 llega al hospital a la unidad UCI.
# 443: Paciente 427 llega al hospital a la unidad Urgencias.
# 443: Paciente 428 llega al hospital a la unidad Urgencias.
# 443: Paciente 429 llega al hospital a la unidad UCI.
# 443: Paciente 430 llega al hospital a la unidad Urgencias.
# 443: Paciente 415 es atendido.
# 444: Al Paciente 386 se le ha dado de alta.
# 444: Al Paciente 413 se le asigno una cama y 8 miembro(s) del personal.
# 444: El Paciente 413 necesita cirugía.
# 444: Paciente 431 llega al hospital a la unidad Urgencias.
# 444: Paciente 432 llega al hospital a la unidad Consultorios.
# 444: Paciente 433 llega al hospital a la unidad Urgencias.
# 444: Paciente 434 llega al hospital a la unidad Urgencias.
# 444: Paciente 416 es atendido.
# 445: Al Paciente 410 se le asigno una cama y 8 miembro(s) del personal.
# 445: Al Paciente 414 se le asigno una cama y 4 miembro(s) del personal.
# 445: El Paciente 414 necesita cirugía.
# 445: Paciente 417 es atendido.
# 445: Paciente 418 es atendido.
# 446: Al Paciente 395 se le ha dado de alta.
# 446: El Paciente 354 murió esperando un kit médico.
# 447: Paciente 435 llega al hospital a la unidad Consultorios.
# 448: Al Paciente 389 se le ha dado de alta.
# 449: Paciente 436 llega al hospital a la unidad UCI.
# 449: Paciente 437 llega al hospital a la unidad Consultorios.
# 449: Paciente 438 llega al hospital a la unidad Urgencias.
# 449: Paciente 439 llega al hospital a la unidad UCI.
# 449: Paciente 440 llega al hospital a la unidad Urgencias.
# 450: Al Paciente 396 se le ha dado de alta.
# 450: Al Paciente 418 se le asigno una cama y 7 miembro(s) del personal.
# 450: El Paciente 358 murió esperando un kit médico.
# 450: Paciente 419 es atendido.
# 451: Al Paciente 400 se le ha dado de alta.
# 451: Al Paciente 416 se le asigno una cama y 8 miembro(s) del personal.
# 451: El Paciente 416 necesita cirugía.
# 451: Paciente 420 es atendido.
# 452: Al Paciente 417 se le asigno una cama y 3 miembro(s) del personal.
# 452: El Paciente 417 necesita cirugía.
# 452: Paciente 421 es atendido.
# 453: Al Paciente 405 se le asigno una cama y 1 miembro(s) del personal.
# 453: Paciente 441 llega al hospital a la unidad Consultorios.
# 453: Paciente 442 llega al hospital a la unidad Urgencias.
# 453: Paciente 443 llega al hospital a la unidad UCI.
# 453: Paciente 444 llega al hospital a la unidad Urgencias.
# 453: Paciente 445 llega al hospital a la unidad Urgencias.
# 453: Paciente 422 es atendido.
# 454: Al Paciente 401 se le ha dado de alta.
# 454: Al Paciente 402 se le ha dado de alta.
# 454: Al Paciente 409 se le ha dado de alta.
# 454: Al Paciente 408 se le ha dado de alta.
# 454: El Paciente 359 murió esperando un kit médico.
# 454: El Paciente 360 murió esperando un kit médico.
# 456: Cirugía completada para el Paciente 350.
# 456: Paciente 350 murió tras el procedimiento.
# 456: Al Paciente 411 se le asigno una cama y 1 miembro(s) del personal.
# 456: Al Paciente 422 se le asigno una cama y 6 miembro(s) del personal.
# 456: El Paciente 422 necesita cirugía.
# 456: Paciente 423 es atendido.
# 456: Paciente 424 es atendido.
# 456: Al Paciente 371 se le asignó un kit médico.
# 458: Al Paciente 410 se le ha dado de alta.
# 458: Paciente 446 llega al hospital a la unidad Consultorios.
# 458: Paciente 447 llega al hospital a la unidad Consultorios.
# 458: Paciente 448 llega al hospital a la unidad Urgencias.
# 458: Paciente 449 llega al hospital a la unidad UCI.
# 459: Al Paciente 421 se le asigno una cama y 1 miembro(s) del personal.
# 459: Al Paciente 423 se le asigno una cama y 8 miembro(s) del personal.
# 459: Al Paciente 424 se le asigno una cama y 4 miembro(s) del personal.
# 459: Paciente 425 es atendido.
# 459: Paciente 426 es atendido.
# 459: Paciente 427 es atendido.
# 460: Al Paciente 406 se le ha dado de alta.
# 462: Al Paciente 404 se le ha dado de alta.
# 462: Al Paciente 425 se le asigno una cama y 7 miembro(s) del personal.
# 462: Al Paciente 427 se le asigno una cama y 6 miembro(s) del personal.
# 462: El Paciente 427 necesita cirugía.
# 462: Paciente 428 es atendido.
# 462: Paciente 429 es atendido.
# 463: Paciente 450 llega al hospital a la unidad UCI.
# 463: Al Paciente 426 se le asigno una cama y 4 miembro(s) del personal.
# 463: Al Paciente 429 se le asigno una cama y 8 miembro(s) del personal.
# 463: Paciente 430 es atendido.
# 463: Paciente 431 es atendido.
# 464: Paciente 451 llega al hospital a la unidad UCI.
# 464: Paciente 452 llega al hospital a la unidad Urgencias.
# 464: Paciente 453 llega al hospital a la unidad UCI.
# 464: Paciente 454 llega al hospital a la unidad Consultorios.
# 465: Paciente 455 llega al hospital a la unidad UCI.
# 465: Paciente 456 llega al hospital a la unidad UCI.
# 465: Paciente 457 llega al hospital a la unidad UCI.
# 466: Al Paciente 415 se le asigno una cama y 1 miembro(s) del personal.
# 466: El Paciente 369 murió esperando un kit médico.
# 466: Paciente 432 es atendido.
# 468: Al Paciente 403 se le ha dado de alta.
# 468: Al Paciente 399 se le ha dado de alta.
# 468: Al Paciente 420 se le asigno una cama y 1 miembro(s) del personal.
# 468: Al Paciente 411 se le ha dado de alta.
# 468: Al Paciente 428 se le asigno una cama y 8 miembro(s) del personal.
# 468: El Paciente 428 necesita cirugía.
# 468: Al Paciente 430 se le asigno una cama y 6 miembro(s) del personal.
# 468: El Paciente 430 necesita cirugía.
# 468: Paciente 458 llega al hospital a la unidad UCI.
# 468: Paciente 459 llega al hospital a la unidad Urgencias.
# 468: Paciente 460 llega al hospital a la unidad Urgencias.
# 468: Paciente 433 es atendido.
# 468: Paciente 434 es atendido.
# 468: Paciente 435 es atendido.
# 469: Al Paciente 412 se le ha dado de alta.
# 469: El Paciente 370 murió esperando un kit médico.
# 470: Al Paciente 423 se le ha dado de alta.
# 470: Al Paciente 431 se le asigno una cama y 8 miembro(s) del personal.
# 470: El Paciente 431 necesita cirugía.
# 470: Paciente 461 llega al hospital a la unidad UCI.
# 470: Paciente 462 llega al hospital a la unidad Urgencias.
# 470: El Paciente 377 murió esperando un kit médico.
# 470: Paciente 436 es atendido.
# 471: Paciente 463 llega al hospital a la unidad Urgencias.
# 471: Paciente 464 llega al hospital a la unidad Consultorios.
# 471: Paciente 465 llega al hospital a la unidad Urgencias.
# 471: El Paciente 372 murió esperando un kit médico.
# 472: Al Paciente 419 se le asigno una cama y 1 miembro(s) del personal.
# 472: Paciente 437 es atendido.
# 473: Al Paciente 433 se le asigno una cama y 3 miembro(s) del personal.
# 473: El Paciente 433 necesita cirugía.
# 473: Al Paciente 434 se le asigno una cama y 6 miembro(s) del personal.
# 473: El Paciente 434 necesita cirugía.
# 473: Paciente 438 es atendido.
# 473: Paciente 439 es atendido.
# 474: El Paciente 381 murió esperando un kit médico.
# 475: Al Paciente 418 se le ha dado de alta.
# 475: Al Paciente 436 se le asigno una cama y 8 miembro(s) del personal.
# 475: Paciente 440 es atendido.
# 476: Al Paciente 425 se le ha dado de alta.
# 476: Paciente 466 llega al hospital a la unidad UCI.
# 476: Paciente 467 llega al hospital a la unidad UCI.
# 476: Paciente 468 llega al hospital a la unidad Urgencias.
# 476: Paciente 469 llega al hospital a la unidad Consultorios.
# 476: Paciente 470 llega al hospital a la unidad Consultorios.
# 477: Al Paciente 405 se le ha dado de alta.
# 477: Paciente 471 llega al hospital a la unidad UCI.
# 477: Paciente 472 llega al hospital a la unidad Urgencias.
# 478: Al Paciente 432 se le asigno una cama y 1 miembro(s) del personal.
# 478: Al Paciente 420 se le ha dado de alta.
# 478: Al Paciente 439 se le asigno una cama y 4 miembro(s) del personal.
# 478: Paciente 441 es atendido.
# 478: Paciente 442 es atendido.
# 479: Paciente 473 llega al hospital a la unidad Urgencias.
# 479: Paciente 474 llega al hospital a la unidad Urgencias.
# 479: Paciente 475 llega al hospital a la unidad Consultorios.
# 479: Paciente 476 llega al hospital a la unidad Urgencias.

# %%
lista_pacientes2 = []

def registrar_paciente(paciente_id, unidad, cirugia,alcanzo_cama):
    lista_pacientes2.append({
        "id": paciente_id,
        "unidad": unidad,
        "cirugia": cirugia,
        "alcanzo_cama": alcanzo_cama
    })

# %%
for p in simulacion2.pacientes:
    registrar_paciente(p.id, p.unidad.nombre, p.cirugia, p.alcanzo_cama)

dfPacientes2 = pd.DataFrame(lista_pacientes2)
dfPacientes2
# Out:
#       id        unidad  cirugia  alcanzo_cama
# 0      1     Urgencias    False          True
# 1      2           UCI    False          True
# 2      3     Urgencias     True          True
# 3      4     Urgencias     True          True
# 4      5           UCI    False          True
# ..   ...           ...      ...           ...
# 471  472     Urgencias     True         False
# 472  473     Urgencias     True         False
# 473  474     Urgencias     True         False
# 474  475  Consultorios    False         False
# 475  476     Urgencias    False         False
#
# [476 rows x 4 columns]

# %%
lista_eventos2 = []
for p in simulacion2.pacientes:
    lista_eventos2.append( p.eventos )

dfeventos2 = pd.concat(lista_eventos2)
dfeventos2 = dfeventos2.reset_index()
dfeventos2.drop( ["index"], axis=1, inplace=True )

dfeventos2
# Out:
#        id                    evento  time
# 0       1                   LLEGADA     2
# 1       1                  ATENDIDO     2
# 2       1  ASIGNACION_CAMA_PERSONAL     8
# 3       1                      ALTA    34
# 4       2                   LLEGADA     2
# ...   ...                       ...   ...
# 1775  472                   LLEGADA   477
# 1776  473                   LLEGADA   479
# 1777  474                   LLEGADA   479
# 1778  475                   LLEGADA   479
# 1779  476                   LLEGADA   479
#
# [1780 rows x 3 columns]

# %%
dfeventos2["lag_time"] = dfeventos2.groupby("id")["time"].shift(1)

# %%
# Filtramos y calculamos el tiempo de espera
df2 = dfeventos2.loc[dfeventos2["evento"] == "ATENDIDO", :].copy()
df2["tiempo_espera"] = df2["time"] - df2["lag_time"]

# Merge con la info de pacientes (asegúrate de que 'id' esté en ambos)
df_merged2 = df2.merge(dfPacientes2, on="id", how="inner")

# Agrupamos por unidad y calculamos el promedio
resultado2 = (
    df_merged2
    .groupby("unidad")
    .agg({"tiempo_espera": "mean"})
)

print(resultado2)
# Out:
#               tiempo_espera
# unidad
# Consultorios      10.179487
# UCI                9.379310
# Urgencias         10.484018

# %% [markdown]
# ### Resultado
# Notamos que el tiempo de espera promedio se reduce considerablemente, indicando que había suficiente personal
# médico pero este no era bien aprovechado por el bajo rendimiento laboral de las recepcionistas.

# %% [markdown]
# ### Aumento de personal

# %%
env3 = simpy.Environment()
unidades_settings = [
    {"nombre": "Urgencias", "num_camas": 20, "personal": 60, "num_kits_medicos": 8},
    {"nombre": "UCI", "num_camas": 35, "personal": 50, "num_kits_medicos": 1},
    {"nombre": "Consultorios", "num_camas": 10, "personal": 16, "num_kits_medicos": 1}
]
num_recepcionistas = 2

#random.seed(111)

simulacion3 = Simulation(env3, unidades_settings, num_recepcionistas)
env3.run(until=60*8)
# Out:
# 1: Paciente 1 llega al hospital a la unidad Consultorios.
# 1: Paciente 2 llega al hospital a la unidad UCI.
# 1: Paciente 3 llega al hospital a la unidad Urgencias.
# 1: Paciente 1 es atendido.
# 1: Paciente 2 es atendido.
# 3: Paciente 4 llega al hospital a la unidad Urgencias.
# 3: Paciente 5 llega al hospital a la unidad Consultorios.
# 3: Paciente 6 llega al hospital a la unidad Urgencias.
# 3: Paciente 7 llega al hospital a la unidad UCI.
# 7: Al Paciente 2 se le asigno una cama y 8 miembro(s) del personal.
# 7: Paciente 3 es atendido.
# 8: Paciente 8 llega al hospital a la unidad Urgencias.
# 11: Al Paciente 3 se le asigno una cama y 7 miembro(s) del personal.
# 11: El Paciente 3 necesita cirugía.
# 11: Paciente 4 es atendido.
# 11: Al Paciente 3 se le asignó un kit médico.
# 12: Paciente 9 llega al hospital a la unidad UCI.
# 12: Paciente 10 llega al hospital a la unidad Consultorios.
# 12: Paciente 11 llega al hospital a la unidad Urgencias.
# 12: Paciente 12 llega al hospital a la unidad Consultorios.
# 12: Al Paciente 4 se le asigno una cama y 4 miembro(s) del personal.
# 12: El Paciente 4 necesita cirugía.
# 12: Paciente 5 es atendido.
# 12: Al Paciente 4 se le asignó un kit médico.
# 13: Al Paciente 1 se le asigno una cama y 1 miembro(s) del personal.
# 13: Paciente 6 es atendido.
# 15: Paciente 13 llega al hospital a la unidad Urgencias.
# 15: Paciente 14 llega al hospital a la unidad UCI.
# 15: Paciente 15 llega al hospital a la unidad Consultorios.
# 15: Paciente 16 llega al hospital a la unidad UCI.
# 17: Al Paciente 6 se le asigno una cama y 4 miembro(s) del personal.
# 17: Paciente 7 es atendido.
# 20: Paciente 17 llega al hospital a la unidad Consultorios.
# 20: Paciente 18 llega al hospital a la unidad Urgencias.
# 20: Paciente 19 llega al hospital a la unidad Urgencias.
# 20: Al Paciente 7 se le asigno una cama y 8 miembro(s) del personal.
# 20: Paciente 8 es atendido.
# 21: Al Paciente 8 se le asigno una cama y 5 miembro(s) del personal.
# 21: El Paciente 8 necesita cirugía.
# 21: Paciente 9 es atendido.
# 21: Al Paciente 8 se le asignó un kit médico.
# 22: Paciente 20 llega al hospital a la unidad UCI.
# 22: Paciente 21 llega al hospital a la unidad Urgencias.
# 22: Paciente 22 llega al hospital a la unidad Urgencias.
# 25: Paciente 23 llega al hospital a la unidad Consultorios.
# 25: Paciente 24 llega al hospital a la unidad Urgencias.
# 26: Al Paciente 9 se le asigno una cama y 6 miembro(s) del personal.
# 26: Paciente 10 es atendido.
# 27: Al Paciente 2 se le ha dado de alta.
# 29: Paciente 25 llega al hospital a la unidad Urgencias.
# 29: Paciente 26 llega al hospital a la unidad UCI.
# 29: Paciente 27 llega al hospital a la unidad Urgencias.
# 31: Paciente 28 llega al hospital a la unidad Consultorios.
# 31: Paciente 29 llega al hospital a la unidad UCI.
# 31: Paciente 30 llega al hospital a la unidad Consultorios.
# 31: Paciente 31 llega al hospital a la unidad Consultorios.
# 32: Al Paciente 7 se le ha dado de alta.
# 33: Al Paciente 1 se le ha dado de alta.
# 33: Al Paciente 9 se le ha dado de alta.
# 33: Al Paciente 10 se le asigno una cama y 1 miembro(s) del personal.
# 33: Paciente 11 es atendido.
# 34: Al Paciente 5 se le asigno una cama y 1 miembro(s) del personal.
# 34: Paciente 12 es atendido.
# 36: Paciente 32 llega al hospital a la unidad Consultorios.
# 36: Paciente 33 llega al hospital a la unidad Urgencias.
# 36: Paciente 34 llega al hospital a la unidad Urgencias.
# 39: Al Paciente 5 se le ha dado de alta.
# 39: Paciente 35 llega al hospital a la unidad Consultorios.
# 39: Paciente 36 llega al hospital a la unidad Urgencias.
# 39: Paciente 37 llega al hospital a la unidad UCI.
# 40: Al Paciente 6 se le ha dado de alta.
# 40: Al Paciente 11 se le asigno una cama y 6 miembro(s) del personal.
# 40: Paciente 13 es atendido.
# 43: Al Paciente 12 se le asigno una cama y 1 miembro(s) del personal.
# 43: Paciente 38 llega al hospital a la unidad Urgencias.
# 43: Paciente 39 llega al hospital a la unidad Urgencias.
# 43: Paciente 40 llega al hospital a la unidad Consultorios.
# 43: Paciente 14 es atendido.
# 46: Paciente 41 llega al hospital a la unidad UCI.
# 46: Paciente 42 llega al hospital a la unidad Consultorios.
# 46: Paciente 43 llega al hospital a la unidad Consultorios.
# 46: Paciente 44 llega al hospital a la unidad Consultorios.
# 46: Paciente 45 llega al hospital a la unidad Consultorios.
# 47: Al Paciente 13 se le asigno una cama y 8 miembro(s) del personal.
# 47: El Paciente 13 necesita cirugía.
# 47: Paciente 46 llega al hospital a la unidad UCI.
# 47: Paciente 47 llega al hospital a la unidad Urgencias.
# 47: Paciente 48 llega al hospital a la unidad UCI.
# 47: Paciente 15 es atendido.
# 47: Al Paciente 13 se le asignó un kit médico.
# 49: Al Paciente 14 se le asigno una cama y 3 miembro(s) del personal.
# 49: Paciente 49 llega al hospital a la unidad Urgencias.
# 49: Paciente 16 es atendido.
# 53: Paciente 50 llega al hospital a la unidad UCI.
# 53: Paciente 51 llega al hospital a la unidad Urgencias.
# 53: Paciente 52 llega al hospital a la unidad Urgencias.
# 54: Al Paciente 14 se le ha dado de alta.
# 56: Al Paciente 10 se le ha dado de alta.
# 56: Al Paciente 16 se le asigno una cama y 4 miembro(s) del personal.
# 56: Paciente 17 es atendido.
# 57: Paciente 53 llega al hospital a la unidad Urgencias.
# 57: Paciente 54 llega al hospital a la unidad UCI.
# 57: Paciente 55 llega al hospital a la unidad Urgencias.
# 57: Paciente 56 llega al hospital a la unidad Consultorios.
# 58: Paciente 57 llega al hospital a la unidad Urgencias.
# 58: Paciente 58 llega al hospital a la unidad Urgencias.
# 59: Al Paciente 11 se le ha dado de alta.
# 60: Paciente 59 llega al hospital a la unidad UCI.
# 62: Al Paciente 15 se le asigno una cama y 1 miembro(s) del personal.
# 62: Paciente 18 es atendido.
# 63: Paciente 60 llega al hospital a la unidad Urgencias.
# 63: Paciente 61 llega al hospital a la unidad Urgencias.
# 63: Al Paciente 18 se le asigno una cama y 5 miembro(s) del personal.
# 63: Paciente 19 es atendido.
# 64: Al Paciente 12 se le ha dado de alta.
# 66: Al Paciente 16 se le ha dado de alta.
# 66: Paciente 62 llega al hospital a la unidad Urgencias.
# 66: Paciente 63 llega al hospital a la unidad UCI.
# 66: Paciente 64 llega al hospital a la unidad Urgencias.
# 66: Paciente 65 llega al hospital a la unidad Consultorios.
# 68: Paciente 66 llega al hospital a la unidad Urgencias.
# 68: Paciente 67 llega al hospital a la unidad Consultorios.
# 68: Paciente 68 llega al hospital a la unidad Urgencias.
# 68: Paciente 69 llega al hospital a la unidad UCI.
# 69: Al Paciente 18 se le ha dado de alta.
# 70: Al Paciente 19 se le asigno una cama y 7 miembro(s) del personal.
# 70: El Paciente 19 necesita cirugía.
# 70: Paciente 20 es atendido.
# 70: Al Paciente 19 se le asignó un kit médico.
# 73: Paciente 70 llega al hospital a la unidad UCI.
# 74: Al Paciente 20 se le asigno una cama y 6 miembro(s) del personal.
# 74: Paciente 21 es atendido.
# 77: Al Paciente 17 se le asigno una cama y 1 miembro(s) del personal.
# 77: Paciente 71 llega al hospital a la unidad UCI.
# 77: Paciente 72 llega al hospital a la unidad Urgencias.
# 77: Paciente 73 llega al hospital a la unidad UCI.
# 77: Paciente 74 llega al hospital a la unidad UCI.
# 77: Al Paciente 21 se le asigno una cama y 4 miembro(s) del personal.
# 77: Paciente 22 es atendido.
# 77: Paciente 23 es atendido.
# 78: Al Paciente 15 se le ha dado de alta.
# 78: Al Paciente 22 se le asigno una cama y 8 miembro(s) del personal.
# 78: Paciente 24 es atendido.
# 80: Paciente 75 llega al hospital a la unidad Urgencias.
# 80: Paciente 76 llega al hospital a la unidad UCI.
# 80: Al Paciente 24 se le asigno una cama y 6 miembro(s) del personal.
# 80: Paciente 25 es atendido.
# 84: Paciente 77 llega al hospital a la unidad Consultorios.
# 84: Paciente 78 llega al hospital a la unidad UCI.
# 84: Paciente 79 llega al hospital a la unidad Urgencias.
# 84: Paciente 80 llega al hospital a la unidad UCI.
# 84: Paciente 81 llega al hospital a la unidad Consultorios.
# 85: Al Paciente 25 se le asigno una cama y 4 miembro(s) del personal.
# 85: El Paciente 25 necesita cirugía.
# 85: Paciente 26 es atendido.
# 85: Al Paciente 25 se le asignó un kit médico.
# 87: Paciente 82 llega al hospital a la unidad Consultorios.
# 87: Paciente 83 llega al hospital a la unidad Urgencias.
# 87: Paciente 84 llega al hospital a la unidad Urgencias.
# 88: Al Paciente 26 se le asigno una cama y 3 miembro(s) del personal.
# 88: Paciente 27 es atendido.
# 90: Al Paciente 20 se le ha dado de alta.
# 91: Al Paciente 22 se le ha dado de alta.
# 91: Paciente 85 llega al hospital a la unidad UCI.
# 91: Paciente 86 llega al hospital a la unidad Urgencias.
# 91: Paciente 87 llega al hospital a la unidad UCI.
# 91: Paciente 88 llega al hospital a la unidad UCI.
# 92: Al Paciente 17 se le ha dado de alta.
# 93: Paciente 89 llega al hospital a la unidad Urgencias.
# 93: Paciente 90 llega al hospital a la unidad Urgencias.
# 93: Paciente 91 llega al hospital a la unidad Urgencias.
# 93: Paciente 92 llega al hospital a la unidad UCI.
# 93: Paciente 93 llega al hospital a la unidad UCI.
# 94: Cirugía completada para el Paciente 13.
# 94: Paciente 13 se le ha dado de alta.
# 95: Al Paciente 23 se le asigno una cama y 1 miembro(s) del personal.
# 95: Al Paciente 27 se le asigno una cama y 3 miembro(s) del personal.
# 95: El Paciente 27 necesita cirugía.
# 95: Paciente 28 es atendido.
# 95: Paciente 29 es atendido.
# 95: Al Paciente 27 se le asignó un kit médico.
# 97: Paciente 94 llega al hospital a la unidad Urgencias.
# 97: Paciente 95 llega al hospital a la unidad Urgencias.
# 97: Paciente 96 llega al hospital a la unidad Consultorios.
# 97: Paciente 97 llega al hospital a la unidad Urgencias.
# 97: Paciente 98 llega al hospital a la unidad Urgencias.
# 98: Al Paciente 29 se le asigno una cama y 5 miembro(s) del personal.
# 98: Paciente 30 es atendido.
# 101: Paciente 99 llega al hospital a la unidad UCI.
# 101: Paciente 100 llega al hospital a la unidad Consultorios.
# 101: Paciente 101 llega al hospital a la unidad UCI.
# 106: Al Paciente 21 se le ha dado de alta.
# 106: Paciente 102 llega al hospital a la unidad Consultorios.
# 106: Paciente 103 llega al hospital a la unidad UCI.
# 106: Paciente 104 llega al hospital a la unidad Urgencias.
# 106: Paciente 105 llega al hospital a la unidad Consultorios.
# 107: Al Paciente 24 se le ha dado de alta.
# 109: Al Paciente 30 se le asigno una cama y 1 miembro(s) del personal.
# 109: Paciente 31 es atendido.
# 111: Paciente 106 llega al hospital a la unidad UCI.
# 111: Paciente 107 llega al hospital a la unidad Consultorios.
# 111: Paciente 108 llega al hospital a la unidad UCI.
# 115: Paciente 109 llega al hospital a la unidad Urgencias.
# 115: Paciente 110 llega al hospital a la unidad Urgencias.
# 118: Al Paciente 26 se le ha dado de alta.
# 118: Al Paciente 23 se le ha dado de alta.
# 119: Paciente 111 llega al hospital a la unidad Consultorios.
# 119: Paciente 112 llega al hospital a la unidad Urgencias.
# 119: Paciente 113 llega al hospital a la unidad UCI.
# 119: Paciente 114 llega al hospital a la unidad UCI.
# 119: Paciente 115 llega al hospital a la unidad Consultorios.
# 120: Al Paciente 28 se le asigno una cama y 1 miembro(s) del personal.
# 120: Paciente 32 es atendido.
# 121: Paciente 116 llega al hospital a la unidad Urgencias.
# 121: Paciente 117 llega al hospital a la unidad Urgencias.
# 123: Paciente 118 llega al hospital a la unidad UCI.
# 123: Paciente 119 llega al hospital a la unidad Urgencias.
# 123: Paciente 120 llega al hospital a la unidad UCI.
# 123: Paciente 121 llega al hospital a la unidad Urgencias.
# 126: Al Paciente 30 se le ha dado de alta.
# 128: Al Paciente 29 se le ha dado de alta.
# 128: Paciente 122 llega al hospital a la unidad Urgencias.
# 132: Cirugía completada para el Paciente 19.
# 132: Paciente 19 se le ha dado de alta.
# 133: Al Paciente 31 se le asigno una cama y 1 miembro(s) del personal.
# 133: Paciente 123 llega al hospital a la unidad Urgencias.
# 133: Paciente 124 llega al hospital a la unidad UCI.
# 133: Paciente 125 llega al hospital a la unidad Urgencias.
# 133: Paciente 126 llega al hospital a la unidad Urgencias.
# 133: Paciente 33 es atendido.
# 134: Paciente 127 llega al hospital a la unidad UCI.
# 134: Paciente 128 llega al hospital a la unidad Urgencias.
# 134: Paciente 129 llega al hospital a la unidad UCI.
# 134: Paciente 130 llega al hospital a la unidad UCI.
# 134: Al Paciente 33 se le asigno una cama y 7 miembro(s) del personal.
# 134: El Paciente 33 necesita cirugía.
# 134: Paciente 34 es atendido.
# 134: Al Paciente 33 se le asignó un kit médico.
# 135: Al Paciente 28 se le ha dado de alta.
# 139: Paciente 131 llega al hospital a la unidad Urgencias.
# 139: Paciente 132 llega al hospital a la unidad Urgencias.
# 139: Paciente 133 llega al hospital a la unidad Consultorios.
# 139: Paciente 134 llega al hospital a la unidad Urgencias.
# 139: Paciente 135 llega al hospital a la unidad Urgencias.
# 140: Al Paciente 32 se le asigno una cama y 1 miembro(s) del personal.
# 140: Paciente 136 llega al hospital a la unidad Consultorios.
# 140: Paciente 137 llega al hospital a la unidad Urgencias.
# 140: Paciente 138 llega al hospital a la unidad UCI.
# 140: Paciente 139 llega al hospital a la unidad Urgencias.
# 140: Paciente 140 llega al hospital a la unidad Urgencias.
# 140: Paciente 35 es atendido.
# 141: Al Paciente 34 se le asigno una cama y 6 miembro(s) del personal.
# 141: Paciente 36 es atendido.
# 145: Paciente 141 llega al hospital a la unidad Urgencias.
# 145: Paciente 142 llega al hospital a la unidad Urgencias.
# 147: Al Paciente 36 se le asigno una cama y 3 miembro(s) del personal.
# 147: Paciente 37 es atendido.
# 149: Paciente 143 llega al hospital a la unidad Urgencias.
# 149: Paciente 144 llega al hospital a la unidad Urgencias.
# 149: Paciente 145 llega al hospital a la unidad UCI.
# 149: Paciente 146 llega al hospital a la unidad Urgencias.
# 149: Paciente 147 llega al hospital a la unidad Urgencias.
# 150: Al Paciente 37 se le asigno una cama y 7 miembro(s) del personal.
# 150: Paciente 38 es atendido.
# 151: Paciente 148 llega al hospital a la unidad Urgencias.
# 151: Paciente 149 llega al hospital a la unidad Urgencias.
# 151: Paciente 150 llega al hospital a la unidad Urgencias.
# 151: Paciente 151 llega al hospital a la unidad UCI.
# 152: Paciente 152 llega al hospital a la unidad Urgencias.
# 156: Al Paciente 37 se le ha dado de alta.
# 156: Al Paciente 38 se le asigno una cama y 8 miembro(s) del personal.
# 156: El Paciente 38 necesita cirugía.
# 156: Paciente 39 es atendido.
# 156: Al Paciente 38 se le asignó un kit médico.
# 157: Paciente 153 llega al hospital a la unidad UCI.
# 157: Paciente 154 llega al hospital a la unidad Consultorios.
# 157: Paciente 155 llega al hospital a la unidad UCI.
# 157: Paciente 156 llega al hospital a la unidad Consultorios.
# 160: Al Paciente 31 se le ha dado de alta.
# 161: Paciente 157 llega al hospital a la unidad Urgencias.
# 161: Paciente 158 llega al hospital a la unidad Urgencias.
# 161: Paciente 159 llega al hospital a la unidad Urgencias.
# 162: Al Paciente 35 se le asigno una cama y 1 miembro(s) del personal.
# 162: Paciente 40 es atendido.
# 163: Al Paciente 39 se le asigno una cama y 6 miembro(s) del personal.
# 163: Paciente 41 es atendido.
# 165: Al Paciente 34 se le ha dado de alta.
# 165: Paciente 160 llega al hospital a la unidad Urgencias.
# 165: Paciente 161 llega al hospital a la unidad Urgencias.
# 165: Paciente 162 llega al hospital a la unidad Urgencias.
# 166: Paciente 163 llega al hospital a la unidad Urgencias.
# 167: Paciente 164 llega al hospital a la unidad Urgencias.
# 167: Paciente 165 llega al hospital a la unidad Urgencias.
# 167: Paciente 166 llega al hospital a la unidad Urgencias.
# 167: Paciente 167 llega al hospital a la unidad Consultorios.
# 168: Al Paciente 41 se le asigno una cama y 5 miembro(s) del personal.
# 168: Paciente 42 es atendido.
# 170: Al Paciente 32 se le ha dado de alta.
# 172: Al Paciente 36 se le ha dado de alta.
# 172: Al Paciente 39 se le ha dado de alta.
# 172: Paciente 168 llega al hospital a la unidad Urgencias.
# 172: Paciente 169 llega al hospital a la unidad UCI.
# 172: Paciente 170 llega al hospital a la unidad UCI.
# 172: Paciente 171 llega al hospital a la unidad Urgencias.
# 176: Al Paciente 42 se le asigno una cama y 1 miembro(s) del personal.
# 176: Paciente 172 llega al hospital a la unidad UCI.
# 176: Paciente 43 es atendido.
# 178: Al Paciente 40 se le asigno una cama y 1 miembro(s) del personal.
# 178: Paciente 173 llega al hospital a la unidad Urgencias.
# 178: Paciente 174 llega al hospital a la unidad UCI.
# 178: Paciente 175 llega al hospital a la unidad Consultorios.
# 178: Paciente 176 llega al hospital a la unidad Urgencias.
# 178: Paciente 44 es atendido.
# 181: Al Paciente 35 se le ha dado de alta.
# 182: Paciente 177 llega al hospital a la unidad Urgencias.
# 182: Paciente 178 llega al hospital a la unidad UCI.
# 183: Paciente 179 llega al hospital a la unidad UCI.
# 186: Cirugía completada para el Paciente 38.
# 186: Paciente 38 se le ha dado de alta.
# 186: Paciente 180 llega al hospital a la unidad UCI.
# 186: Paciente 181 llega al hospital a la unidad Consultorios.
# 186: Paciente 182 llega al hospital a la unidad Urgencias.
# 186: Paciente 183 llega al hospital a la unidad Urgencias.
# 187: Paciente 184 llega al hospital a la unidad Consultorios.
# 187: Paciente 185 llega al hospital a la unidad UCI.
# 187: Paciente 186 llega al hospital a la unidad Consultorios.
# 187: Paciente 187 llega al hospital a la unidad Consultorios.
# 192: Al Paciente 42 se le ha dado de alta.
# 192: Paciente 188 llega al hospital a la unidad Urgencias.
# 192: Paciente 189 llega al hospital a la unidad Consultorios.
# 193: Al Paciente 41 se le ha dado de alta.
# 193: Paciente 190 llega al hospital a la unidad Consultorios.
# 193: Paciente 191 llega al hospital a la unidad UCI.
# 193: Paciente 192 llega al hospital a la unidad Urgencias.
# 193: Paciente 193 llega al hospital a la unidad Urgencias.
# 196: Al Paciente 44 se le asigno una cama y 1 miembro(s) del personal.
# 196: Paciente 45 es atendido.
# 198: Paciente 194 llega al hospital a la unidad Consultorios.
# 198: Paciente 195 llega al hospital a la unidad Consultorios.
# 201: Al Paciente 43 se le asigno una cama y 1 miembro(s) del personal.
# 201: Paciente 46 es atendido.
# 203: Paciente 196 llega al hospital a la unidad UCI.
# 204: Al Paciente 40 se le ha dado de alta.
# 205: Al Paciente 46 se le asigno una cama y 8 miembro(s) del personal.
# 205: Paciente 47 es atendido.
# 206: Paciente 197 llega al hospital a la unidad Consultorios.
# 206: Paciente 198 llega al hospital a la unidad UCI.
# 206: Paciente 199 llega al hospital a la unidad UCI.
# 209: Al Paciente 47 se le asigno una cama y 5 miembro(s) del personal.
# 209: Paciente 200 llega al hospital a la unidad Consultorios.
# 209: Paciente 201 llega al hospital a la unidad Urgencias.
# 209: Paciente 202 llega al hospital a la unidad Consultorios.
# 209: Paciente 48 es atendido.
# 211: Paciente 203 llega al hospital a la unidad Urgencias.
# 211: Paciente 204 llega al hospital a la unidad Urgencias.
# 211: Paciente 205 llega al hospital a la unidad UCI.
# 211: Paciente 206 llega al hospital a la unidad UCI.
# 211: Paciente 207 llega al hospital a la unidad Urgencias.
# 213: Al Paciente 45 se le asigno una cama y 1 miembro(s) del personal.
# 213: Al Paciente 48 se le asigno una cama y 4 miembro(s) del personal.
# 213: Paciente 49 es atendido.
# 213: Paciente 50 es atendido.
# 215: Paciente 208 llega al hospital a la unidad Urgencias.
# 216: Paciente 209 llega al hospital a la unidad Consultorios.
# 216: Paciente 210 llega al hospital a la unidad Urgencias.
# 216: Paciente 211 llega al hospital a la unidad UCI.
# 216: Paciente 212 llega al hospital a la unidad Urgencias.
# 218: Al Paciente 48 se le ha dado de alta.
# 218: Al Paciente 49 se le asigno una cama y 4 miembro(s) del personal.
# 218: El Paciente 49 necesita cirugía.
# 218: Paciente 51 es atendido.
# 218: Al Paciente 49 se le asignó un kit médico.
# 219: Paciente 213 llega al hospital a la unidad Urgencias.
# 219: Paciente 214 llega al hospital a la unidad Consultorios.
# 219: Paciente 215 llega al hospital a la unidad UCI.
# 219: Paciente 216 llega al hospital a la unidad Urgencias.
# 220: Al Paciente 50 se le asigno una cama y 4 miembro(s) del personal.
# 220: Paciente 52 es atendido.
# 221: Al Paciente 52 se le asigno una cama y 4 miembro(s) del personal.
# 221: El Paciente 52 necesita cirugía.
# 221: Paciente 53 es atendido.
# 221: Al Paciente 52 se le asignó un kit médico.
# 224: Paciente 217 llega al hospital a la unidad UCI.
# 224: Paciente 218 llega al hospital a la unidad Consultorios.
# 225: Al Paciente 44 se le ha dado de alta.
# 225: Al Paciente 46 se le ha dado de alta.
# 225: Al Paciente 51 se le asigno una cama y 4 miembro(s) del personal.
# 225: Paciente 54 es atendido.
# 228: Al Paciente 53 se le asigno una cama y 8 miembro(s) del personal.
# 228: Paciente 219 llega al hospital a la unidad Urgencias.
# 228: Paciente 220 llega al hospital a la unidad Urgencias.
# 228: Paciente 55 es atendido.
# 230: Al Paciente 43 se le ha dado de alta.
# 230: Al Paciente 47 se le ha dado de alta.
# 230: Paciente 221 llega al hospital a la unidad UCI.
# 230: Paciente 222 llega al hospital a la unidad Urgencias.
# 230: Paciente 223 llega al hospital a la unidad Consultorios.
# 230: Paciente 224 llega al hospital a la unidad Urgencias.
# 230: Paciente 225 llega al hospital a la unidad Consultorios.
# 231: Al Paciente 54 se le asigno una cama y 3 miembro(s) del personal.
# 231: Paciente 226 llega al hospital a la unidad Consultorios.
# 231: Paciente 227 llega al hospital a la unidad Consultorios.
# 231: Paciente 228 llega al hospital a la unidad Urgencias.
# 231: Paciente 229 llega al hospital a la unidad UCI.
# 231: Paciente 230 llega al hospital a la unidad Consultorios.
# 231: Paciente 56 es atendido.
# 233: Al Paciente 55 se le asigno una cama y 3 miembro(s) del personal.
# 233: El Paciente 55 necesita cirugía.
# 233: Paciente 57 es atendido.
# 235: Al Paciente 53 se le ha dado de alta.
# 235: Paciente 231 llega al hospital a la unidad Urgencias.
# 235: Paciente 232 llega al hospital a la unidad UCI.
# 236: Al Paciente 51 se le ha dado de alta.
# 236: Paciente 233 llega al hospital a la unidad Urgencias.
# 236: Paciente 234 llega al hospital a la unidad Urgencias.
# 236: Paciente 235 llega al hospital a la unidad Consultorios.
# 238: Paciente 236 llega al hospital a la unidad Urgencias.
# 238: Paciente 237 llega al hospital a la unidad Urgencias.
# 239: Al Paciente 57 se le asigno una cama y 5 miembro(s) del personal.
# 239: Paciente 58 es atendido.
# 241: Cirugía completada para el Paciente 49.
# 241: Paciente 49 se le ha dado de alta.
# 241: Al Paciente 55 se le asignó un kit médico.
# 242: Al Paciente 58 se le asigno una cama y 8 miembro(s) del personal.
# 242: El Paciente 58 necesita cirugía.
# 242: Paciente 59 es atendido.
# 243: Al Paciente 45 se le ha dado de alta.
# 243: Paciente 238 llega al hospital a la unidad Urgencias.
# 243: Paciente 239 llega al hospital a la unidad Consultorios.
# 243: Paciente 240 llega al hospital a la unidad Consultorios.
# 244: Al Paciente 56 se le asigno una cama y 1 miembro(s) del personal.
# 244: Al Paciente 59 se le asigno una cama y 8 miembro(s) del personal.
# 244: Paciente 60 es atendido.
# 244: Paciente 61 es atendido.
# 245: Al Paciente 50 se le ha dado de alta.
# 246: Al Paciente 54 se le ha dado de alta.
# 248: Paciente 241 llega al hospital a la unidad Urgencias.
# 248: Paciente 242 llega al hospital a la unidad Urgencias.
# 250: Al Paciente 60 se le asigno una cama y 8 miembro(s) del personal.
# 250: El Paciente 60 necesita cirugía.
# 250: Paciente 62 es atendido.
# 251: Al Paciente 61 se le asigno una cama y 7 miembro(s) del personal.
# 251: El Paciente 61 necesita cirugía.
# 251: Paciente 243 llega al hospital a la unidad Urgencias.
# 251: Paciente 63 es atendido.
# 253: Al Paciente 62 se le asigno una cama y 8 miembro(s) del personal.
# 253: El Paciente 62 necesita cirugía.
# 253: Paciente 244 llega al hospital a la unidad Consultorios.
# 253: Paciente 245 llega al hospital a la unidad Urgencias.
# 253: Al Paciente 63 se le asigno una cama y 5 miembro(s) del personal.
# 253: Paciente 64 es atendido.
# 253: Paciente 65 es atendido.
# 254: Al Paciente 64 se le asigno una cama y 8 miembro(s) del personal.
# 254: Paciente 66 es atendido.
# 256: Paciente 246 llega al hospital a la unidad UCI.
# 256: Paciente 247 llega al hospital a la unidad UCI.
# 256: Paciente 248 llega al hospital a la unidad Consultorios.
# 256: Paciente 249 llega al hospital a la unidad Consultorios.
# 256: Paciente 250 llega al hospital a la unidad Urgencias.
# 260: Al Paciente 66 se le asigno una cama y 4 miembro(s) del personal.
# 260: El Paciente 66 necesita cirugía.
# 260: Paciente 251 llega al hospital a la unidad Consultorios.
# 260: Paciente 252 llega al hospital a la unidad Consultorios.
# 260: Paciente 253 llega al hospital a la unidad Consultorios.
# 260: Paciente 254 llega al hospital a la unidad Urgencias.
# 260: Paciente 67 es atendido.
# 263: Al Paciente 64 se le ha dado de alta.
# 264: Paciente 255 llega al hospital a la unidad Urgencias.
# 264: Paciente 256 llega al hospital a la unidad UCI.
# 264: Paciente 257 llega al hospital a la unidad Urgencias.
# 264: Paciente 258 llega al hospital a la unidad Consultorios.
# 264: Paciente 259 llega al hospital a la unidad Urgencias.
# 266: Paciente 260 llega al hospital a la unidad Urgencias.
# 266: Paciente 261 llega al hospital a la unidad Consultorios.
# 266: Paciente 262 llega al hospital a la unidad Urgencias.
# 266: Paciente 263 llega al hospital a la unidad UCI.
# 266: Paciente 264 llega al hospital a la unidad UCI.
# 267: Al Paciente 56 se le ha dado de alta.
# 269: Al Paciente 57 se le ha dado de alta.
# 269: Al Paciente 67 se le asigno una cama y 1 miembro(s) del personal.
# 269: Paciente 265 llega al hospital a la unidad Consultorios.
# 269: Paciente 266 llega al hospital a la unidad UCI.
# 269: Paciente 267 llega al hospital a la unidad Urgencias.
# 269: Paciente 68 es atendido.
# 270: Paciente 268 llega al hospital a la unidad UCI.
# 270: Paciente 269 llega al hospital a la unidad Urgencias.
# 270: Paciente 270 llega al hospital a la unidad UCI.
# 270: Al Paciente 68 se le asigno una cama y 3 miembro(s) del personal.
# 270: Paciente 69 es atendido.
# 271: Al Paciente 65 se le asigno una cama y 1 miembro(s) del personal.
# 271: Al Paciente 69 se le asigno una cama y 8 miembro(s) del personal.
# 271: Paciente 70 es atendido.
# 271: Paciente 71 es atendido.
# 272: Al Paciente 63 se le ha dado de alta.
# 272: Paciente 271 llega al hospital a la unidad Urgencias.
# 273: Cirugía completada para el Paciente 55.
# 273: Paciente 55 se le ha dado de alta.
# 273: Al Paciente 59 se le ha dado de alta.
# 273: Al Paciente 58 se le asignó un kit médico.
# 274: Paciente 272 llega al hospital a la unidad UCI.
# 274: Paciente 273 llega al hospital a la unidad Urgencias.
# 274: Paciente 274 llega al hospital a la unidad UCI.
# 274: Paciente 275 llega al hospital a la unidad Urgencias.
# 274: Paciente 276 llega al hospital a la unidad UCI.
# 276: Al Paciente 71 se le asigno una cama y 3 miembro(s) del personal.
# 276: Paciente 72 es atendido.
# 277: Paciente 277 llega al hospital a la unidad Urgencias.
# 277: Paciente 278 llega al hospital a la unidad Urgencias.
# 277: Paciente 279 llega al hospital a la unidad UCI.
# 277: Paciente 280 llega al hospital a la unidad Urgencias.
# 278: Al Paciente 69 se le ha dado de alta.
# 278: Al Paciente 70 se le asigno una cama y 4 miembro(s) del personal.
# 278: Paciente 73 es atendido.
# 280: Al Paciente 73 se le asigno una cama y 5 miembro(s) del personal.
# 280: Paciente 74 es atendido.
# 281: Paciente 281 llega al hospital a la unidad Urgencias.
# 281: Paciente 282 llega al hospital a la unidad UCI.
# 281: Paciente 283 llega al hospital a la unidad Urgencias.
# 281: Al Paciente 74 se le asigno una cama y 8 miembro(s) del personal.
# 281: Paciente 75 es atendido.
# 282: Al Paciente 72 se le asigno una cama y 6 miembro(s) del personal.
# 282: El Paciente 72 necesita cirugía.
# 282: Paciente 76 es atendido.
# 286: Paciente 284 llega al hospital a la unidad Consultorios.
# 286: Al Paciente 75 se le asigno una cama y 3 miembro(s) del personal.
# 286: Paciente 77 es atendido.
# 287: Al Paciente 68 se le ha dado de alta.
# 287: Al Paciente 76 se le asigno una cama y 3 miembro(s) del personal.
# 287: Paciente 78 es atendido.
# 288: Paciente 285 llega al hospital a la unidad Urgencias.
# 289: Paciente 286 llega al hospital a la unidad Consultorios.
# 289: Paciente 287 llega al hospital a la unidad Urgencias.
# 289: Paciente 288 llega al hospital a la unidad UCI.
# 291: Al Paciente 67 se le ha dado de alta.
# 293: Al Paciente 78 se le asigno una cama y 3 miembro(s) del personal.
# 293: Paciente 79 es atendido.
# 294: Paciente 289 llega al hospital a la unidad UCI.
# 294: Paciente 290 llega al hospital a la unidad Urgencias.
# 294: Paciente 291 llega al hospital a la unidad Urgencias.
# 294: Paciente 292 llega al hospital a la unidad Urgencias.
# 294: Paciente 293 llega al hospital a la unidad Urgencias.
# 295: Al Paciente 76 se le ha dado de alta.
# 296: Al Paciente 71 se le ha dado de alta.
# 297: Al Paciente 65 se le ha dado de alta.
# 297: Al Paciente 73 se le ha dado de alta.
# 297: Al Paciente 75 se le ha dado de alta.
# 298: Al Paciente 70 se le ha dado de alta.
# 299: Al Paciente 79 se le asigno una cama y 3 miembro(s) del personal.
# 299: El Paciente 79 necesita cirugía.
# 299: Paciente 294 llega al hospital a la unidad Urgencias.
# 299: Paciente 295 llega al hospital a la unidad UCI.
# 299: Paciente 296 llega al hospital a la unidad UCI.
# 299: Paciente 297 llega al hospital a la unidad Consultorios.
# 299: Paciente 80 es atendido.
# 300: Al Paciente 80 se le asigno una cama y 4 miembro(s) del personal.
# 300: Paciente 81 es atendido.
# 303: Paciente 298 llega al hospital a la unidad Urgencias.
# 303: Paciente 299 llega al hospital a la unidad Urgencias.
# 305: Al Paciente 74 se le ha dado de alta.
# 308: Cirugía completada para el Paciente 3.
# 308: Paciente 3 se le ha dado de alta.
# 308: Paciente 300 llega al hospital a la unidad Consultorios.
# 308: Paciente 301 llega al hospital a la unidad Consultorios.
# 308: Paciente 302 llega al hospital a la unidad UCI.
# 308: Al Paciente 60 se le asignó un kit médico.
# 311: Al Paciente 77 se le asigno una cama y 1 miembro(s) del personal.
# 311: El Paciente 61 murió esperando un kit médico.
# 311: Paciente 82 es atendido.
# 312: Paciente 303 llega al hospital a la unidad Urgencias.
# 312: Paciente 304 llega al hospital a la unidad Urgencias.
# 312: Paciente 305 llega al hospital a la unidad UCI.
# 312: Paciente 306 llega al hospital a la unidad UCI.
# 312: Paciente 307 llega al hospital a la unidad Consultorios.
# 313: El Paciente 62 murió esperando un kit médico.
# 314: Al Paciente 81 se le asigno una cama y 1 miembro(s) del personal.
# 314: Paciente 83 es atendido.
# 317: Paciente 308 llega al hospital a la unidad Consultorios.
# 317: Paciente 309 llega al hospital a la unidad Urgencias.
# 317: Paciente 310 llega al hospital a la unidad UCI.
# 317: Paciente 311 llega al hospital a la unidad UCI.
# 317: Paciente 312 llega al hospital a la unidad UCI.
# 318: Al Paciente 80 se le ha dado de alta.
# 318: Al Paciente 82 se le asigno una cama y 1 miembro(s) del personal.
# 318: Al Paciente 83 se le asigno una cama y 6 miembro(s) del personal.
# 318: Paciente 84 es atendido.
# 318: Paciente 85 es atendido.
# 319: Al Paciente 84 se le asigno una cama y 4 miembro(s) del personal.
# 319: Paciente 86 es atendido.
# 320: El Paciente 66 murió esperando un kit médico.
# 321: Paciente 313 llega al hospital a la unidad Consultorios.
# 322: Al Paciente 78 se le ha dado de alta.
# 324: Al Paciente 86 se le asigno una cama y 8 miembro(s) del personal.
# 324: El Paciente 86 necesita cirugía.
# 324: Paciente 314 llega al hospital a la unidad UCI.
# 324: Paciente 315 llega al hospital a la unidad UCI.
# 324: Paciente 316 llega al hospital a la unidad Urgencias.
# 324: Paciente 87 es atendido.
# 325: Al Paciente 85 se le asigno una cama y 6 miembro(s) del personal.
# 325: Paciente 317 llega al hospital a la unidad Urgencias.
# 325: Paciente 318 llega al hospital a la unidad UCI.
# 325: Paciente 88 es atendido.
# 326: Al Paciente 81 se le ha dado de alta.
# 326: Al Paciente 87 se le asigno una cama y 4 miembro(s) del personal.
# 326: Paciente 89 es atendido.
# 328: Paciente 319 llega al hospital a la unidad Urgencias.
# 328: Paciente 320 llega al hospital a la unidad Consultorios.
# 329: Al Paciente 88 se le asigno una cama y 4 miembro(s) del personal.
# 329: Al Paciente 89 se le asigno una cama y 3 miembro(s) del personal.
# 329: Paciente 90 es atendido.
# 329: Paciente 91 es atendido.
# 331: Cirugía completada para el Paciente 4.
# 331: Paciente 4 se le ha dado de alta.
# 331: Paciente 321 llega al hospital a la unidad Urgencias.
# 331: Paciente 322 llega al hospital a la unidad Consultorios.
# 331: Paciente 323 llega al hospital a la unidad Urgencias.
# 331: Paciente 324 llega al hospital a la unidad Urgencias.
# 331: Paciente 325 llega al hospital a la unidad Urgencias.
# 331: Al Paciente 72 se le asignó un kit médico.
# 332: Al Paciente 82 se le ha dado de alta.
# 332: Al Paciente 83 se le ha dado de alta.
# 335: Al Paciente 89 se le ha dado de alta.
# 335: Al Paciente 91 se le asigno una cama y 5 miembro(s) del personal.
# 335: El Paciente 91 necesita cirugía.
# 335: Paciente 326 llega al hospital a la unidad Urgencias.
# 335: Paciente 327 llega al hospital a la unidad Consultorios.
# 335: Paciente 92 es atendido.
# 336: Al Paciente 84 se le ha dado de alta.
# 336: Al Paciente 90 se le asigno una cama y 7 miembro(s) del personal.
# 336: El Paciente 90 necesita cirugía.
# 336: Paciente 93 es atendido.
# 337: Al Paciente 77 se le ha dado de alta.
# 337: Al Paciente 85 se le ha dado de alta.
# 338: Al Paciente 93 se le asigno una cama y 3 miembro(s) del personal.
# 338: Paciente 94 es atendido.
# 340: Paciente 328 llega al hospital a la unidad UCI.
# 340: Paciente 329 llega al hospital a la unidad Urgencias.
# 340: Paciente 330 llega al hospital a la unidad Urgencias.
# 340: Paciente 331 llega al hospital a la unidad Urgencias.
# 340: Paciente 332 llega al hospital a la unidad Urgencias.
# 341: Al Paciente 92 se le asigno una cama y 7 miembro(s) del personal.
# 341: Paciente 95 es atendido.
# 344: Paciente 333 llega al hospital a la unidad Urgencias.
# 344: Paciente 334 llega al hospital a la unidad UCI.
# 345: Al Paciente 94 se le asigno una cama y 5 miembro(s) del personal.
# 345: Paciente 96 es atendido.
# 348: Al Paciente 87 se le ha dado de alta.
# 348: Al Paciente 95 se le asigno una cama y 8 miembro(s) del personal.
# 348: El Paciente 95 necesita cirugía.
# 348: Paciente 97 es atendido.
# 349: Cirugía completada para el Paciente 8.
# 349: Paciente 8 se le ha dado de alta.
# 349: Paciente 335 llega al hospital a la unidad Consultorios.
# 349: Paciente 336 llega al hospital a la unidad UCI.
# 349: Paciente 337 llega al hospital a la unidad Urgencias.
# 349: Paciente 338 llega al hospital a la unidad Urgencias.
# 349: Paciente 339 llega al hospital a la unidad Urgencias.
# 349: Al Paciente 79 se le asignó un kit médico.
# 350: Al Paciente 88 se le ha dado de alta.
# 351: Al Paciente 97 se le asigno una cama y 4 miembro(s) del personal.
# 351: El Paciente 97 necesita cirugía.
# 351: Paciente 340 llega al hospital a la unidad Consultorios.
# 351: Paciente 341 llega al hospital a la unidad Urgencias.
# 351: Paciente 342 llega al hospital a la unidad UCI.
# 351: Paciente 343 llega al hospital a la unidad Urgencias.
# 351: Paciente 344 llega al hospital a la unidad Consultorios.
# 351: Paciente 98 es atendido.
# 352: Paciente 345 llega al hospital a la unidad Urgencias.
# 352: Paciente 346 llega al hospital a la unidad Urgencias.
# 354: Cirugía completada para el Paciente 72.
# 354: Paciente 72 se le ha dado de alta.
# 354: Al Paciente 96 se le asigno una cama y 1 miembro(s) del personal.
# 354: Paciente 99 es atendido.
# 354: Al Paciente 86 se le asignó un kit médico.
# 356: Paciente 347 llega al hospital a la unidad UCI.
# 358: Al Paciente 93 se le ha dado de alta.
# 358: Al Paciente 98 se le asigno una cama y 6 miembro(s) del personal.
# 358: El Paciente 98 necesita cirugía.
# 358: Paciente 100 es atendido.
# 359: Al Paciente 92 se le ha dado de alta.
# 359: Paciente 348 llega al hospital a la unidad Consultorios.
# 361: Al Paciente 96 se le ha dado de alta.
# 361: Al Paciente 99 se le asigno una cama y 8 miembro(s) del personal.
# 361: Paciente 101 es atendido.
# 362: Al Paciente 101 se le asigno una cama y 5 miembro(s) del personal.
# 362: Paciente 102 es atendido.
# 364: Paciente 349 llega al hospital a la unidad Urgencias.
# 364: Paciente 350 llega al hospital a la unidad UCI.
# 366: Al Paciente 94 se le ha dado de alta.
# 367: Al Paciente 101 se le ha dado de alta.
# 367: Paciente 351 llega al hospital a la unidad Consultorios.
# 367: Paciente 352 llega al hospital a la unidad Urgencias.
# 371: Al Paciente 99 se le ha dado de alta.
# 371: Paciente 353 llega al hospital a la unidad Urgencias.
# 371: Paciente 354 llega al hospital a la unidad UCI.
# 372: Paciente 355 llega al hospital a la unidad UCI.
# 375: Paciente 356 llega al hospital a la unidad Consultorios.
# 379: Al Paciente 100 se le asigno una cama y 1 miembro(s) del personal.
# 379: Paciente 357 llega al hospital a la unidad UCI.
# 379: Paciente 358 llega al hospital a la unidad Urgencias.
# 379: Paciente 359 llega al hospital a la unidad Urgencias.
# 379: Paciente 360 llega al hospital a la unidad Urgencias.
# 379: Paciente 361 llega al hospital a la unidad Urgencias.
# 379: Paciente 103 es atendido.
# 380: Al Paciente 103 se le asigno una cama y 5 miembro(s) del personal.
# 380: Paciente 104 es atendido.
# 382: Paciente 362 llega al hospital a la unidad UCI.
# 382: Paciente 363 llega al hospital a la unidad Urgencias.
# 385: Paciente 364 llega al hospital a la unidad UCI.
# 386: Al Paciente 102 se le asigno una cama y 1 miembro(s) del personal.
# 386: Al Paciente 104 se le asigno una cama y 6 miembro(s) del personal.
# 386: Paciente 365 llega al hospital a la unidad Urgencias.
# 386: Paciente 366 llega al hospital a la unidad UCI.
# 386: Paciente 105 es atendido.
# 386: Paciente 106 es atendido.
# 387: Al Paciente 100 se le ha dado de alta.
# 388: Paciente 367 llega al hospital a la unidad Consultorios.
# 388: Paciente 368 llega al hospital a la unidad UCI.
# 391: Al Paciente 106 se le asigno una cama y 3 miembro(s) del personal.
# 391: Paciente 107 es atendido.
# 393: Paciente 369 llega al hospital a la unidad Consultorios.
# 395: El Paciente 91 murió esperando un kit médico.
# 396: El Paciente 90 murió esperando un kit médico.
# 397: Paciente 370 llega al hospital a la unidad UCI.
# 397: Paciente 371 llega al hospital a la unidad Urgencias.
# 398: Paciente 372 llega al hospital a la unidad Urgencias.
# 398: Paciente 373 llega al hospital a la unidad Urgencias.
# 398: Paciente 374 llega al hospital a la unidad Consultorios.
# 398: Paciente 375 llega al hospital a la unidad UCI.
# 398: Paciente 376 llega al hospital a la unidad Urgencias.
# 400: Paciente 377 llega al hospital a la unidad UCI.
# 400: Paciente 378 llega al hospital a la unidad UCI.
# 400: Paciente 379 llega al hospital a la unidad Urgencias.
# 400: Paciente 380 llega al hospital a la unidad UCI.
# 400: Paciente 381 llega al hospital a la unidad Urgencias.
# 401: Paciente 382 llega al hospital a la unidad Urgencias.
# 401: Paciente 383 llega al hospital a la unidad UCI.
# 401: Paciente 384 llega al hospital a la unidad Urgencias.
# 405: Paciente 385 llega al hospital a la unidad Urgencias.
# 406: Al Paciente 105 se le asigno una cama y 1 miembro(s) del personal.
# 406: Paciente 108 es atendido.
# 407: Paciente 386 llega al hospital a la unidad Urgencias.
# 407: Paciente 387 llega al hospital a la unidad UCI.
# 407: Paciente 388 llega al hospital a la unidad Consultorios.
# 407: Paciente 389 llega al hospital a la unidad Consultorios.
# 408: Al Paciente 102 se le ha dado de alta.
# 408: Al Paciente 108 se le asigno una cama y 8 miembro(s) del personal.
# 408: El Paciente 95 murió esperando un kit médico.
# 408: Paciente 109 es atendido.
# 409: Al Paciente 103 se le ha dado de alta.
# 411: Al Paciente 107 se le asigno una cama y 1 miembro(s) del personal.
# 411: Paciente 390 llega al hospital a la unidad Urgencias.
# 411: Paciente 391 llega al hospital a la unidad Urgencias.
# 411: Paciente 392 llega al hospital a la unidad UCI.
# 411: Paciente 393 llega al hospital a la unidad Urgencias.
# 411: Paciente 394 llega al hospital a la unidad UCI.
# 411: Al Paciente 109 se le asigno una cama y 6 miembro(s) del personal.
# 411: El Paciente 109 necesita cirugía.
# 411: El Paciente 97 murió esperando un kit médico.
# 411: Paciente 110 es atendido.
# 411: Paciente 111 es atendido.
# 415: Al Paciente 104 se le ha dado de alta.
# 415: Paciente 395 llega al hospital a la unidad UCI.
# 417: Al Paciente 106 se le ha dado de alta.
# 417: Al Paciente 110 se le asigno una cama y 6 miembro(s) del personal.
# 417: El Paciente 110 necesita cirugía.
# 417: Paciente 112 es atendido.
# 418: El Paciente 98 murió esperando un kit médico.
# 419: Al Paciente 112 se le asigno una cama y 3 miembro(s) del personal.
# 419: Paciente 113 es atendido.
# 420: Paciente 396 llega al hospital a la unidad Urgencias.
# 421: Al Paciente 113 se le asigno una cama y 8 miembro(s) del personal.
# 421: Paciente 397 llega al hospital a la unidad UCI.
# 421: Paciente 114 es atendido.
# 423: Paciente 398 llega al hospital a la unidad Urgencias.
# 423: Paciente 399 llega al hospital a la unidad UCI.
# 425: Paciente 400 llega al hospital a la unidad Consultorios.
# 425: Paciente 401 llega al hospital a la unidad UCI.
# 426: Al Paciente 114 se le asigno una cama y 6 miembro(s) del personal.
# 426: Paciente 115 es atendido.
# 428: Al Paciente 113 se le ha dado de alta.
# 429: Al Paciente 108 se le ha dado de alta.
# 429: Paciente 402 llega al hospital a la unidad UCI.
# 429: Paciente 403 llega al hospital a la unidad Consultorios.
# 429: Paciente 404 llega al hospital a la unidad Urgencias.
# 429: Paciente 405 llega al hospital a la unidad Urgencias.
# 429: Paciente 406 llega al hospital a la unidad Urgencias.
# 431: Paciente 407 llega al hospital a la unidad UCI.
# 431: Paciente 408 llega al hospital a la unidad Consultorios.
# 433: Al Paciente 111 se le asigno una cama y 1 miembro(s) del personal.
# 433: Paciente 116 es atendido.
# 435: Al Paciente 105 se le ha dado de alta.
# 435: Al Paciente 114 se le ha dado de alta.
# 435: Paciente 409 llega al hospital a la unidad Urgencias.
# 435: Paciente 410 llega al hospital a la unidad Consultorios.
# 438: Al Paciente 107 se le ha dado de alta.
# 439: Al Paciente 116 se le asigno una cama y 5 miembro(s) del personal.
# 439: Paciente 411 llega al hospital a la unidad Consultorios.
# 439: Paciente 412 llega al hospital a la unidad Consultorios.
# 439: Paciente 413 llega al hospital a la unidad UCI.
# 439: Paciente 414 llega al hospital a la unidad UCI.
# 439: Paciente 415 llega al hospital a la unidad Urgencias.
# 439: Paciente 117 es atendido.
# 441: Al Paciente 117 se le asigno una cama y 3 miembro(s) del personal.
# 441: El Paciente 117 necesita cirugía.
# 441: Paciente 118 es atendido.
# 442: Al Paciente 115 se le asigno una cama y 1 miembro(s) del personal.
# 442: Paciente 119 es atendido.
# 443: Al Paciente 111 se le ha dado de alta.
# 443: Paciente 416 llega al hospital a la unidad Urgencias.
# 444: Al Paciente 112 se le ha dado de alta.
# 445: Al Paciente 118 se le asigno una cama y 7 miembro(s) del personal.
# 445: Paciente 417 llega al hospital a la unidad UCI.
# 445: Paciente 418 llega al hospital a la unidad Urgencias.
# 445: Paciente 120 es atendido.
# 447: Paciente 419 llega al hospital a la unidad Consultorios.
# 447: Paciente 420 llega al hospital a la unidad Urgencias.
# 447: Paciente 421 llega al hospital a la unidad UCI.
# 447: Paciente 422 llega al hospital a la unidad UCI.
# 448: Al Paciente 119 se le asigno una cama y 7 miembro(s) del personal.
# 448: El Paciente 119 necesita cirugía.
# 448: Paciente 121 es atendido.
# 449: Al Paciente 120 se le asigno una cama y 4 miembro(s) del personal.
# 449: Paciente 122 es atendido.
# 450: Cirugía completada para el Paciente 58.
# 450: Paciente 58 murió tras el procedimiento.
# 450: Al Paciente 109 se le asignó un kit médico.
# 451: Paciente 423 llega al hospital a la unidad Urgencias.
# 451: Paciente 424 llega al hospital a la unidad Urgencias.
# 451: Paciente 425 llega al hospital a la unidad Consultorios.
# 451: Paciente 426 llega al hospital a la unidad Urgencias.
# 451: Paciente 427 llega al hospital a la unidad Urgencias.
# 454: Al Paciente 121 se le asigno una cama y 7 miembro(s) del personal.
# 454: El Paciente 121 necesita cirugía.
# 454: Al Paciente 122 se le asigno una cama y 4 miembro(s) del personal.
# 454: Paciente 123 es atendido.
# 454: Paciente 124 es atendido.
# 455: Paciente 428 llega al hospital a la unidad Urgencias.
# 455: Paciente 429 llega al hospital a la unidad UCI.
# 455: Paciente 430 llega al hospital a la unidad Urgencias.
# 455: Paciente 431 llega al hospital a la unidad Consultorios.
# 455: Paciente 432 llega al hospital a la unidad Urgencias.
# 456: Paciente 433 llega al hospital a la unidad Urgencias.
# 456: Paciente 434 llega al hospital a la unidad Consultorios.
# 456: Paciente 435 llega al hospital a la unidad UCI.
# 456: Paciente 436 llega al hospital a la unidad Urgencias.
# 457: Al Paciente 116 se le ha dado de alta.
# 457: Al Paciente 118 se le ha dado de alta.
# 458: Al Paciente 124 se le asigno una cama y 5 miembro(s) del personal.
# 458: Paciente 125 es atendido.
# 459: Cirugía completada para el Paciente 79.
# 459: Paciente 79 murió tras el procedimiento.
# 459: Al Paciente 110 se le asignó un kit médico.
# 461: Al Paciente 123 se le asigno una cama y 4 miembro(s) del personal.
# 461: El Paciente 123 necesita cirugía.
# 461: Paciente 437 llega al hospital a la unidad Consultorios.
# 461: Paciente 438 llega al hospital a la unidad Consultorios.
# 461: Paciente 439 llega al hospital a la unidad UCI.
# 461: Paciente 126 es atendido.
# 463: Al Paciente 126 se le asigno una cama y 7 miembro(s) del personal.
# 463: Paciente 127 es atendido.
# 464: Al Paciente 127 se le asigno una cama y 8 miembro(s) del personal.
# 464: Paciente 128 es atendido.
# 465: Al Paciente 125 se le asigno una cama y 6 miembro(s) del personal.
# 465: El Paciente 125 necesita cirugía.
# 465: Paciente 129 es atendido.
# 466: Al Paciente 115 se le ha dado de alta.
# 466: Paciente 440 llega al hospital a la unidad Urgencias.
# 466: Paciente 441 llega al hospital a la unidad UCI.
# 466: Paciente 442 llega al hospital a la unidad Urgencias.
# 466: Al Paciente 128 se le asigno una cama y 5 miembro(s) del personal.
# 466: Paciente 130 es atendido.
# 469: Al Paciente 120 se le ha dado de alta.
# 470: Cirugía completada para el Paciente 52.
# 470: Paciente 52 se le ha dado de alta.
# 470: Al Paciente 124 se le ha dado de alta.
# 470: Al Paciente 127 se le ha dado de alta.
# 470: Al Paciente 129 se le asigno una cama y 8 miembro(s) del personal.
# 470: Paciente 443 llega al hospital a la unidad Urgencias.
# 470: Paciente 131 es atendido.
# 470: Al Paciente 117 se le asignó un kit médico.
# 471: Al Paciente 131 se le asigno una cama y 6 miembro(s) del personal.
# 471: Paciente 132 es atendido.
# 472: Al Paciente 130 se le asigno una cama y 7 miembro(s) del personal.
# 472: Paciente 133 es atendido.
# 473: Al Paciente 132 se le asigno una cama y 5 miembro(s) del personal.
# 473: Paciente 134 es atendido.
# 475: Paciente 444 llega al hospital a la unidad Consultorios.
# 475: Paciente 445 llega al hospital a la unidad Urgencias.
# 475: Paciente 446 llega al hospital a la unidad UCI.
# 475: Paciente 447 llega al hospital a la unidad Urgencias.
# 476: Al Paciente 122 se le ha dado de alta.
# 476: Al Paciente 134 se le asigno una cama y 4 miembro(s) del personal.
# 476: El Paciente 134 necesita cirugía.
# 476: Paciente 135 es atendido.
# 479: Al Paciente 133 se le asigno una cama y 1 miembro(s) del personal.
# 479: Paciente 136 es atendido.

# %%
lista_pacientes3 = []

def registrar_paciente(paciente_id, unidad, cirugia,alcanzo_cama):
    lista_pacientes3.append({
        "id": paciente_id,
        "unidad": unidad,
        "cirugia": cirugia,
        "alcanzo_cama": alcanzo_cama
    })

# %%
for p in simulacion3.pacientes:
    registrar_paciente(p.id, p.unidad.nombre, p.cirugia, p.alcanzo_cama)

dfPacientes3 = pd.DataFrame(lista_pacientes3)
dfPacientes3
# Out:
#       id        unidad  cirugia  alcanzo_cama
# 0      1  Consultorios    False          True
# 1      2           UCI    False          True
# 2      3     Urgencias     True          True
# 3      4     Urgencias     True          True
# 4      5  Consultorios    False          True
# ..   ...           ...      ...           ...
# 442  443     Urgencias     True         False
# 443  444  Consultorios    False         False
# 444  445     Urgencias    False         False
# 445  446           UCI    False         False
# 446  447     Urgencias    False         False
#
# [447 rows x 4 columns]

# %%
lista_eventos3 = []
for p in simulacion3.pacientes:
    lista_eventos3.append( p.eventos )

dfeventos3 = pd.concat(lista_eventos3)
dfeventos3 = dfeventos3.reset_index()
dfeventos3.drop( ["index"], axis=1, inplace=True )

dfeventos3
# Out:
#       id                    evento  time
# 0      1                   LLEGADA     1
# 1      1                  ATENDIDO     1
# 2      1  ASIGNACION_CAMA_PERSONAL    13
# 3      1                      ALTA    33
# 4      2                   LLEGADA     1
# ..   ...                       ...   ...
# 846  443                   LLEGADA   470
# 847  444                   LLEGADA   475
# 848  445                   LLEGADA   475
# 849  446                   LLEGADA   475
# 850  447                   LLEGADA   475
#
# [851 rows x 3 columns]

# %%
dfeventos3["lag_time"] = dfeventos3.groupby("id")["time"].shift(1)

# %%
# Filtramos y calculamos el tiempo de espera
df3 = dfeventos3.loc[dfeventos3["evento"] == "ATENDIDO", :].copy()
df3["tiempo_espera"] = df3["time"] - df3["lag_time"]

# Merge con la info de pacientes (asegúrate de que 'id' esté en ambos)
df_merged3 = df3.merge(dfPacientes3, on="id", how="inner")

# Agrupamos por unidad y calculamos el promedio
resultado3 = (
    df_merged3
    .groupby("unidad")
    .agg({"tiempo_espera": "mean"})
)

print(resultado3)
# Out:
#               tiempo_espera
# unidad
# Consultorios     156.218750
# UCI              195.166667
# Urgencias        190.370968

# %% [markdown]
# ## Resultado
# Observamos que el tiempo de espera media se mantiene bastante cercano al original, lo que justifica
# nuestra respuesta anterior, el mal rendimiento de las recepcionistas evita el correcto uso de recursos
# como el del personal médico.
